# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 100
lr = 0.001
train_ratio = 0.75
num_layers = 2
hidden_size= 128
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = []

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva la nuvola sottocampionata nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10,
                  train_ratio=0.75, mode='all'):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled
        self.train_ratio = train_ratio
        self.mode = mode

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        all_files_sorted = sorted(all_files, key=extract_number)

        split_index = int(len(all_files_sorted) * train_ratio)

        if mode == "train":
            self.npz_files = all_files_sorted[:split_index]
            self.point_clouds_subsampled = point_clouds_subsampled[:split_index]
        elif mode == "test":
            self.npz_files = all_files_sorted[split_index:]
            self.point_clouds_subsampled = point_clouds_subsampled[split_index:]
        else:
            self.npz_files = all_files_sorted
            self.point_clouds_subsampled = point_clouds_subsampled

    def __len__(self):
        return len(self.npz_files)

    def local_smoothing(self, future_traj, iterations=1):
        smoothed_traj = future_traj.clone()

        for _ in range(iterations):
            temp_traj = smoothed_traj.clone()

            prev_points = temp_traj[:-2]
            current_points = temp_traj[1:-1]
            next_points = temp_traj[2:]

            smoothed_traj[1:-1] = 0.25*prev_points + 0.5*current_points + 0.25*next_points   
        
        return smoothed_traj

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx])

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        if(self.mode == "train"):
            if(np.random.rand() < 0.5):
                n_iterations = np.random.randint(1, 3)
                future_trajectory = self.local_smoothing(future_trajectory, iterations=n_iterations)

            if np.random.rand() < 0.5:
                # Flip orizzontale
                past_trajectory[:, 0] *= -1
                future_trajectory[:, 0] *= -1
                point_clouds_subsampled[:, 0] *= -1    


        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class MyModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]

original_dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, mode="all")
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="train")

test_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="test")

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 1024, 3])

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z nel futuro

all_x_values = []
all_z_values = []

for past, future, _ in original_dataset:
    all_x_values.append(future[:, 0])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the future x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the future z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the future x-coordinate: 0.5187198519706726
# Global variance of the future z-coordinate: 2.072277069091797

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.818635,   MSE X = 0.556780,   MSE Z = 1.505137
# Test: MSE Total = 0.905562,   MSE X = 0.450931,   MSE Z = 0.402298
#
#
# Train Epoch 2: MSE Total = 1.028794,   MSE X = 0.556075,   MSE Z = 0.369538
# Test: MSE Total = 0.778089,   MSE X = 0.440962,   MSE Z = 0.238721
#
#
# Train Epoch 3: MSE Total = 0.955705,   MSE X = 0.554103,   MSE Z = 0.268265
# Test: MSE Total = 0.818094,   MSE X = 0.471270,   MSE Z = 0.235731
#
#
# Train Epoch 4: MSE Total = 0.929781,   MSE X = 0.554749,   MSE Z = 0.229655
# Test: MSE Total = 0.730122,   MSE X = 0.443563,   MSE Z = 0.164471
#
#
# Train Epoch 5: MSE Total = 0.909850,   MSE X = 0.553104,   MSE Z = 0.204253
# Test: MSE Total = 0.732135,   MSE X = 0.448983,   MSE Z = 0.156536
#
#
# Train Epoch 6: MSE Total = 0.907353,   MSE X = 0.552251,   MSE Z = 0.202363
# Test: MSE Total = 0.717769,   MSE X = 0.439478,   MSE Z = 0.154853
#
#
# Train Epoch 7: MSE Total = 0.903322,   MSE X = 0.552512,   MSE Z = 0.196037
# Test: MSE Total = 0.722760,   MSE X = 0.441147,   MSE Z = 0.158702
#
#
# Train Epoch 8: MSE Total = 0.897012,   MSE X = 0.553191,   MSE Z = 0.185597
# Test: MSE Total = 0.715596,   MSE X = 0.439480,   MSE Z = 0.151721
#
#
# Train Epoch 9: MSE Total = 0.891953,   MSE X = 0.552826,   MSE Z = 0.179046
# Test: MSE Total = 0.712391,   MSE X = 0.441113,   MSE Z = 0.143844
#
#
# Train Epoch 10: MSE Total = 0.891652,   MSE X = 0.555060,   MSE Z = 0.174145
# Test: MSE Total = 0.718160,   MSE X = 0.439742,   MSE Z = 0.154889
#
#
# Train Epoch 11: MSE Total = 0.882621,   MSE X = 0.547344,   MSE Z = 0.176567
# Test: MSE Total = 0.723578,   MSE X = 0.447786,   MSE Z = 0.146610
#
#
# Train Epoch 12: MSE Total = 0.833895,   MSE X = 0.498738,   MSE Z = 0.203575
# Test: MSE Total = 0.786926,   MSE X = 0.451727,   MSE Z = 0.229924
#
#
# Train Epoch 13: MSE Total = 0.673232,   MSE X = 0.374290,   MSE Z = 0.221034
# Test: MSE Total = 0.481800,   MSE X = 0.245513,   MSE Z = 0.202853
#
#
# Train Epoch 14: MSE Total = 0.579892,   MSE X = 0.302963,   MSE Z = 0.229232
# Test: MSE Total = 0.362807,   MSE X = 0.183467,   MSE Z = 0.155571
#
#
# Train Epoch 15: MSE Total = 0.502990,   MSE X = 0.263462,   MSE Z = 0.197481
# Test: MSE Total = 0.367832,   MSE X = 0.185883,   MSE Z = 0.157976
#
#
# Train Epoch 16: MSE Total = 0.462934,   MSE X = 0.238340,   MSE Z = 0.190031
# Test: MSE Total = 0.325884,   MSE X = 0.158383,   MSE Z = 0.152556
#
#
# Train Epoch 17: MSE Total = 0.468435,   MSE X = 0.243931,   MSE Z = 0.186776
# Test: MSE Total = 0.366809,   MSE X = 0.185400,   MSE Z = 0.157469
#
#
# Train Epoch 18: MSE Total = 0.433226,   MSE X = 0.216403,   MSE Z = 0.191112
# Test: MSE Total = 0.314383,   MSE X = 0.150471,   MSE Z = 0.151813
#
#
# Train Epoch 19: MSE Total = 0.413313,   MSE X = 0.206001,   MSE Z = 0.183237
# Test: MSE Total = 0.318853,   MSE X = 0.144705,   MSE Z = 0.169774
#
#
# Train Epoch 20: MSE Total = 0.418332,   MSE X = 0.206455,   MSE Z = 0.189555
# Test: MSE Total = 0.329493,   MSE X = 0.159054,   MSE Z = 0.156410
#
#
# Train Epoch 21: MSE Total = 0.404162,   MSE X = 0.203315,   MSE Z = 0.175432
# Test: MSE Total = 0.320709,   MSE X = 0.154943,   MSE Z = 0.151982
#
#
# Train Epoch 22: MSE Total = 0.386276,   MSE X = 0.195333,   MSE Z = 0.165639
# Test: MSE Total = 0.366875,   MSE X = 0.166038,   MSE Z = 0.196262
#
#
# Train Epoch 23: MSE Total = 0.437047,   MSE X = 0.223218,   MSE Z = 0.182991
# Test: MSE Total = 0.363061,   MSE X = 0.188156,   MSE Z = 0.146565
#
#
# Train Epoch 24: MSE Total = 0.382509,   MSE X = 0.191668,   MSE Z = 0.167542
# Test: MSE Total = 0.419032,   MSE X = 0.206339,   MSE Z = 0.190794
#
#
# Train Epoch 25: MSE Total = 0.398621,   MSE X = 0.192234,   MSE Z = 0.189605
# Test: MSE Total = 0.345197,   MSE X = 0.161881,   MSE Z = 0.173365
#
#
# Train Epoch 26: MSE Total = 0.379358,   MSE X = 0.185150,   MSE Z = 0.176032
# Test: MSE Total = 0.332924,   MSE X = 0.166187,   MSE Z = 0.147092
#
#
# Train Epoch 27: MSE Total = 0.368565,   MSE X = 0.181398,   MSE Z = 0.167996
# Test: MSE Total = 0.319338,   MSE X = 0.149895,   MSE Z = 0.160098
#
#
# Train Epoch 28: MSE Total = 0.352615,   MSE X = 0.171445,   MSE Z = 0.164929
# Test: MSE Total = 0.345896,   MSE X = 0.174079,   MSE Z = 0.149992
#
#
# Train Epoch 29: MSE Total = 0.351964,   MSE X = 0.173652,   MSE Z = 0.159580
# Test: MSE Total = 0.321141,   MSE X = 0.156781,   MSE Z = 0.148931
#
#
# Train Epoch 30: MSE Total = 0.346480,   MSE X = 0.168901,   MSE Z = 0.161181
# Test: MSE Total = 0.408548,   MSE X = 0.193891,   MSE Z = 0.200582
#
#
# Train Epoch 31: MSE Total = 0.356409,   MSE X = 0.175508,   MSE Z = 0.162270
# Test: MSE Total = 0.319648,   MSE X = 0.157524,   MSE Z = 0.145296
#
#
# Train Epoch 32: MSE Total = 0.351028,   MSE X = 0.169211,   MSE Z = 0.167109
# Test: MSE Total = 0.318154,   MSE X = 0.155648,   MSE Z = 0.146895
#
#
# Train Epoch 33: MSE Total = 0.340083,   MSE X = 0.165916,   MSE Z = 0.157940
# Test: MSE Total = 0.316784,   MSE X = 0.151028,   MSE Z = 0.154156
#
#
# Train Epoch 34: MSE Total = 0.354840,   MSE X = 0.175411,   MSE Z = 0.160204
# Test: MSE Total = 0.328637,   MSE X = 0.163660,   MSE Z = 0.145972
#
#
# Train Epoch 35: MSE Total = 0.328601,   MSE X = 0.156936,   MSE Z = 0.159358
# Test: MSE Total = 0.315801,   MSE X = 0.154852,   MSE Z = 0.145098
#
#
# Train Epoch 36: MSE Total = 0.330162,   MSE X = 0.155662,   MSE Z = 0.164152
# Test: MSE Total = 0.312761,   MSE X = 0.156098,   MSE Z = 0.138233
#
#
# Train Epoch 37: MSE Total = 0.331873,   MSE X = 0.160604,   MSE Z = 0.156739
# Test: MSE Total = 0.332089,   MSE X = 0.170347,   MSE Z = 0.137576
#
#
# Train Epoch 38: MSE Total = 0.318854,   MSE X = 0.151965,   MSE Z = 0.155263
# Test: MSE Total = 0.337536,   MSE X = 0.169317,   MSE Z = 0.147475
#
#
# Train Epoch 39: MSE Total = 0.316654,   MSE X = 0.147597,   MSE Z = 0.160829
# Test: MSE Total = 0.313701,   MSE X = 0.142301,   MSE Z = 0.167163
#
#
# Train Epoch 40: MSE Total = 0.299736,   MSE X = 0.141083,   MSE Z = 0.149492
# Test: MSE Total = 0.349170,   MSE X = 0.173655,   MSE Z = 0.155551
#
#
# Train Epoch 41: MSE Total = 0.290067,   MSE X = 0.136449,   MSE Z = 0.144837
# Test: MSE Total = 0.350680,   MSE X = 0.180983,   MSE Z = 0.143079
#
#
# Train Epoch 42: MSE Total = 0.283089,   MSE X = 0.132399,   MSE Z = 0.142886
# Test: MSE Total = 0.336276,   MSE X = 0.168945,   MSE Z = 0.146405
#
#
# Train Epoch 43: MSE Total = 0.312743,   MSE X = 0.148517,   MSE Z = 0.153359
# Test: MSE Total = 0.338532,   MSE X = 0.164963,   MSE Z = 0.157610
#
#
# Train Epoch 44: MSE Total = 0.289630,   MSE X = 0.135701,   MSE Z = 0.145704
# Test: MSE Total = 0.323417,   MSE X = 0.157909,   MSE Z = 0.149952
#
#
# Train Epoch 45: MSE Total = 0.285624,   MSE X = 0.133353,   MSE Z = 0.144629
# Test: MSE Total = 0.307809,   MSE X = 0.142603,   MSE Z = 0.158077
#
#
# Train Epoch 46: MSE Total = 0.262317,   MSE X = 0.119178,   MSE Z = 0.139410
# Test: MSE Total = 0.302979,   MSE X = 0.141988,   MSE Z = 0.152351
#
#
# Train Epoch 47: MSE Total = 0.268830,   MSE X = 0.120050,   MSE Z = 0.147042
# Test: MSE Total = 0.402446,   MSE X = 0.200670,   MSE Z = 0.178248
#
#
# Train Epoch 48: MSE Total = 0.289588,   MSE X = 0.137173,   MSE Z = 0.142701
# Test: MSE Total = 0.307392,   MSE X = 0.153730,   MSE Z = 0.135237
#
#
# Train Epoch 49: MSE Total = 0.260441,   MSE X = 0.119848,   MSE Z = 0.135370
# Test: MSE Total = 0.310523,   MSE X = 0.151200,   MSE Z = 0.144800
#
#
# Train Epoch 50: MSE Total = 0.270855,   MSE X = 0.123836,   MSE Z = 0.142390
# Test: MSE Total = 0.323575,   MSE X = 0.150459,   MSE Z = 0.165071
#
#
# Train Epoch 51: MSE Total = 0.244681,   MSE X = 0.108847,   MSE Z = 0.134671
# Test: MSE Total = 0.331851,   MSE X = 0.169861,   MSE Z = 0.138205
#
#
# Train Epoch 52: MSE Total = 0.245885,   MSE X = 0.108532,   MSE Z = 0.137034
# Test: MSE Total = 0.345670,   MSE X = 0.162284,   MSE Z = 0.173241
#
#
# Train Epoch 53: MSE Total = 0.242407,   MSE X = 0.106375,   MSE Z = 0.136339
# Test: MSE Total = 0.310282,   MSE X = 0.151964,   MSE Z = 0.142926
#
#
# Train Epoch 54: MSE Total = 0.264873,   MSE X = 0.121131,   MSE Z = 0.139184
# Test: MSE Total = 0.322071,   MSE X = 0.164675,   MSE Z = 0.134491
#
#
# Train Epoch 55: MSE Total = 0.318485,   MSE X = 0.154541,   MSE Z = 0.149584
# Test: MSE Total = 0.339634,   MSE X = 0.157752,   MSE Z = 0.173610
#
#
# Train Epoch 56: MSE Total = 0.256438,   MSE X = 0.113434,   MSE Z = 0.142428
# Test: MSE Total = 0.333149,   MSE X = 0.158364,   MSE Z = 0.163052
#
#
# Train Epoch 57: MSE Total = 0.234551,   MSE X = 0.101935,   MSE Z = 0.133903
# Test: MSE Total = 0.318400,   MSE X = 0.153616,   MSE Z = 0.151310
#
#
# Train Epoch 58: MSE Total = 0.234374,   MSE X = 0.104677,   MSE Z = 0.128169
# Test: MSE Total = 0.318398,   MSE X = 0.154956,   MSE Z = 0.148629
#
#
# Train Epoch 59: MSE Total = 0.246123,   MSE X = 0.107763,   MSE Z = 0.138912
# Test: MSE Total = 0.314172,   MSE X = 0.150219,   MSE Z = 0.152014
#
#
# Train Epoch 60: MSE Total = 0.262060,   MSE X = 0.120195,   MSE Z = 0.137007
# Test: MSE Total = 0.305375,   MSE X = 0.145153,   MSE Z = 0.149476
#
#
# Train Epoch 61: MSE Total = 0.237505,   MSE X = 0.106695,   MSE Z = 0.128641
# Test: MSE Total = 0.353823,   MSE X = 0.183134,   MSE Z = 0.143303
#
#
# Train Epoch 62: MSE Total = 0.236126,   MSE X = 0.104691,   MSE Z = 0.130662
# Test: MSE Total = 0.295756,   MSE X = 0.145236,   MSE Z = 0.135463
#
#
# Train Epoch 63: MSE Total = 0.216514,   MSE X = 0.094907,   MSE Z = 0.121987
# Test: MSE Total = 0.346673,   MSE X = 0.165541,   MSE Z = 0.168176
#
#
# Train Epoch 64: MSE Total = 0.217056,   MSE X = 0.093013,   MSE Z = 0.126552
# Test: MSE Total = 0.317759,   MSE X = 0.155827,   MSE Z = 0.145969
#
#
# Train Epoch 65: MSE Total = 0.236582,   MSE X = 0.106259,   MSE Z = 0.128185
# Test: MSE Total = 0.295474,   MSE X = 0.137601,   MSE Z = 0.150316
#
#
# Train Epoch 66: MSE Total = 0.208508,   MSE X = 0.090229,   MSE Z = 0.119812
# Test: MSE Total = 0.312168,   MSE X = 0.151740,   MSE Z = 0.146088
#
#
# Train Epoch 67: MSE Total = 0.202496,   MSE X = 0.083761,   MSE Z = 0.124085
# Test: MSE Total = 0.295111,   MSE X = 0.138741,   MSE Z = 0.147516
#
#
# Train Epoch 68: MSE Total = 0.211386,   MSE X = 0.090031,   MSE Z = 0.124350
# Test: MSE Total = 0.363007,   MSE X = 0.162663,   MSE Z = 0.197442
#
#
# Train Epoch 69: MSE Total = 0.216607,   MSE X = 0.093391,   MSE Z = 0.125149
# Test: MSE Total = 0.308957,   MSE X = 0.146219,   MSE Z = 0.152502
#
#
# Train Epoch 70: MSE Total = 0.201877,   MSE X = 0.086897,   MSE Z = 0.116925
# Test: MSE Total = 0.330195,   MSE X = 0.156789,   MSE Z = 0.161948
#
#
# Train Epoch 71: MSE Total = 0.203936,   MSE X = 0.086502,   MSE Z = 0.120679
# Test: MSE Total = 0.304324,   MSE X = 0.145659,   MSE Z = 0.146952
#
#
# Train Epoch 72: MSE Total = 0.207298,   MSE X = 0.084597,   MSE Z = 0.129325
# Test: MSE Total = 0.326193,   MSE X = 0.152253,   MSE Z = 0.165253
#
#
# Train Epoch 73: MSE Total = 0.204864,   MSE X = 0.087554,   MSE Z = 0.119914
# Test: MSE Total = 0.339306,   MSE X = 0.171840,   MSE Z = 0.144981
#
#
# Train Epoch 74: MSE Total = 0.203781,   MSE X = 0.085195,   MSE Z = 0.123069
# Test: MSE Total = 0.307916,   MSE X = 0.145609,   MSE Z = 0.152222
#
#
# Train Epoch 75: MSE Total = 0.201338,   MSE X = 0.085845,   MSE Z = 0.118251
# Test: MSE Total = 0.290188,   MSE X = 0.136408,   MSE Z = 0.145093
#
#
# Train Epoch 76: MSE Total = 0.177410,   MSE X = 0.073863,   MSE Z = 0.107756
# Test: MSE Total = 0.301100,   MSE X = 0.143464,   MSE Z = 0.146696
#
#
# Train Epoch 77: MSE Total = 0.176791,   MSE X = 0.072892,   MSE Z = 0.108806
# Test: MSE Total = 0.301793,   MSE X = 0.142274,   MSE Z = 0.150073
#
#
# Train Epoch 78: MSE Total = 0.182237,   MSE X = 0.076765,   MSE Z = 0.108904
# Test: MSE Total = 0.338127,   MSE X = 0.168776,   MSE Z = 0.149408
#
#
# Train Epoch 79: MSE Total = 0.183837,   MSE X = 0.077411,   MSE Z = 0.109916
# Test: MSE Total = 0.330532,   MSE X = 0.161081,   MSE Z = 0.153854
#
#
# Train Epoch 80: MSE Total = 0.225771,   MSE X = 0.101339,   MSE Z = 0.122455
# Test: MSE Total = 0.314646,   MSE X = 0.151415,   MSE Z = 0.150305
#
#
# Train Epoch 81: MSE Total = 0.187703,   MSE X = 0.078439,   MSE Z = 0.113426
# Test: MSE Total = 0.339461,   MSE X = 0.167772,   MSE Z = 0.153334
#
#
# Train Epoch 82: MSE Total = 0.173886,   MSE X = 0.071233,   MSE Z = 0.107939
# Test: MSE Total = 0.325858,   MSE X = 0.162164,   MSE Z = 0.144962
#
#
# Train Epoch 83: MSE Total = 0.182164,   MSE X = 0.077228,   MSE Z = 0.107873
# Test: MSE Total = 0.295981,   MSE X = 0.135229,   MSE Z = 0.155788
#
#
# Train Epoch 84: MSE Total = 0.174517,   MSE X = 0.074146,   MSE Z = 0.103026
# Test: MSE Total = 0.309756,   MSE X = 0.129545,   MSE Z = 0.186978
#
#
# Train Epoch 85: MSE Total = 0.176041,   MSE X = 0.073381,   MSE Z = 0.106747
# Test: MSE Total = 0.286761,   MSE X = 0.132214,   MSE Z = 0.148541
#
#
# Train Epoch 86: MSE Total = 0.159217,   MSE X = 0.065013,   MSE Z = 0.099256
# Test: MSE Total = 0.314919,   MSE X = 0.143491,   MSE Z = 0.166536
#
#
# Train Epoch 87: MSE Total = 0.161013,   MSE X = 0.066153,   MSE Z = 0.099560
# Test: MSE Total = 0.289070,   MSE X = 0.132387,   MSE Z = 0.151520
#
#
# Train Epoch 88: MSE Total = 0.231932,   MSE X = 0.105306,   MSE Z = 0.123397
# Test: MSE Total = 0.351273,   MSE X = 0.181194,   MSE Z = 0.143510
#
#
# Train Epoch 89: MSE Total = 0.185828,   MSE X = 0.078904,   MSE Z = 0.109798
# Test: MSE Total = 0.371299,   MSE X = 0.183308,   MSE Z = 0.168113
#
#
# Train Epoch 90: MSE Total = 0.185197,   MSE X = 0.078676,   MSE Z = 0.109344
# Test: MSE Total = 0.317917,   MSE X = 0.149583,   MSE Z = 0.158675
#
#
# Train Epoch 91: MSE Total = 0.165622,   MSE X = 0.071274,   MSE Z = 0.095960
# Test: MSE Total = 0.270460,   MSE X = 0.124227,   MSE Z = 0.141040
#
#
# Train Epoch 92: MSE Total = 0.155006,   MSE X = 0.063609,   MSE Z = 0.096000
# Test: MSE Total = 0.272647,   MSE X = 0.124483,   MSE Z = 0.143676
#
#
# Train Epoch 93: MSE Total = 0.163060,   MSE X = 0.067507,   MSE Z = 0.099803
# Test: MSE Total = 0.279165,   MSE X = 0.131359,   MSE Z = 0.139316
#
#
# Train Epoch 94: MSE Total = 0.171803,   MSE X = 0.073800,   MSE Z = 0.099809
# Test: MSE Total = 0.303233,   MSE X = 0.140566,   MSE Z = 0.155561
#
#
# Train Epoch 95: MSE Total = 0.168117,   MSE X = 0.072332,   MSE Z = 0.097437
# Test: MSE Total = 0.307095,   MSE X = 0.145991,   MSE Z = 0.150278
#
#
# Train Epoch 96: MSE Total = 0.148461,   MSE X = 0.060104,   MSE Z = 0.093583
# Test: MSE Total = 0.303616,   MSE X = 0.133173,   MSE Z = 0.170889
#
#
# Train Epoch 97: MSE Total = 0.147314,   MSE X = 0.057935,   MSE Z = 0.096267
# Test: MSE Total = 0.317969,   MSE X = 0.155686,   MSE Z = 0.146552
#
#
# Train Epoch 98: MSE Total = 0.156141,   MSE X = 0.066156,   MSE Z = 0.092542
# Test: MSE Total = 0.324184,   MSE X = 0.157422,   MSE Z = 0.152030
#
#
# Train Epoch 99: MSE Total = 0.154917,   MSE X = 0.065699,   MSE Z = 0.091694
# Test: MSE Total = 0.373905,   MSE X = 0.181015,   MSE Z = 0.176449
#
#
# Train Epoch 100: MSE Total = 0.161781,   MSE X = 0.067690,   MSE Z = 0.097596
# Test: MSE Total = 0.289976,   MSE X = 0.128179,   MSE Z = 0.161236
#
#
# Got the weights of the epoch 91
# Execution time: 7 minutes, 40.86 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step2_autoregressive"))

model.eval()
# Out:
# MyModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=128, bias=True)
#   (pc_emb_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
model.eval()

examples = []
batch_indices = 6   # numero batch consecutivi usati
example_index = [9, 9, 9, 0, 5, 50]

# Itera sui primi 6 batch del test_loader
for b_idx, batch in enumerate(test_loader):
    if b_idx >= batch_indices:
        break

    past_batch, future_batch, pc_batch = batch
    
    examples.append((past_batch[example_index[b_idx]], future_batch[example_index[b_idx]], pc_batch[example_index[b_idx]]))

examples[3], examples[4], examples[5] = examples[4], examples[5], examples[3]    

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past_np = past.cpu().numpy()
    future_np = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past.unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc.unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past_np[:, 0], past_np[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future_np[:, 0], future_np[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.281644,   ADE X = 0.150381,   ADE Z = 0.204427
# FDE Total = 0.564105,   FDE X = 0.361469,   FDE Z = 0.356615
#
# Model performances on test set:
#
# ADE Total = 0.369830,   ADE X = 0.211619,   ADE Z = 0.259839
# FDE Total = 0.796483,   FDE X = 0.545610,   FDE Z = 0.474591

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiungi la nuova coppia chiave-array
    data_dict['step2_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
