# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = []

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva la nuvola sottocampionata nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.npz_files = sorted(all_files, key=extract_number)

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx]).transpose(0, 1)

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class MyModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]

dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, past_seconds=past_seconds, 
                        future_seconds=future_seconds, framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 3, 1024])

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.3510107398033142
# Global variance of the z-coordinate: 4.372647285461426

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.361681,   MSE X = 0.521757,   MSE Z = 1.005858
# Test: MSE Total = 1.058084,   MSE X = 0.537520,   MSE Z = 0.315374
#
#
# Train Epoch 2: MSE Total = 1.006490,   MSE X = 0.517956,   MSE Z = 0.276537
# Test: MSE Total = 1.014527,   MSE X = 0.538479,   MSE Z = 0.220910
#
#
# Train Epoch 3: MSE Total = 0.989441,   MSE X = 0.518598,   MSE Z = 0.238623
# Test: MSE Total = 1.028803,   MSE X = 0.548372,   MSE Z = 0.215844
#
#
# Train Epoch 4: MSE Total = 0.955262,   MSE X = 0.495394,   MSE Z = 0.249048
# Test: MSE Total = 0.872528,   MSE X = 0.435510,   MSE Z = 0.287405
#
#
# Train Epoch 5: MSE Total = 0.721490,   MSE X = 0.336202,   MSE Z = 0.322078
# Test: MSE Total = 0.671180,   MSE X = 0.323325,   MSE Z = 0.262325
#
#
# Train Epoch 6: MSE Total = 0.534465,   MSE X = 0.247288,   MSE Z = 0.244813
# Test: MSE Total = 0.501419,   MSE X = 0.237638,   MSE Z = 0.209768
#
#
# Train Epoch 7: MSE Total = 0.484084,   MSE X = 0.216792,   MSE Z = 0.247098
# Test: MSE Total = 0.473453,   MSE X = 0.210653,   MSE Z = 0.246533
#
#
# Train Epoch 8: MSE Total = 0.468258,   MSE X = 0.210057,   MSE Z = 0.237775
# Test: MSE Total = 0.439215,   MSE X = 0.197897,   MSE Z = 0.219960
#
#
# Train Epoch 9: MSE Total = 0.401645,   MSE X = 0.179682,   MSE Z = 0.205688
# Test: MSE Total = 0.493208,   MSE X = 0.236181,   MSE Z = 0.197745
#
#
# Train Epoch 10: MSE Total = 0.392936,   MSE X = 0.177053,   MSE Z = 0.196759
# Test: MSE Total = 0.379858,   MSE X = 0.172112,   MSE Z = 0.186850
#
#
# Train Epoch 11: MSE Total = 0.372053,   MSE X = 0.166494,   MSE Z = 0.190356
# Test: MSE Total = 0.379667,   MSE X = 0.171797,   MSE Z = 0.187562
#
#
# Train Epoch 12: MSE Total = 0.353157,   MSE X = 0.155429,   MSE Z = 0.189896
# Test: MSE Total = 0.425660,   MSE X = 0.199823,   MSE Z = 0.184820
#
#
# Train Epoch 13: MSE Total = 0.364207,   MSE X = 0.159199,   MSE Z = 0.199697
# Test: MSE Total = 0.368643,   MSE X = 0.165938,   MSE Z = 0.185189
#
#
# Train Epoch 14: MSE Total = 0.346394,   MSE X = 0.153454,   MSE Z = 0.182727
# Test: MSE Total = 0.365227,   MSE X = 0.163119,   MSE Z = 0.187994
#
#
# Train Epoch 15: MSE Total = 0.322274,   MSE X = 0.138378,   MSE Z = 0.185501
# Test: MSE Total = 0.339469,   MSE X = 0.150781,   MSE Z = 0.177677
#
#
# Train Epoch 16: MSE Total = 0.300789,   MSE X = 0.128610,   MSE Z = 0.175050
# Test: MSE Total = 0.312611,   MSE X = 0.138354,   MSE Z = 0.165378
#
#
# Train Epoch 17: MSE Total = 0.299952,   MSE X = 0.126325,   MSE Z = 0.181363
# Test: MSE Total = 0.342484,   MSE X = 0.150899,   MSE Z = 0.183568
#
#
# Train Epoch 18: MSE Total = 0.317620,   MSE X = 0.137035,   MSE Z = 0.180508
# Test: MSE Total = 0.371908,   MSE X = 0.168379,   MSE Z = 0.183401
#
#
# Train Epoch 19: MSE Total = 0.298691,   MSE X = 0.124318,   MSE Z = 0.185809
# Test: MSE Total = 0.349212,   MSE X = 0.161230,   MSE Z = 0.161172
#
#
# Train Epoch 20: MSE Total = 0.302079,   MSE X = 0.127673,   MSE Z = 0.181053
# Test: MSE Total = 0.355081,   MSE X = 0.152758,   MSE Z = 0.203348
#
#
# Train Epoch 21: MSE Total = 0.284506,   MSE X = 0.118943,   MSE Z = 0.175118
# Test: MSE Total = 0.288754,   MSE X = 0.126461,   MSE Z = 0.157467
#
#
# Train Epoch 22: MSE Total = 0.265820,   MSE X = 0.110454,   MSE Z = 0.166005
# Test: MSE Total = 0.275537,   MSE X = 0.120991,   MSE Z = 0.149136
#
#
# Train Epoch 23: MSE Total = 0.297614,   MSE X = 0.122964,   MSE Z = 0.188339
# Test: MSE Total = 0.301411,   MSE X = 0.130661,   MSE Z = 0.169110
#
#
# Train Epoch 24: MSE Total = 0.267978,   MSE X = 0.112260,   MSE Z = 0.164145
# Test: MSE Total = 0.275345,   MSE X = 0.117244,   MSE Z = 0.161958
#
#
# Train Epoch 25: MSE Total = 0.253363,   MSE X = 0.105289,   MSE Z = 0.158186
# Test: MSE Total = 0.299648,   MSE X = 0.134848,   MSE Z = 0.150645
#
#
# Train Epoch 26: MSE Total = 0.243133,   MSE X = 0.101289,   MSE Z = 0.150912
# Test: MSE Total = 0.251573,   MSE X = 0.105221,   MSE Z = 0.154685
#
#
# Train Epoch 27: MSE Total = 0.232506,   MSE X = 0.095400,   MSE Z = 0.149477
# Test: MSE Total = 0.248891,   MSE X = 0.105978,   MSE Z = 0.146405
#
#
# Train Epoch 28: MSE Total = 0.219145,   MSE X = 0.088476,   MSE Z = 0.145976
# Test: MSE Total = 0.242327,   MSE X = 0.102658,   MSE Z = 0.144397
#
#
# Train Epoch 29: MSE Total = 0.213639,   MSE X = 0.086400,   MSE Z = 0.141789
# Test: MSE Total = 0.251198,   MSE X = 0.109094,   MSE Z = 0.140231
#
#
# Train Epoch 30: MSE Total = 0.214875,   MSE X = 0.087390,   MSE Z = 0.140879
# Test: MSE Total = 0.230832,   MSE X = 0.095940,   MSE Z = 0.144069
#
#
# Train Epoch 31: MSE Total = 0.219980,   MSE X = 0.090627,   MSE Z = 0.140129
# Test: MSE Total = 0.283448,   MSE X = 0.128893,   MSE Z = 0.137786
#
#
# Train Epoch 32: MSE Total = 0.220973,   MSE X = 0.090851,   MSE Z = 0.141417
# Test: MSE Total = 0.260185,   MSE X = 0.102363,   MSE Z = 0.182781
#
#
# Train Epoch 33: MSE Total = 0.200373,   MSE X = 0.081467,   MSE Z = 0.131458
# Test: MSE Total = 0.233540,   MSE X = 0.097445,   MSE Z = 0.144422
#
#
# Train Epoch 34: MSE Total = 0.193188,   MSE X = 0.076355,   MSE Z = 0.134478
# Test: MSE Total = 0.212445,   MSE X = 0.088566,   MSE Z = 0.131647
#
#
# Train Epoch 35: MSE Total = 0.189377,   MSE X = 0.075841,   MSE Z = 0.128324
# Test: MSE Total = 0.205485,   MSE X = 0.083682,   MSE Z = 0.134335
#
#
# Train Epoch 36: MSE Total = 0.169212,   MSE X = 0.066499,   MSE Z = 0.119130
# Test: MSE Total = 0.198871,   MSE X = 0.083901,   MSE Z = 0.119730
#
#
# Train Epoch 37: MSE Total = 0.191870,   MSE X = 0.078932,   MSE Z = 0.122627
# Test: MSE Total = 0.233336,   MSE X = 0.103928,   MSE Z = 0.121115
#
#
# Train Epoch 38: MSE Total = 0.167877,   MSE X = 0.065673,   MSE Z = 0.119251
# Test: MSE Total = 0.217183,   MSE X = 0.093093,   MSE Z = 0.125577
#
#
# Train Epoch 39: MSE Total = 0.171596,   MSE X = 0.068718,   MSE Z = 0.116284
# Test: MSE Total = 0.190849,   MSE X = 0.078498,   MSE Z = 0.122025
#
#
# Train Epoch 40: MSE Total = 0.156196,   MSE X = 0.060647,   MSE Z = 0.112567
# Test: MSE Total = 0.196190,   MSE X = 0.084353,   MSE Z = 0.112529
#
#
# Train Epoch 41: MSE Total = 0.193186,   MSE X = 0.079132,   MSE Z = 0.124673
# Test: MSE Total = 0.231598,   MSE X = 0.100539,   MSE Z = 0.129441
#
#
# Train Epoch 42: MSE Total = 0.156547,   MSE X = 0.059952,   MSE Z = 0.115753
# Test: MSE Total = 0.183069,   MSE X = 0.075883,   MSE Z = 0.114983
#
#
# Train Epoch 43: MSE Total = 0.147855,   MSE X = 0.057174,   MSE Z = 0.107383
# Test: MSE Total = 0.209484,   MSE X = 0.088576,   MSE Z = 0.125419
#
#
# Train Epoch 44: MSE Total = 0.178740,   MSE X = 0.072927,   MSE Z = 0.116367
# Test: MSE Total = 0.184520,   MSE X = 0.079799,   MSE Z = 0.104199
#
#
# Train Epoch 45: MSE Total = 0.150616,   MSE X = 0.059489,   MSE Z = 0.104984
# Test: MSE Total = 0.175200,   MSE X = 0.074068,   MSE Z = 0.104937
#
#
# Train Epoch 46: MSE Total = 0.139156,   MSE X = 0.054374,   MSE Z = 0.099076
# Test: MSE Total = 0.191609,   MSE X = 0.082561,   MSE Z = 0.109274
#
#
# Train Epoch 47: MSE Total = 0.124986,   MSE X = 0.048126,   MSE Z = 0.091498
# Test: MSE Total = 0.165500,   MSE X = 0.065829,   MSE Z = 0.113731
#
#
# Train Epoch 48: MSE Total = 0.119216,   MSE X = 0.045304,   MSE Z = 0.089391
# Test: MSE Total = 0.164896,   MSE X = 0.070551,   MSE Z = 0.095805
#
#
# Train Epoch 49: MSE Total = 0.120685,   MSE X = 0.046721,   MSE Z = 0.087461
# Test: MSE Total = 0.177572,   MSE X = 0.071377,   MSE Z = 0.119393
#
#
# Train Epoch 50: MSE Total = 0.128881,   MSE X = 0.049912,   MSE Z = 0.093339
# Test: MSE Total = 0.166562,   MSE X = 0.067749,   MSE Z = 0.109175
#
#
# Train Epoch 51: MSE Total = 0.127890,   MSE X = 0.049362,   MSE Z = 0.093206
# Test: MSE Total = 0.169966,   MSE X = 0.072681,   MSE Z = 0.098886
#
#
# Train Epoch 52: MSE Total = 0.112995,   MSE X = 0.043141,   MSE Z = 0.084016
# Test: MSE Total = 0.152084,   MSE X = 0.064225,   MSE Z = 0.091338
#
#
# Train Epoch 53: MSE Total = 0.104612,   MSE X = 0.039312,   MSE Z = 0.080000
# Test: MSE Total = 0.155372,   MSE X = 0.066309,   MSE Z = 0.090862
#
#
# Train Epoch 54: MSE Total = 0.098630,   MSE X = 0.036417,   MSE Z = 0.077711
# Test: MSE Total = 0.150500,   MSE X = 0.062013,   MSE Z = 0.095835
#
#
# Train Epoch 55: MSE Total = 0.093239,   MSE X = 0.035045,   MSE Z = 0.071281
# Test: MSE Total = 0.151227,   MSE X = 0.061122,   MSE Z = 0.100499
#
#
# Train Epoch 56: MSE Total = 0.091729,   MSE X = 0.034170,   MSE Z = 0.071212
# Test: MSE Total = 0.158439,   MSE X = 0.065365,   MSE Z = 0.100603
#
#
# Train Epoch 57: MSE Total = 0.126570,   MSE X = 0.051177,   MSE Z = 0.084042
# Test: MSE Total = 0.169965,   MSE X = 0.072360,   MSE Z = 0.100017
#
#
# Train Epoch 58: MSE Total = 0.100360,   MSE X = 0.038687,   MSE Z = 0.073314
# Test: MSE Total = 0.148578,   MSE X = 0.064418,   MSE Z = 0.083328
#
#
# Train Epoch 59: MSE Total = 0.084229,   MSE X = 0.031257,   MSE Z = 0.065810
# Test: MSE Total = 0.131911,   MSE X = 0.054316,   MSE Z = 0.084131
#
#
# Train Epoch 60: MSE Total = 0.077715,   MSE X = 0.027873,   MSE Z = 0.064130
# Test: MSE Total = 0.134304,   MSE X = 0.056846,   MSE Z = 0.080205
#
#
# Train Epoch 61: MSE Total = 0.094216,   MSE X = 0.036495,   MSE Z = 0.068206
# Test: MSE Total = 0.155040,   MSE X = 0.068842,   MSE Z = 0.081223
#
#
# Train Epoch 62: MSE Total = 0.078394,   MSE X = 0.029061,   MSE Z = 0.061360
# Test: MSE Total = 0.130034,   MSE X = 0.055815,   MSE Z = 0.074913
#
#
# Train Epoch 63: MSE Total = 0.077142,   MSE X = 0.028739,   MSE Z = 0.059878
# Test: MSE Total = 0.135242,   MSE X = 0.058227,   MSE Z = 0.077293
#
#
# Train Epoch 64: MSE Total = 0.083672,   MSE X = 0.031871,   MSE Z = 0.062477
# Test: MSE Total = 0.140318,   MSE X = 0.059757,   MSE Z = 0.082506
#
#
# Train Epoch 65: MSE Total = 0.076858,   MSE X = 0.029525,   MSE Z = 0.056508
# Test: MSE Total = 0.124758,   MSE X = 0.052228,   MSE Z = 0.076541
#
#
# Train Epoch 66: MSE Total = 0.067474,   MSE X = 0.024801,   MSE Z = 0.053557
# Test: MSE Total = 0.125135,   MSE X = 0.052801,   MSE Z = 0.075307
#
#
# Train Epoch 67: MSE Total = 0.071513,   MSE X = 0.026232,   MSE Z = 0.056953
# Test: MSE Total = 0.128362,   MSE X = 0.055047,   MSE Z = 0.074128
#
#
# Train Epoch 68: MSE Total = 0.069345,   MSE X = 0.026432,   MSE Z = 0.051715
# Test: MSE Total = 0.119947,   MSE X = 0.050428,   MSE Z = 0.072834
#
#
# Train Epoch 69: MSE Total = 0.059285,   MSE X = 0.021655,   MSE Z = 0.047539
# Test: MSE Total = 0.121469,   MSE X = 0.049985,   MSE Z = 0.077580
#
#
# Train Epoch 70: MSE Total = 0.061468,   MSE X = 0.022060,   MSE Z = 0.050673
# Test: MSE Total = 0.124109,   MSE X = 0.051144,   MSE Z = 0.079013
#
#
# Train Epoch 71: MSE Total = 0.070474,   MSE X = 0.025958,   MSE Z = 0.055748
# Test: MSE Total = 0.127588,   MSE X = 0.053561,   MSE Z = 0.077752
#
#
# Train Epoch 72: MSE Total = 0.111241,   MSE X = 0.046678,   MSE Z = 0.067866
# Test: MSE Total = 0.148938,   MSE X = 0.065413,   MSE Z = 0.080568
#
#
# Train Epoch 73: MSE Total = 0.087389,   MSE X = 0.034199,   MSE Z = 0.062031
# Test: MSE Total = 0.130802,   MSE X = 0.056179,   MSE Z = 0.075237
#
#
# Train Epoch 74: MSE Total = 0.059766,   MSE X = 0.022229,   MSE Z = 0.046521
# Test: MSE Total = 0.120600,   MSE X = 0.051593,   MSE Z = 0.070088
#
#
# Train Epoch 75: MSE Total = 0.052487,   MSE X = 0.018736,   MSE Z = 0.043627
# Test: MSE Total = 0.114792,   MSE X = 0.048070,   MSE Z = 0.070378
#
#
# Train Epoch 76: MSE Total = 0.057594,   MSE X = 0.020732,   MSE Z = 0.047259
# Test: MSE Total = 0.142858,   MSE X = 0.058015,   MSE Z = 0.093963
#
#
# Train Epoch 77: MSE Total = 0.061493,   MSE X = 0.022862,   MSE Z = 0.047897
# Test: MSE Total = 0.115973,   MSE X = 0.048767,   MSE Z = 0.070386
#
#
# Train Epoch 78: MSE Total = 0.051336,   MSE X = 0.019185,   MSE Z = 0.039635
# Test: MSE Total = 0.120134,   MSE X = 0.051786,   MSE Z = 0.068434
#
#
# Train Epoch 79: MSE Total = 0.056095,   MSE X = 0.020678,   MSE Z = 0.044318
# Test: MSE Total = 0.115573,   MSE X = 0.049201,   MSE Z = 0.068019
#
#
# Train Epoch 80: MSE Total = 0.046657,   MSE X = 0.016533,   MSE Z = 0.039212
# Test: MSE Total = 0.113987,   MSE X = 0.048315,   MSE Z = 0.067829
#
#
# Train Epoch 81: MSE Total = 0.042361,   MSE X = 0.015130,   MSE Z = 0.035179
# Test: MSE Total = 0.106903,   MSE X = 0.044435,   MSE Z = 0.066710
#
#
# Train Epoch 82: MSE Total = 0.044609,   MSE X = 0.016092,   MSE Z = 0.036485
# Test: MSE Total = 0.116170,   MSE X = 0.050041,   MSE Z = 0.066304
#
#
# Train Epoch 83: MSE Total = 0.051752,   MSE X = 0.019212,   MSE Z = 0.040412
# Test: MSE Total = 0.137800,   MSE X = 0.056644,   MSE Z = 0.088228
#
#
# Train Epoch 84: MSE Total = 0.053718,   MSE X = 0.020000,   MSE Z = 0.041738
# Test: MSE Total = 0.113224,   MSE X = 0.049170,   MSE Z = 0.063218
#
#
# Train Epoch 85: MSE Total = 0.045664,   MSE X = 0.016725,   MSE Z = 0.036456
# Test: MSE Total = 0.103394,   MSE X = 0.043246,   MSE Z = 0.063568
#
#
# Train Epoch 86: MSE Total = 0.041403,   MSE X = 0.014836,   MSE Z = 0.034215
# Test: MSE Total = 0.111171,   MSE X = 0.047660,   MSE Z = 0.064252
#
#
# Train Epoch 87: MSE Total = 0.038259,   MSE X = 0.013685,   MSE Z = 0.031701
# Test: MSE Total = 0.106290,   MSE X = 0.044485,   MSE Z = 0.065252
#
#
# Train Epoch 88: MSE Total = 0.037830,   MSE X = 0.013459,   MSE Z = 0.031601
# Test: MSE Total = 0.113011,   MSE X = 0.049132,   MSE Z = 0.062906
#
#
# Train Epoch 89: MSE Total = 0.041543,   MSE X = 0.015246,   MSE Z = 0.033060
# Test: MSE Total = 0.102934,   MSE X = 0.042477,   MSE Z = 0.065320
#
#
# Train Epoch 90: MSE Total = 0.033748,   MSE X = 0.011722,   MSE Z = 0.029195
# Test: MSE Total = 0.098196,   MSE X = 0.041514,   MSE Z = 0.058812
#
#
# Train Epoch 91: MSE Total = 0.031324,   MSE X = 0.010758,   MSE Z = 0.027531
# Test: MSE Total = 0.102726,   MSE X = 0.042778,   MSE Z = 0.063827
#
#
# Train Epoch 92: MSE Total = 0.034485,   MSE X = 0.012289,   MSE Z = 0.028737
# Test: MSE Total = 0.117046,   MSE X = 0.050027,   MSE Z = 0.068185
#
#
# Train Epoch 93: MSE Total = 0.041895,   MSE X = 0.015549,   MSE Z = 0.032728
# Test: MSE Total = 0.107608,   MSE X = 0.044841,   MSE Z = 0.066753
#
#
# Train Epoch 94: MSE Total = 0.040974,   MSE X = 0.014420,   MSE Z = 0.034786
# Test: MSE Total = 0.106790,   MSE X = 0.045507,   MSE Z = 0.062691
#
#
# Train Epoch 95: MSE Total = 0.041758,   MSE X = 0.014507,   MSE Z = 0.036116
# Test: MSE Total = 0.096656,   MSE X = 0.039250,   MSE Z = 0.063582
#
#
# Train Epoch 96: MSE Total = 0.034332,   MSE X = 0.012637,   MSE Z = 0.027187
# Test: MSE Total = 0.104981,   MSE X = 0.042857,   MSE Z = 0.068260
#
#
# Train Epoch 97: MSE Total = 0.094119,   MSE X = 0.039037,   MSE Z = 0.059031
# Test: MSE Total = 0.174793,   MSE X = 0.073753,   MSE Z = 0.105197
#
#
# Train Epoch 98: MSE Total = 0.109322,   MSE X = 0.044835,   MSE Z = 0.070357
# Test: MSE Total = 0.134451,   MSE X = 0.055336,   MSE Z = 0.085842
#
#
# Train Epoch 99: MSE Total = 0.122049,   MSE X = 0.050860,   MSE Z = 0.075705
# Test: MSE Total = 0.228360,   MSE X = 0.101884,   MSE Z = 0.117921
#
#
# Train Epoch 100: MSE Total = 0.127972,   MSE X = 0.050039,   MSE Z = 0.090988
# Test: MSE Total = 0.135416,   MSE X = 0.055998,   MSE Z = 0.085523
#
#
# Train Epoch 101: MSE Total = 0.063980,   MSE X = 0.023587,   MSE Z = 0.050540
# Test: MSE Total = 0.102250,   MSE X = 0.041208,   MSE Z = 0.068371
#
#
# Train Epoch 102: MSE Total = 0.040789,   MSE X = 0.014539,   MSE Z = 0.033979
# Test: MSE Total = 0.099093,   MSE X = 0.041199,   MSE Z = 0.061801
#
#
# Train Epoch 103: MSE Total = 0.033456,   MSE X = 0.011731,   MSE Z = 0.028554
# Test: MSE Total = 0.099751,   MSE X = 0.042654,   MSE Z = 0.058042
#
#
# Train Epoch 104: MSE Total = 0.037816,   MSE X = 0.013357,   MSE Z = 0.031932
# Test: MSE Total = 0.111457,   MSE X = 0.044515,   MSE Z = 0.075953
#
#
# Train Epoch 105: MSE Total = 0.039342,   MSE X = 0.013763,   MSE Z = 0.033692
# Test: MSE Total = 0.100498,   MSE X = 0.042931,   MSE Z = 0.058626
#
#
# Train Epoch 106: MSE Total = 0.030267,   MSE X = 0.010568,   MSE Z = 0.025991
# Test: MSE Total = 0.095630,   MSE X = 0.039724,   MSE Z = 0.059763
#
#
# Train Epoch 107: MSE Total = 0.027448,   MSE X = 0.009562,   MSE Z = 0.023648
# Test: MSE Total = 0.086575,   MSE X = 0.036287,   MSE Z = 0.052961
#
#
# Train Epoch 108: MSE Total = 0.025067,   MSE X = 0.008500,   MSE Z = 0.022415
# Test: MSE Total = 0.092660,   MSE X = 0.038501,   MSE Z = 0.057871
#
#
# Train Epoch 109: MSE Total = 0.027822,   MSE X = 0.009731,   MSE Z = 0.023833
# Test: MSE Total = 0.090984,   MSE X = 0.037921,   MSE Z = 0.056413
#
#
# Train Epoch 110: MSE Total = 0.041308,   MSE X = 0.016133,   MSE Z = 0.029438
# Test: MSE Total = 0.184407,   MSE X = 0.074603,   MSE Z = 0.122299
#
#
# Train Epoch 111: MSE Total = 0.086747,   MSE X = 0.033998,   MSE Z = 0.061400
# Test: MSE Total = 0.119850,   MSE X = 0.050119,   MSE Z = 0.073722
#
#
# Train Epoch 112: MSE Total = 0.045387,   MSE X = 0.016189,   MSE Z = 0.037769
# Test: MSE Total = 0.096888,   MSE X = 0.041429,   MSE Z = 0.056376
#
#
# Train Epoch 113: MSE Total = 0.029778,   MSE X = 0.010433,   MSE Z = 0.025444
# Test: MSE Total = 0.087518,   MSE X = 0.036475,   MSE Z = 0.054269
#
#
# Train Epoch 114: MSE Total = 0.029022,   MSE X = 0.010416,   MSE Z = 0.023925
# Test: MSE Total = 0.092117,   MSE X = 0.038865,   MSE Z = 0.055451
#
#
# Train Epoch 115: MSE Total = 0.024630,   MSE X = 0.008675,   MSE Z = 0.020886
# Test: MSE Total = 0.086614,   MSE X = 0.036430,   MSE Z = 0.052538
#
#
# Train Epoch 116: MSE Total = 0.028322,   MSE X = 0.010138,   MSE Z = 0.023442
# Test: MSE Total = 0.091968,   MSE X = 0.039838,   MSE Z = 0.051703
#
#
# Train Epoch 117: MSE Total = 0.023962,   MSE X = 0.008606,   MSE Z = 0.019730
# Test: MSE Total = 0.087552,   MSE X = 0.037677,   MSE Z = 0.050099
#
#
# Train Epoch 118: MSE Total = 0.020460,   MSE X = 0.007135,   MSE Z = 0.017602
# Test: MSE Total = 0.087123,   MSE X = 0.037323,   MSE Z = 0.050452
#
#
# Train Epoch 119: MSE Total = 0.019418,   MSE X = 0.006651,   MSE Z = 0.017129
# Test: MSE Total = 0.085907,   MSE X = 0.036565,   MSE Z = 0.050585
#
#
# Train Epoch 120: MSE Total = 0.018531,   MSE X = 0.006475,   MSE Z = 0.015897
# Test: MSE Total = 0.085751,   MSE X = 0.036196,   MSE Z = 0.051560
#
#
# Train Epoch 121: MSE Total = 0.019041,   MSE X = 0.006518,   MSE Z = 0.016811
# Test: MSE Total = 0.087792,   MSE X = 0.036893,   MSE Z = 0.053368
#
#
# Train Epoch 122: MSE Total = 0.020032,   MSE X = 0.006983,   MSE Z = 0.017244
# Test: MSE Total = 0.085051,   MSE X = 0.036142,   MSE Z = 0.050287
#
#
# Train Epoch 123: MSE Total = 0.018117,   MSE X = 0.006241,   MSE Z = 0.015857
# Test: MSE Total = 0.085717,   MSE X = 0.036865,   MSE Z = 0.049126
#
#
# Train Epoch 124: MSE Total = 0.021695,   MSE X = 0.007828,   MSE Z = 0.017736
# Test: MSE Total = 0.091271,   MSE X = 0.040138,   MSE Z = 0.049187
#
#
# Train Epoch 125: MSE Total = 0.022286,   MSE X = 0.008126,   MSE Z = 0.017921
# Test: MSE Total = 0.086893,   MSE X = 0.037239,   MSE Z = 0.050267
#
#
# Train Epoch 126: MSE Total = 0.017863,   MSE X = 0.005953,   MSE Z = 0.016343
# Test: MSE Total = 0.083740,   MSE X = 0.035844,   MSE Z = 0.048595
#
#
# Train Epoch 127: MSE Total = 0.018948,   MSE X = 0.006663,   MSE Z = 0.016105
# Test: MSE Total = 0.085926,   MSE X = 0.036871,   MSE Z = 0.049542
#
#
# Train Epoch 128: MSE Total = 0.016054,   MSE X = 0.005303,   MSE Z = 0.014854
# Test: MSE Total = 0.082305,   MSE X = 0.034858,   MSE Z = 0.049078
#
#
# Train Epoch 129: MSE Total = 0.017410,   MSE X = 0.006079,   MSE Z = 0.014951
# Test: MSE Total = 0.081835,   MSE X = 0.034024,   MSE Z = 0.051037
#
#
# Train Epoch 130: MSE Total = 0.018279,   MSE X = 0.006506,   MSE Z = 0.015259
# Test: MSE Total = 0.089096,   MSE X = 0.037672,   MSE Z = 0.053347
#
#
# Train Epoch 131: MSE Total = 0.018029,   MSE X = 0.006273,   MSE Z = 0.015558
# Test: MSE Total = 0.084577,   MSE X = 0.034276,   MSE Z = 0.055882
#
#
# Train Epoch 132: MSE Total = 0.021409,   MSE X = 0.007391,   MSE Z = 0.018680
# Test: MSE Total = 0.080731,   MSE X = 0.032938,   MSE Z = 0.052560
#
#
# Train Epoch 133: MSE Total = 0.019062,   MSE X = 0.006769,   MSE Z = 0.015969
# Test: MSE Total = 0.090291,   MSE X = 0.037797,   MSE Z = 0.055402
#
#
# Train Epoch 134: MSE Total = 0.019298,   MSE X = 0.006838,   MSE Z = 0.016219
# Test: MSE Total = 0.085549,   MSE X = 0.036423,   MSE Z = 0.050338
#
#
# Train Epoch 135: MSE Total = 0.016630,   MSE X = 0.005833,   MSE Z = 0.014186
# Test: MSE Total = 0.084353,   MSE X = 0.035796,   MSE Z = 0.050047
#
#
# Train Epoch 136: MSE Total = 0.015929,   MSE X = 0.005460,   MSE Z = 0.014038
# Test: MSE Total = 0.080199,   MSE X = 0.033897,   MSE Z = 0.048064
#
#
# Train Epoch 137: MSE Total = 0.015254,   MSE X = 0.005156,   MSE Z = 0.013700
# Test: MSE Total = 0.084308,   MSE X = 0.035356,   MSE Z = 0.051507
#
#
# Train Epoch 138: MSE Total = 0.014732,   MSE X = 0.004783,   MSE Z = 0.013925
# Test: MSE Total = 0.088866,   MSE X = 0.037737,   MSE Z = 0.052634
#
#
# Train Epoch 139: MSE Total = 0.021284,   MSE X = 0.007879,   MSE Z = 0.016699
# Test: MSE Total = 0.086350,   MSE X = 0.036571,   MSE Z = 0.051487
#
#
# Train Epoch 140: MSE Total = 0.108377,   MSE X = 0.046026,   MSE Z = 0.064178
# Test: MSE Total = 0.261360,   MSE X = 0.093117,   MSE Z = 0.217872
#
#
# Train Epoch 141: MSE Total = 0.142163,   MSE X = 0.057560,   MSE Z = 0.094117
# Test: MSE Total = 0.131443,   MSE X = 0.054533,   MSE Z = 0.082385
#
#
# Train Epoch 142: MSE Total = 0.075375,   MSE X = 0.030073,   MSE Z = 0.051473
# Test: MSE Total = 0.125171,   MSE X = 0.051011,   MSE Z = 0.081699
#
#
# Train Epoch 143: MSE Total = 0.107008,   MSE X = 0.043682,   MSE Z = 0.069587
# Test: MSE Total = 0.172976,   MSE X = 0.078061,   MSE Z = 0.086193
#
#
# Train Epoch 144: MSE Total = 0.084603,   MSE X = 0.034058,   MSE Z = 0.056705
# Test: MSE Total = 0.143344,   MSE X = 0.058832,   MSE Z = 0.092097
#
#
# Train Epoch 145: MSE Total = 0.072164,   MSE X = 0.028913,   MSE Z = 0.048851
# Test: MSE Total = 0.111156,   MSE X = 0.046126,   MSE Z = 0.069636
#
#
# Train Epoch 146: MSE Total = 0.039374,   MSE X = 0.014482,   MSE Z = 0.031222
# Test: MSE Total = 0.102320,   MSE X = 0.042353,   MSE Z = 0.064475
#
#
# Train Epoch 147: MSE Total = 0.028664,   MSE X = 0.010488,   MSE Z = 0.022923
# Test: MSE Total = 0.088024,   MSE X = 0.037264,   MSE Z = 0.052543
#
#
# Train Epoch 148: MSE Total = 0.024013,   MSE X = 0.008479,   MSE Z = 0.020286
# Test: MSE Total = 0.087280,   MSE X = 0.036907,   MSE Z = 0.052249
#
#
# Train Epoch 149: MSE Total = 0.019685,   MSE X = 0.006723,   MSE Z = 0.017435
# Test: MSE Total = 0.080280,   MSE X = 0.033752,   MSE Z = 0.048747
#
#
# Train Epoch 150: MSE Total = 0.017834,   MSE X = 0.006155,   MSE Z = 0.015566
# Test: MSE Total = 0.077698,   MSE X = 0.032480,   MSE Z = 0.047835
#
#
# Train Epoch 151: MSE Total = 0.016814,   MSE X = 0.005779,   MSE Z = 0.014763
# Test: MSE Total = 0.080251,   MSE X = 0.033785,   MSE Z = 0.048568
#
#
# Train Epoch 152: MSE Total = 0.020409,   MSE X = 0.007560,   MSE Z = 0.015994
# Test: MSE Total = 0.085296,   MSE X = 0.034959,   MSE Z = 0.054974
#
#
# Train Epoch 153: MSE Total = 0.020094,   MSE X = 0.007209,   MSE Z = 0.016573
# Test: MSE Total = 0.082514,   MSE X = 0.034516,   MSE Z = 0.050720
#
#
# Train Epoch 154: MSE Total = 0.016562,   MSE X = 0.005676,   MSE Z = 0.014597
# Test: MSE Total = 0.081991,   MSE X = 0.034179,   MSE Z = 0.050815
#
#
# Train Epoch 155: MSE Total = 0.015175,   MSE X = 0.005038,   MSE Z = 0.013950
# Test: MSE Total = 0.080068,   MSE X = 0.033898,   MSE Z = 0.047785
#
#
# Train Epoch 156: MSE Total = 0.015553,   MSE X = 0.005388,   MSE Z = 0.013504
# Test: MSE Total = 0.080905,   MSE X = 0.034808,   MSE Z = 0.046324
#
#
# Train Epoch 157: MSE Total = 0.015213,   MSE X = 0.005200,   MSE Z = 0.013457
# Test: MSE Total = 0.078141,   MSE X = 0.033360,   MSE Z = 0.045656
#
#
# Train Epoch 158: MSE Total = 0.014572,   MSE X = 0.005042,   MSE Z = 0.012674
# Test: MSE Total = 0.081634,   MSE X = 0.035002,   MSE Z = 0.047163
#
#
# Train Epoch 159: MSE Total = 0.015555,   MSE X = 0.005400,   MSE Z = 0.013467
# Test: MSE Total = 0.082300,   MSE X = 0.035360,   MSE Z = 0.047295
#
#
# Train Epoch 160: MSE Total = 0.013787,   MSE X = 0.004604,   MSE Z = 0.012578
# Test: MSE Total = 0.080792,   MSE X = 0.033820,   MSE Z = 0.049577
#
#
# Train Epoch 161: MSE Total = 0.011864,   MSE X = 0.003887,   MSE Z = 0.011089
# Test: MSE Total = 0.077132,   MSE X = 0.032923,   MSE Z = 0.045091
#
#
# Train Epoch 162: MSE Total = 0.011431,   MSE X = 0.003618,   MSE Z = 0.011134
# Test: MSE Total = 0.077334,   MSE X = 0.033004,   MSE Z = 0.045227
#
#
# Train Epoch 163: MSE Total = 0.012040,   MSE X = 0.004034,   MSE Z = 0.010939
# Test: MSE Total = 0.077445,   MSE X = 0.032732,   MSE Z = 0.046418
#
#
# Train Epoch 164: MSE Total = 0.012647,   MSE X = 0.004348,   MSE Z = 0.011101
# Test: MSE Total = 0.080646,   MSE X = 0.034356,   MSE Z = 0.047379
#
#
# Train Epoch 165: MSE Total = 0.012335,   MSE X = 0.004010,   MSE Z = 0.011640
# Test: MSE Total = 0.076242,   MSE X = 0.032076,   MSE Z = 0.046215
#
#
# Train Epoch 166: MSE Total = 0.011243,   MSE X = 0.003765,   MSE Z = 0.010222
# Test: MSE Total = 0.076946,   MSE X = 0.032967,   MSE Z = 0.044543
#
#
# Train Epoch 167: MSE Total = 0.010847,   MSE X = 0.003613,   MSE Z = 0.009931
# Test: MSE Total = 0.076259,   MSE X = 0.032560,   MSE Z = 0.044543
#
#
# Train Epoch 168: MSE Total = 0.011102,   MSE X = 0.003661,   MSE Z = 0.010292
# Test: MSE Total = 0.078836,   MSE X = 0.034188,   MSE Z = 0.044189
#
#
# Train Epoch 169: MSE Total = 0.011460,   MSE X = 0.003807,   MSE Z = 0.010528
# Test: MSE Total = 0.079891,   MSE X = 0.034042,   MSE Z = 0.046906
#
#
# Train Epoch 170: MSE Total = 0.010691,   MSE X = 0.003460,   MSE Z = 0.010143
# Test: MSE Total = 0.075198,   MSE X = 0.031858,   MSE Z = 0.044802
#
#
# Train Epoch 171: MSE Total = 0.011293,   MSE X = 0.003681,   MSE Z = 0.010623
# Test: MSE Total = 0.079927,   MSE X = 0.034103,   MSE Z = 0.046767
#
#
# Train Epoch 172: MSE Total = 0.011424,   MSE X = 0.003781,   MSE Z = 0.010543
# Test: MSE Total = 0.079651,   MSE X = 0.034280,   MSE Z = 0.045566
#
#
# Train Epoch 173: MSE Total = 0.010363,   MSE X = 0.003458,   MSE Z = 0.009465
# Test: MSE Total = 0.073848,   MSE X = 0.031345,   MSE Z = 0.043789
#
#
# Train Epoch 174: MSE Total = 0.010697,   MSE X = 0.003491,   MSE Z = 0.010048
# Test: MSE Total = 0.075750,   MSE X = 0.032246,   MSE Z = 0.044589
#
#
# Train Epoch 175: MSE Total = 0.012285,   MSE X = 0.004363,   MSE Z = 0.010288
# Test: MSE Total = 0.079877,   MSE X = 0.033955,   MSE Z = 0.047186
#
#
# Train Epoch 176: MSE Total = 0.020547,   MSE X = 0.007951,   MSE Z = 0.014902
# Test: MSE Total = 0.087980,   MSE X = 0.037804,   MSE Z = 0.050545
#
#
# Train Epoch 177: MSE Total = 0.046477,   MSE X = 0.018240,   MSE Z = 0.032810
# Test: MSE Total = 0.108904,   MSE X = 0.046794,   MSE Z = 0.062570
#
#
# Train Epoch 178: MSE Total = 0.062566,   MSE X = 0.024143,   MSE Z = 0.045618
# Test: MSE Total = 0.216075,   MSE X = 0.096397,   MSE Z = 0.111601
#
#
# Train Epoch 179: MSE Total = 0.098457,   MSE X = 0.040597,   MSE Z = 0.062595
# Test: MSE Total = 0.117776,   MSE X = 0.049269,   MSE Z = 0.072385
#
#
# Train Epoch 180: MSE Total = 0.038754,   MSE X = 0.013789,   MSE Z = 0.032370
# Test: MSE Total = 0.094171,   MSE X = 0.040188,   MSE Z = 0.055078
#
#
# Train Epoch 181: MSE Total = 0.021623,   MSE X = 0.007848,   MSE Z = 0.017514
# Test: MSE Total = 0.087990,   MSE X = 0.037854,   MSE Z = 0.050390
#
#
# Train Epoch 182: MSE Total = 0.024805,   MSE X = 0.009050,   MSE Z = 0.019927
# Test: MSE Total = 0.092597,   MSE X = 0.038739,   MSE Z = 0.056900
#
#
# Train Epoch 183: MSE Total = 0.031979,   MSE X = 0.012482,   MSE Z = 0.022814
# Test: MSE Total = 0.100952,   MSE X = 0.043154,   MSE Z = 0.058787
#
#
# Train Epoch 184: MSE Total = 0.041303,   MSE X = 0.015890,   MSE Z = 0.030284
# Test: MSE Total = 0.101697,   MSE X = 0.041962,   MSE Z = 0.064550
#
#
# Train Epoch 185: MSE Total = 0.129521,   MSE X = 0.056613,   MSE Z = 0.071026
# Test: MSE Total = 0.158078,   MSE X = 0.067571,   MSE Z = 0.092064
#
#
# Train Epoch 186: MSE Total = 0.095641,   MSE X = 0.039901,   MSE Z = 0.059161
# Test: MSE Total = 0.212817,   MSE X = 0.089411,   MSE Z = 0.129446
#
#
# Train Epoch 187: MSE Total = 0.187652,   MSE X = 0.081375,   MSE Z = 0.105185
# Test: MSE Total = 0.201250,   MSE X = 0.086059,   MSE Z = 0.117089
#
#
# Train Epoch 188: MSE Total = 0.111731,   MSE X = 0.045266,   MSE Z = 0.073874
# Test: MSE Total = 0.133792,   MSE X = 0.057225,   MSE Z = 0.077798
#
#
# Train Epoch 189: MSE Total = 0.063440,   MSE X = 0.025201,   MSE Z = 0.043712
# Test: MSE Total = 0.099065,   MSE X = 0.040903,   MSE Z = 0.062786
#
#
# Train Epoch 190: MSE Total = 0.033405,   MSE X = 0.012093,   MSE Z = 0.027172
# Test: MSE Total = 0.086853,   MSE X = 0.035886,   MSE Z = 0.054957
#
#
# Train Epoch 191: MSE Total = 0.023258,   MSE X = 0.008252,   MSE Z = 0.019508
# Test: MSE Total = 0.083806,   MSE X = 0.034574,   MSE Z = 0.053217
#
#
# Train Epoch 192: MSE Total = 0.020325,   MSE X = 0.007191,   MSE Z = 0.017120
# Test: MSE Total = 0.083668,   MSE X = 0.033746,   MSE Z = 0.055853
#
#
# Train Epoch 193: MSE Total = 0.018709,   MSE X = 0.006348,   MSE Z = 0.016714
# Test: MSE Total = 0.088840,   MSE X = 0.037909,   MSE Z = 0.051972
#
#
# Train Epoch 194: MSE Total = 0.018476,   MSE X = 0.006529,   MSE Z = 0.015592
# Test: MSE Total = 0.078698,   MSE X = 0.032291,   MSE Z = 0.050594
#
#
# Train Epoch 195: MSE Total = 0.015624,   MSE X = 0.005303,   MSE Z = 0.013955
# Test: MSE Total = 0.079526,   MSE X = 0.033146,   MSE Z = 0.049310
#
#
# Train Epoch 196: MSE Total = 0.015499,   MSE X = 0.005237,   MSE Z = 0.013925
# Test: MSE Total = 0.078133,   MSE X = 0.032002,   MSE Z = 0.050430
#
#
# Train Epoch 197: MSE Total = 0.014410,   MSE X = 0.004941,   MSE Z = 0.012694
# Test: MSE Total = 0.076993,   MSE X = 0.031581,   MSE Z = 0.049534
#
#
# Train Epoch 198: MSE Total = 0.012832,   MSE X = 0.004340,   MSE Z = 0.011514
# Test: MSE Total = 0.076696,   MSE X = 0.031787,   MSE Z = 0.048184
#
#
# Train Epoch 199: MSE Total = 0.014141,   MSE X = 0.004975,   MSE Z = 0.012011
# Test: MSE Total = 0.090057,   MSE X = 0.038650,   MSE Z = 0.051902
#
#
# Train Epoch 200: MSE Total = 0.020145,   MSE X = 0.007353,   MSE Z = 0.016172
# Test: MSE Total = 0.079305,   MSE X = 0.032858,   MSE Z = 0.049861
#
#
# Got the weights of the epoch 173
# Execution time: 16 minutes, 55.66 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step2_autoregressive"))

model.eval()
# Out:
# MyModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=256, bias=True)
#   (pc_emb_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [5, 10, 15, 20, 25, 26]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.075461,   ADE X = 0.031060,   ADE Z = 0.062091
# FDE Total = 0.132386,   FDE X = 0.064243,   FDE Z = 0.101747
#
# Model performances on test set:
#
# ADE Total = 0.149291,   ADE X = 0.071771,   ADE Z = 0.114047
# FDE Total = 0.270007,   FDE X = 0.162269,   FDE Z = 0.177668

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    with np.load(file_name) as data:
        data_dict = dict(data)

    # Aggiungi la nuova coppia chiave-array
    data_dict['step2_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
