# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 150
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]

point_clouds_subsampled = [] # lista per salvare gli embedding

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e mettila su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva l'embedding nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva gli embedding in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx]).transpose(0, 1)

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class MyModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x, h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_variance, global_z_variance):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_variance, global_z_variance):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]

dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, past_seconds=past_seconds, 
                        future_seconds=future_seconds, framerate=framerate)
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 3, 1024])

# %%
#Calcolo della varianza globale di x e di z lungo le traiettore

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

# concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.37383729219436646
# Global variance of the z-coordinate: 4.3598480224609375

# %%
batch = next(iter(test_loader))  # Prendi un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = 1000

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_variance, global_z_variance)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_variance, global_z_variance)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.308629,   MSE X = 0.571325,   MSE Z = 0.781356
# Test: MSE Total = 1.005813,   MSE X = 0.551276,   MSE Z = 0.217540
#
#
# Train Epoch 2: MSE Total = 1.021335,   MSE X = 0.558013,   MSE Z = 0.226943
# Test: MSE Total = 0.982828,   MSE X = 0.500378,   MSE Z = 0.343364
#
#
# Train Epoch 3: MSE Total = 0.727340,   MSE X = 0.352593,   MSE Z = 0.314588
# Test: MSE Total = 0.515982,   MSE X = 0.254667,   MSE Z = 0.207688
#
#
# Train Epoch 4: MSE Total = 0.601925,   MSE X = 0.292764,   MSE Z = 0.257038
# Test: MSE Total = 0.469385,   MSE X = 0.224498,   MSE Z = 0.213420
#
#
# Train Epoch 5: MSE Total = 0.481271,   MSE X = 0.230868,   MSE Z = 0.216484
# Test: MSE Total = 0.478580,   MSE X = 0.231836,   MSE Z = 0.207559
#
#
# Train Epoch 6: MSE Total = 0.450579,   MSE X = 0.213772,   MSE Z = 0.210782
# Test: MSE Total = 0.468763,   MSE X = 0.225600,   MSE Z = 0.208359
#
#
# Train Epoch 7: MSE Total = 0.461795,   MSE X = 0.217081,   MSE Z = 0.222903
# Test: MSE Total = 0.501556,   MSE X = 0.246876,   MSE Z = 0.204174
#
#
# Train Epoch 8: MSE Total = 0.483681,   MSE X = 0.225854,   MSE Z = 0.238638
# Test: MSE Total = 0.424020,   MSE X = 0.194210,   MSE Z = 0.222131
#
#
# Train Epoch 9: MSE Total = 0.440519,   MSE X = 0.206245,   MSE Z = 0.215480
# Test: MSE Total = 0.398528,   MSE X = 0.186222,   MSE Z = 0.196184
#
#
# Train Epoch 10: MSE Total = 0.386716,   MSE X = 0.174755,   MSE Z = 0.210679
# Test: MSE Total = 0.455260,   MSE X = 0.185964,   MSE Z = 0.315523
#
#
# Train Epoch 11: MSE Total = 0.378142,   MSE X = 0.169617,   MSE Z = 0.210322
# Test: MSE Total = 0.323862,   MSE X = 0.143598,   MSE Z = 0.185839
#
#
# Train Epoch 12: MSE Total = 0.334369,   MSE X = 0.149584,   MSE Z = 0.187339
# Test: MSE Total = 0.300219,   MSE X = 0.131696,   MSE Z = 0.177118
#
#
# Train Epoch 13: MSE Total = 0.327146,   MSE X = 0.145155,   MSE Z = 0.187381
# Test: MSE Total = 0.274256,   MSE X = 0.117799,   MSE Z = 0.170365
#
#
# Train Epoch 14: MSE Total = 0.294789,   MSE X = 0.130378,   MSE Z = 0.170281
# Test: MSE Total = 0.288118,   MSE X = 0.128985,   MSE Z = 0.161111
#
#
# Train Epoch 15: MSE Total = 0.282703,   MSE X = 0.123322,   MSE Z = 0.169145
# Test: MSE Total = 0.272209,   MSE X = 0.120887,   MSE Z = 0.155547
#
#
# Train Epoch 16: MSE Total = 0.298133,   MSE X = 0.133728,   MSE Z = 0.165826
# Test: MSE Total = 0.262103,   MSE X = 0.110698,   MSE Z = 0.169239
#
#
# Train Epoch 17: MSE Total = 0.268523,   MSE X = 0.114110,   MSE Z = 0.170995
# Test: MSE Total = 0.262121,   MSE X = 0.107793,   MSE Z = 0.179199
#
#
# Train Epoch 18: MSE Total = 0.246823,   MSE X = 0.104318,   MSE Z = 0.159124
# Test: MSE Total = 0.248515,   MSE X = 0.100602,   MSE Z = 0.175346
#
#
# Train Epoch 19: MSE Total = 0.253107,   MSE X = 0.108015,   MSE Z = 0.159618
# Test: MSE Total = 0.264390,   MSE X = 0.120908,   MSE Z = 0.139148
#
#
# Train Epoch 20: MSE Total = 0.247028,   MSE X = 0.105733,   MSE Z = 0.154721
# Test: MSE Total = 0.237423,   MSE X = 0.097811,   MSE Z = 0.161719
#
#
# Train Epoch 21: MSE Total = 0.213335,   MSE X = 0.086929,   MSE Z = 0.148584
# Test: MSE Total = 0.264475,   MSE X = 0.105757,   MSE Z = 0.191068
#
#
# Train Epoch 22: MSE Total = 0.216719,   MSE X = 0.088561,   MSE Z = 0.150076
# Test: MSE Total = 0.197875,   MSE X = 0.080709,   MSE Z = 0.137543
#
#
# Train Epoch 23: MSE Total = 0.246493,   MSE X = 0.105926,   MSE Z = 0.152942
# Test: MSE Total = 0.251307,   MSE X = 0.105841,   MSE Z = 0.163284
#
#
# Train Epoch 24: MSE Total = 0.213213,   MSE X = 0.088108,   MSE Z = 0.144303
# Test: MSE Total = 0.196372,   MSE X = 0.079281,   MSE Z = 0.139283
#
#
# Train Epoch 25: MSE Total = 0.206606,   MSE X = 0.086170,   MSE Z = 0.137127
# Test: MSE Total = 0.208448,   MSE X = 0.087120,   MSE Z = 0.137729
#
#
# Train Epoch 26: MSE Total = 0.199418,   MSE X = 0.082392,   MSE Z = 0.135020
# Test: MSE Total = 0.178613,   MSE X = 0.073429,   MSE Z = 0.122186
#
#
# Train Epoch 27: MSE Total = 0.180221,   MSE X = 0.072509,   MSE Z = 0.128685
# Test: MSE Total = 0.186618,   MSE X = 0.074348,   MSE Z = 0.135763
#
#
# Train Epoch 28: MSE Total = 0.171589,   MSE X = 0.067687,   MSE Z = 0.127129
# Test: MSE Total = 0.186099,   MSE X = 0.078596,   MSE Z = 0.120173
#
#
# Train Epoch 29: MSE Total = 0.169554,   MSE X = 0.067966,   MSE Z = 0.121927
# Test: MSE Total = 0.187655,   MSE X = 0.078743,   MSE Z = 0.122921
#
#
# Train Epoch 30: MSE Total = 0.165832,   MSE X = 0.066779,   MSE Z = 0.118209
# Test: MSE Total = 0.186451,   MSE X = 0.076756,   MSE Z = 0.127191
#
#
# Train Epoch 31: MSE Total = 0.158350,   MSE X = 0.063884,   MSE Z = 0.112474
# Test: MSE Total = 0.171712,   MSE X = 0.074526,   MSE Z = 0.104030
#
#
# Train Epoch 32: MSE Total = 0.158194,   MSE X = 0.063809,   MSE Z = 0.112403
# Test: MSE Total = 0.173541,   MSE X = 0.074119,   MSE Z = 0.109239
#
#
# Train Epoch 33: MSE Total = 0.140501,   MSE X = 0.055303,   MSE Z = 0.104509
# Test: MSE Total = 0.135440,   MSE X = 0.054352,   MSE Z = 0.097189
#
#
# Train Epoch 34: MSE Total = 0.135995,   MSE X = 0.054194,   MSE Z = 0.098888
# Test: MSE Total = 0.150842,   MSE X = 0.062778,   MSE Z = 0.100571
#
#
# Train Epoch 35: MSE Total = 0.131099,   MSE X = 0.052418,   MSE Z = 0.094728
# Test: MSE Total = 0.170833,   MSE X = 0.073288,   MSE Z = 0.106423
#
#
# Train Epoch 36: MSE Total = 0.131631,   MSE X = 0.052431,   MSE Z = 0.095796
# Test: MSE Total = 0.142785,   MSE X = 0.060250,   MSE Z = 0.092383
#
#
# Train Epoch 37: MSE Total = 0.121672,   MSE X = 0.048785,   MSE Z = 0.087454
# Test: MSE Total = 0.147429,   MSE X = 0.053710,   MSE Z = 0.124412
#
#
# Train Epoch 38: MSE Total = 0.119853,   MSE X = 0.046956,   MSE Z = 0.089898
# Test: MSE Total = 0.143064,   MSE X = 0.062091,   MSE Z = 0.086678
#
#
# Train Epoch 39: MSE Total = 0.108922,   MSE X = 0.043536,   MSE Z = 0.078753
# Test: MSE Total = 0.128040,   MSE X = 0.056090,   MSE Z = 0.075800
#
#
# Train Epoch 40: MSE Total = 0.113487,   MSE X = 0.046258,   MSE Z = 0.078991
# Test: MSE Total = 0.127683,   MSE X = 0.055750,   MSE Z = 0.076218
#
#
# Train Epoch 41: MSE Total = 0.124681,   MSE X = 0.051643,   MSE Z = 0.083976
# Test: MSE Total = 0.210582,   MSE X = 0.104160,   MSE Z = 0.083992
#
#
# Train Epoch 42: MSE Total = 0.133321,   MSE X = 0.055132,   MSE Z = 0.090102
# Test: MSE Total = 0.114414,   MSE X = 0.047339,   MSE Z = 0.077236
#
#
# Train Epoch 43: MSE Total = 0.098536,   MSE X = 0.039470,   MSE Z = 0.070955
# Test: MSE Total = 0.111612,   MSE X = 0.049118,   MSE Z = 0.065309
#
#
# Train Epoch 44: MSE Total = 0.091760,   MSE X = 0.036120,   MSE Z = 0.068245
# Test: MSE Total = 0.103883,   MSE X = 0.045305,   MSE Z = 0.062193
#
#
# Train Epoch 45: MSE Total = 0.086329,   MSE X = 0.033573,   MSE Z = 0.065605
# Test: MSE Total = 0.097712,   MSE X = 0.041799,   MSE Z = 0.061280
#
#
# Train Epoch 46: MSE Total = 0.082329,   MSE X = 0.032219,   MSE Z = 0.061877
# Test: MSE Total = 0.117913,   MSE X = 0.051773,   MSE Z = 0.069400
#
#
# Train Epoch 47: MSE Total = 0.076910,   MSE X = 0.030201,   MSE Z = 0.057453
# Test: MSE Total = 0.092487,   MSE X = 0.039995,   MSE Z = 0.056533
#
#
# Train Epoch 48: MSE Total = 0.083827,   MSE X = 0.033060,   MSE Z = 0.062131
# Test: MSE Total = 0.084902,   MSE X = 0.036968,   MSE Z = 0.051029
#
#
# Train Epoch 49: MSE Total = 0.077992,   MSE X = 0.031222,   MSE Z = 0.056227
# Test: MSE Total = 0.088131,   MSE X = 0.034972,   MSE Z = 0.064591
#
#
# Train Epoch 50: MSE Total = 0.074038,   MSE X = 0.029127,   MSE Z = 0.055123
# Test: MSE Total = 0.082245,   MSE X = 0.031519,   MSE Z = 0.064091
#
#
# Train Epoch 51: MSE Total = 0.071731,   MSE X = 0.028530,   MSE Z = 0.052345
# Test: MSE Total = 0.077959,   MSE X = 0.033475,   MSE Z = 0.048462
#
#
# Train Epoch 52: MSE Total = 0.078111,   MSE X = 0.031728,   MSE Z = 0.054745
# Test: MSE Total = 0.073497,   MSE X = 0.030480,   MSE Z = 0.049373
#
#
# Train Epoch 53: MSE Total = 0.066828,   MSE X = 0.026662,   MSE Z = 0.048487
# Test: MSE Total = 0.098501,   MSE X = 0.042908,   MSE Z = 0.059140
#
#
# Train Epoch 54: MSE Total = 0.070766,   MSE X = 0.028608,   MSE Z = 0.050064
# Test: MSE Total = 0.077357,   MSE X = 0.033948,   MSE Z = 0.045588
#
#
# Train Epoch 55: MSE Total = 0.056105,   MSE X = 0.021720,   MSE Z = 0.042975
# Test: MSE Total = 0.072260,   MSE X = 0.030612,   MSE Z = 0.046340
#
#
# Train Epoch 56: MSE Total = 0.051735,   MSE X = 0.019315,   MSE Z = 0.042063
# Test: MSE Total = 0.063364,   MSE X = 0.026145,   MSE Z = 0.043021
#
#
# Train Epoch 57: MSE Total = 0.048916,   MSE X = 0.019023,   MSE Z = 0.037175
# Test: MSE Total = 0.089772,   MSE X = 0.037727,   MSE Z = 0.058608
#
#
# Train Epoch 58: MSE Total = 0.061099,   MSE X = 0.023836,   MSE Z = 0.046177
# Test: MSE Total = 0.058762,   MSE X = 0.024874,   MSE Z = 0.037750
#
#
# Train Epoch 59: MSE Total = 0.045147,   MSE X = 0.017360,   MSE Z = 0.034983
# Test: MSE Total = 0.056953,   MSE X = 0.023107,   MSE Z = 0.040008
#
#
# Train Epoch 60: MSE Total = 0.044931,   MSE X = 0.017173,   MSE Z = 0.035171
# Test: MSE Total = 0.056543,   MSE X = 0.023859,   MSE Z = 0.036585
#
#
# Train Epoch 61: MSE Total = 0.043362,   MSE X = 0.016256,   MSE Z = 0.035027
# Test: MSE Total = 0.061067,   MSE X = 0.025560,   MSE Z = 0.040220
#
#
# Train Epoch 62: MSE Total = 0.070822,   MSE X = 0.029199,   MSE Z = 0.048161
# Test: MSE Total = 0.112771,   MSE X = 0.052780,   MSE Z = 0.055225
#
#
# Train Epoch 63: MSE Total = 0.075230,   MSE X = 0.031013,   MSE Z = 0.051171
# Test: MSE Total = 0.067479,   MSE X = 0.028553,   MSE Z = 0.043387
#
#
# Train Epoch 64: MSE Total = 0.051068,   MSE X = 0.019901,   MSE Z = 0.038667
# Test: MSE Total = 0.053973,   MSE X = 0.022190,   MSE Z = 0.036918
#
#
# Train Epoch 65: MSE Total = 0.043572,   MSE X = 0.016759,   MSE Z = 0.033747
# Test: MSE Total = 0.043665,   MSE X = 0.018414,   MSE Z = 0.028289
#
#
# Train Epoch 66: MSE Total = 0.045744,   MSE X = 0.017781,   MSE Z = 0.034792
# Test: MSE Total = 0.057564,   MSE X = 0.024995,   MSE Z = 0.034837
#
#
# Train Epoch 67: MSE Total = 0.044775,   MSE X = 0.017787,   MSE Z = 0.032746
# Test: MSE Total = 0.067263,   MSE X = 0.030182,   MSE Z = 0.037374
#
#
# Train Epoch 68: MSE Total = 0.040085,   MSE X = 0.015850,   MSE Z = 0.029570
# Test: MSE Total = 0.065010,   MSE X = 0.029633,   MSE Z = 0.034546
#
#
# Train Epoch 69: MSE Total = 0.032600,   MSE X = 0.012317,   MSE Z = 0.026007
# Test: MSE Total = 0.044590,   MSE X = 0.019113,   MSE Z = 0.027835
#
#
# Train Epoch 70: MSE Total = 0.029559,   MSE X = 0.010582,   MSE Z = 0.025580
# Test: MSE Total = 0.042264,   MSE X = 0.017635,   MSE Z = 0.028026
#
#
# Train Epoch 71: MSE Total = 0.138211,   MSE X = 0.062572,   MSE Z = 0.074902
# Test: MSE Total = 0.252827,   MSE X = 0.117438,   MSE Z = 0.126855
#
#
# Train Epoch 72: MSE Total = 0.135112,   MSE X = 0.057359,   MSE Z = 0.086234
# Test: MSE Total = 0.127841,   MSE X = 0.060109,   MSE Z = 0.061661
#
#
# Train Epoch 73: MSE Total = 0.068117,   MSE X = 0.027304,   MSE Z = 0.048985
# Test: MSE Total = 0.059188,   MSE X = 0.026155,   MSE Z = 0.034265
#
#
# Train Epoch 74: MSE Total = 0.042894,   MSE X = 0.016442,   MSE Z = 0.033413
# Test: MSE Total = 0.060789,   MSE X = 0.025233,   MSE Z = 0.040756
#
#
# Train Epoch 75: MSE Total = 0.037083,   MSE X = 0.014033,   MSE Z = 0.029507
# Test: MSE Total = 0.049149,   MSE X = 0.021481,   MSE Z = 0.029265
#
#
# Train Epoch 76: MSE Total = 0.031658,   MSE X = 0.011596,   MSE Z = 0.026501
# Test: MSE Total = 0.043482,   MSE X = 0.018632,   MSE Z = 0.027163
#
#
# Train Epoch 77: MSE Total = 0.030006,   MSE X = 0.011170,   MSE Z = 0.024509
# Test: MSE Total = 0.047374,   MSE X = 0.018951,   MSE Z = 0.034201
#
#
# Train Epoch 78: MSE Total = 0.025807,   MSE X = 0.009325,   MSE Z = 0.022038
# Test: MSE Total = 0.040849,   MSE X = 0.017919,   MSE Z = 0.024101
#
#
# Train Epoch 79: MSE Total = 0.025209,   MSE X = 0.009202,   MSE Z = 0.021211
# Test: MSE Total = 0.038010,   MSE X = 0.016503,   MSE Z = 0.023007
#
#
# Train Epoch 80: MSE Total = 0.024812,   MSE X = 0.009196,   MSE Z = 0.020403
# Test: MSE Total = 0.041003,   MSE X = 0.017247,   MSE Z = 0.026717
#
#
# Train Epoch 81: MSE Total = 0.023792,   MSE X = 0.008833,   MSE Z = 0.019511
# Test: MSE Total = 0.038936,   MSE X = 0.016471,   MSE Z = 0.025052
#
#
# Train Epoch 82: MSE Total = 0.029633,   MSE X = 0.011002,   MSE Z = 0.024302
# Test: MSE Total = 0.066672,   MSE X = 0.029651,   MSE Z = 0.037954
#
#
# Train Epoch 83: MSE Total = 0.027812,   MSE X = 0.010198,   MSE Z = 0.023246
# Test: MSE Total = 0.038985,   MSE X = 0.016671,   MSE Z = 0.024470
#
#
# Train Epoch 84: MSE Total = 0.022635,   MSE X = 0.008105,   MSE Z = 0.019582
# Test: MSE Total = 0.059666,   MSE X = 0.027533,   MSE Z = 0.030559
#
#
# Train Epoch 85: MSE Total = 0.025538,   MSE X = 0.009665,   MSE Z = 0.020320
# Test: MSE Total = 0.038545,   MSE X = 0.016462,   MSE Z = 0.024263
#
#
# Train Epoch 86: MSE Total = 0.021672,   MSE X = 0.007660,   MSE Z = 0.019095
# Test: MSE Total = 0.033258,   MSE X = 0.014509,   MSE Z = 0.019894
#
#
# Train Epoch 87: MSE Total = 0.021211,   MSE X = 0.007705,   MSE Z = 0.017975
# Test: MSE Total = 0.035922,   MSE X = 0.014580,   MSE Z = 0.025213
#
#
# Train Epoch 88: MSE Total = 0.020009,   MSE X = 0.007170,   MSE Z = 0.017296
# Test: MSE Total = 0.032595,   MSE X = 0.013847,   MSE Z = 0.020770
#
#
# Train Epoch 89: MSE Total = 0.025571,   MSE X = 0.009633,   MSE Z = 0.020498
# Test: MSE Total = 0.108032,   MSE X = 0.038874,   MSE Z = 0.092818
#
#
# Train Epoch 90: MSE Total = 0.043734,   MSE X = 0.016643,   MSE Z = 0.034483
# Test: MSE Total = 0.053093,   MSE X = 0.022356,   MSE Z = 0.034513
#
#
# Train Epoch 91: MSE Total = 0.047452,   MSE X = 0.018821,   MSE Z = 0.034806
# Test: MSE Total = 0.079530,   MSE X = 0.033917,   MSE Z = 0.050232
#
#
# Train Epoch 92: MSE Total = 0.054808,   MSE X = 0.022089,   MSE Z = 0.039006
# Test: MSE Total = 0.074490,   MSE X = 0.031993,   MSE Z = 0.046279
#
#
# Train Epoch 93: MSE Total = 0.065741,   MSE X = 0.027347,   MSE Z = 0.043877
# Test: MSE Total = 0.092001,   MSE X = 0.038632,   MSE Z = 0.060173
#
#
# Train Epoch 94: MSE Total = 0.039869,   MSE X = 0.015306,   MSE Z = 0.030979
# Test: MSE Total = 0.060014,   MSE X = 0.027590,   MSE Z = 0.031088
#
#
# Train Epoch 95: MSE Total = 0.037091,   MSE X = 0.014703,   MSE Z = 0.027235
# Test: MSE Total = 0.043789,   MSE X = 0.018962,   MSE Z = 0.026677
#
#
# Train Epoch 96: MSE Total = 0.023973,   MSE X = 0.008937,   MSE Z = 0.019538
# Test: MSE Total = 0.042247,   MSE X = 0.018316,   MSE Z = 0.025662
#
#
# Train Epoch 97: MSE Total = 0.018945,   MSE X = 0.006580,   MSE Z = 0.017088
# Test: MSE Total = 0.032166,   MSE X = 0.013665,   MSE Z = 0.020497
#
#
# Train Epoch 98: MSE Total = 0.015831,   MSE X = 0.005640,   MSE Z = 0.013794
# Test: MSE Total = 0.030883,   MSE X = 0.013309,   MSE Z = 0.019032
#
#
# Train Epoch 99: MSE Total = 0.018771,   MSE X = 0.007027,   MSE Z = 0.015197
# Test: MSE Total = 0.034197,   MSE X = 0.014692,   MSE Z = 0.021232
#
#
# Train Epoch 100: MSE Total = 0.014985,   MSE X = 0.005235,   MSE Z = 0.013411
# Test: MSE Total = 0.030580,   MSE X = 0.013687,   MSE Z = 0.017111
#
#
# Train Epoch 101: MSE Total = 0.014216,   MSE X = 0.005013,   MSE Z = 0.012562
# Test: MSE Total = 0.029137,   MSE X = 0.012972,   MSE Z = 0.016540
#
#
# Train Epoch 102: MSE Total = 0.013488,   MSE X = 0.004732,   MSE Z = 0.012003
# Test: MSE Total = 0.030023,   MSE X = 0.013869,   MSE Z = 0.015326
#
#
# Train Epoch 103: MSE Total = 0.015072,   MSE X = 0.005358,   MSE Z = 0.013174
# Test: MSE Total = 0.037850,   MSE X = 0.015121,   MSE Z = 0.027393
#
#
# Train Epoch 104: MSE Total = 0.015407,   MSE X = 0.005280,   MSE Z = 0.014138
# Test: MSE Total = 0.029106,   MSE X = 0.012602,   MSE Z = 0.017737
#
#
# Train Epoch 105: MSE Total = 0.016074,   MSE X = 0.006022,   MSE Z = 0.013000
# Test: MSE Total = 0.058023,   MSE X = 0.024524,   MSE Z = 0.037403
#
#
# Train Epoch 106: MSE Total = 0.091128,   MSE X = 0.039560,   MSE Z = 0.055178
# Test: MSE Total = 0.201859,   MSE X = 0.090969,   MSE Z = 0.110824
#
#
# Train Epoch 107: MSE Total = 0.095825,   MSE X = 0.038938,   MSE Z = 0.067112
# Test: MSE Total = 0.070950,   MSE X = 0.028648,   MSE Z = 0.050312
#
#
# Train Epoch 108: MSE Total = 0.038891,   MSE X = 0.015103,   MSE Z = 0.029628
# Test: MSE Total = 0.039088,   MSE X = 0.016939,   MSE Z = 0.023769
#
#
# Train Epoch 109: MSE Total = 0.022161,   MSE X = 0.008112,   MSE Z = 0.018570
# Test: MSE Total = 0.033609,   MSE X = 0.014682,   MSE Z = 0.020035
#
#
# Train Epoch 110: MSE Total = 0.017725,   MSE X = 0.006248,   MSE Z = 0.015672
# Test: MSE Total = 0.032525,   MSE X = 0.014400,   MSE Z = 0.018737
#
#
# Train Epoch 111: MSE Total = 0.017763,   MSE X = 0.006542,   MSE Z = 0.014748
# Test: MSE Total = 0.028307,   MSE X = 0.012527,   MSE Z = 0.016325
#
#
# Train Epoch 112: MSE Total = 0.014580,   MSE X = 0.005205,   MSE Z = 0.012669
# Test: MSE Total = 0.026015,   MSE X = 0.011630,   MSE Z = 0.014603
#
#
# Train Epoch 113: MSE Total = 0.015219,   MSE X = 0.005467,   MSE Z = 0.013108
# Test: MSE Total = 0.034955,   MSE X = 0.014954,   MSE Z = 0.021920
#
#
# Train Epoch 114: MSE Total = 0.021561,   MSE X = 0.008028,   MSE Z = 0.017605
# Test: MSE Total = 0.030539,   MSE X = 0.013612,   MSE Z = 0.017281
#
#
# Train Epoch 115: MSE Total = 0.015000,   MSE X = 0.005298,   MSE Z = 0.013228
# Test: MSE Total = 0.026881,   MSE X = 0.011716,   MSE Z = 0.016118
#
#
# Train Epoch 116: MSE Total = 0.014313,   MSE X = 0.004931,   MSE Z = 0.013047
# Test: MSE Total = 0.027710,   MSE X = 0.012211,   MSE Z = 0.016159
#
#
# Train Epoch 117: MSE Total = 0.013039,   MSE X = 0.004544,   MSE Z = 0.011709
# Test: MSE Total = 0.026474,   MSE X = 0.011745,   MSE Z = 0.015168
#
#
# Train Epoch 118: MSE Total = 0.013202,   MSE X = 0.004591,   MSE Z = 0.011889
# Test: MSE Total = 0.026254,   MSE X = 0.011792,   MSE Z = 0.014551
#
#
# Train Epoch 119: MSE Total = 0.013093,   MSE X = 0.004497,   MSE Z = 0.011979
# Test: MSE Total = 0.029738,   MSE X = 0.012272,   MSE Z = 0.020185
#
#
# Train Epoch 120: MSE Total = 0.013555,   MSE X = 0.004548,   MSE Z = 0.012770
# Test: MSE Total = 0.026273,   MSE X = 0.012045,   MSE Z = 0.013725
#
#
# Train Epoch 121: MSE Total = 0.011691,   MSE X = 0.004136,   MSE Z = 0.010287
# Test: MSE Total = 0.025837,   MSE X = 0.011779,   MSE Z = 0.013724
#
#
# Train Epoch 122: MSE Total = 0.012194,   MSE X = 0.004258,   MSE Z = 0.010921
# Test: MSE Total = 0.029641,   MSE X = 0.013000,   MSE Z = 0.017495
#
#
# Train Epoch 123: MSE Total = 0.014396,   MSE X = 0.005188,   MSE Z = 0.012341
# Test: MSE Total = 0.039735,   MSE X = 0.015056,   MSE Z = 0.031551
#
#
# Train Epoch 124: MSE Total = 0.126270,   MSE X = 0.055375,   MSE Z = 0.074548
# Test: MSE Total = 0.115523,   MSE X = 0.048268,   MSE Z = 0.076376
#
#
# Train Epoch 125: MSE Total = 0.059141,   MSE X = 0.023668,   MSE Z = 0.042660
# Test: MSE Total = 0.048262,   MSE X = 0.021440,   MSE Z = 0.027556
#
#
# Train Epoch 126: MSE Total = 0.039651,   MSE X = 0.015514,   MSE Z = 0.029811
# Test: MSE Total = 0.048589,   MSE X = 0.021960,   MSE Z = 0.026462
#
#
# Train Epoch 127: MSE Total = 0.026721,   MSE X = 0.010505,   MSE Z = 0.019918
# Test: MSE Total = 0.030381,   MSE X = 0.012431,   MSE Z = 0.020987
#
#
# Train Epoch 128: MSE Total = 0.017852,   MSE X = 0.006463,   MSE Z = 0.015202
# Test: MSE Total = 0.029435,   MSE X = 0.012603,   MSE Z = 0.018421
#
#
# Train Epoch 129: MSE Total = 0.015633,   MSE X = 0.005618,   MSE Z = 0.013457
# Test: MSE Total = 0.023862,   MSE X = 0.010317,   MSE Z = 0.014593
#
#
# Train Epoch 130: MSE Total = 0.012656,   MSE X = 0.004424,   MSE Z = 0.011318
# Test: MSE Total = 0.027026,   MSE X = 0.011962,   MSE Z = 0.015580
#
#
# Train Epoch 131: MSE Total = 0.014247,   MSE X = 0.005045,   MSE Z = 0.012518
# Test: MSE Total = 0.023467,   MSE X = 0.010188,   MSE Z = 0.014206
#
#
# Train Epoch 132: MSE Total = 0.011178,   MSE X = 0.003834,   MSE Z = 0.010247
# Test: MSE Total = 0.023487,   MSE X = 0.010545,   MSE Z = 0.013028
#
#
# Train Epoch 133: MSE Total = 0.011760,   MSE X = 0.004167,   MSE Z = 0.010323
# Test: MSE Total = 0.023637,   MSE X = 0.010324,   MSE Z = 0.014098
#
#
# Train Epoch 134: MSE Total = 0.010671,   MSE X = 0.003644,   MSE Z = 0.009837
# Test: MSE Total = 0.020903,   MSE X = 0.008983,   MSE Z = 0.012971
#
#
# Train Epoch 135: MSE Total = 0.040559,   MSE X = 0.017312,   MSE Z = 0.025565
# Test: MSE Total = 0.260048,   MSE X = 0.122153,   MSE Z = 0.125831
#
#
# Train Epoch 136: MSE Total = 0.117194,   MSE X = 0.049691,   MSE Z = 0.075006
# Test: MSE Total = 0.051596,   MSE X = 0.019786,   MSE Z = 0.040166
#
#
# Train Epoch 137: MSE Total = 0.027393,   MSE X = 0.009995,   MSE Z = 0.023062
# Test: MSE Total = 0.037224,   MSE X = 0.014612,   MSE Z = 0.027824
#
#
# Train Epoch 138: MSE Total = 0.019546,   MSE X = 0.006783,   MSE Z = 0.017650
# Test: MSE Total = 0.032105,   MSE X = 0.013313,   MSE Z = 0.021570
#
#
# Train Epoch 139: MSE Total = 0.014847,   MSE X = 0.005135,   MSE Z = 0.013466
# Test: MSE Total = 0.026609,   MSE X = 0.011811,   MSE Z = 0.015224
#
#
# Train Epoch 140: MSE Total = 0.013088,   MSE X = 0.004482,   MSE Z = 0.012023
# Test: MSE Total = 0.024768,   MSE X = 0.010638,   MSE Z = 0.015385
#
#
# Train Epoch 141: MSE Total = 0.040904,   MSE X = 0.016963,   MSE Z = 0.027480
# Test: MSE Total = 0.100758,   MSE X = 0.040794,   MSE Z = 0.071072
#
#
# Train Epoch 142: MSE Total = 0.058995,   MSE X = 0.024109,   MSE Z = 0.040850
# Test: MSE Total = 0.040841,   MSE X = 0.016892,   MSE Z = 0.027589
#
#
# Train Epoch 143: MSE Total = 0.028085,   MSE X = 0.010736,   MSE Z = 0.021980
# Test: MSE Total = 0.036867,   MSE X = 0.016072,   MSE Z = 0.022095
#
#
# Train Epoch 144: MSE Total = 0.023071,   MSE X = 0.008862,   MSE Z = 0.017909
# Test: MSE Total = 0.032474,   MSE X = 0.013490,   MSE Z = 0.021736
#
#
# Train Epoch 145: MSE Total = 0.015761,   MSE X = 0.005619,   MSE Z = 0.013721
# Test: MSE Total = 0.028341,   MSE X = 0.011487,   MSE Z = 0.019949
#
#
# Train Epoch 146: MSE Total = 0.013474,   MSE X = 0.004638,   MSE Z = 0.012296
# Test: MSE Total = 0.023565,   MSE X = 0.010111,   MSE Z = 0.014676
#
#
# Train Epoch 147: MSE Total = 0.011780,   MSE X = 0.004144,   MSE Z = 0.010446
# Test: MSE Total = 0.025145,   MSE X = 0.011165,   MSE Z = 0.014375
#
#
# Train Epoch 148: MSE Total = 0.012173,   MSE X = 0.004297,   MSE Z = 0.010745
# Test: MSE Total = 0.026101,   MSE X = 0.011622,   MSE Z = 0.014809
#
#
# Train Epoch 149: MSE Total = 0.010858,   MSE X = 0.003712,   MSE Z = 0.009993
# Test: MSE Total = 0.023665,   MSE X = 0.010202,   MSE Z = 0.014572
#
#
# Train Epoch 150: MSE Total = 0.010593,   MSE X = 0.003598,   MSE Z = 0.009834
# Test: MSE Total = 0.024600,   MSE X = 0.011106,   MSE Z = 0.013439
#
#
# Got the weights of the epoch 134
# Execution time: 24 minutes, 52.14 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
model.load_state_dict(torch.load("model_weights_step2"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [14, 20, 32, 35, 50, 60]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.075127,   ADE X = 0.034414,   ADE Z = 0.059115
# FDE Total = 0.143524,   FDE X = 0.073357,   FDE Z = 0.107055
#
# Model performances on test set:
#
# ADE Total = 0.092366,   ADE X = 0.044158,   ADE Z = 0.070792
# FDE Total = 0.176535,   FDE X = 0.097581,   FDE Z = 0.124017

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    with np.load(file_name) as data:
        data_dict = dict(data)

    # Aggiungi la nuova coppia chiave-array
    data_dict['step2'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=14)
