# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 100
lr = 0.001
train_ratio = 0.75
num_layers = 2
hidden_size= 128
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = []

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva la nuvola sottocampionata nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10,
                  train_ratio=0.75, mode='all'):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled
        self.train_ratio = train_ratio
        self.mode = mode

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        all_files_sorted = sorted(all_files, key=extract_number)

        split_index = int(len(all_files_sorted) * train_ratio)

        if mode == "train":
            self.npz_files = all_files_sorted[:split_index]
            self.point_clouds_subsampled = point_clouds_subsampled[:split_index]
        elif mode == "test":
            self.npz_files = all_files_sorted[split_index:]
            self.point_clouds_subsampled = point_clouds_subsampled[split_index:]
        else:
            self.npz_files = all_files_sorted
            self.point_clouds_subsampled = point_clouds_subsampled

    def __len__(self):
        return len(self.npz_files)

    def local_smoothing(self, future_traj, iterations=1):
        smoothed_traj = future_traj.clone()

        for _ in range(iterations):
            temp_traj = smoothed_traj.clone()

            prev_points = temp_traj[:-2]
            current_points = temp_traj[1:-1]
            next_points = temp_traj[2:]

            smoothed_traj[1:-1] = 0.25*prev_points + 0.5*current_points + 0.25*next_points   
        
        return smoothed_traj

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx])

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        past_trajectory = torch.flip(past_trajectory, [0])

        if(self.mode == "train"):
            if(np.random.rand() < 0.5):
                n_iterations = np.random.randint(1, 3)
                future_trajectory = self.local_smoothing(future_trajectory, iterations=n_iterations)

            if np.random.rand() < 0.5:
                # Flip orizzontale
                past_trajectory[:, 0] *= -1
                future_trajectory[:, 0] *= -1
                point_clouds_subsampled[:, 0] *= -1    


        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class MyModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]

original_dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, mode="all")
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="train")

test_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="test")

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 1024, 3])

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z nel futuro

all_x_values = []
all_z_values = []

for past, future, _ in original_dataset:
    all_x_values.append(future[:, 0])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_var = torch.var(all_x_values)
global_z_var = torch.var(all_z_values)

global_x_std = global_x_var ** 0.5
global_z_std = global_z_var ** 0.5

print(f"Global variance of the future x-coordinate: {global_x_var.item()}")
print(f"Global variance of the future z-coordinate: {global_z_var.item()}")
# Out:
# Global variance of the future x-coordinate: 0.5222423076629639
# Global variance of the future z-coordinate: 2.0641021728515625

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.830955,   MSE X = 0.554020,   MSE Z = 1.529104
# Test: MSE Total = 0.859729,   MSE X = 0.466406,   MSE Z = 0.307927
#
#
# Train Epoch 2: MSE Total = 0.980980,   MSE X = 0.557099,   MSE Z = 0.301825
# Test: MSE Total = 0.814332,   MSE X = 0.444750,   MSE Z = 0.285759
#
#
# Train Epoch 3: MSE Total = 0.923435,   MSE X = 0.554136,   MSE Z = 0.225042
# Test: MSE Total = 0.753962,   MSE X = 0.443855,   MSE Z = 0.200806
#
#
# Train Epoch 4: MSE Total = 0.914323,   MSE X = 0.555253,   MSE Z = 0.209731
# Test: MSE Total = 0.721681,   MSE X = 0.443601,   MSE Z = 0.154932
#
#
# Train Epoch 5: MSE Total = 0.908674,   MSE X = 0.554728,   MSE Z = 0.202658
# Test: MSE Total = 0.764504,   MSE X = 0.480260,   MSE Z = 0.143576
#
#
# Train Epoch 6: MSE Total = 0.904086,   MSE X = 0.556978,   MSE Z = 0.191591
# Test: MSE Total = 0.719396,   MSE X = 0.446313,   MSE Z = 0.146258
#
#
# Train Epoch 7: MSE Total = 0.887116,   MSE X = 0.556012,   MSE Z = 0.169132
# Test: MSE Total = 0.746211,   MSE X = 0.443927,   MSE Z = 0.189527
#
#
# Train Epoch 8: MSE Total = 0.908572,   MSE X = 0.558054,   MSE Z = 0.195899
# Test: MSE Total = 0.718133,   MSE X = 0.449688,   MSE Z = 0.137735
#
#
# Train Epoch 9: MSE Total = 0.882590,   MSE X = 0.554511,   MSE Z = 0.165614
# Test: MSE Total = 0.820947,   MSE X = 0.464386,   MSE Z = 0.256226
#
#
# Train Epoch 10: MSE Total = 0.896524,   MSE X = 0.554736,   MSE Z = 0.185187
# Test: MSE Total = 0.721934,   MSE X = 0.448858,   MSE Z = 0.144844
#
#
# Train Epoch 11: MSE Total = 0.880066,   MSE X = 0.553199,   MSE Z = 0.164596
# Test: MSE Total = 0.742706,   MSE X = 0.442095,   MSE Z = 0.188134
#
#
# Train Epoch 12: MSE Total = 0.839139,   MSE X = 0.501799,   MSE Z = 0.207983
# Test: MSE Total = 0.654877,   MSE X = 0.364047,   MSE Z = 0.217113
#
#
# Train Epoch 13: MSE Total = 0.804365,   MSE X = 0.440406,   MSE Z = 0.280075
# Test: MSE Total = 0.754182,   MSE X = 0.380704,   MSE Z = 0.326670
#
#
# Train Epoch 14: MSE Total = 0.660847,   MSE X = 0.347081,   MSE Z = 0.259420
# Test: MSE Total = 0.545806,   MSE X = 0.296853,   MSE Z = 0.193996
#
#
# Train Epoch 15: MSE Total = 0.548162,   MSE X = 0.283333,   MSE Z = 0.224262
# Test: MSE Total = 0.580564,   MSE X = 0.318207,   MSE Z = 0.201482
#
#
# Train Epoch 16: MSE Total = 0.513202,   MSE X = 0.260512,   MSE Z = 0.219403
# Test: MSE Total = 0.592062,   MSE X = 0.321277,   MSE Z = 0.211896
#
#
# Train Epoch 17: MSE Total = 0.559167,   MSE X = 0.293162,   MSE Z = 0.220531
# Test: MSE Total = 0.498011,   MSE X = 0.260857,   MSE Z = 0.196891
#
#
# Train Epoch 18: MSE Total = 0.465692,   MSE X = 0.236035,   MSE Z = 0.199806
# Test: MSE Total = 0.374055,   MSE X = 0.189991,   MSE Z = 0.159689
#
#
# Train Epoch 19: MSE Total = 0.471300,   MSE X = 0.233815,   MSE Z = 0.212278
# Test: MSE Total = 0.430916,   MSE X = 0.179524,   MSE Z = 0.262192
#
#
# Train Epoch 20: MSE Total = 0.412630,   MSE X = 0.206638,   MSE Z = 0.182016
# Test: MSE Total = 0.439244,   MSE X = 0.236979,   MSE Z = 0.159932
#
#
# Train Epoch 21: MSE Total = 0.442454,   MSE X = 0.225319,   MSE Z = 0.187725
# Test: MSE Total = 0.336542,   MSE X = 0.161303,   MSE Z = 0.162828
#
#
# Train Epoch 22: MSE Total = 0.395368,   MSE X = 0.197904,   MSE Z = 0.174579
# Test: MSE Total = 0.364448,   MSE X = 0.182594,   MSE Z = 0.160592
#
#
# Train Epoch 23: MSE Total = 0.378091,   MSE X = 0.185403,   MSE Z = 0.174609
# Test: MSE Total = 0.360550,   MSE X = 0.170735,   MSE Z = 0.178569
#
#
# Train Epoch 24: MSE Total = 0.392013,   MSE X = 0.187614,   MSE Z = 0.190217
# Test: MSE Total = 0.315040,   MSE X = 0.158221,   MSE Z = 0.138064
#
#
# Train Epoch 25: MSE Total = 0.363339,   MSE X = 0.179373,   MSE Z = 0.165406
# Test: MSE Total = 0.342426,   MSE X = 0.165792,   MSE Z = 0.162359
#
#
# Train Epoch 26: MSE Total = 0.376734,   MSE X = 0.182265,   MSE Z = 0.178900
# Test: MSE Total = 0.337181,   MSE X = 0.179967,   MSE Z = 0.126641
#
#
# Train Epoch 27: MSE Total = 0.372500,   MSE X = 0.184656,   MSE Z = 0.168063
# Test: MSE Total = 0.374438,   MSE X = 0.189136,   MSE Z = 0.161941
#
#
# Train Epoch 28: MSE Total = 0.392439,   MSE X = 0.195406,   MSE Z = 0.175338
# Test: MSE Total = 0.331311,   MSE X = 0.172982,   MSE Z = 0.132095
#
#
# Train Epoch 29: MSE Total = 0.347883,   MSE X = 0.171286,   MSE Z = 0.159275
# Test: MSE Total = 0.331501,   MSE X = 0.168615,   MSE Z = 0.141051
#
#
# Train Epoch 30: MSE Total = 0.348884,   MSE X = 0.173285,   MSE Z = 0.156741
# Test: MSE Total = 0.311286,   MSE X = 0.161798,   MSE Z = 0.125560
#
#
# Train Epoch 31: MSE Total = 0.346833,   MSE X = 0.172092,   MSE Z = 0.156165
# Test: MSE Total = 0.364576,   MSE X = 0.182200,   MSE Z = 0.161561
#
#
# Train Epoch 32: MSE Total = 0.373052,   MSE X = 0.180910,   MSE Z = 0.176304
# Test: MSE Total = 0.301608,   MSE X = 0.149488,   MSE Z = 0.136130
#
#
# Train Epoch 33: MSE Total = 0.320778,   MSE X = 0.156220,   MSE Z = 0.150285
# Test: MSE Total = 0.403865,   MSE X = 0.219814,   MSE Z = 0.143230
#
#
# Train Epoch 34: MSE Total = 0.347813,   MSE X = 0.174981,   MSE Z = 0.151830
# Test: MSE Total = 0.398926,   MSE X = 0.180396,   MSE Z = 0.214499
#
#
# Train Epoch 35: MSE Total = 0.349950,   MSE X = 0.167418,   MSE Z = 0.169935
# Test: MSE Total = 0.318344,   MSE X = 0.155227,   MSE Z = 0.148764
#
#
# Train Epoch 36: MSE Total = 0.321481,   MSE X = 0.152884,   MSE Z = 0.157930
# Test: MSE Total = 0.295012,   MSE X = 0.146291,   MSE Z = 0.133007
#
#
# Train Epoch 37: MSE Total = 0.301149,   MSE X = 0.143553,   MSE Z = 0.147268
# Test: MSE Total = 0.348144,   MSE X = 0.185924,   MSE Z = 0.130550
#
#
# Train Epoch 38: MSE Total = 0.316367,   MSE X = 0.154712,   MSE Z = 0.146948
# Test: MSE Total = 0.351016,   MSE X = 0.190389,   MSE Z = 0.125798
#
#
# Train Epoch 39: MSE Total = 0.316579,   MSE X = 0.153093,   MSE Z = 0.150470
# Test: MSE Total = 0.301439,   MSE X = 0.151182,   MSE Z = 0.132518
#
#
# Train Epoch 40: MSE Total = 0.295839,   MSE X = 0.141891,   MSE Z = 0.142943
# Test: MSE Total = 0.307548,   MSE X = 0.157888,   MSE Z = 0.127962
#
#
# Train Epoch 41: MSE Total = 0.296261,   MSE X = 0.142120,   MSE Z = 0.143095
# Test: MSE Total = 0.350699,   MSE X = 0.191205,   MSE Z = 0.123721
#
#
# Train Epoch 42: MSE Total = 0.308210,   MSE X = 0.151321,   MSE Z = 0.141970
# Test: MSE Total = 0.314867,   MSE X = 0.154192,   MSE Z = 0.145826
#
#
# Train Epoch 43: MSE Total = 0.293182,   MSE X = 0.139933,   MSE Z = 0.143019
# Test: MSE Total = 0.341982,   MSE X = 0.180590,   MSE Z = 0.132300
#
#
# Train Epoch 44: MSE Total = 0.286090,   MSE X = 0.132903,   MSE Z = 0.146806
# Test: MSE Total = 0.333663,   MSE X = 0.167068,   MSE Z = 0.147232
#
#
# Train Epoch 45: MSE Total = 0.286048,   MSE X = 0.132586,   MSE Z = 0.147374
# Test: MSE Total = 0.325081,   MSE X = 0.167677,   MSE Z = 0.133691
#
#
# Train Epoch 46: MSE Total = 0.287216,   MSE X = 0.138461,   MSE Z = 0.137374
# Test: MSE Total = 0.372355,   MSE X = 0.203152,   MSE Z = 0.131082
#
#
# Train Epoch 47: MSE Total = 0.270759,   MSE X = 0.126259,   MSE Z = 0.137989
# Test: MSE Total = 0.309360,   MSE X = 0.159887,   MSE Z = 0.126592
#
#
# Train Epoch 48: MSE Total = 0.269695,   MSE X = 0.125037,   MSE Z = 0.138890
# Test: MSE Total = 0.336462,   MSE X = 0.170882,   MSE Z = 0.143670
#
#
# Train Epoch 49: MSE Total = 0.304718,   MSE X = 0.147933,   MSE Z = 0.143688
# Test: MSE Total = 0.351900,   MSE X = 0.179281,   MSE Z = 0.149153
#
#
# Train Epoch 50: MSE Total = 0.273682,   MSE X = 0.127282,   MSE Z = 0.140154
# Test: MSE Total = 0.295091,   MSE X = 0.149357,   MSE Z = 0.127026
#
#
# Train Epoch 51: MSE Total = 0.259866,   MSE X = 0.120372,   MSE Z = 0.134042
# Test: MSE Total = 0.327226,   MSE X = 0.173709,   MSE Z = 0.124781
#
#
# Train Epoch 52: MSE Total = 0.258891,   MSE X = 0.120428,   MSE Z = 0.132530
# Test: MSE Total = 0.323462,   MSE X = 0.146007,   MSE Z = 0.174446
#
#
# Train Epoch 53: MSE Total = 0.277874,   MSE X = 0.130100,   MSE Z = 0.140574
# Test: MSE Total = 0.340654,   MSE X = 0.167190,   MSE Z = 0.157033
#
#
# Train Epoch 54: MSE Total = 0.255439,   MSE X = 0.118238,   MSE Z = 0.131925
# Test: MSE Total = 0.324088,   MSE X = 0.166451,   MSE Z = 0.134702
#
#
# Train Epoch 55: MSE Total = 0.245473,   MSE X = 0.111652,   MSE Z = 0.130701
# Test: MSE Total = 0.287647,   MSE X = 0.139862,   MSE Z = 0.135208
#
#
# Train Epoch 56: MSE Total = 0.283468,   MSE X = 0.132165,   MSE Z = 0.144506
# Test: MSE Total = 0.319933,   MSE X = 0.162733,   MSE Z = 0.136125
#
#
# Train Epoch 57: MSE Total = 0.282562,   MSE X = 0.136287,   MSE Z = 0.135008
# Test: MSE Total = 0.357860,   MSE X = 0.188350,   MSE Z = 0.139685
#
#
# Train Epoch 58: MSE Total = 0.256775,   MSE X = 0.117424,   MSE Z = 0.135462
# Test: MSE Total = 0.340456,   MSE X = 0.177650,   MSE Z = 0.135954
#
#
# Train Epoch 59: MSE Total = 0.232455,   MSE X = 0.102462,   MSE Z = 0.130267
# Test: MSE Total = 0.328977,   MSE X = 0.165318,   MSE Z = 0.143978
#
#
# Train Epoch 60: MSE Total = 0.232269,   MSE X = 0.103154,   MSE Z = 0.128624
# Test: MSE Total = 0.315786,   MSE X = 0.161958,   MSE Z = 0.131708
#
#
# Train Epoch 61: MSE Total = 0.230825,   MSE X = 0.103328,   MSE Z = 0.126203
# Test: MSE Total = 0.316372,   MSE X = 0.159310,   MSE Z = 0.137813
#
#
# Train Epoch 62: MSE Total = 0.228397,   MSE X = 0.098874,   MSE Z = 0.131569
# Test: MSE Total = 0.328735,   MSE X = 0.161788,   MSE Z = 0.150650
#
#
# Train Epoch 63: MSE Total = 0.221359,   MSE X = 0.095980,   MSE Z = 0.127211
# Test: MSE Total = 0.294277,   MSE X = 0.149732,   MSE Z = 0.125112
#
#
# Train Epoch 64: MSE Total = 0.222066,   MSE X = 0.101091,   MSE Z = 0.118066
# Test: MSE Total = 0.350130,   MSE X = 0.179964,   MSE Z = 0.145252
#
#
# Train Epoch 65: MSE Total = 0.223369,   MSE X = 0.102200,   MSE Z = 0.117735
# Test: MSE Total = 0.441101,   MSE X = 0.188260,   MSE Z = 0.259456
#
#
# Train Epoch 66: MSE Total = 0.213726,   MSE X = 0.090523,   MSE Z = 0.127095
# Test: MSE Total = 0.345487,   MSE X = 0.178609,   MSE Z = 0.141275
#
#
# Train Epoch 67: MSE Total = 0.209085,   MSE X = 0.089731,   MSE Z = 0.122003
# Test: MSE Total = 0.363849,   MSE X = 0.184157,   MSE Z = 0.156625
#
#
# Train Epoch 68: MSE Total = 0.206453,   MSE X = 0.089820,   MSE Z = 0.118043
# Test: MSE Total = 0.299998,   MSE X = 0.149885,   MSE Z = 0.133025
#
#
# Train Epoch 69: MSE Total = 0.207647,   MSE X = 0.093396,   MSE Z = 0.112648
# Test: MSE Total = 0.317782,   MSE X = 0.154507,   MSE Z = 0.149387
#
#
# Train Epoch 70: MSE Total = 0.261092,   MSE X = 0.124460,   MSE Z = 0.127678
# Test: MSE Total = 0.325667,   MSE X = 0.167480,   MSE Z = 0.134925
#
#
# Train Epoch 71: MSE Total = 0.203009,   MSE X = 0.088529,   MSE Z = 0.115661
# Test: MSE Total = 0.336604,   MSE X = 0.161974,   MSE Z = 0.161586
#
#
# Train Epoch 72: MSE Total = 0.197059,   MSE X = 0.085582,   MSE Z = 0.112973
# Test: MSE Total = 0.323989,   MSE X = 0.159443,   MSE Z = 0.148492
#
#
# Train Epoch 73: MSE Total = 0.190022,   MSE X = 0.081119,   MSE Z = 0.111734
# Test: MSE Total = 0.381028,   MSE X = 0.209052,   MSE Z = 0.131816
#
#
# Train Epoch 74: MSE Total = 0.208888,   MSE X = 0.095021,   MSE Z = 0.111201
# Test: MSE Total = 0.405900,   MSE X = 0.211286,   MSE Z = 0.163106
#
#
# Train Epoch 75: MSE Total = 0.196296,   MSE X = 0.086829,   MSE Z = 0.109397
# Test: MSE Total = 0.323196,   MSE X = 0.168081,   MSE Z = 0.130180
#
#
# Train Epoch 76: MSE Total = 0.191570,   MSE X = 0.084979,   MSE Z = 0.106285
# Test: MSE Total = 0.393410,   MSE X = 0.210108,   MSE Z = 0.147503
#
#
# Train Epoch 77: MSE Total = 0.200904,   MSE X = 0.089716,   MSE Z = 0.110278
# Test: MSE Total = 0.355839,   MSE X = 0.176986,   MSE Z = 0.159375
#
#
# Train Epoch 78: MSE Total = 0.189482,   MSE X = 0.082428,   MSE Z = 0.108356
# Test: MSE Total = 0.286425,   MSE X = 0.139646,   MSE Z = 0.133883
#
#
# Train Epoch 79: MSE Total = 0.173910,   MSE X = 0.074433,   MSE Z = 0.101879
# Test: MSE Total = 0.302945,   MSE X = 0.148375,   MSE Z = 0.140262
#
#
# Train Epoch 80: MSE Total = 0.219068,   MSE X = 0.099097,   MSE Z = 0.117724
# Test: MSE Total = 0.373845,   MSE X = 0.176846,   MSE Z = 0.185522
#
#
# Train Epoch 81: MSE Total = 0.193306,   MSE X = 0.081801,   MSE Z = 0.115096
# Test: MSE Total = 0.320513,   MSE X = 0.165473,   MSE Z = 0.131510
#
#
# Train Epoch 82: MSE Total = 0.177957,   MSE X = 0.078202,   MSE Z = 0.100201
# Test: MSE Total = 0.359405,   MSE X = 0.180957,   MSE Z = 0.156603
#
#
# Train Epoch 83: MSE Total = 0.176144,   MSE X = 0.075438,   MSE Z = 0.103090
# Test: MSE Total = 0.341856,   MSE X = 0.176894,   MSE Z = 0.139467
#
#
# Train Epoch 84: MSE Total = 0.184126,   MSE X = 0.082562,   MSE Z = 0.100394
# Test: MSE Total = 0.345778,   MSE X = 0.170572,   MSE Z = 0.157671
#
#
# Train Epoch 85: MSE Total = 0.163766,   MSE X = 0.068365,   MSE Z = 0.099369
# Test: MSE Total = 0.323193,   MSE X = 0.161704,   MSE Z = 0.142854
#
#
# Train Epoch 86: MSE Total = 0.166407,   MSE X = 0.072101,   MSE Z = 0.095736
# Test: MSE Total = 0.369353,   MSE X = 0.180389,   MSE Z = 0.172026
#
#
# Train Epoch 87: MSE Total = 0.175285,   MSE X = 0.075412,   MSE Z = 0.101907
# Test: MSE Total = 0.330400,   MSE X = 0.155013,   MSE Z = 0.166511
#
#
# Train Epoch 88: MSE Total = 0.167715,   MSE X = 0.073028,   MSE Z = 0.095771
# Test: MSE Total = 0.324555,   MSE X = 0.160653,   MSE Z = 0.146900
#
#
# Train Epoch 89: MSE Total = 0.159577,   MSE X = 0.067726,   MSE Z = 0.094619
# Test: MSE Total = 0.303749,   MSE X = 0.146519,   MSE Z = 0.145108
#
#
# Train Epoch 90: MSE Total = 0.164561,   MSE X = 0.071451,   MSE Z = 0.094376
# Test: MSE Total = 0.348290,   MSE X = 0.177728,   MSE Z = 0.147054
#
#
# Train Epoch 91: MSE Total = 0.172825,   MSE X = 0.077922,   MSE Z = 0.093384
# Test: MSE Total = 0.346190,   MSE X = 0.173429,   MSE Z = 0.152583
#
#
# Train Epoch 92: MSE Total = 0.155300,   MSE X = 0.067199,   MSE Z = 0.089524
# Test: MSE Total = 0.317905,   MSE X = 0.159129,   MSE Z = 0.140376
#
#
# Train Epoch 93: MSE Total = 0.154151,   MSE X = 0.067649,   MSE Z = 0.086978
# Test: MSE Total = 0.310066,   MSE X = 0.151020,   MSE Z = 0.145235
#
#
# Train Epoch 94: MSE Total = 0.148048,   MSE X = 0.063738,   MSE Z = 0.085985
# Test: MSE Total = 0.409355,   MSE X = 0.222275,   MSE Z = 0.146224
#
#
# Train Epoch 95: MSE Total = 0.189725,   MSE X = 0.085141,   MSE Z = 0.103311
# Test: MSE Total = 0.313286,   MSE X = 0.161023,   MSE Z = 0.129974
#
#
# Train Epoch 96: MSE Total = 0.152236,   MSE X = 0.066485,   MSE Z = 0.086541
# Test: MSE Total = 0.377271,   MSE X = 0.205381,   MSE Z = 0.133715
#
#
# Train Epoch 97: MSE Total = 0.157746,   MSE X = 0.067946,   MSE Z = 0.091552
# Test: MSE Total = 0.354101,   MSE X = 0.178635,   MSE Z = 0.153599
#
#
# Train Epoch 98: MSE Total = 0.151633,   MSE X = 0.067232,   MSE Z = 0.084189
# Test: MSE Total = 0.333510,   MSE X = 0.171222,   MSE Z = 0.138754
#
#
# Train Epoch 99: MSE Total = 0.139286,   MSE X = 0.060163,   MSE Z = 0.080504
# Test: MSE Total = 0.328483,   MSE X = 0.164734,   MSE Z = 0.144430
#
#
# Train Epoch 100: MSE Total = 0.145738,   MSE X = 0.063899,   MSE Z = 0.082346
# Test: MSE Total = 0.308869,   MSE X = 0.146607,   MSE Z = 0.152288
#
#
# Got the weights of the epoch 78
# Execution time: 10 minutes, 6.37 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step2_autoregressive"))

model.eval()
# Out:
# MyModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=128, bias=True)
#   (pc_emb_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
model.eval()

examples = []
batch_indices = 6   # numero batch consecutivi usati
example_index = [9, 9, 9, 0, 5, 50]

# Itera sui primi 6 batch del test_loader
for b_idx, batch in enumerate(test_loader):
    if b_idx >= batch_indices:
        break

    past_batch, future_batch, pc_batch = batch
    
    examples.append((past_batch[example_index[b_idx]], future_batch[example_index[b_idx]], pc_batch[example_index[b_idx]]))

examples[3], examples[4], examples[5] = examples[4], examples[5], examples[3]    

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past_np = past.cpu().numpy()
    future_np = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past.unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc.unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past_np[:, 0], past_np[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future_np[:, 0], future_np[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.307930,   ADE X = 0.172029,   ADE Z = 0.217058
# FDE Total = 0.660940,   FDE X = 0.435795,   FDE Z = 0.407028
#
# Model performances on test set:
#
# ADE Total = 0.376047,   ADE X = 0.226147,   ADE Z = 0.249131
# FDE Total = 0.834687,   FDE X = 0.578118,   FDE Z = 0.473857

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiungi la nuova coppia chiave-array
    data_dict['step2_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
