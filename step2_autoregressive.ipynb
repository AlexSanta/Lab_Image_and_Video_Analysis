# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = []

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva la nuvola sottocampionata nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.npz_files = sorted(all_files, key=extract_number)

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx]).transpose(0, 1)

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class MyModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]

dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, past_seconds=past_seconds, 
                        future_seconds=future_seconds, framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 3, 1024])

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.3510107398033142
# Global variance of the z-coordinate: 4.372647285461426

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.371390,   MSE X = 0.516790,   MSE Z = 1.043690
# Test: MSE Total = 1.075414,   MSE X = 0.547638,   MSE Z = 0.315903
#
#
# Train Epoch 2: MSE Total = 1.015322,   MSE X = 0.515615,   MSE Z = 0.303269
# Test: MSE Total = 1.131835,   MSE X = 0.550538,   MSE Z = 0.423647
#
#
# Train Epoch 3: MSE Total = 1.007296,   MSE X = 0.519292,   MSE Z = 0.273508
# Test: MSE Total = 0.991711,   MSE X = 0.529214,   MSE Z = 0.205899
#
#
# Train Epoch 4: MSE Total = 0.890331,   MSE X = 0.448555,   MSE Z = 0.278589
# Test: MSE Total = 1.200759,   MSE X = 0.580610,   MSE Z = 0.461635
#
#
# Train Epoch 5: MSE Total = 0.992206,   MSE X = 0.509050,   MSE Z = 0.278104
# Test: MSE Total = 0.997697,   MSE X = 0.500784,   MSE Z = 0.318759
#
#
# Train Epoch 6: MSE Total = 0.841049,   MSE X = 0.400464,   MSE Z = 0.345273
# Test: MSE Total = 0.687347,   MSE X = 0.316998,   MSE Z = 0.318461
#
#
# Train Epoch 7: MSE Total = 0.605158,   MSE X = 0.281784,   MSE Z = 0.270885
# Test: MSE Total = 0.705773,   MSE X = 0.353045,   MSE Z = 0.229764
#
#
# Train Epoch 8: MSE Total = 0.573805,   MSE X = 0.264178,   MSE Z = 0.267464
# Test: MSE Total = 0.556477,   MSE X = 0.270838,   MSE Z = 0.207721
#
#
# Train Epoch 9: MSE Total = 0.540975,   MSE X = 0.256423,   MSE Z = 0.226182
# Test: MSE Total = 0.541609,   MSE X = 0.260913,   MSE Z = 0.211662
#
#
# Train Epoch 10: MSE Total = 0.543690,   MSE X = 0.257339,   MSE Z = 0.228629
# Test: MSE Total = 0.551021,   MSE X = 0.261659,   MSE Z = 0.228711
#
#
# Train Epoch 11: MSE Total = 0.512595,   MSE X = 0.242738,   MSE Z = 0.215139
# Test: MSE Total = 0.521389,   MSE X = 0.250660,   MSE Z = 0.205569
#
#
# Train Epoch 12: MSE Total = 0.505364,   MSE X = 0.239084,   MSE Z = 0.212917
# Test: MSE Total = 0.494672,   MSE X = 0.237086,   MSE Z = 0.197610
#
#
# Train Epoch 13: MSE Total = 0.465743,   MSE X = 0.218555,   MSE Z = 0.202523
# Test: MSE Total = 0.512109,   MSE X = 0.249612,   MSE Z = 0.189863
#
#
# Train Epoch 14: MSE Total = 0.464771,   MSE X = 0.217275,   MSE Z = 0.205007
# Test: MSE Total = 0.476331,   MSE X = 0.228698,   MSE Z = 0.188864
#
#
# Train Epoch 15: MSE Total = 0.445659,   MSE X = 0.205863,   MSE Z = 0.205319
# Test: MSE Total = 0.451990,   MSE X = 0.209025,   MSE Z = 0.207399
#
#
# Train Epoch 16: MSE Total = 0.421721,   MSE X = 0.194080,   MSE Z = 0.196852
# Test: MSE Total = 0.456426,   MSE X = 0.219396,   MSE Z = 0.180069
#
#
# Train Epoch 17: MSE Total = 0.420095,   MSE X = 0.194007,   MSE Z = 0.193709
# Test: MSE Total = 0.406712,   MSE X = 0.190222,   MSE Z = 0.179085
#
#
# Train Epoch 18: MSE Total = 0.390835,   MSE X = 0.179719,   MSE Z = 0.182953
# Test: MSE Total = 0.409850,   MSE X = 0.191306,   MSE Z = 0.181820
#
#
# Train Epoch 19: MSE Total = 0.372927,   MSE X = 0.166368,   MSE Z = 0.192629
# Test: MSE Total = 0.385496,   MSE X = 0.181148,   MSE Z = 0.166744
#
#
# Train Epoch 20: MSE Total = 0.350333,   MSE X = 0.155513,   MSE Z = 0.183697
# Test: MSE Total = 0.404202,   MSE X = 0.188727,   MSE Z = 0.179113
#
#
# Train Epoch 21: MSE Total = 0.340702,   MSE X = 0.151564,   MSE Z = 0.177493
# Test: MSE Total = 0.361248,   MSE X = 0.162039,   MSE Z = 0.183486
#
#
# Train Epoch 22: MSE Total = 0.328437,   MSE X = 0.146217,   MSE Z = 0.170718
# Test: MSE Total = 0.456063,   MSE X = 0.220430,   MSE Z = 0.175661
#
#
# Train Epoch 23: MSE Total = 0.312750,   MSE X = 0.138299,   MSE Z = 0.165860
# Test: MSE Total = 0.346811,   MSE X = 0.160649,   MSE Z = 0.158205
#
#
# Train Epoch 24: MSE Total = 0.314415,   MSE X = 0.136883,   MSE Z = 0.174342
# Test: MSE Total = 0.335607,   MSE X = 0.154536,   MSE Z = 0.156350
#
#
# Train Epoch 25: MSE Total = 0.306825,   MSE X = 0.133743,   MSE Z = 0.169552
# Test: MSE Total = 0.344585,   MSE X = 0.157864,   MSE Z = 0.163379
#
#
# Train Epoch 26: MSE Total = 0.292517,   MSE X = 0.127708,   MSE Z = 0.160933
# Test: MSE Total = 0.324558,   MSE X = 0.148635,   MSE Z = 0.154072
#
#
# Train Epoch 27: MSE Total = 0.276288,   MSE X = 0.118145,   MSE Z = 0.160752
# Test: MSE Total = 0.319384,   MSE X = 0.146661,   MSE Z = 0.150222
#
#
# Train Epoch 28: MSE Total = 0.292918,   MSE X = 0.124989,   MSE Z = 0.171372
# Test: MSE Total = 0.302465,   MSE X = 0.134848,   MSE Z = 0.156536
#
#
# Train Epoch 29: MSE Total = 0.270797,   MSE X = 0.117188,   MSE Z = 0.152646
# Test: MSE Total = 0.301942,   MSE X = 0.125513,   MSE Z = 0.188390
#
#
# Train Epoch 30: MSE Total = 0.276724,   MSE X = 0.117047,   MSE Z = 0.165539
# Test: MSE Total = 0.300593,   MSE X = 0.135725,   MSE Z = 0.149525
#
#
# Train Epoch 31: MSE Total = 0.256861,   MSE X = 0.108384,   MSE Z = 0.154578
# Test: MSE Total = 0.298471,   MSE X = 0.133512,   MSE Z = 0.152901
#
#
# Train Epoch 32: MSE Total = 0.242082,   MSE X = 0.099633,   MSE Z = 0.154560
# Test: MSE Total = 0.266294,   MSE X = 0.117206,   MSE Z = 0.143166
#
#
# Train Epoch 33: MSE Total = 0.243163,   MSE X = 0.100896,   MSE Z = 0.152363
# Test: MSE Total = 0.265623,   MSE X = 0.113574,   MSE Z = 0.154584
#
#
# Train Epoch 34: MSE Total = 0.245310,   MSE X = 0.103287,   MSE Z = 0.148416
# Test: MSE Total = 0.291734,   MSE X = 0.132928,   MSE Z = 0.140875
#
#
# Train Epoch 35: MSE Total = 0.225689,   MSE X = 0.092469,   MSE Z = 0.145569
# Test: MSE Total = 0.263122,   MSE X = 0.114024,   MSE Z = 0.147765
#
#
# Train Epoch 36: MSE Total = 0.222038,   MSE X = 0.091012,   MSE Z = 0.143075
# Test: MSE Total = 0.269543,   MSE X = 0.115018,   MSE Z = 0.157683
#
#
# Train Epoch 37: MSE Total = 0.234656,   MSE X = 0.095996,   MSE Z = 0.151868
# Test: MSE Total = 0.268664,   MSE X = 0.116815,   MSE Z = 0.149502
#
#
# Train Epoch 38: MSE Total = 0.227143,   MSE X = 0.094049,   MSE Z = 0.143031
# Test: MSE Total = 0.257412,   MSE X = 0.113584,   MSE Z = 0.137378
#
#
# Train Epoch 39: MSE Total = 0.192421,   MSE X = 0.076819,   MSE Z = 0.131237
# Test: MSE Total = 0.235478,   MSE X = 0.100484,   MSE Z = 0.137748
#
#
# Train Epoch 40: MSE Total = 0.186564,   MSE X = 0.074803,   MSE Z = 0.126104
# Test: MSE Total = 0.223932,   MSE X = 0.092952,   MSE Z = 0.140187
#
#
# Train Epoch 41: MSE Total = 0.196853,   MSE X = 0.079965,   MSE Z = 0.129399
# Test: MSE Total = 0.248041,   MSE X = 0.108906,   MSE Z = 0.134294
#
#
# Train Epoch 42: MSE Total = 0.194802,   MSE X = 0.077740,   MSE Z = 0.132963
# Test: MSE Total = 0.240358,   MSE X = 0.104491,   MSE Z = 0.133811
#
#
# Train Epoch 43: MSE Total = 0.176755,   MSE X = 0.069156,   MSE Z = 0.125524
# Test: MSE Total = 0.212514,   MSE X = 0.089320,   MSE Z = 0.129132
#
#
# Train Epoch 44: MSE Total = 0.184014,   MSE X = 0.073682,   MSE Z = 0.124728
# Test: MSE Total = 0.226833,   MSE X = 0.093532,   MSE Z = 0.144206
#
#
# Train Epoch 45: MSE Total = 0.174780,   MSE X = 0.068394,   MSE Z = 0.124084
# Test: MSE Total = 0.209172,   MSE X = 0.088938,   MSE Z = 0.123494
#
#
# Train Epoch 46: MSE Total = 0.184334,   MSE X = 0.073852,   MSE Z = 0.124799
# Test: MSE Total = 0.242201,   MSE X = 0.100518,   MSE Z = 0.151687
#
#
# Train Epoch 47: MSE Total = 0.191921,   MSE X = 0.076794,   MSE Z = 0.130281
# Test: MSE Total = 0.227097,   MSE X = 0.098212,   MSE Z = 0.128243
#
#
# Train Epoch 48: MSE Total = 0.177021,   MSE X = 0.070241,   MSE Z = 0.122251
# Test: MSE Total = 0.214539,   MSE X = 0.089759,   MSE Z = 0.131815
#
#
# Train Epoch 49: MSE Total = 0.157045,   MSE X = 0.061270,   MSE Z = 0.112144
# Test: MSE Total = 0.193764,   MSE X = 0.080599,   MSE Z = 0.120706
#
#
# Train Epoch 50: MSE Total = 0.171998,   MSE X = 0.068070,   MSE Z = 0.119410
# Test: MSE Total = 0.234504,   MSE X = 0.101955,   MSE Z = 0.130522
#
#
# Train Epoch 51: MSE Total = 0.160299,   MSE X = 0.062484,   MSE Z = 0.114661
# Test: MSE Total = 0.191693,   MSE X = 0.080120,   MSE Z = 0.118063
#
#
# Train Epoch 52: MSE Total = 0.156298,   MSE X = 0.061134,   MSE Z = 0.111060
# Test: MSE Total = 0.190390,   MSE X = 0.081764,   MSE Z = 0.109537
#
#
# Train Epoch 53: MSE Total = 0.158976,   MSE X = 0.062406,   MSE Z = 0.112171
# Test: MSE Total = 0.185492,   MSE X = 0.077612,   MSE Z = 0.113949
#
#
# Train Epoch 54: MSE Total = 0.133837,   MSE X = 0.051556,   MSE Z = 0.097899
# Test: MSE Total = 0.171976,   MSE X = 0.072552,   MSE Z = 0.103545
#
#
# Train Epoch 55: MSE Total = 0.136128,   MSE X = 0.051702,   MSE Z = 0.102176
# Test: MSE Total = 0.189349,   MSE X = 0.077088,   MSE Z = 0.123862
#
#
# Train Epoch 56: MSE Total = 0.139997,   MSE X = 0.052694,   MSE Z = 0.106762
# Test: MSE Total = 0.173874,   MSE X = 0.073029,   MSE Z = 0.105829
#
#
# Train Epoch 57: MSE Total = 0.127747,   MSE X = 0.048928,   MSE Z = 0.094441
# Test: MSE Total = 0.174635,   MSE X = 0.073948,   MSE Z = 0.104180
#
#
# Train Epoch 58: MSE Total = 0.134207,   MSE X = 0.052354,   MSE Z = 0.095855
# Test: MSE Total = 0.173890,   MSE X = 0.072144,   MSE Z = 0.108987
#
#
# Train Epoch 59: MSE Total = 0.130383,   MSE X = 0.049476,   MSE Z = 0.098018
# Test: MSE Total = 0.173462,   MSE X = 0.070374,   MSE Z = 0.114341
#
#
# Train Epoch 60: MSE Total = 0.129180,   MSE X = 0.049593,   MSE Z = 0.095088
# Test: MSE Total = 0.190322,   MSE X = 0.080251,   MSE Z = 0.114736
#
#
# Train Epoch 61: MSE Total = 0.142472,   MSE X = 0.056214,   MSE Z = 0.099513
# Test: MSE Total = 0.166784,   MSE X = 0.069809,   MSE Z = 0.102369
#
#
# Train Epoch 62: MSE Total = 0.110802,   MSE X = 0.041831,   MSE Z = 0.084055
# Test: MSE Total = 0.160054,   MSE X = 0.068321,   MSE Z = 0.093549
#
#
# Train Epoch 63: MSE Total = 0.112268,   MSE X = 0.043732,   MSE Z = 0.080412
# Test: MSE Total = 0.153401,   MSE X = 0.064813,   MSE Z = 0.092017
#
#
# Train Epoch 64: MSE Total = 0.128064,   MSE X = 0.051359,   MSE Z = 0.086523
# Test: MSE Total = 0.188137,   MSE X = 0.078395,   MSE Z = 0.116717
#
#
# Train Epoch 65: MSE Total = 0.150851,   MSE X = 0.061502,   MSE Z = 0.098369
# Test: MSE Total = 0.185648,   MSE X = 0.078772,   MSE Z = 0.110179
#
#
# Train Epoch 66: MSE Total = 0.117496,   MSE X = 0.045293,   MSE Z = 0.085834
# Test: MSE Total = 0.169492,   MSE X = 0.073886,   MSE Z = 0.093645
#
#
# Train Epoch 67: MSE Total = 0.102567,   MSE X = 0.039409,   MSE Z = 0.075383
# Test: MSE Total = 0.180147,   MSE X = 0.079186,   MSE Z = 0.097216
#
#
# Train Epoch 68: MSE Total = 0.108047,   MSE X = 0.041614,   MSE Z = 0.079058
# Test: MSE Total = 0.145422,   MSE X = 0.063065,   MSE Z = 0.081502
#
#
# Train Epoch 69: MSE Total = 0.092056,   MSE X = 0.034182,   MSE Z = 0.071852
# Test: MSE Total = 0.149617,   MSE X = 0.064429,   MSE Z = 0.085463
#
#
# Train Epoch 70: MSE Total = 0.090460,   MSE X = 0.035676,   MSE Z = 0.063242
# Test: MSE Total = 0.163077,   MSE X = 0.071692,   MSE Z = 0.087971
#
#
# Train Epoch 71: MSE Total = 0.130866,   MSE X = 0.051666,   MSE Z = 0.091297
# Test: MSE Total = 0.166004,   MSE X = 0.072988,   MSE Z = 0.089518
#
#
# Train Epoch 72: MSE Total = 0.107366,   MSE X = 0.041297,   MSE Z = 0.078757
# Test: MSE Total = 0.149087,   MSE X = 0.063435,   MSE Z = 0.087862
#
#
# Train Epoch 73: MSE Total = 0.083918,   MSE X = 0.031056,   MSE Z = 0.065869
# Test: MSE Total = 0.140470,   MSE X = 0.058907,   MSE Z = 0.085824
#
#
# Train Epoch 74: MSE Total = 0.074824,   MSE X = 0.027377,   MSE Z = 0.059836
# Test: MSE Total = 0.136215,   MSE X = 0.058871,   MSE Z = 0.077052
#
#
# Train Epoch 75: MSE Total = 0.079866,   MSE X = 0.030200,   MSE Z = 0.060416
# Test: MSE Total = 0.162126,   MSE X = 0.069639,   MSE Z = 0.093229
#
#
# Train Epoch 76: MSE Total = 0.087831,   MSE X = 0.033735,   MSE Z = 0.064595
# Test: MSE Total = 0.137007,   MSE X = 0.058224,   MSE Z = 0.080994
#
#
# Train Epoch 77: MSE Total = 0.093631,   MSE X = 0.036483,   MSE Z = 0.067027
# Test: MSE Total = 0.142240,   MSE X = 0.061024,   MSE Z = 0.082053
#
#
# Train Epoch 78: MSE Total = 0.077581,   MSE X = 0.029263,   MSE Z = 0.058946
# Test: MSE Total = 0.136425,   MSE X = 0.058622,   MSE Z = 0.078371
#
#
# Train Epoch 79: MSE Total = 0.064452,   MSE X = 0.023670,   MSE Z = 0.051232
# Test: MSE Total = 0.139781,   MSE X = 0.057943,   MSE Z = 0.087786
#
#
# Train Epoch 80: MSE Total = 0.059600,   MSE X = 0.022262,   MSE Z = 0.046056
# Test: MSE Total = 0.130181,   MSE X = 0.056325,   MSE Z = 0.073424
#
#
# Train Epoch 81: MSE Total = 0.062024,   MSE X = 0.023111,   MSE Z = 0.048128
# Test: MSE Total = 0.128255,   MSE X = 0.055506,   MSE Z = 0.072285
#
#
# Train Epoch 82: MSE Total = 0.061339,   MSE X = 0.022551,   MSE Z = 0.048672
# Test: MSE Total = 0.119990,   MSE X = 0.050080,   MSE Z = 0.074153
#
#
# Train Epoch 83: MSE Total = 0.063468,   MSE X = 0.024160,   MSE Z = 0.047446
# Test: MSE Total = 0.125525,   MSE X = 0.053437,   MSE Z = 0.073879
#
#
# Train Epoch 84: MSE Total = 0.056662,   MSE X = 0.020665,   MSE Z = 0.045546
# Test: MSE Total = 0.124788,   MSE X = 0.053888,   MSE Z = 0.070747
#
#
# Train Epoch 85: MSE Total = 0.058779,   MSE X = 0.021564,   MSE Z = 0.046802
# Test: MSE Total = 0.116359,   MSE X = 0.049613,   MSE Z = 0.068209
#
#
# Train Epoch 86: MSE Total = 0.056235,   MSE X = 0.021123,   MSE Z = 0.043040
# Test: MSE Total = 0.117749,   MSE X = 0.050238,   MSE Z = 0.068909
#
#
# Train Epoch 87: MSE Total = 0.057300,   MSE X = 0.020600,   MSE Z = 0.047112
# Test: MSE Total = 0.121253,   MSE X = 0.050897,   MSE Z = 0.073911
#
#
# Train Epoch 88: MSE Total = 0.053193,   MSE X = 0.019342,   MSE Z = 0.042962
# Test: MSE Total = 0.116136,   MSE X = 0.048716,   MSE Z = 0.070907
#
#
# Train Epoch 89: MSE Total = 0.048093,   MSE X = 0.016611,   MSE Z = 0.041938
# Test: MSE Total = 0.111541,   MSE X = 0.047803,   MSE Z = 0.064523
#
#
# Train Epoch 90: MSE Total = 0.045587,   MSE X = 0.016334,   MSE Z = 0.037675
# Test: MSE Total = 0.115297,   MSE X = 0.050147,   MSE Z = 0.064104
#
#
# Train Epoch 91: MSE Total = 0.046535,   MSE X = 0.016992,   MSE Z = 0.037334
# Test: MSE Total = 0.115170,   MSE X = 0.049679,   MSE Z = 0.065489
#
#
# Train Epoch 92: MSE Total = 0.046706,   MSE X = 0.016790,   MSE Z = 0.038407
# Test: MSE Total = 0.125438,   MSE X = 0.054075,   MSE Z = 0.071442
#
#
# Train Epoch 93: MSE Total = 0.051192,   MSE X = 0.019176,   MSE Z = 0.039365
# Test: MSE Total = 0.114774,   MSE X = 0.048113,   MSE Z = 0.070188
#
#
# Train Epoch 94: MSE Total = 0.047669,   MSE X = 0.018147,   MSE Z = 0.035630
# Test: MSE Total = 0.112489,   MSE X = 0.046809,   MSE Z = 0.070012
#
#
# Train Epoch 95: MSE Total = 0.047425,   MSE X = 0.017351,   MSE Z = 0.037930
# Test: MSE Total = 0.115687,   MSE X = 0.049313,   MSE Z = 0.067864
#
#
# Train Epoch 96: MSE Total = 0.090702,   MSE X = 0.035285,   MSE Z = 0.065128
# Test: MSE Total = 0.176188,   MSE X = 0.080414,   MSE Z = 0.084605
#
#
# Train Epoch 97: MSE Total = 0.089249,   MSE X = 0.034264,   MSE Z = 0.065694
# Test: MSE Total = 0.138946,   MSE X = 0.057414,   MSE Z = 0.087906
#
#
# Train Epoch 98: MSE Total = 0.062791,   MSE X = 0.022973,   MSE Z = 0.050220
# Test: MSE Total = 0.120663,   MSE X = 0.050433,   MSE Z = 0.074313
#
#
# Train Epoch 99: MSE Total = 0.044338,   MSE X = 0.015558,   MSE Z = 0.037803
# Test: MSE Total = 0.118391,   MSE X = 0.049814,   MSE Z = 0.071746
#
#
# Train Epoch 100: MSE Total = 0.044101,   MSE X = 0.015533,   MSE Z = 0.037396
# Test: MSE Total = 0.108601,   MSE X = 0.046439,   MSE Z = 0.063189
#
#
# Train Epoch 101: MSE Total = 0.042423,   MSE X = 0.015180,   MSE Z = 0.035134
# Test: MSE Total = 0.125757,   MSE X = 0.052902,   MSE Z = 0.076251
#
#
# Train Epoch 102: MSE Total = 0.047100,   MSE X = 0.016819,   MSE Z = 0.039128
# Test: MSE Total = 0.110150,   MSE X = 0.047611,   MSE Z = 0.062290
#
#
# Train Epoch 103: MSE Total = 0.065778,   MSE X = 0.025967,   MSE Z = 0.045897
# Test: MSE Total = 0.139956,   MSE X = 0.059278,   MSE Z = 0.083437
#
#
# Train Epoch 104: MSE Total = 0.084255,   MSE X = 0.033284,   MSE Z = 0.058710
# Test: MSE Total = 0.155073,   MSE X = 0.065417,   MSE Z = 0.093381
#
#
# Train Epoch 105: MSE Total = 0.052029,   MSE X = 0.019109,   MSE Z = 0.041350
# Test: MSE Total = 0.113001,   MSE X = 0.047406,   MSE Z = 0.068975
#
#
# Train Epoch 106: MSE Total = 0.038441,   MSE X = 0.013558,   MSE Z = 0.032530
# Test: MSE Total = 0.110223,   MSE X = 0.048383,   MSE Z = 0.059719
#
#
# Train Epoch 107: MSE Total = 0.041063,   MSE X = 0.014953,   MSE Z = 0.033092
# Test: MSE Total = 0.102959,   MSE X = 0.041992,   MSE Z = 0.067087
#
#
# Train Epoch 108: MSE Total = 0.044812,   MSE X = 0.016870,   MSE Z = 0.034164
# Test: MSE Total = 0.120517,   MSE X = 0.052496,   MSE Z = 0.066727
#
#
# Train Epoch 109: MSE Total = 0.059507,   MSE X = 0.022593,   MSE Z = 0.044693
# Test: MSE Total = 0.105902,   MSE X = 0.044711,   MSE Z = 0.063643
#
#
# Train Epoch 110: MSE Total = 0.037201,   MSE X = 0.013401,   MSE Z = 0.030492
# Test: MSE Total = 0.104863,   MSE X = 0.044735,   MSE Z = 0.061386
#
#
# Train Epoch 111: MSE Total = 0.032280,   MSE X = 0.011560,   MSE Z = 0.026698
# Test: MSE Total = 0.100029,   MSE X = 0.043049,   MSE Z = 0.057228
#
#
# Train Epoch 112: MSE Total = 0.034188,   MSE X = 0.011859,   MSE Z = 0.029636
# Test: MSE Total = 0.104850,   MSE X = 0.045284,   MSE Z = 0.059423
#
#
# Train Epoch 113: MSE Total = 0.028397,   MSE X = 0.010053,   MSE Z = 0.023899
# Test: MSE Total = 0.095189,   MSE X = 0.040199,   MSE Z = 0.057164
#
#
# Train Epoch 114: MSE Total = 0.027235,   MSE X = 0.009453,   MSE Z = 0.023586
# Test: MSE Total = 0.097436,   MSE X = 0.041235,   MSE Z = 0.058207
#
#
# Train Epoch 115: MSE Total = 0.026140,   MSE X = 0.009109,   MSE Z = 0.022511
# Test: MSE Total = 0.100394,   MSE X = 0.042875,   MSE Z = 0.058606
#
#
# Train Epoch 116: MSE Total = 0.027209,   MSE X = 0.009663,   MSE Z = 0.022790
# Test: MSE Total = 0.104064,   MSE X = 0.045747,   MSE Z = 0.056144
#
#
# Train Epoch 117: MSE Total = 0.027399,   MSE X = 0.009572,   MSE Z = 0.023510
# Test: MSE Total = 0.103999,   MSE X = 0.045015,   MSE Z = 0.058591
#
#
# Train Epoch 118: MSE Total = 0.025902,   MSE X = 0.008956,   MSE Z = 0.022554
# Test: MSE Total = 0.092068,   MSE X = 0.038929,   MSE Z = 0.055122
#
#
# Train Epoch 119: MSE Total = 0.022949,   MSE X = 0.007715,   MSE Z = 0.020758
# Test: MSE Total = 0.095552,   MSE X = 0.040167,   MSE Z = 0.058040
#
#
# Train Epoch 120: MSE Total = 0.022463,   MSE X = 0.007763,   MSE Z = 0.019572
# Test: MSE Total = 0.096879,   MSE X = 0.042003,   MSE Z = 0.054333
#
#
# Train Epoch 121: MSE Total = 0.023356,   MSE X = 0.007975,   MSE Z = 0.020694
# Test: MSE Total = 0.097901,   MSE X = 0.041692,   MSE Z = 0.057569
#
#
# Train Epoch 122: MSE Total = 0.025714,   MSE X = 0.009066,   MSE Z = 0.021773
# Test: MSE Total = 0.097264,   MSE X = 0.042331,   MSE Z = 0.053982
#
#
# Train Epoch 123: MSE Total = 0.024344,   MSE X = 0.008370,   MSE Z = 0.021362
# Test: MSE Total = 0.093647,   MSE X = 0.039122,   MSE Z = 0.057743
#
#
# Train Epoch 124: MSE Total = 0.028532,   MSE X = 0.010114,   MSE Z = 0.023966
# Test: MSE Total = 0.101753,   MSE X = 0.043062,   MSE Z = 0.060790
#
#
# Train Epoch 125: MSE Total = 0.029566,   MSE X = 0.010590,   MSE Z = 0.024446
# Test: MSE Total = 0.114189,   MSE X = 0.048684,   MSE Z = 0.066948
#
#
# Train Epoch 126: MSE Total = 0.090215,   MSE X = 0.036996,   MSE Z = 0.058071
# Test: MSE Total = 0.208982,   MSE X = 0.090928,   MSE Z = 0.116069
#
#
# Train Epoch 127: MSE Total = 0.126379,   MSE X = 0.051899,   MSE Z = 0.081093
# Test: MSE Total = 0.180126,   MSE X = 0.081120,   MSE Z = 0.090347
#
#
# Train Epoch 128: MSE Total = 0.061369,   MSE X = 0.023159,   MSE Z = 0.046589
# Test: MSE Total = 0.118075,   MSE X = 0.050785,   MSE Z = 0.067660
#
#
# Train Epoch 129: MSE Total = 0.043929,   MSE X = 0.016477,   MSE Z = 0.033704
# Test: MSE Total = 0.120024,   MSE X = 0.050422,   MSE Z = 0.073017
#
#
# Train Epoch 130: MSE Total = 0.038880,   MSE X = 0.014707,   MSE Z = 0.029395
# Test: MSE Total = 0.106601,   MSE X = 0.046248,   MSE Z = 0.059680
#
#
# Train Epoch 131: MSE Total = 0.027980,   MSE X = 0.009974,   MSE Z = 0.023305
# Test: MSE Total = 0.098848,   MSE X = 0.043022,   MSE Z = 0.054855
#
#
# Train Epoch 132: MSE Total = 0.038738,   MSE X = 0.015088,   MSE Z = 0.027751
# Test: MSE Total = 0.140058,   MSE X = 0.061205,   MSE Z = 0.076851
#
#
# Train Epoch 133: MSE Total = 0.067380,   MSE X = 0.026924,   MSE Z = 0.045869
# Test: MSE Total = 0.117226,   MSE X = 0.048906,   MSE Z = 0.072517
#
#
# Train Epoch 134: MSE Total = 0.038961,   MSE X = 0.014148,   MSE Z = 0.031537
# Test: MSE Total = 0.115971,   MSE X = 0.050934,   MSE Z = 0.062734
#
#
# Train Epoch 135: MSE Total = 0.033720,   MSE X = 0.011896,   MSE Z = 0.028525
# Test: MSE Total = 0.099272,   MSE X = 0.042176,   MSE Z = 0.058727
#
#
# Train Epoch 136: MSE Total = 0.034395,   MSE X = 0.012490,   MSE Z = 0.027840
# Test: MSE Total = 0.123151,   MSE X = 0.054171,   MSE Z = 0.066323
#
#
# Train Epoch 137: MSE Total = 0.030836,   MSE X = 0.011101,   MSE Z = 0.025300
# Test: MSE Total = 0.101292,   MSE X = 0.042462,   MSE Z = 0.061942
#
#
# Train Epoch 138: MSE Total = 0.026540,   MSE X = 0.009458,   MSE Z = 0.022117
# Test: MSE Total = 0.100325,   MSE X = 0.043837,   MSE Z = 0.055066
#
#
# Train Epoch 139: MSE Total = 0.026861,   MSE X = 0.009503,   MSE Z = 0.022625
# Test: MSE Total = 0.104680,   MSE X = 0.043441,   MSE Z = 0.065570
#
#
# Train Epoch 140: MSE Total = 0.023642,   MSE X = 0.007947,   MSE Z = 0.021386
# Test: MSE Total = 0.097626,   MSE X = 0.040721,   MSE Z = 0.060422
#
#
# Train Epoch 141: MSE Total = 0.022498,   MSE X = 0.007912,   MSE Z = 0.019120
# Test: MSE Total = 0.096279,   MSE X = 0.040583,   MSE Z = 0.058092
#
#
# Train Epoch 142: MSE Total = 0.018759,   MSE X = 0.006251,   MSE Z = 0.017166
# Test: MSE Total = 0.089578,   MSE X = 0.038467,   MSE Z = 0.051549
#
#
# Train Epoch 143: MSE Total = 0.016602,   MSE X = 0.005577,   MSE Z = 0.015032
# Test: MSE Total = 0.092055,   MSE X = 0.038951,   MSE Z = 0.055019
#
#
# Train Epoch 144: MSE Total = 0.016365,   MSE X = 0.005522,   MSE Z = 0.014730
# Test: MSE Total = 0.092519,   MSE X = 0.039146,   MSE Z = 0.055302
#
#
# Train Epoch 145: MSE Total = 0.017440,   MSE X = 0.006065,   MSE Z = 0.015063
# Test: MSE Total = 0.096723,   MSE X = 0.041382,   MSE Z = 0.056199
#
#
# Train Epoch 146: MSE Total = 0.016530,   MSE X = 0.005481,   MSE Z = 0.015219
# Test: MSE Total = 0.093284,   MSE X = 0.039356,   MSE Z = 0.056158
#
#
# Train Epoch 147: MSE Total = 0.015501,   MSE X = 0.005095,   MSE Z = 0.014432
# Test: MSE Total = 0.090884,   MSE X = 0.038505,   MSE Z = 0.054146
#
#
# Train Epoch 148: MSE Total = 0.015918,   MSE X = 0.005385,   MSE Z = 0.014279
# Test: MSE Total = 0.089090,   MSE X = 0.037714,   MSE Z = 0.053184
#
#
# Train Epoch 149: MSE Total = 0.016468,   MSE X = 0.005726,   MSE Z = 0.014226
# Test: MSE Total = 0.089943,   MSE X = 0.038322,   MSE Z = 0.052823
#
#
# Train Epoch 150: MSE Total = 0.015328,   MSE X = 0.005089,   MSE Z = 0.014088
# Test: MSE Total = 0.090022,   MSE X = 0.037626,   MSE Z = 0.055441
#
#
# Train Epoch 151: MSE Total = 0.018184,   MSE X = 0.006056,   MSE Z = 0.016651
# Test: MSE Total = 0.091500,   MSE X = 0.038233,   MSE Z = 0.056394
#
#
# Train Epoch 152: MSE Total = 0.017785,   MSE X = 0.006050,   MSE Z = 0.015836
# Test: MSE Total = 0.089565,   MSE X = 0.038506,   MSE Z = 0.051382
#
#
# Train Epoch 153: MSE Total = 0.014913,   MSE X = 0.004972,   MSE Z = 0.013638
# Test: MSE Total = 0.097302,   MSE X = 0.042289,   MSE Z = 0.054207
#
#
# Train Epoch 154: MSE Total = 0.015331,   MSE X = 0.005225,   MSE Z = 0.013617
# Test: MSE Total = 0.089383,   MSE X = 0.037938,   MSE Z = 0.053004
#
#
# Train Epoch 155: MSE Total = 0.017004,   MSE X = 0.005623,   MSE Z = 0.015710
# Test: MSE Total = 0.093892,   MSE X = 0.039528,   MSE Z = 0.056824
#
#
# Train Epoch 156: MSE Total = 0.016429,   MSE X = 0.005604,   MSE Z = 0.014575
# Test: MSE Total = 0.095467,   MSE X = 0.040546,   MSE Z = 0.056523
#
#
# Train Epoch 157: MSE Total = 0.017157,   MSE X = 0.005811,   MSE Z = 0.015366
# Test: MSE Total = 0.091142,   MSE X = 0.038642,   MSE Z = 0.054199
#
#
# Train Epoch 158: MSE Total = 0.015109,   MSE X = 0.004991,   MSE Z = 0.013980
# Test: MSE Total = 0.090531,   MSE X = 0.038490,   MSE Z = 0.053460
#
#
# Train Epoch 159: MSE Total = 0.028536,   MSE X = 0.011124,   MSE Z = 0.020410
# Test: MSE Total = 0.107101,   MSE X = 0.045757,   MSE Z = 0.062458
#
#
# Train Epoch 160: MSE Total = 0.030949,   MSE X = 0.011638,   MSE Z = 0.023643
# Test: MSE Total = 0.104607,   MSE X = 0.045071,   MSE Z = 0.059662
#
#
# Train Epoch 161: MSE Total = 0.030706,   MSE X = 0.011676,   MSE Z = 0.023000
# Test: MSE Total = 0.131040,   MSE X = 0.056253,   MSE Z = 0.075472
#
#
# Train Epoch 162: MSE Total = 0.042413,   MSE X = 0.016316,   MSE Z = 0.031101
# Test: MSE Total = 0.117558,   MSE X = 0.049920,   MSE Z = 0.069630
#
#
# Train Epoch 163: MSE Total = 0.063109,   MSE X = 0.025763,   MSE Z = 0.041036
# Test: MSE Total = 0.132590,   MSE X = 0.057419,   MSE Z = 0.074597
#
#
# Train Epoch 164: MSE Total = 0.118584,   MSE X = 0.054109,   MSE Z = 0.056990
# Test: MSE Total = 0.181545,   MSE X = 0.077087,   MSE Z = 0.107550
#
#
# Train Epoch 165: MSE Total = 0.125562,   MSE X = 0.050743,   MSE Z = 0.083463
# Test: MSE Total = 0.162420,   MSE X = 0.070638,   MSE Z = 0.090319
#
#
# Train Epoch 166: MSE Total = 0.124964,   MSE X = 0.052501,   MSE Z = 0.076010
# Test: MSE Total = 0.144647,   MSE X = 0.063081,   MSE Z = 0.079826
#
#
# Train Epoch 167: MSE Total = 0.057215,   MSE X = 0.021146,   MSE Z = 0.045006
# Test: MSE Total = 0.105390,   MSE X = 0.045486,   MSE Z = 0.059840
#
#
# Train Epoch 168: MSE Total = 0.030163,   MSE X = 0.010608,   MSE Z = 0.025634
# Test: MSE Total = 0.099736,   MSE X = 0.042512,   MSE Z = 0.058511
#
#
# Train Epoch 169: MSE Total = 0.030529,   MSE X = 0.011303,   MSE Z = 0.023944
# Test: MSE Total = 0.097760,   MSE X = 0.040403,   MSE Z = 0.061824
#
#
# Train Epoch 170: MSE Total = 0.023825,   MSE X = 0.008590,   MSE Z = 0.019501
# Test: MSE Total = 0.089069,   MSE X = 0.037633,   MSE Z = 0.053423
#
#
# Train Epoch 171: MSE Total = 0.019732,   MSE X = 0.006735,   MSE Z = 0.017488
# Test: MSE Total = 0.089058,   MSE X = 0.038005,   MSE Z = 0.052090
#
#
# Train Epoch 172: MSE Total = 0.017379,   MSE X = 0.005895,   MSE Z = 0.015535
# Test: MSE Total = 0.089216,   MSE X = 0.038316,   MSE Z = 0.051323
#
#
# Train Epoch 173: MSE Total = 0.016176,   MSE X = 0.005455,   MSE Z = 0.014573
# Test: MSE Total = 0.089984,   MSE X = 0.038300,   MSE Z = 0.052986
#
#
# Train Epoch 174: MSE Total = 0.015108,   MSE X = 0.005053,   MSE Z = 0.013760
# Test: MSE Total = 0.086969,   MSE X = 0.037113,   MSE Z = 0.050871
#
#
# Train Epoch 175: MSE Total = 0.013572,   MSE X = 0.004467,   MSE Z = 0.012613
# Test: MSE Total = 0.086623,   MSE X = 0.037085,   MSE Z = 0.050246
#
#
# Train Epoch 176: MSE Total = 0.013319,   MSE X = 0.004343,   MSE Z = 0.012523
# Test: MSE Total = 0.089153,   MSE X = 0.038328,   MSE Z = 0.051146
#
#
# Train Epoch 177: MSE Total = 0.012975,   MSE X = 0.004321,   MSE Z = 0.011882
# Test: MSE Total = 0.085929,   MSE X = 0.036576,   MSE Z = 0.050589
#
#
# Train Epoch 178: MSE Total = 0.012359,   MSE X = 0.004086,   MSE Z = 0.011421
# Test: MSE Total = 0.090380,   MSE X = 0.038040,   MSE Z = 0.054731
#
#
# Train Epoch 179: MSE Total = 0.013240,   MSE X = 0.004467,   MSE Z = 0.011919
# Test: MSE Total = 0.088181,   MSE X = 0.037732,   MSE Z = 0.051220
#
#
# Train Epoch 180: MSE Total = 0.011972,   MSE X = 0.003931,   MSE Z = 0.011161
# Test: MSE Total = 0.085390,   MSE X = 0.036816,   MSE Z = 0.048615
#
#
# Train Epoch 181: MSE Total = 0.011532,   MSE X = 0.003744,   MSE Z = 0.010901
# Test: MSE Total = 0.089546,   MSE X = 0.038231,   MSE Z = 0.052310
#
#
# Train Epoch 182: MSE Total = 0.012617,   MSE X = 0.004226,   MSE Z = 0.011467
# Test: MSE Total = 0.093433,   MSE X = 0.039215,   MSE Z = 0.056967
#
#
# Train Epoch 183: MSE Total = 0.015715,   MSE X = 0.005421,   MSE Z = 0.013727
# Test: MSE Total = 0.088484,   MSE X = 0.037404,   MSE Z = 0.053012
#
#
# Train Epoch 184: MSE Total = 0.014528,   MSE X = 0.004933,   MSE Z = 0.012967
# Test: MSE Total = 0.093449,   MSE X = 0.040017,   MSE Z = 0.054169
#
#
# Train Epoch 185: MSE Total = 0.014497,   MSE X = 0.004960,   MSE Z = 0.012808
# Test: MSE Total = 0.087156,   MSE X = 0.037604,   MSE Z = 0.049530
#
#
# Train Epoch 186: MSE Total = 0.013529,   MSE X = 0.004584,   MSE Z = 0.012112
# Test: MSE Total = 0.089901,   MSE X = 0.039087,   MSE Z = 0.050033
#
#
# Train Epoch 187: MSE Total = 0.011480,   MSE X = 0.003796,   MSE Z = 0.010607
# Test: MSE Total = 0.089668,   MSE X = 0.038590,   MSE Z = 0.051302
#
#
# Train Epoch 188: MSE Total = 0.011027,   MSE X = 0.003644,   MSE Z = 0.010196
# Test: MSE Total = 0.087557,   MSE X = 0.037794,   MSE Z = 0.049697
#
#
# Train Epoch 189: MSE Total = 0.010707,   MSE X = 0.003468,   MSE Z = 0.010150
# Test: MSE Total = 0.089075,   MSE X = 0.038418,   MSE Z = 0.050666
#
#
# Train Epoch 190: MSE Total = 0.024951,   MSE X = 0.009989,   MSE Z = 0.016920
# Test: MSE Total = 0.114383,   MSE X = 0.050741,   MSE Z = 0.060096
#
#
# Train Epoch 191: MSE Total = 0.064332,   MSE X = 0.026142,   MSE Z = 0.042256
# Test: MSE Total = 0.123623,   MSE X = 0.053673,   MSE Z = 0.069067
#
#
# Train Epoch 192: MSE Total = 0.062531,   MSE X = 0.025300,   MSE Z = 0.041460
# Test: MSE Total = 0.147004,   MSE X = 0.063231,   MSE Z = 0.084225
#
#
# Train Epoch 193: MSE Total = 0.075500,   MSE X = 0.030649,   MSE Z = 0.049703
# Test: MSE Total = 0.126787,   MSE X = 0.055568,   MSE Z = 0.068996
#
#
# Train Epoch 194: MSE Total = 0.066302,   MSE X = 0.027463,   MSE Z = 0.041714
# Test: MSE Total = 0.170490,   MSE X = 0.074600,   MSE Z = 0.093211
#
#
# Train Epoch 195: MSE Total = 0.044655,   MSE X = 0.017023,   MSE Z = 0.033296
# Test: MSE Total = 0.100440,   MSE X = 0.042911,   MSE Z = 0.058576
#
#
# Train Epoch 196: MSE Total = 0.025186,   MSE X = 0.008963,   MSE Z = 0.021030
# Test: MSE Total = 0.097841,   MSE X = 0.042260,   MSE Z = 0.055440
#
#
# Train Epoch 197: MSE Total = 0.019920,   MSE X = 0.007136,   MSE Z = 0.016470
# Test: MSE Total = 0.089440,   MSE X = 0.038997,   MSE Z = 0.049387
#
#
# Train Epoch 198: MSE Total = 0.019174,   MSE X = 0.006807,   MSE Z = 0.016069
# Test: MSE Total = 0.087288,   MSE X = 0.036836,   MSE Z = 0.052515
#
#
# Train Epoch 199: MSE Total = 0.017069,   MSE X = 0.005943,   MSE Z = 0.014719
# Test: MSE Total = 0.085802,   MSE X = 0.036833,   MSE Z = 0.049417
#
#
# Train Epoch 200: MSE Total = 0.016365,   MSE X = 0.005430,   MSE Z = 0.015057
# Test: MSE Total = 0.084510,   MSE X = 0.036642,   MSE Z = 0.047393
#
#
# Got the weights of the epoch 200
# Execution time: 21 minutes, 43.85 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step2_autoregressive"))

model.eval()
# Out:
# MyModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=256, bias=True)
#   (pc_emb_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [5, 10, 15, 20, 25, 26]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.090280,   ADE X = 0.039804,   ADE Z = 0.072280
# FDE Total = 0.161920,   FDE X = 0.082647,   FDE Z = 0.120905
#
# Model performances on test set:
#
# ADE Total = 0.164220,   ADE X = 0.081676,   ADE Z = 0.123628
# FDE Total = 0.304913,   FDE X = 0.189818,   FDE Z = 0.198851

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    with np.load(file_name) as data:
        data_dict = dict(data)

    # Aggiungi la nuova coppia chiave-array
    data_dict['step2_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
