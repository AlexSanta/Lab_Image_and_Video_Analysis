# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
embedding_dim = 32
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = [] # lista per salvare gli embedding

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e mettila su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva l'embedding nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva gli embedding in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Annotazione dei punti delle nuvole sottocampionate

# %%
original_res = (376, 672) # risoluzione originale (H, W) delle immagini catturate

# matrice intrinseca K della camera per la risoluzione originale
K = np.array([
    [357.1, 0.0, 335.4],
    [0.0, 357.1, 180.2],
    [0.0, 0.0, 1.0]
])

# %%
import sys
sys.path.append("./Mask2Former")  # locazione di Mask2Former

from detectron2.utils.logger import setup_logger
setup_logger(name="mask2former")

from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.projects.deeplab import add_deeplab_config
from mask2former import add_maskformer2_config
# Out:
# /data01/iva24alesan/miniconda3/envs/IVA/lib/python3.13/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /data01/iva24alesan/Lab_IVA/Mask2Former/mask2former/modeling/pixel_decoder/msdeformattn.py:314: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)

# %%
cfg = get_cfg()
add_deeplab_config(cfg)
add_maskformer2_config(cfg)

cfg.merge_from_file("Mask2Former/configs/coco/panoptic-segmentation/swin/maskformer2_swin_small_bs16_50ep.yaml")
cfg.MODEL.WEIGHTS = 'https://dl.fbaipublicfiles.com/maskformer/mask2former/coco/panoptic/maskformer2_swin_small_bs16_50ep/model_final_a407fd.pkl'
cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
cfg.MODEL.MASK_FORMER.TEST.SEMANTIC_ON = True
cfg.MODEL.MASK_FORMER.TEST.INSTANCE_ON = False
cfg.MODEL.MASK_FORMER.TEST.PANOPTIC_ON = False

predictor = DefaultPredictor(cfg)
# Out:
# /data01/iva24alesan/miniconda3/envs/IVA/lib/python3.13/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# WARNING [06/04 22:16:44 mask2former.modeling.transformer_decoder.mask2former_transformer_decoder]: Weight format of MultiScaleMaskedTransformerDecoder have changed! Please upgrade your models. Applying automatic conversion now ...

# %%
# Scala la matrice intrinseca K dalla risoluzione originale a quella corrente

def scale_intrinsic_matrix(K, original_res, current_res):
    orig_h, orig_w = original_res
    curr_h, curr_w = current_res

    scale_x = curr_w / orig_w
    scale_y = curr_h / orig_h

    K_scaled = K.copy()
    K_scaled[0, 0] *= scale_x  # fx
    K_scaled[0, 2] *= scale_x  # cx
    K_scaled[1, 1] *= scale_y  # fy
    K_scaled[1, 2] *= scale_y  # cy

    return K_scaled

# %%
# Proietta una nuvola di punti nell'immagine RGB usando la matrice intrinseca K

def project_points_to_image(pc, K):

    # Estrae i singoli assi
    X, Y, Z = pc[:, 0], pc[:, 1], pc[:, 2]
    valid_mask = Z > 0  # considera solo i punti davanti alla camera

    X, Y, Z = X[valid_mask], Y[valid_mask], Z[valid_mask]

    fx, fy = K[0, 0], K[1, 1]
    cx, cy = K[0, 2], K[1, 2]

    u = (X * fx / Z + cx).astype(int)
    v = (Y * fy / Z + cy).astype(int)

    valid_pixels = np.stack([u, v], axis=1)
    valid_indices = np.where(valid_mask)[0]

    return valid_pixels, valid_indices

# %%
# Annota ciascun punto della nuvola concatenando alle coordinate spaziali l'indice della classe del rispettivo
# pixel nell'immagine RGB. La nuvola di punti, quindi, da dimensione [N, 3] passerà a dimensione [N, 4]

def annotate_point_cloud_with_semantics(pc, sem_seg, K, original_res, current_res):
    pc_np = pc.numpy()
    
    # Scala, se necessario, la matrice intrinseca
    K_scaled = scale_intrinsic_matrix(K, original_res, current_res)

    # Usa la funzione di proiezione
    valid_pixels, valid_indices = project_points_to_image(pc_np, K_scaled)

    H, W = sem_seg.shape
    u, v = valid_pixels[:, 0], valid_pixels[:, 1]

    # Maschera per filtrare i pixel proiettati che cadono fuori dall'immagine
    inside_mask = (u >= 0) & (u < W) & (v >= 0) & (v < H)

    class_indices = np.full(len(pc_np), -1, dtype=np.int32)  # default -1
    valid_inside_indices = valid_indices[inside_mask]
    class_indices[valid_inside_indices] = sem_seg[v[inside_mask], u[inside_mask]]

    # Concatenazione come tensore PyTorch
    annotated_pc = torch.cat([
        pc,
        torch.tensor(class_indices, dtype=torch.float32).unsqueeze(1)
    ], dim=1)

    return annotated_pc

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

# Carica le nuvole di punti sottocampionate
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [subsampling for subsampling in loaded_pc_subsampled["subsampling"]]

# Carica le immagini RGB
loaded_images = [np.load(os.path.join(folder_path, f))["rgb_frame"] for f in npz_files]

image_maps = []

for rgb_image in loaded_images:
    rgb_image = np.flipud(rgb_image) # prende l'immagine e la mette sopra-sotto
    bgr_image = rgb_image[:, :, ::-1] # conversione dell'immagine da RGB a BGR

    with torch.no_grad():  
        outputs = predictor(bgr_image)
    sem_seg = outputs["sem_seg"].argmax(dim=0) #mappa 2D dove ogni pixel ha un valore intero corrispondente all’indice 
                                               #della classe predetta
    sem_seg = sem_seg.cpu().numpy() # NON ricapovolge la mappa semantica

    image_maps.append(sem_seg)

# %%
annotated_point_clouds = []

#Annota tutte le nuvole di punti sottocampionate
for pc, sem_seg in zip(point_clouds_subsampled, image_maps):
    pc_tensor = torch.tensor(pc, dtype=torch.float32)    

    annotated_pc = annotate_point_cloud_with_semantics(
        pc_tensor,
        sem_seg,
        K=K, 
        original_res=(376, 672),
        current_res=sem_seg.shape
    )

    annotated_point_clouds.append(annotated_pc.numpy())

# Salva tutte le nuvole di punti annotate in un unico file .npz
np.savez_compressed(
    "point_clouds_subsampled_annotated.npz",
    annotated_subsampling=np.stack(annotated_point_clouds)
)

print("Annotated subsampled point clouds saved in 'point_clouds_subsampled_annotated.npz'!")

# %%
# Funzione per visualizzare un'immagine con sopra i punti della rispettiva nuvola proiettati

def visualize_annotated_projection_on_image(rgb_image, annotated_pc, K, original_res, current_res, class_colors=None):
    # Separa coordinate 3D e classi
    coords = annotated_pc[:, :3]
    class_ids = annotated_pc[:, 3].astype(int)

    # Scala, se necessario, la matrice intrinseca
    K_scaled = scale_intrinsic_matrix(K, original_res, current_res)

    # Proiezione dei punti della nuvola sull'immagine
    projected_pixels, valid_indices = project_points_to_image(coords, K_scaled)

    H, W, _ = rgb_image.shape
    u, v = projected_pixels[:, 0], projected_pixels[:, 1]

    # Filtra i punti dentro l'immagine
    inside_mask = (u >= 0) & (u < W) & (v >= 0) & (v < H)
    u, v = u[inside_mask], v[inside_mask]
    valid_class_ids = class_ids[valid_indices][inside_mask]

    # Mappa classi → colori (se non fornita)
    if class_colors is None:
        num_classes = valid_class_ids.max() + 1
        cmap = plt.cm.get_cmap('tab20', num_classes)
        class_colors = [cmap(i) for i in range(num_classes)]

    # Ottiene i colori
    point_colors = [class_colors[i] if i >= 0 else (0, 0, 0, 0.5) for i in valid_class_ids]

    # Plot
    plt.figure(figsize=(10, 6))
    plt.imshow(np.flipud(rgb_image))
    plt.scatter(u, v, c=point_colors, s=2)
    plt.title("An image with the cloud points projected")
    plt.axis('off')
    plt.show()

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

# Carica le nuvole di punti annotate e le immagini. Prende poi una nuvola con la rispettiva immagine, e richiama la 
# funzione per visualizzare l'immagine con i punti della nuvola proiettati

annotated_data = np.load("point_clouds_subsampled_annotated.npz", allow_pickle=True)
annotated_point_clouds = annotated_data["annotated_subsampling"]
loaded_images = [np.load(os.path.join(folder_path, f))["rgb_frame"] for f in npz_files]

idx = 0  # indice del frame da visualizzare

annotated_pc = annotated_point_clouds[idx]
rgb_image = loaded_images[idx]

visualize_annotated_projection_on_image(
    rgb_image=rgb_image,
    annotated_pc=annotated_pc,
    K=K,
    original_res=(376, 672),
    current_res=rgb_image.shape[:2]
)
# Out:
# /tmp/ipykernel_1861964/4012935824.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab20', num_classes)

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self, embedding_dim):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3+embedding_dim, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_annotated, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_annotated = point_clouds_annotated

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.npz_files = sorted(all_files, key=extract_number)

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_annotated = (self.point_clouds_annotated[idx])

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_clouds_annotated

# %%
class MyModel(nn.Module):
    def __init__(self, class_to_emb_idx, embedding_dim=32, input_size=2, hidden_size=256, output_size=2, num_layers=3, 
                 future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        self.class_to_emb_idx = class_to_emb_idx
        self.embedding_dim = embedding_dim
        self.class_mapping = torch.full((max(class_to_emb_idx.keys()) + 1,), -1, dtype=torch.long)
        for cls, idx in class_to_emb_idx.items():
            self.class_mapping[cls] = idx
        
        self.embedding_layer = nn.Embedding(num_embeddings=len(self.class_to_emb_idx), embedding_dim=self.embedding_dim)
        self.pointnet = PointNetfeat(embedding_dim=self.embedding_dim)
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(self.input_size, self.hidden_size, self.num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, past, point_clouds):
        all_coord = point_clouds[:, :, :3]
        all_classes = point_clouds[:, :, 3].long()
        mapped_indices = self.class_mapping.to(past.device)[all_classes]
        all_idx_emb = self.embedding_layer(mapped_indices)
        new_point_clouds = torch.cat((all_coord, all_idx_emb), dim=2)
        
        new_point_clouds_emb = self.pointnet(new_point_clouds)
        new_point_clouds_emb = self.pc_emb_norm(self.pc_emb_proj(new_point_clouds_emb))

        h0 = new_point_clouds_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(past.device)
        
        out, h = self.gru(past[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = past[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future, pc = past.to(device), future.to(device), pc.to(device) #spostamento dati sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_annotated = np.load("point_clouds_subsampled_annotated.npz")
point_clouds_annotated = [torch.tensor(pc, dtype=torch.float32) for pc in 
                           loaded_pc_annotated["annotated_subsampling"]]

dataset = CustomDataset(folder_path=folder_path, point_clouds_annotated=point_clouds_annotated, past_seconds=past_seconds, 
                        future_seconds=future_seconds, framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 1024, 4])

# %%
#Prende tutte le classi valide dei punti delle nelle nuvole di e costruisce un dizionario dove le chiavi sono le classi e
#i valori rappresentano i rispettivi indici 

all_classes = set()

for _, _, pc in dataset:
    pc_annotations = pc[:, 3].tolist()
    valid_classes = [int(c) for c in pc_annotations if c >= 0]
    all_classes.update(valid_classes)

all_classes = list(all_classes)
all_classes.sort()
num_embeddings = len(all_classes)
class_to_emb_idx = {cl : i for i, cl in enumerate(all_classes)}

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.3510107398033142
# Global variance of the z-coordinate: 4.372647285461426

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(class_to_emb_idx=class_to_emb_idx, embedding_dim=embedding_dim,
                input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
                num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.395939,   MSE X = 0.518208,   MSE Z = 1.090020
# Test: MSE Total = 1.082102,   MSE X = 0.538504,   MSE Z = 0.362124
#
#
# Train Epoch 2: MSE Total = 0.999653,   MSE X = 0.514831,   MSE Z = 0.273273
# Test: MSE Total = 1.058275,   MSE X = 0.538754,   MSE Z = 0.311418
#
#
# Train Epoch 3: MSE Total = 0.974078,   MSE X = 0.511832,   MSE Z = 0.230378
# Test: MSE Total = 1.012975,   MSE X = 0.541114,   MSE Z = 0.208362
#
#
# Train Epoch 4: MSE Total = 0.930846,   MSE X = 0.477166,   MSE Z = 0.262326
# Test: MSE Total = 0.737307,   MSE X = 0.323552,   MSE Z = 0.399801
#
#
# Train Epoch 5: MSE Total = 0.634954,   MSE X = 0.286663,   MSE Z = 0.315971
# Test: MSE Total = 0.610709,   MSE X = 0.286292,   MSE Z = 0.266580
#
#
# Train Epoch 6: MSE Total = 0.569437,   MSE X = 0.265745,   MSE Z = 0.252799
# Test: MSE Total = 0.489008,   MSE X = 0.233015,   MSE Z = 0.200134
#
#
# Train Epoch 7: MSE Total = 0.476473,   MSE X = 0.219726,   MSE Z = 0.220825
# Test: MSE Total = 0.441518,   MSE X = 0.199299,   MSE Z = 0.219829
#
#
# Train Epoch 8: MSE Total = 0.452540,   MSE X = 0.204547,   MSE Z = 0.224354
# Test: MSE Total = 0.553655,   MSE X = 0.273806,   MSE Z = 0.191345
#
#
# Train Epoch 9: MSE Total = 0.448457,   MSE X = 0.199235,   MSE Z = 0.234565
# Test: MSE Total = 0.509675,   MSE X = 0.230799,   MSE Z = 0.251174
#
#
# Train Epoch 10: MSE Total = 0.420008,   MSE X = 0.189617,   MSE Z = 0.209023
# Test: MSE Total = 0.402569,   MSE X = 0.179179,   MSE Z = 0.209396
#
#
# Train Epoch 11: MSE Total = 0.370772,   MSE X = 0.167197,   MSE Z = 0.185196
# Test: MSE Total = 0.357899,   MSE X = 0.165414,   MSE Z = 0.164573
#
#
# Train Epoch 12: MSE Total = 0.370384,   MSE X = 0.161525,   MSE Z = 0.204404
# Test: MSE Total = 0.339156,   MSE X = 0.150165,   MSE Z = 0.179201
#
#
# Train Epoch 13: MSE Total = 0.328719,   MSE X = 0.141428,   MSE Z = 0.188211
# Test: MSE Total = 0.416790,   MSE X = 0.170716,   MSE Z = 0.269004
#
#
# Train Epoch 14: MSE Total = 0.322476,   MSE X = 0.135261,   MSE Z = 0.196921
# Test: MSE Total = 0.314149,   MSE X = 0.135915,   MSE Z = 0.177203
#
#
# Train Epoch 15: MSE Total = 0.286793,   MSE X = 0.121802,   MSE Z = 0.169809
# Test: MSE Total = 0.288748,   MSE X = 0.122030,   MSE Z = 0.173094
#
#
# Train Epoch 16: MSE Total = 0.292334,   MSE X = 0.120399,   MSE Z = 0.186349
# Test: MSE Total = 0.297050,   MSE X = 0.130011,   MSE Z = 0.162282
#
#
# Train Epoch 17: MSE Total = 0.312289,   MSE X = 0.134527,   MSE Z = 0.178211
# Test: MSE Total = 0.255219,   MSE X = 0.103412,   MSE Z = 0.168693
#
#
# Train Epoch 18: MSE Total = 0.231010,   MSE X = 0.090063,   MSE Z = 0.165183
# Test: MSE Total = 0.274601,   MSE X = 0.118274,   MSE Z = 0.156768
#
#
# Train Epoch 19: MSE Total = 0.210607,   MSE X = 0.081834,   MSE Z = 0.151565
# Test: MSE Total = 0.224752,   MSE X = 0.088792,   MSE Z = 0.156588
#
#
# Train Epoch 20: MSE Total = 0.194832,   MSE X = 0.074594,   MSE Z = 0.144131
# Test: MSE Total = 0.211818,   MSE X = 0.082291,   MSE Z = 0.152485
#
#
# Train Epoch 21: MSE Total = 0.189125,   MSE X = 0.071665,   MSE Z = 0.142537
# Test: MSE Total = 0.233857,   MSE X = 0.098570,   MSE Z = 0.141114
#
#
# Train Epoch 22: MSE Total = 0.180979,   MSE X = 0.067363,   MSE Z = 0.140686
# Test: MSE Total = 0.217349,   MSE X = 0.088574,   MSE Z = 0.141875
#
#
# Train Epoch 23: MSE Total = 0.164109,   MSE X = 0.060519,   MSE Z = 0.129566
# Test: MSE Total = 0.216939,   MSE X = 0.088190,   MSE Z = 0.142372
#
#
# Train Epoch 24: MSE Total = 0.167085,   MSE X = 0.064991,   MSE Z = 0.120006
# Test: MSE Total = 0.238915,   MSE X = 0.105388,   MSE Z = 0.127626
#
#
# Train Epoch 25: MSE Total = 0.195871,   MSE X = 0.079499,   MSE Z = 0.128993
# Test: MSE Total = 0.194555,   MSE X = 0.075028,   MSE Z = 0.142021
#
#
# Train Epoch 26: MSE Total = 0.145276,   MSE X = 0.053941,   MSE Z = 0.113400
# Test: MSE Total = 0.179739,   MSE X = 0.070302,   MSE Z = 0.127720
#
#
# Train Epoch 27: MSE Total = 0.133569,   MSE X = 0.047282,   MSE Z = 0.112422
# Test: MSE Total = 0.176065,   MSE X = 0.070049,   MSE Z = 0.120929
#
#
# Train Epoch 28: MSE Total = 0.136565,   MSE X = 0.049326,   MSE Z = 0.111475
# Test: MSE Total = 0.161187,   MSE X = 0.061616,   MSE Z = 0.119584
#
#
# Train Epoch 29: MSE Total = 0.127268,   MSE X = 0.044624,   MSE Z = 0.108628
# Test: MSE Total = 0.167624,   MSE X = 0.066984,   MSE Z = 0.114096
#
#
# Train Epoch 30: MSE Total = 0.139393,   MSE X = 0.051706,   MSE Z = 0.108987
# Test: MSE Total = 0.223965,   MSE X = 0.077330,   MSE Z = 0.195393
#
#
# Train Epoch 31: MSE Total = 0.125163,   MSE X = 0.045081,   MSE Z = 0.102615
# Test: MSE Total = 0.172423,   MSE X = 0.070782,   MSE Z = 0.110727
#
#
# Train Epoch 32: MSE Total = 0.121348,   MSE X = 0.045957,   MSE Z = 0.091546
# Test: MSE Total = 0.151957,   MSE X = 0.059308,   MSE Z = 0.108427
#
#
# Train Epoch 33: MSE Total = 0.118780,   MSE X = 0.042186,   MSE Z = 0.099482
# Test: MSE Total = 0.163092,   MSE X = 0.058766,   MSE Z = 0.133627
#
#
# Train Epoch 34: MSE Total = 0.112281,   MSE X = 0.040001,   MSE Z = 0.093604
# Test: MSE Total = 0.189462,   MSE X = 0.076138,   MSE Z = 0.127454
#
#
# Train Epoch 35: MSE Total = 0.121437,   MSE X = 0.044455,   MSE Z = 0.097030
# Test: MSE Total = 0.178584,   MSE X = 0.071354,   MSE Z = 0.121592
#
#
# Train Epoch 36: MSE Total = 0.106804,   MSE X = 0.039604,   MSE Z = 0.083553
# Test: MSE Total = 0.153229,   MSE X = 0.063173,   MSE Z = 0.097446
#
#
# Train Epoch 37: MSE Total = 0.103561,   MSE X = 0.038236,   MSE Z = 0.081603
# Test: MSE Total = 0.149087,   MSE X = 0.060884,   MSE Z = 0.096865
#
#
# Train Epoch 38: MSE Total = 0.108376,   MSE X = 0.038930,   MSE Z = 0.089220
# Test: MSE Total = 0.152680,   MSE X = 0.061472,   MSE Z = 0.102303
#
#
# Train Epoch 39: MSE Total = 0.095640,   MSE X = 0.031580,   MSE Z = 0.088531
# Test: MSE Total = 0.171812,   MSE X = 0.068043,   MSE Z = 0.119119
#
#
# Train Epoch 40: MSE Total = 0.092480,   MSE X = 0.033342,   MSE Z = 0.075704
# Test: MSE Total = 0.145925,   MSE X = 0.058538,   MSE Z = 0.098533
#
#
# Train Epoch 41: MSE Total = 0.090487,   MSE X = 0.032341,   MSE Z = 0.075070
# Test: MSE Total = 0.136730,   MSE X = 0.054071,   MSE Z = 0.095072
#
#
# Train Epoch 42: MSE Total = 0.086067,   MSE X = 0.030256,   MSE Z = 0.073187
# Test: MSE Total = 0.137470,   MSE X = 0.056473,   MSE Z = 0.088140
#
#
# Train Epoch 43: MSE Total = 0.095942,   MSE X = 0.033765,   MSE Z = 0.081448
# Test: MSE Total = 0.136783,   MSE X = 0.054353,   MSE Z = 0.094185
#
#
# Train Epoch 44: MSE Total = 0.082446,   MSE X = 0.028203,   MSE Z = 0.072861
# Test: MSE Total = 0.128159,   MSE X = 0.049628,   MSE Z = 0.092831
#
#
# Train Epoch 45: MSE Total = 0.074575,   MSE X = 0.026096,   MSE Z = 0.063838
# Test: MSE Total = 0.135596,   MSE X = 0.054817,   MSE Z = 0.090067
#
#
# Train Epoch 46: MSE Total = 0.089799,   MSE X = 0.032924,   MSE Z = 0.071574
# Test: MSE Total = 0.125016,   MSE X = 0.049151,   MSE Z = 0.087941
#
#
# Train Epoch 47: MSE Total = 0.073456,   MSE X = 0.024713,   MSE Z = 0.066378
# Test: MSE Total = 0.132022,   MSE X = 0.052270,   MSE Z = 0.091580
#
#
# Train Epoch 48: MSE Total = 0.066369,   MSE X = 0.022949,   MSE Z = 0.057785
# Test: MSE Total = 0.139611,   MSE X = 0.057679,   MSE Z = 0.088363
#
#
# Train Epoch 49: MSE Total = 0.086230,   MSE X = 0.031653,   MSE Z = 0.068594
# Test: MSE Total = 0.140515,   MSE X = 0.055326,   MSE Z = 0.098557
#
#
# Train Epoch 50: MSE Total = 0.072556,   MSE X = 0.025413,   MSE Z = 0.062026
# Test: MSE Total = 0.121739,   MSE X = 0.047818,   MSE Z = 0.085792
#
#
# Train Epoch 51: MSE Total = 0.063650,   MSE X = 0.021771,   MSE Z = 0.056256
# Test: MSE Total = 0.142641,   MSE X = 0.060703,   MSE Z = 0.084024
#
#
# Train Epoch 52: MSE Total = 0.066730,   MSE X = 0.024267,   MSE Z = 0.053889
# Test: MSE Total = 0.113738,   MSE X = 0.044587,   MSE Z = 0.080466
#
#
# Train Epoch 53: MSE Total = 0.057101,   MSE X = 0.019642,   MSE Z = 0.050077
# Test: MSE Total = 0.141751,   MSE X = 0.060470,   MSE Z = 0.082985
#
#
# Train Epoch 54: MSE Total = 0.075363,   MSE X = 0.026393,   MSE Z = 0.064438
# Test: MSE Total = 0.132055,   MSE X = 0.052549,   MSE Z = 0.090665
#
#
# Train Epoch 55: MSE Total = 0.070933,   MSE X = 0.025697,   MSE Z = 0.057631
# Test: MSE Total = 0.157405,   MSE X = 0.059635,   MSE Z = 0.118665
#
#
# Train Epoch 56: MSE Total = 0.072400,   MSE X = 0.026411,   MSE Z = 0.058177
# Test: MSE Total = 0.146706,   MSE X = 0.060104,   MSE Z = 0.094638
#
#
# Train Epoch 57: MSE Total = 0.071975,   MSE X = 0.026615,   MSE Z = 0.056568
# Test: MSE Total = 0.108739,   MSE X = 0.041812,   MSE Z = 0.079807
#
#
# Train Epoch 58: MSE Total = 0.057362,   MSE X = 0.019394,   MSE Z = 0.051499
# Test: MSE Total = 0.115819,   MSE X = 0.045857,   MSE Z = 0.080336
#
#
# Train Epoch 59: MSE Total = 0.052198,   MSE X = 0.017535,   MSE Z = 0.047261
# Test: MSE Total = 0.124477,   MSE X = 0.043316,   MSE Z = 0.107408
#
#
# Train Epoch 60: MSE Total = 0.061142,   MSE X = 0.022015,   MSE Z = 0.050150
# Test: MSE Total = 0.116138,   MSE X = 0.044535,   MSE Z = 0.085671
#
#
# Train Epoch 61: MSE Total = 0.055081,   MSE X = 0.019752,   MSE Z = 0.045465
# Test: MSE Total = 0.124590,   MSE X = 0.053075,   MSE Z = 0.073199
#
#
# Train Epoch 62: MSE Total = 0.056750,   MSE X = 0.019125,   MSE Z = 0.051166
# Test: MSE Total = 0.105473,   MSE X = 0.042470,   MSE Z = 0.070656
#
#
# Train Epoch 63: MSE Total = 0.049568,   MSE X = 0.016433,   MSE Z = 0.045650
# Test: MSE Total = 0.105439,   MSE X = 0.041273,   MSE Z = 0.074807
#
#
# Train Epoch 64: MSE Total = 0.044208,   MSE X = 0.015079,   MSE Z = 0.039219
# Test: MSE Total = 0.107530,   MSE X = 0.043300,   MSE Z = 0.072028
#
#
# Train Epoch 65: MSE Total = 0.043333,   MSE X = 0.014411,   MSE Z = 0.039750
# Test: MSE Total = 0.107210,   MSE X = 0.040674,   MSE Z = 0.080627
#
#
# Train Epoch 66: MSE Total = 0.045342,   MSE X = 0.015855,   MSE Z = 0.038855
# Test: MSE Total = 0.101053,   MSE X = 0.039667,   MSE Z = 0.071306
#
#
# Train Epoch 67: MSE Total = 0.049120,   MSE X = 0.017364,   MSE Z = 0.041427
# Test: MSE Total = 0.110096,   MSE X = 0.046071,   MSE Z = 0.067615
#
#
# Train Epoch 68: MSE Total = 0.043370,   MSE X = 0.014426,   MSE Z = 0.039774
# Test: MSE Total = 0.104216,   MSE X = 0.041100,   MSE Z = 0.072861
#
#
# Train Epoch 69: MSE Total = 0.055745,   MSE X = 0.019070,   MSE Z = 0.049263
# Test: MSE Total = 0.098673,   MSE X = 0.039829,   MSE Z = 0.065757
#
#
# Train Epoch 70: MSE Total = 0.048259,   MSE X = 0.017349,   MSE Z = 0.039679
# Test: MSE Total = 0.094502,   MSE X = 0.037397,   MSE Z = 0.065619
#
#
# Train Epoch 71: MSE Total = 0.040836,   MSE X = 0.013640,   MSE Z = 0.037250
# Test: MSE Total = 0.098042,   MSE X = 0.039732,   MSE Z = 0.064782
#
#
# Train Epoch 72: MSE Total = 0.048641,   MSE X = 0.017190,   MSE Z = 0.041042
# Test: MSE Total = 0.103782,   MSE X = 0.042874,   MSE Z = 0.065693
#
#
# Train Epoch 73: MSE Total = 0.042967,   MSE X = 0.014134,   MSE Z = 0.039963
# Test: MSE Total = 0.092464,   MSE X = 0.036576,   MSE Z = 0.064256
#
#
# Train Epoch 74: MSE Total = 0.045584,   MSE X = 0.016278,   MSE Z = 0.037868
# Test: MSE Total = 0.099090,   MSE X = 0.039933,   MSE Z = 0.066262
#
#
# Train Epoch 75: MSE Total = 0.040931,   MSE X = 0.013956,   MSE Z = 0.036334
# Test: MSE Total = 0.089648,   MSE X = 0.034865,   MSE Z = 0.064404
#
#
# Train Epoch 76: MSE Total = 0.039166,   MSE X = 0.013132,   MSE Z = 0.035551
# Test: MSE Total = 0.104585,   MSE X = 0.041282,   MSE Z = 0.072993
#
#
# Train Epoch 77: MSE Total = 0.041976,   MSE X = 0.015276,   MSE Z = 0.033859
# Test: MSE Total = 0.096413,   MSE X = 0.039504,   MSE Z = 0.062180
#
#
# Train Epoch 78: MSE Total = 0.040954,   MSE X = 0.014547,   MSE Z = 0.034294
# Test: MSE Total = 0.095202,   MSE X = 0.037382,   MSE Z = 0.067138
#
#
# Train Epoch 79: MSE Total = 0.036950,   MSE X = 0.012963,   MSE Z = 0.031512
# Test: MSE Total = 0.102735,   MSE X = 0.042912,   MSE Z = 0.063370
#
#
# Train Epoch 80: MSE Total = 0.036246,   MSE X = 0.011777,   MSE Z = 0.034226
# Test: MSE Total = 0.096014,   MSE X = 0.035686,   MSE Z = 0.074818
#
#
# Train Epoch 81: MSE Total = 0.035224,   MSE X = 0.012129,   MSE Z = 0.030848
# Test: MSE Total = 0.099813,   MSE X = 0.039771,   MSE Z = 0.068347
#
#
# Train Epoch 82: MSE Total = 0.035767,   MSE X = 0.012126,   MSE Z = 0.031995
# Test: MSE Total = 0.092537,   MSE X = 0.036675,   MSE Z = 0.064056
#
#
# Train Epoch 83: MSE Total = 0.037230,   MSE X = 0.012331,   MSE Z = 0.034329
# Test: MSE Total = 0.091552,   MSE X = 0.036450,   MSE Z = 0.062794
#
#
# Train Epoch 84: MSE Total = 0.033545,   MSE X = 0.011880,   MSE Z = 0.028217
# Test: MSE Total = 0.101608,   MSE X = 0.037416,   MSE Z = 0.080413
#
#
# Train Epoch 85: MSE Total = 0.041204,   MSE X = 0.015173,   MSE Z = 0.032609
# Test: MSE Total = 0.090983,   MSE X = 0.037028,   MSE Z = 0.059563
#
#
# Train Epoch 86: MSE Total = 0.036960,   MSE X = 0.012382,   MSE Z = 0.033582
# Test: MSE Total = 0.092817,   MSE X = 0.034144,   MSE Z = 0.073578
#
#
# Train Epoch 87: MSE Total = 0.034435,   MSE X = 0.011422,   MSE Z = 0.031692
# Test: MSE Total = 0.083644,   MSE X = 0.033978,   MSE Z = 0.054984
#
#
# Train Epoch 88: MSE Total = 0.032151,   MSE X = 0.011113,   MSE Z = 0.028006
# Test: MSE Total = 0.087839,   MSE X = 0.035963,   MSE Z = 0.056750
#
#
# Train Epoch 89: MSE Total = 0.047761,   MSE X = 0.018416,   MSE Z = 0.034872
# Test: MSE Total = 0.105302,   MSE X = 0.040453,   MSE Z = 0.077417
#
#
# Train Epoch 90: MSE Total = 0.042213,   MSE X = 0.014958,   MSE Z = 0.035477
# Test: MSE Total = 0.090344,   MSE X = 0.035593,   MSE Z = 0.063291
#
#
# Train Epoch 91: MSE Total = 0.041215,   MSE X = 0.014353,   MSE Z = 0.035523
# Test: MSE Total = 0.096044,   MSE X = 0.040189,   MSE Z = 0.058988
#
#
# Train Epoch 92: MSE Total = 0.040706,   MSE X = 0.015426,   MSE Z = 0.030672
# Test: MSE Total = 0.097939,   MSE X = 0.041895,   MSE Z = 0.056930
#
#
# Train Epoch 93: MSE Total = 0.034884,   MSE X = 0.012436,   MSE Z = 0.029050
# Test: MSE Total = 0.088227,   MSE X = 0.035994,   MSE Z = 0.057449
#
#
# Train Epoch 94: MSE Total = 0.039592,   MSE X = 0.014686,   MSE Z = 0.030956
# Test: MSE Total = 0.098966,   MSE X = 0.042866,   MSE Z = 0.055653
#
#
# Train Epoch 95: MSE Total = 0.033678,   MSE X = 0.011748,   MSE Z = 0.028961
# Test: MSE Total = 0.099078,   MSE X = 0.032031,   MSE Z = 0.094128
#
#
# Train Epoch 96: MSE Total = 0.033321,   MSE X = 0.011142,   MSE Z = 0.030351
# Test: MSE Total = 0.091427,   MSE X = 0.032526,   MSE Z = 0.076382
#
#
# Train Epoch 97: MSE Total = 0.030339,   MSE X = 0.010272,   MSE Z = 0.027188
# Test: MSE Total = 0.089596,   MSE X = 0.036089,   MSE Z = 0.059978
#
#
# Train Epoch 98: MSE Total = 0.027226,   MSE X = 0.009792,   MSE Z = 0.022370
# Test: MSE Total = 0.111136,   MSE X = 0.035794,   MSE Z = 0.106062
#
#
# Train Epoch 99: MSE Total = 0.037895,   MSE X = 0.013870,   MSE Z = 0.030287
# Test: MSE Total = 0.096290,   MSE X = 0.038419,   MSE Z = 0.065752
#
#
# Train Epoch 100: MSE Total = 0.036740,   MSE X = 0.013120,   MSE Z = 0.030521
# Test: MSE Total = 0.093492,   MSE X = 0.039024,   MSE Z = 0.057765
#
#
# Train Epoch 101: MSE Total = 0.028820,   MSE X = 0.010448,   MSE Z = 0.023388
# Test: MSE Total = 0.089668,   MSE X = 0.035151,   MSE Z = 0.063438
#
#
# Train Epoch 102: MSE Total = 0.030316,   MSE X = 0.010545,   MSE Z = 0.026176
# Test: MSE Total = 0.094942,   MSE X = 0.035303,   MSE Z = 0.073931
#
#
# Train Epoch 103: MSE Total = 0.023981,   MSE X = 0.007942,   MSE Z = 0.022114
# Test: MSE Total = 0.080257,   MSE X = 0.032507,   MSE Z = 0.053090
#
#
# Train Epoch 104: MSE Total = 0.033714,   MSE X = 0.012332,   MSE Z = 0.026972
# Test: MSE Total = 0.098480,   MSE X = 0.037422,   MSE Z = 0.073849
#
#
# Train Epoch 105: MSE Total = 0.031493,   MSE X = 0.011579,   MSE Z = 0.024986
# Test: MSE Total = 0.088954,   MSE X = 0.036377,   MSE Z = 0.057620
#
#
# Train Epoch 106: MSE Total = 0.026001,   MSE X = 0.009222,   MSE Z = 0.021821
# Test: MSE Total = 0.077541,   MSE X = 0.031066,   MSE Z = 0.052498
#
#
# Train Epoch 107: MSE Total = 0.023916,   MSE X = 0.008649,   MSE Z = 0.019484
# Test: MSE Total = 0.098451,   MSE X = 0.038883,   MSE Z = 0.068634
#
#
# Train Epoch 108: MSE Total = 0.024292,   MSE X = 0.008130,   MSE Z = 0.022102
# Test: MSE Total = 0.079021,   MSE X = 0.031648,   MSE Z = 0.053537
#
#
# Train Epoch 109: MSE Total = 0.024550,   MSE X = 0.008833,   MSE Z = 0.020162
# Test: MSE Total = 0.084731,   MSE X = 0.032112,   MSE Z = 0.063843
#
#
# Train Epoch 110: MSE Total = 0.027666,   MSE X = 0.010222,   MSE Z = 0.021774
# Test: MSE Total = 0.107851,   MSE X = 0.047900,   MSE Z = 0.056464
#
#
# Train Epoch 111: MSE Total = 0.029784,   MSE X = 0.010544,   MSE Z = 0.025067
# Test: MSE Total = 0.084714,   MSE X = 0.031320,   MSE Z = 0.066599
#
#
# Train Epoch 112: MSE Total = 0.030409,   MSE X = 0.011075,   MSE Z = 0.024500
# Test: MSE Total = 0.084214,   MSE X = 0.034295,   MSE Z = 0.055055
#
#
# Train Epoch 113: MSE Total = 0.023148,   MSE X = 0.008247,   MSE Z = 0.019297
# Test: MSE Total = 0.081097,   MSE X = 0.032660,   MSE Z = 0.054309
#
#
# Train Epoch 114: MSE Total = 0.022564,   MSE X = 0.007438,   MSE Z = 0.020931
# Test: MSE Total = 0.093071,   MSE X = 0.035513,   MSE Z = 0.069276
#
#
# Train Epoch 115: MSE Total = 0.027394,   MSE X = 0.010400,   MSE Z = 0.020576
# Test: MSE Total = 0.083778,   MSE X = 0.033867,   MSE Z = 0.055655
#
#
# Train Epoch 116: MSE Total = 0.025580,   MSE X = 0.008822,   MSE Z = 0.022354
# Test: MSE Total = 0.083326,   MSE X = 0.033314,   MSE Z = 0.056662
#
#
# Train Epoch 117: MSE Total = 0.031083,   MSE X = 0.011548,   MSE Z = 0.024240
# Test: MSE Total = 0.095347,   MSE X = 0.039890,   MSE Z = 0.058586
#
#
# Train Epoch 118: MSE Total = 0.045364,   MSE X = 0.017323,   MSE Z = 0.033719
# Test: MSE Total = 0.174153,   MSE X = 0.052916,   MSE Z = 0.177403
#
#
# Train Epoch 119: MSE Total = 0.083355,   MSE X = 0.030829,   MSE Z = 0.065493
# Test: MSE Total = 0.105218,   MSE X = 0.043913,   MSE Z = 0.065029
#
#
# Train Epoch 120: MSE Total = 0.054908,   MSE X = 0.021579,   MSE Z = 0.038656
# Test: MSE Total = 0.112090,   MSE X = 0.044176,   MSE Z = 0.078470
#
#
# Train Epoch 121: MSE Total = 0.038164,   MSE X = 0.013271,   MSE Z = 0.032966
# Test: MSE Total = 0.081826,   MSE X = 0.033052,   MSE Z = 0.054447
#
#
# Train Epoch 122: MSE Total = 0.026685,   MSE X = 0.009723,   MSE Z = 0.021484
# Test: MSE Total = 0.079689,   MSE X = 0.031069,   MSE Z = 0.056980
#
#
# Train Epoch 123: MSE Total = 0.025497,   MSE X = 0.008644,   MSE Z = 0.022809
# Test: MSE Total = 0.080955,   MSE X = 0.031217,   MSE Z = 0.059103
#
#
# Train Epoch 124: MSE Total = 0.025555,   MSE X = 0.008755,   MSE Z = 0.022538
# Test: MSE Total = 0.075472,   MSE X = 0.030497,   MSE Z = 0.050180
#
#
# Train Epoch 125: MSE Total = 0.022457,   MSE X = 0.007986,   MSE Z = 0.018773
# Test: MSE Total = 0.077123,   MSE X = 0.030225,   MSE Z = 0.054593
#
#
# Train Epoch 126: MSE Total = 0.017555,   MSE X = 0.005863,   MSE Z = 0.016014
# Test: MSE Total = 0.073687,   MSE X = 0.029510,   MSE Z = 0.049932
#
#
# Train Epoch 127: MSE Total = 0.016343,   MSE X = 0.005405,   MSE Z = 0.015095
# Test: MSE Total = 0.070819,   MSE X = 0.028307,   MSE Z = 0.048178
#
#
# Train Epoch 128: MSE Total = 0.018033,   MSE X = 0.006087,   MSE Z = 0.016226
# Test: MSE Total = 0.072128,   MSE X = 0.028575,   MSE Z = 0.049970
#
#
# Train Epoch 129: MSE Total = 0.018181,   MSE X = 0.006134,   MSE Z = 0.016369
# Test: MSE Total = 0.074567,   MSE X = 0.028037,   MSE Z = 0.056972
#
#
# Train Epoch 130: MSE Total = 0.017715,   MSE X = 0.006170,   MSE Z = 0.015268
# Test: MSE Total = 0.077813,   MSE X = 0.031982,   MSE Z = 0.049834
#
#
# Train Epoch 131: MSE Total = 0.015379,   MSE X = 0.005294,   MSE Z = 0.013473
# Test: MSE Total = 0.073403,   MSE X = 0.030438,   MSE Z = 0.046059
#
#
# Train Epoch 132: MSE Total = 0.015078,   MSE X = 0.005101,   MSE Z = 0.013524
# Test: MSE Total = 0.072098,   MSE X = 0.028550,   MSE Z = 0.049997
#
#
# Train Epoch 133: MSE Total = 0.014222,   MSE X = 0.004726,   MSE Z = 0.013061
# Test: MSE Total = 0.073965,   MSE X = 0.029857,   MSE Z = 0.049287
#
#
# Train Epoch 134: MSE Total = 0.015236,   MSE X = 0.005183,   MSE Z = 0.013569
# Test: MSE Total = 0.070433,   MSE X = 0.028842,   MSE Z = 0.045483
#
#
# Train Epoch 135: MSE Total = 0.016590,   MSE X = 0.005897,   MSE Z = 0.013878
# Test: MSE Total = 0.073037,   MSE X = 0.029845,   MSE Z = 0.047391
#
#
# Train Epoch 136: MSE Total = 0.022622,   MSE X = 0.008759,   MSE Z = 0.016388
# Test: MSE Total = 0.080859,   MSE X = 0.033150,   MSE Z = 0.052081
#
#
# Train Epoch 137: MSE Total = 0.020446,   MSE X = 0.007385,   MSE Z = 0.016689
# Test: MSE Total = 0.071954,   MSE X = 0.029518,   MSE Z = 0.046277
#
#
# Train Epoch 138: MSE Total = 0.022458,   MSE X = 0.008131,   MSE Z = 0.018263
# Test: MSE Total = 0.074770,   MSE X = 0.029259,   MSE Z = 0.053082
#
#
# Train Epoch 139: MSE Total = 0.020452,   MSE X = 0.007350,   MSE Z = 0.016827
# Test: MSE Total = 0.083164,   MSE X = 0.033384,   MSE Z = 0.056075
#
#
# Train Epoch 140: MSE Total = 0.022152,   MSE X = 0.007117,   MSE Z = 0.021203
# Test: MSE Total = 0.072137,   MSE X = 0.028954,   MSE Z = 0.048651
#
#
# Train Epoch 141: MSE Total = 0.025071,   MSE X = 0.008877,   MSE Z = 0.021096
# Test: MSE Total = 0.080183,   MSE X = 0.031761,   MSE Z = 0.055570
#
#
# Train Epoch 142: MSE Total = 0.019513,   MSE X = 0.006842,   MSE Z = 0.016654
# Test: MSE Total = 0.078500,   MSE X = 0.032014,   MSE Z = 0.051158
#
#
# Train Epoch 143: MSE Total = 0.023046,   MSE X = 0.008896,   MSE Z = 0.016793
# Test: MSE Total = 0.081170,   MSE X = 0.032847,   MSE Z = 0.053802
#
#
# Train Epoch 144: MSE Total = 0.019144,   MSE X = 0.006696,   MSE Z = 0.016397
# Test: MSE Total = 0.077207,   MSE X = 0.029828,   MSE Z = 0.056169
#
#
# Train Epoch 145: MSE Total = 0.019407,   MSE X = 0.006883,   MSE Z = 0.016287
# Test: MSE Total = 0.077356,   MSE X = 0.032075,   MSE Z = 0.048551
#
#
# Train Epoch 146: MSE Total = 0.016557,   MSE X = 0.005667,   MSE Z = 0.014621
# Test: MSE Total = 0.066395,   MSE X = 0.025659,   MSE Z = 0.048275
#
#
# Train Epoch 147: MSE Total = 0.015194,   MSE X = 0.005400,   MSE Z = 0.012714
# Test: MSE Total = 0.069908,   MSE X = 0.028620,   MSE Z = 0.045167
#
#
# Train Epoch 148: MSE Total = 0.014745,   MSE X = 0.004846,   MSE Z = 0.013730
# Test: MSE Total = 0.071909,   MSE X = 0.029005,   MSE Z = 0.047995
#
#
# Train Epoch 149: MSE Total = 0.019487,   MSE X = 0.006752,   MSE Z = 0.016918
# Test: MSE Total = 0.075345,   MSE X = 0.028246,   MSE Z = 0.057861
#
#
# Train Epoch 150: MSE Total = 0.016815,   MSE X = 0.005640,   MSE Z = 0.015256
# Test: MSE Total = 0.072539,   MSE X = 0.029142,   MSE Z = 0.048828
#
#
# Train Epoch 151: MSE Total = 0.015770,   MSE X = 0.005243,   MSE Z = 0.014470
# Test: MSE Total = 0.071238,   MSE X = 0.028973,   MSE Z = 0.046707
#
#
# Train Epoch 152: MSE Total = 0.017075,   MSE X = 0.005833,   MSE Z = 0.015116
# Test: MSE Total = 0.077425,   MSE X = 0.031732,   MSE Z = 0.049905
#
#
# Train Epoch 153: MSE Total = 0.022319,   MSE X = 0.008222,   MSE Z = 0.017652
# Test: MSE Total = 0.076774,   MSE X = 0.031414,   MSE Z = 0.049666
#
#
# Train Epoch 154: MSE Total = 0.021658,   MSE X = 0.007605,   MSE Z = 0.018447
# Test: MSE Total = 0.072579,   MSE X = 0.028751,   MSE Z = 0.050294
#
#
# Train Epoch 155: MSE Total = 0.015509,   MSE X = 0.005226,   MSE Z = 0.013986
# Test: MSE Total = 0.068332,   MSE X = 0.027298,   MSE Z = 0.046539
#
#
# Train Epoch 156: MSE Total = 0.012514,   MSE X = 0.004237,   MSE Z = 0.011211
# Test: MSE Total = 0.064884,   MSE X = 0.026521,   MSE Z = 0.042072
#
#
# Train Epoch 157: MSE Total = 0.014143,   MSE X = 0.005170,   MSE Z = 0.011325
# Test: MSE Total = 0.069682,   MSE X = 0.027927,   MSE Z = 0.047145
#
#
# Train Epoch 158: MSE Total = 0.021142,   MSE X = 0.007578,   MSE Z = 0.017465
# Test: MSE Total = 0.068613,   MSE X = 0.027719,   MSE Z = 0.045643
#
#
# Train Epoch 159: MSE Total = 0.019706,   MSE X = 0.006996,   MSE Z = 0.016517
# Test: MSE Total = 0.076452,   MSE X = 0.027896,   MSE Z = 0.061410
#
#
# Train Epoch 160: MSE Total = 0.018381,   MSE X = 0.006454,   MSE Z = 0.015658
# Test: MSE Total = 0.072243,   MSE X = 0.029307,   MSE Z = 0.047627
#
#
# Train Epoch 161: MSE Total = 0.021516,   MSE X = 0.008202,   MSE Z = 0.016044
# Test: MSE Total = 0.078288,   MSE X = 0.029485,   MSE Z = 0.059641
#
#
# Train Epoch 162: MSE Total = 0.022817,   MSE X = 0.008442,   MSE Z = 0.017918
# Test: MSE Total = 0.081030,   MSE X = 0.032347,   MSE Z = 0.055271
#
#
# Train Epoch 163: MSE Total = 0.019406,   MSE X = 0.007081,   MSE Z = 0.015586
# Test: MSE Total = 0.067248,   MSE X = 0.026741,   MSE Z = 0.046239
#
#
# Train Epoch 164: MSE Total = 0.014770,   MSE X = 0.005253,   MSE Z = 0.012345
# Test: MSE Total = 0.067907,   MSE X = 0.027307,   MSE Z = 0.045619
#
#
# Train Epoch 165: MSE Total = 0.015218,   MSE X = 0.005113,   MSE Z = 0.013777
# Test: MSE Total = 0.066535,   MSE X = 0.026546,   MSE Z = 0.045434
#
#
# Train Epoch 166: MSE Total = 0.034373,   MSE X = 0.013848,   MSE Z = 0.023000
# Test: MSE Total = 0.097014,   MSE X = 0.037820,   MSE Z = 0.069380
#
#
# Train Epoch 167: MSE Total = 0.070287,   MSE X = 0.027123,   MSE Z = 0.051249
# Test: MSE Total = 0.119833,   MSE X = 0.052169,   MSE Z = 0.066452
#
#
# Train Epoch 168: MSE Total = 0.046882,   MSE X = 0.017572,   MSE Z = 0.036013
# Test: MSE Total = 0.088668,   MSE X = 0.034320,   MSE Z = 0.064281
#
#
# Train Epoch 169: MSE Total = 0.023375,   MSE X = 0.008317,   MSE Z = 0.019524
# Test: MSE Total = 0.069708,   MSE X = 0.026898,   MSE Z = 0.050829
#
#
# Train Epoch 170: MSE Total = 0.015879,   MSE X = 0.005390,   MSE Z = 0.014180
# Test: MSE Total = 0.066600,   MSE X = 0.026802,   MSE Z = 0.044670
#
#
# Train Epoch 171: MSE Total = 0.012653,   MSE X = 0.004277,   MSE Z = 0.011363
# Test: MSE Total = 0.061210,   MSE X = 0.023925,   MSE Z = 0.043552
#
#
# Train Epoch 172: MSE Total = 0.011532,   MSE X = 0.004009,   MSE Z = 0.009964
# Test: MSE Total = 0.061113,   MSE X = 0.023954,   MSE Z = 0.043247
#
#
# Train Epoch 173: MSE Total = 0.011018,   MSE X = 0.003739,   MSE Z = 0.009841
# Test: MSE Total = 0.062793,   MSE X = 0.024893,   MSE Z = 0.043446
#
#
# Train Epoch 174: MSE Total = 0.010400,   MSE X = 0.003273,   MSE Z = 0.010197
# Test: MSE Total = 0.063530,   MSE X = 0.024782,   MSE Z = 0.045379
#
#
# Train Epoch 175: MSE Total = 0.010572,   MSE X = 0.003587,   MSE Z = 0.009447
# Test: MSE Total = 0.063364,   MSE X = 0.024068,   MSE Z = 0.047550
#
#
# Train Epoch 176: MSE Total = 0.010575,   MSE X = 0.003443,   MSE Z = 0.009960
# Test: MSE Total = 0.062136,   MSE X = 0.024424,   MSE Z = 0.043730
#
#
# Train Epoch 177: MSE Total = 0.010247,   MSE X = 0.003398,   MSE Z = 0.009432
# Test: MSE Total = 0.062175,   MSE X = 0.024655,   MSE Z = 0.042992
#
#
# Train Epoch 178: MSE Total = 0.009485,   MSE X = 0.003185,   MSE Z = 0.008595
# Test: MSE Total = 0.060669,   MSE X = 0.023403,   MSE Z = 0.044263
#
#
# Train Epoch 179: MSE Total = 0.014875,   MSE X = 0.005414,   MSE Z = 0.011996
# Test: MSE Total = 0.075287,   MSE X = 0.027987,   MSE Z = 0.058651
#
#
# Train Epoch 180: MSE Total = 0.012617,   MSE X = 0.004322,   MSE Z = 0.011128
# Test: MSE Total = 0.061644,   MSE X = 0.023977,   MSE Z = 0.044278
#
#
# Train Epoch 181: MSE Total = 0.011054,   MSE X = 0.003657,   MSE Z = 0.010208
# Test: MSE Total = 0.067611,   MSE X = 0.027582,   MSE Z = 0.044030
#
#
# Train Epoch 182: MSE Total = 0.011032,   MSE X = 0.003815,   MSE Z = 0.009602
# Test: MSE Total = 0.058992,   MSE X = 0.022960,   MSE Z = 0.042322
#
#
# Train Epoch 183: MSE Total = 0.010317,   MSE X = 0.003548,   MSE Z = 0.009052
# Test: MSE Total = 0.063382,   MSE X = 0.024872,   MSE Z = 0.044752
#
#
# Train Epoch 184: MSE Total = 0.009135,   MSE X = 0.002959,   MSE Z = 0.008661
# Test: MSE Total = 0.060234,   MSE X = 0.024050,   MSE Z = 0.041069
#
#
# Train Epoch 185: MSE Total = 0.008637,   MSE X = 0.002880,   MSE Z = 0.007896
# Test: MSE Total = 0.061539,   MSE X = 0.023172,   MSE Z = 0.046900
#
#
# Train Epoch 186: MSE Total = 0.009573,   MSE X = 0.003403,   MSE Z = 0.008006
# Test: MSE Total = 0.058346,   MSE X = 0.022847,   MSE Z = 0.041370
#
#
# Train Epoch 187: MSE Total = 0.009681,   MSE X = 0.003318,   MSE Z = 0.008531
# Test: MSE Total = 0.057990,   MSE X = 0.023048,   MSE Z = 0.039915
#
#
# Train Epoch 188: MSE Total = 0.009260,   MSE X = 0.003113,   MSE Z = 0.008377
# Test: MSE Total = 0.057771,   MSE X = 0.022218,   MSE Z = 0.042388
#
#
# Train Epoch 189: MSE Total = 0.008618,   MSE X = 0.002895,   MSE Z = 0.007803
# Test: MSE Total = 0.062597,   MSE X = 0.023983,   MSE Z = 0.046247
#
#
# Train Epoch 190: MSE Total = 0.010598,   MSE X = 0.003494,   MSE Z = 0.009831
# Test: MSE Total = 0.063241,   MSE X = 0.025118,   MSE Z = 0.043589
#
#
# Train Epoch 191: MSE Total = 0.011096,   MSE X = 0.003656,   MSE Z = 0.010298
# Test: MSE Total = 0.058323,   MSE X = 0.022901,   MSE Z = 0.041131
#
#
# Train Epoch 192: MSE Total = 0.009153,   MSE X = 0.003144,   MSE Z = 0.008040
# Test: MSE Total = 0.056871,   MSE X = 0.022432,   MSE Z = 0.039748
#
#
# Train Epoch 193: MSE Total = 0.008999,   MSE X = 0.003080,   MSE Z = 0.007947
# Test: MSE Total = 0.060558,   MSE X = 0.023725,   MSE Z = 0.042894
#
#
# Train Epoch 194: MSE Total = 0.009281,   MSE X = 0.003253,   MSE Z = 0.007927
# Test: MSE Total = 0.061961,   MSE X = 0.024584,   MSE Z = 0.042797
#
#
# Train Epoch 195: MSE Total = 0.008596,   MSE X = 0.002953,   MSE Z = 0.007554
# Test: MSE Total = 0.061118,   MSE X = 0.023900,   MSE Z = 0.043448
#
#
# Train Epoch 196: MSE Total = 0.010994,   MSE X = 0.004165,   MSE Z = 0.008289
# Test: MSE Total = 0.065836,   MSE X = 0.026301,   MSE Z = 0.044840
#
#
# Train Epoch 197: MSE Total = 0.013176,   MSE X = 0.004662,   MSE Z = 0.011098
# Test: MSE Total = 0.063132,   MSE X = 0.025670,   MSE Z = 0.041413
#
#
# Train Epoch 198: MSE Total = 0.010393,   MSE X = 0.003586,   MSE Z = 0.009076
# Test: MSE Total = 0.055980,   MSE X = 0.021543,   MSE Z = 0.041025
#
#
# Train Epoch 199: MSE Total = 0.009533,   MSE X = 0.003236,   MSE Z = 0.008512
# Test: MSE Total = 0.060876,   MSE X = 0.024315,   MSE Z = 0.041476
#
#
# Train Epoch 200: MSE Total = 0.009237,   MSE X = 0.003171,   MSE Z = 0.008124
# Test: MSE Total = 0.061785,   MSE X = 0.025563,   MSE Z = 0.038973
#
#
# Got the weights of the epoch 198
# Execution time: 16 minutes, 57.83 seconds

# %%
torch.save(model.state_dict(), "model_weights_step3_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(class_to_emb_idx=class_to_emb_idx, embedding_dim=embedding_dim,
                input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
                num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step3_autoregressive"))

model.eval()
# Out:
# MyModel(
#   (embedding_layer): Embedding(59, 32)
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(35, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=256, bias=True)
#   (pc_emb_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [5, 10, 15, 20, 25, 26]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.077757,   ADE X = 0.035429,   ADE Z = 0.061276
# FDE Total = 0.146831,   FDE X = 0.075268,   FDE Z = 0.110549
#
# Model performances on test set:
#
# ADE Total = 0.151664,   ADE X = 0.076443,   ADE Z = 0.112553
# FDE Total = 0.284077,   FDE X = 0.173304,   FDE Z = 0.186122

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiungi la nuova coppia chiave-array
    data_dict['step3_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
