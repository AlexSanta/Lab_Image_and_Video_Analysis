# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data" # locazione della cartella in cui risiedono i campioni del Dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 100
lr = 0.001 # learning rate
train_ratio = 0.75 # percentuale campioni del Dataset che faranno parte del training set
num_layers = 2 # n° layer della GRU
hidden_size= 128 # n° features degli hidden state dei layer della GRU 
input_size = 2 # n° coordinate dei punti della traiettoria in input alla GRU (non si considera la y)
past_seconds = 2 # n° secondi che si considerano della traiettoria passata
future_seconds = 4 # n° secondi che si considerano della traiettoria futura
framerate = 10 # n° punti delle traiettorie campionati in un secondo

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = [] # lista delle nuvole di punti sottocampionate

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Aggiunge la nuvola sottocampionata alla lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")
# Out:
# Subsampled point clouds saved in 'point_clouds_subsampled.npz'!

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_subsampled, past_seconds=2, future_seconds=4, framerate=10,
                  train_ratio=0.75, mode='all'):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_subsampled = point_clouds_subsampled
        self.train_ratio = train_ratio
        self.mode = mode

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0]) 

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        all_files_sorted = sorted(all_files, key=extract_number)

        split_index = int(len(all_files_sorted) * train_ratio) # indice di separazione tra training e test set

        if mode == "train":
            self.npz_files = all_files_sorted[:split_index]
            self.point_clouds_subsampled = point_clouds_subsampled[:split_index]
        elif mode == "test":
            self.npz_files = all_files_sorted[split_index:]
            self.point_clouds_subsampled = point_clouds_subsampled[split_index:]
        else:
            self.npz_files = all_files_sorted
            self.point_clouds_subsampled = point_clouds_subsampled

    def __len__(self):
        return len(self.npz_files)

    def local_smoothing(self, future_traj, iterations=1): # funzione che esegue lo smoothing locale
                                                          # della traiettoria futura
        smoothed_traj = future_traj.clone()

        for _ in range(iterations):
            temp_traj = smoothed_traj.clone()

            prev_points = temp_traj[:-2]
            current_points = temp_traj[1:-1]
            next_points = temp_traj[2:]

            smoothed_traj[1:-1] = 0.25*prev_points + 0.5*current_points + 0.25*next_points   
        
        return smoothed_traj

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte le traiettorie (senza la coordinata y) e la nuvola in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_subsampled = (self.point_clouds_subsampled[idx])

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        past_trajectory = torch.flip(past_trajectory, [0]) # Inverte la traiettoria passata in modo che
                                                           # inizi dal punto più lontano nel tempo e termini
                                                           # con quello presente (0, 0)

        if(self.mode == "train"): # Data Augmentation
            if(np.random.rand() < 0.5):
                # smoothing locale della traiettoria futura
                n_iterations = np.random.randint(1, 3)
                future_trajectory = self.local_smoothing(future_trajectory, iterations=n_iterations)

            if np.random.rand() < 0.5:
                # flip orizzontale di tutta la traiettoria e dei punti della nuvola
                past_trajectory[:, 0] *= -1
                future_trajectory[:, 0] *= -1
                point_clouds_subsampled[:, 0] *= -1    


        return past_trajectory, future_trajectory, point_clouds_subsampled

# %%
class AutoregressiveModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=128, output_size=2, num_layers=2, future_steps=40):
        super(AutoregressiveModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) 
                                            # di tutta la sequenza (ultimo punto escluso) ed ha quindi dimensione 
                                            # [batch_size, seq_length-1, hidden_dim]
                                            # h contiene l'ultimo hidden state della sequenza di ogni layer della 
                                            # GRU, ed ha dimensione [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
class OneShotModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=128, output_size=2*40, num_layers=2, future_steps=40):
        super(OneShotModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.pointnet = PointNetfeat()
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc):
        pc = pc.to(x.device)
        pc_emb = self.pointnet(pc)
        pc_emb = self.pc_emb_norm(self.pc_emb_proj(pc_emb))

        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        _, h = self.gru(x, h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                               # sequenza ed ha quindi dimensione [batch_size, seq_length, hidden_dim]
                               # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha 
                               # dimensione [num_layers, batch_size, hidden_dim]
        
        last_hidden = h[-1]  # [batch_size, hidden_size]
        future_points = self.fc(last_hidden)  # [batch_size, 2*future_steps]
        future_points = future_points.view(x.size(0), self.future_steps, self.input_size)
             
        return future_points

# %%
def train(model, device, train_loader, optimizer, future_x_std, future_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./future_x_std
    lambda_z = 1./future_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train: MSE Total = {train_mse_total:.6f},  MSE X = {train_mse_x:.6f},  MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, future_x_std, future_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./future_x_std
    lambda_z = 1./future_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test:  MSE Total = {test_mse_total:.6f},  MSE X = {test_mse_x:.6f},  MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def fit(model, device, train_loader, test_loader, optimizer, epochs, future_x_std, future_z_std):

    best_weights = copy.deepcopy(model.state_dict())
    best_epoch = 0
    best_test_loss = float("inf")

    train_losses_x = []
    train_losses_z = []
    train_losses_total = []
    test_losses_x = []
    test_losses_z = []
    test_losses_total = []

    start_time = time.time()

    for epoch in range(1, epochs + 1):
        #esegue un'epoca di training
        print(f"Epoch {epoch}")
        train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer,
                                                            future_x_std, future_z_std)
        test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, future_x_std, future_z_std)

        if(test_loss_total < best_test_loss):
            best_epoch = epoch
            best_test_loss = test_loss_total
            best_weights = copy.deepcopy(model.state_dict()) 

        train_losses_total.append(train_loss_total)
        train_losses_x.append(train_loss_x)
        train_losses_z.append(train_loss_z)
        test_losses_total.append(test_loss_total)
        test_losses_x.append(test_loss_x)
        test_losses_z.append(test_loss_z)
        print()

    model.load_state_dict(best_weights)
    print(f"Got the weights of the epoch {best_epoch}")

    end_time = time.time()

    execution_time = end_time - start_time

    minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

    print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")

    return {
        "train_losses": {
            "total": train_losses_total,
            "x": train_losses_x,
            "z": train_losses_z
        },
        "test_losses": {
            "total": test_losses_total,
            "x": test_losses_x,
            "z": test_losses_z
        }
    }

# %%
def plot_loss(epochs, history):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), history["train_losses"]["total"], marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), history["test_losses"]["total"], marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), history["train_losses"]["x"], marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), history["test_losses"]["x"], marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), history["train_losses"]["z"], marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), history["test_losses"]["z"], marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
# Carica le nuvole di punti sottocampionate e crea un lista contenente i rispettivi tensori
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [torch.tensor(subsampling, dtype=torch.float32) for subsampling in 
                           loaded_pc_subsampled["subsampling"]]


# Istanziamento del Dataset completo e del training e test set con i rispettivi DataLoader

original_dataset = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, mode="all")

train_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="train")

test_set = CustomDataset(folder_path=folder_path, point_clouds_subsampled=point_clouds_subsampled, 
                        past_seconds=past_seconds, future_seconds=future_seconds, framerate=framerate, 
                        train_ratio=train_ratio, mode="test")

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 1024, 3])

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z nel futuro

all_x_values = []
all_z_values = []

for past, future, _ in original_dataset:
    all_x_values.append(future[:, 0])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

future_x_var = torch.var(all_x_values)
future_z_var = torch.var(all_z_values)

future_x_std = future_x_var ** 0.5
future_z_std = future_z_var ** 0.5

print(f"Global variance of the future x-coordinate: {future_x_var.item()}")
print(f"Global variance of the future z-coordinate: {future_z_var.item()}")
# Out:
# Global variance of the future x-coordinate: 0.5222423076629639
# Global variance of the future z-coordinate: 2.0641021728515625

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
# Istanziamento e fitting del modello autoregressivo

autoregressive_model = AutoregressiveModel(input_size=input_size, hidden_size=hidden_size, 
                                           output_size=input_size, num_layers=num_layers, 
                                           future_steps=future_seconds*framerate).to(device)

autoregressive_optimizer = optim.Adam(autoregressive_model.parameters(), lr=lr, weight_decay=1e-5)

print("Fitting autoregressive model:\n")
autoregressive_history = fit(autoregressive_model, device, train_loader, test_loader, 
                             autoregressive_optimizer, epochs, future_x_std, future_z_std)
# Out:
# Fitting autoregressive model:
#
# Epoch 1
# Train: MSE Total = 1.896424,  MSE X = 0.570414,  MSE Z = 1.590572
# Test:  MSE Total = 0.890460,  MSE X = 0.450528,  MSE Z = 0.383645
#
# Epoch 2
# Train: MSE Total = 0.983029,  MSE X = 0.556357,  MSE Z = 0.306245
# Test:  MSE Total = 0.756627,  MSE X = 0.445946,  MSE Z = 0.200477
#
# Epoch 3
# Train: MSE Total = 0.925481,  MSE X = 0.556769,  MSE Z = 0.222747
# Test:  MSE Total = 0.890993,  MSE X = 0.445894,  MSE Z = 0.393625
#
# Epoch 4
# Train: MSE Total = 0.925333,  MSE X = 0.554921,  MSE Z = 0.226209
# Test:  MSE Total = 0.725250,  MSE X = 0.444691,  MSE Z = 0.157894
#
# Epoch 5
# Train: MSE Total = 0.902355,  MSE X = 0.555344,  MSE Z = 0.192355
# Test:  MSE Total = 0.734357,  MSE X = 0.446188,  MSE Z = 0.168000
#
# Epoch 6
# Train: MSE Total = 0.899613,  MSE X = 0.555493,  MSE Z = 0.188119
# Test:  MSE Total = 0.732709,  MSE X = 0.452332,  MSE Z = 0.153419
#
# Epoch 7
# Train: MSE Total = 0.905599,  MSE X = 0.557029,  MSE Z = 0.193665
# Test:  MSE Total = 0.721090,  MSE X = 0.442516,  MSE Z = 0.156239
#
# Epoch 8
# Train: MSE Total = 0.888554,  MSE X = 0.550798,  MSE Z = 0.181564
# Test:  MSE Total = 0.730549,  MSE X = 0.441518,  MSE Z = 0.171813
#
# Epoch 9
# Train: MSE Total = 0.884331,  MSE X = 0.543190,  MSE Z = 0.190622
# Test:  MSE Total = 0.703261,  MSE X = 0.406088,  MSE Z = 0.203046
#
# Epoch 10
# Train: MSE Total = 0.836965,  MSE X = 0.477709,  MSE Z = 0.252752
# Test:  MSE Total = 0.627610,  MSE X = 0.349081,  MSE Z = 0.207692
#
# Epoch 11
# Train: MSE Total = 0.750631,  MSE X = 0.403209,  MSE Z = 0.276826
# Test:  MSE Total = 0.561565,  MSE X = 0.304948,  MSE Z = 0.200544
#
# Epoch 12
# Train: MSE Total = 0.634556,  MSE X = 0.326123,  MSE Z = 0.263314
# Test:  MSE Total = 0.690429,  MSE X = 0.370074,  MSE Z = 0.256207
#
# Epoch 13
# Train: MSE Total = 0.571293,  MSE X = 0.286274,  MSE Z = 0.251647
# Test:  MSE Total = 0.650206,  MSE X = 0.319514,  MSE Z = 0.298937
#
# Epoch 14
# Train: MSE Total = 0.529829,  MSE X = 0.269743,  MSE Z = 0.224940
# Test:  MSE Total = 0.593210,  MSE X = 0.323839,  MSE Z = 0.208453
#
# Epoch 15
# Train: MSE Total = 0.520036,  MSE X = 0.267376,  MSE Z = 0.215575
# Test:  MSE Total = 0.540192,  MSE X = 0.267064,  MSE Z = 0.245155
#
# Epoch 16
# Train: MSE Total = 0.461711,  MSE X = 0.227509,  MSE Z = 0.211038
# Test:  MSE Total = 0.390375,  MSE X = 0.204857,  MSE Z = 0.153584
#
# Epoch 17
# Train: MSE Total = 0.436482,  MSE X = 0.219405,  MSE Z = 0.190902
# Test:  MSE Total = 0.338805,  MSE X = 0.167604,  MSE Z = 0.153553
#
# Epoch 18
# Train: MSE Total = 0.431443,  MSE X = 0.213540,  MSE Z = 0.195323
# Test:  MSE Total = 0.341594,  MSE X = 0.177313,  MSE Z = 0.138259
#
# Epoch 19
# Train: MSE Total = 0.412920,  MSE X = 0.204938,  MSE Z = 0.185813
# Test:  MSE Total = 0.447284,  MSE X = 0.220145,  MSE Z = 0.204952
#
# Epoch 20
# Train: MSE Total = 0.438172,  MSE X = 0.220896,  MSE Z = 0.190366
# Test:  MSE Total = 0.343022,  MSE X = 0.165519,  MSE Z = 0.163757
#
# Epoch 21
# Train: MSE Total = 0.385483,  MSE X = 0.192668,  MSE Z = 0.170787
# Test:  MSE Total = 0.331371,  MSE X = 0.167381,  MSE Z = 0.143318
#
# Epoch 22
# Train: MSE Total = 0.406006,  MSE X = 0.203674,  MSE Z = 0.178392
# Test:  MSE Total = 0.465079,  MSE X = 0.208627,  MSE Z = 0.253416
#
# Epoch 23
# Train: MSE Total = 0.375166,  MSE X = 0.186041,  MSE Z = 0.169140
# Test:  MSE Total = 0.354270,  MSE X = 0.185936,  MSE Z = 0.139327
#
# Epoch 24
# Train: MSE Total = 0.378604,  MSE X = 0.189047,  MSE Z = 0.168103
# Test:  MSE Total = 0.331195,  MSE X = 0.161171,  MSE Z = 0.155409
#
# Epoch 25
# Train: MSE Total = 0.389379,  MSE X = 0.196694,  MSE Z = 0.168380
# Test:  MSE Total = 0.401293,  MSE X = 0.215008,  MSE Z = 0.149088
#
# Epoch 26
# Train: MSE Total = 0.368767,  MSE X = 0.183794,  MSE Z = 0.164413
# Test:  MSE Total = 0.341252,  MSE X = 0.176953,  MSE Z = 0.138483
#
# Epoch 27
# Train: MSE Total = 0.363659,  MSE X = 0.180367,  MSE Z = 0.163887
# Test:  MSE Total = 0.388721,  MSE X = 0.174156,  MSE Z = 0.212241
#
# Epoch 28
# Train: MSE Total = 0.361681,  MSE X = 0.178481,  MSE Z = 0.164796
# Test:  MSE Total = 0.298435,  MSE X = 0.151265,  MSE Z = 0.128037
#
# Epoch 29
# Train: MSE Total = 0.345348,  MSE X = 0.171378,  MSE Z = 0.155450
# Test:  MSE Total = 0.374184,  MSE X = 0.171384,  MSE Z = 0.196867
#
# Epoch 30
# Train: MSE Total = 0.367360,  MSE X = 0.176152,  MSE Z = 0.177585
# Test:  MSE Total = 0.397805,  MSE X = 0.201450,  MSE Z = 0.171032
#
# Epoch 31
# Train: MSE Total = 0.338390,  MSE X = 0.167632,  MSE Z = 0.152903
# Test:  MSE Total = 0.362379,  MSE X = 0.174166,  MSE Z = 0.174377
#
# Epoch 32
# Train: MSE Total = 0.322531,  MSE X = 0.157520,  MSE Z = 0.150221
# Test:  MSE Total = 0.352697,  MSE X = 0.182026,  MSE Z = 0.144841
#
# Epoch 33
# Train: MSE Total = 0.343540,  MSE X = 0.167831,  MSE Z = 0.159906
# Test:  MSE Total = 0.412563,  MSE X = 0.215994,  MSE Z = 0.163321
#
# Epoch 34
# Train: MSE Total = 0.342448,  MSE X = 0.171106,  MSE Z = 0.151825
# Test:  MSE Total = 0.387000,  MSE X = 0.182389,  MSE Z = 0.193400
#
# Epoch 35
# Train: MSE Total = 0.345916,  MSE X = 0.173246,  MSE Z = 0.152554
# Test:  MSE Total = 0.364923,  MSE X = 0.193446,  MSE Z = 0.139703
#
# Epoch 36
# Train: MSE Total = 0.324061,  MSE X = 0.156078,  MSE Z = 0.155286
# Test:  MSE Total = 0.424471,  MSE X = 0.223416,  MSE Z = 0.165673
#
# Epoch 37
# Train: MSE Total = 0.315624,  MSE X = 0.154665,  MSE Z = 0.145974
# Test:  MSE Total = 0.309957,  MSE X = 0.159366,  MSE Z = 0.128484
#
# Epoch 38
# Train: MSE Total = 0.311645,  MSE X = 0.151955,  MSE Z = 0.145644
# Test:  MSE Total = 0.372936,  MSE X = 0.202500,  MSE Z = 0.133215
#
# Epoch 39
# Train: MSE Total = 0.306327,  MSE X = 0.148827,  MSE Z = 0.144221
# Test:  MSE Total = 0.333681,  MSE X = 0.169700,  MSE Z = 0.142025
#
# Epoch 40
# Train: MSE Total = 0.309897,  MSE X = 0.150156,  MSE Z = 0.146709
# Test:  MSE Total = 0.410484,  MSE X = 0.217576,  MSE Z = 0.157188
#
# Epoch 41
# Train: MSE Total = 0.326569,  MSE X = 0.159501,  MSE Z = 0.152083
# Test:  MSE Total = 0.336021,  MSE X = 0.179244,  MSE Z = 0.126413
#
# Epoch 42
# Train: MSE Total = 0.284360,  MSE X = 0.134825,  MSE Z = 0.140501
# Test:  MSE Total = 0.376648,  MSE X = 0.188607,  MSE Z = 0.166167
#
# Epoch 43
# Train: MSE Total = 0.291997,  MSE X = 0.138539,  MSE Z = 0.144087
# Test:  MSE Total = 0.329054,  MSE X = 0.166758,  MSE Z = 0.141226
#
# Epoch 44
# Train: MSE Total = 0.290011,  MSE X = 0.137824,  MSE Z = 0.142656
# Test:  MSE Total = 0.405675,  MSE X = 0.188956,  MSE Z = 0.207177
#
# Epoch 45
# Train: MSE Total = 0.307434,  MSE X = 0.143846,  MSE Z = 0.155716
# Test:  MSE Total = 0.393347,  MSE X = 0.171578,  MSE Z = 0.224014
#
# Epoch 46
# Train: MSE Total = 0.278160,  MSE X = 0.131374,  MSE Z = 0.138452
# Test:  MSE Total = 0.355079,  MSE X = 0.181721,  MSE Z = 0.148869
#
# Epoch 47
# Train: MSE Total = 0.274425,  MSE X = 0.126793,  MSE Z = 0.142193
# Test:  MSE Total = 0.388035,  MSE X = 0.211344,  MSE Z = 0.137325
#
# Epoch 48
# Train: MSE Total = 0.275710,  MSE X = 0.132250,  MSE Z = 0.133191
# Test:  MSE Total = 0.355847,  MSE X = 0.186918,  MSE Z = 0.139640
#
# Epoch 49
# Train: MSE Total = 0.264886,  MSE X = 0.125448,  MSE Z = 0.131163
# Test:  MSE Total = 0.329738,  MSE X = 0.171837,  MSE Z = 0.132113
#
# Epoch 50
# Train: MSE Total = 0.266989,  MSE X = 0.119709,  MSE Z = 0.145593
# Test:  MSE Total = 0.360114,  MSE X = 0.195789,  MSE Z = 0.128136
#
# Epoch 51
# Train: MSE Total = 0.260000,  MSE X = 0.122228,  MSE Z = 0.130544
# Test:  MSE Total = 0.306267,  MSE X = 0.156744,  MSE Z = 0.128397
#
# Epoch 52
# Train: MSE Total = 0.255338,  MSE X = 0.118319,  MSE Z = 0.131618
# Test:  MSE Total = 0.418152,  MSE X = 0.234645,  MSE Z = 0.134270
#
# Epoch 53
# Train: MSE Total = 0.263651,  MSE X = 0.123378,  MSE Z = 0.133504
# Test:  MSE Total = 0.354205,  MSE X = 0.170127,  MSE Z = 0.170663
#
# Epoch 54
# Train: MSE Total = 0.282843,  MSE X = 0.136493,  MSE Z = 0.135003
# Test:  MSE Total = 0.353207,  MSE X = 0.185361,  MSE Z = 0.138943
#
# Epoch 55
# Train: MSE Total = 0.284350,  MSE X = 0.134769,  MSE Z = 0.140597
# Test:  MSE Total = 0.300714,  MSE X = 0.155279,  MSE Z = 0.123331
#
# Epoch 56
# Train: MSE Total = 0.249376,  MSE X = 0.118175,  MSE Z = 0.123338
# Test:  MSE Total = 0.305360,  MSE X = 0.160002,  MSE Z = 0.120617
#
# Epoch 57
# Train: MSE Total = 0.242645,  MSE X = 0.112290,  MSE Z = 0.125370
# Test:  MSE Total = 0.347886,  MSE X = 0.162740,  MSE Z = 0.176270
#
# Epoch 58
# Train: MSE Total = 0.235502,  MSE X = 0.107907,  MSE Z = 0.123819
# Test:  MSE Total = 0.352499,  MSE X = 0.180850,  MSE Z = 0.146894
#
# Epoch 59
# Train: MSE Total = 0.224864,  MSE X = 0.101536,  MSE Z = 0.121201
# Test:  MSE Total = 0.364910,  MSE X = 0.192647,  MSE Z = 0.141273
#
# Epoch 60
# Train: MSE Total = 0.229021,  MSE X = 0.105963,  MSE Z = 0.118375
# Test:  MSE Total = 0.334940,  MSE X = 0.178251,  MSE Z = 0.126835
#
# Epoch 61
# Train: MSE Total = 0.215741,  MSE X = 0.098413,  MSE Z = 0.114305
# Test:  MSE Total = 0.354758,  MSE X = 0.189659,  MSE Z = 0.132626
#
# Epoch 62
# Train: MSE Total = 0.220083,  MSE X = 0.100689,  MSE Z = 0.116018
# Test:  MSE Total = 0.329668,  MSE X = 0.165720,  MSE Z = 0.144172
#
# Epoch 63
# Train: MSE Total = 0.256617,  MSE X = 0.126419,  MSE Z = 0.117354
# Test:  MSE Total = 0.448890,  MSE X = 0.247108,  MSE Z = 0.153655
#
# Epoch 64
# Train: MSE Total = 0.255063,  MSE X = 0.123422,  MSE Z = 0.121078
# Test:  MSE Total = 0.344819,  MSE X = 0.180882,  MSE Z = 0.135796
#
# Epoch 65
# Train: MSE Total = 0.210725,  MSE X = 0.094753,  MSE Z = 0.114374
# Test:  MSE Total = 0.356068,  MSE X = 0.185689,  MSE Z = 0.142401
#
# Epoch 66
# Train: MSE Total = 0.206451,  MSE X = 0.094575,  MSE Z = 0.108587
# Test:  MSE Total = 0.334224,  MSE X = 0.176074,  MSE Z = 0.130133
#
# Epoch 67
# Train: MSE Total = 0.216854,  MSE X = 0.097095,  MSE Z = 0.118524
# Test:  MSE Total = 0.327319,  MSE X = 0.167233,  MSE Z = 0.137788
#
# Epoch 68
# Train: MSE Total = 0.210454,  MSE X = 0.097649,  MSE Z = 0.108227
# Test:  MSE Total = 0.318103,  MSE X = 0.161553,  MSE Z = 0.135841
#
# Epoch 69
# Train: MSE Total = 0.204990,  MSE X = 0.094215,  MSE Z = 0.107203
# Test:  MSE Total = 0.344537,  MSE X = 0.168612,  MSE Z = 0.159785
#
# Epoch 70
# Train: MSE Total = 0.195573,  MSE X = 0.089113,  MSE Z = 0.103817
# Test:  MSE Total = 0.372907,  MSE X = 0.199280,  MSE Z = 0.139575
#
# Epoch 71
# Train: MSE Total = 0.217794,  MSE X = 0.103014,  MSE Z = 0.108105
# Test:  MSE Total = 0.389701,  MSE X = 0.202783,  MSE Z = 0.156737
#
# Epoch 72
# Train: MSE Total = 0.197987,  MSE X = 0.087908,  MSE Z = 0.109681
# Test:  MSE Total = 0.368507,  MSE X = 0.182963,  MSE Z = 0.165692
#
# Epoch 73
# Train: MSE Total = 0.196449,  MSE X = 0.086551,  MSE Z = 0.110169
# Test:  MSE Total = 0.348226,  MSE X = 0.177217,  MSE Z = 0.147977
#
# Epoch 74
# Train: MSE Total = 0.254281,  MSE X = 0.121660,  MSE Z = 0.123457
# Test:  MSE Total = 0.380569,  MSE X = 0.184454,  MSE Z = 0.180057
#
# Epoch 75
# Train: MSE Total = 0.189692,  MSE X = 0.084867,  MSE Z = 0.103809
# Test:  MSE Total = 0.339943,  MSE X = 0.174095,  MSE Z = 0.142284
#
# Epoch 76
# Train: MSE Total = 0.180677,  MSE X = 0.081261,  MSE Z = 0.098028
# Test:  MSE Total = 0.324467,  MSE X = 0.162401,  MSE Z = 0.143299
#
# Epoch 77
# Train: MSE Total = 0.189033,  MSE X = 0.087499,  MSE Z = 0.097630
# Test:  MSE Total = 0.371557,  MSE X = 0.188714,  MSE Z = 0.158640
#
# Epoch 78
# Train: MSE Total = 0.192224,  MSE X = 0.088028,  MSE Z = 0.101164
# Test:  MSE Total = 0.469968,  MSE X = 0.231897,  MSE Z = 0.214177
#
# Epoch 79
# Train: MSE Total = 0.200687,  MSE X = 0.093443,  MSE Z = 0.102557
# Test:  MSE Total = 0.355999,  MSE X = 0.184934,  MSE Z = 0.143802
#
# Epoch 80
# Train: MSE Total = 0.172317,  MSE X = 0.076385,  MSE Z = 0.095710
# Test:  MSE Total = 0.354293,  MSE X = 0.161394,  MSE Z = 0.188153
#
# Epoch 81
# Train: MSE Total = 0.174932,  MSE X = 0.077796,  MSE Z = 0.096661
# Test:  MSE Total = 0.362114,  MSE X = 0.184106,  MSE Z = 0.154235
#
# Epoch 82
# Train: MSE Total = 0.177081,  MSE X = 0.078543,  MSE Z = 0.098264
# Test:  MSE Total = 0.345397,  MSE X = 0.165966,  MSE Z = 0.166282
#
# Epoch 83
# Train: MSE Total = 0.179660,  MSE X = 0.083325,  MSE Z = 0.092461
# Test:  MSE Total = 0.368123,  MSE X = 0.187839,  MSE Z = 0.155447
#
# Epoch 84
# Train: MSE Total = 0.177053,  MSE X = 0.081052,  MSE Z = 0.093234
# Test:  MSE Total = 0.359176,  MSE X = 0.189015,  MSE Z = 0.140254
#
# Epoch 85
# Train: MSE Total = 0.176969,  MSE X = 0.081026,  MSE Z = 0.093167
# Test:  MSE Total = 0.404534,  MSE X = 0.194826,  MSE Z = 0.193867
#
# Epoch 86
# Train: MSE Total = 0.166495,  MSE X = 0.076174,  MSE Z = 0.087765
# Test:  MSE Total = 0.305692,  MSE X = 0.148256,  MSE Z = 0.144445
#
# Epoch 87
# Train: MSE Total = 0.170419,  MSE X = 0.075831,  MSE Z = 0.094084
# Test:  MSE Total = 0.307431,  MSE X = 0.142695,  MSE Z = 0.157999
#
# Epoch 88
# Train: MSE Total = 0.172593,  MSE X = 0.077979,  MSE Z = 0.092937
# Test:  MSE Total = 0.367842,  MSE X = 0.196858,  MSE Z = 0.137112
#
# Epoch 89
# Train: MSE Total = 0.167864,  MSE X = 0.076383,  MSE Z = 0.089317
# Test:  MSE Total = 0.321543,  MSE X = 0.161124,  MSE Z = 0.141637
#
# Epoch 90
# Train: MSE Total = 0.160600,  MSE X = 0.071990,  MSE Z = 0.087614
# Test:  MSE Total = 0.340608,  MSE X = 0.167854,  MSE Z = 0.155647
#
# Epoch 91
# Train: MSE Total = 0.148881,  MSE X = 0.066662,  MSE Z = 0.081369
# Test:  MSE Total = 0.303696,  MSE X = 0.147618,  MSE Z = 0.142846
#
# Epoch 92
# Train: MSE Total = 0.154238,  MSE X = 0.069498,  MSE Z = 0.083428
# Test:  MSE Total = 0.349206,  MSE X = 0.178898,  MSE Z = 0.146044
#
# Epoch 93
# Train: MSE Total = 0.158152,  MSE X = 0.072912,  MSE Z = 0.082264
# Test:  MSE Total = 0.363237,  MSE X = 0.164360,  MSE Z = 0.195104
#
# Epoch 94
# Train: MSE Total = 0.148154,  MSE X = 0.065132,  MSE Z = 0.083366
# Test:  MSE Total = 0.332864,  MSE X = 0.165416,  MSE Z = 0.149369
#
# Epoch 95
# Train: MSE Total = 0.141539,  MSE X = 0.061105,  MSE Z = 0.081867
# Test:  MSE Total = 0.326825,  MSE X = 0.160363,  MSE Z = 0.150737
#
# Epoch 96
# Train: MSE Total = 0.143315,  MSE X = 0.064342,  MSE Z = 0.077984
# Test:  MSE Total = 0.360316,  MSE X = 0.189432,  MSE Z = 0.141063
#
# Epoch 97
# Train: MSE Total = 0.157399,  MSE X = 0.072153,  MSE Z = 0.082690
# Test:  MSE Total = 0.383791,  MSE X = 0.188159,  MSE Z = 0.177322
#
# Epoch 98
# Train: MSE Total = 0.174377,  MSE X = 0.083178,  MSE Z = 0.085164
# Test:  MSE Total = 0.352332,  MSE X = 0.173943,  MSE Z = 0.160385
#
# Epoch 99
# Train: MSE Total = 0.145642,  MSE X = 0.065190,  MSE Z = 0.079642
# Test:  MSE Total = 0.347424,  MSE X = 0.181526,  MSE Z = 0.138259
#
# Epoch 100
# Train: MSE Total = 0.141864,  MSE X = 0.063302,  MSE Z = 0.077969
# Test:  MSE Total = 0.355400,  MSE X = 0.169811,  MSE Z = 0.173009
#
# Got the weights of the epoch 28
# Execution time: 7 minutes, 41.87 seconds

# %%
# Plot delle loss del modello autoregressivo

print("Autoregressive model losses:")
plot_loss(epochs, autoregressive_history)
# Out:
# Autoregressive model losses:

# %%
# Salvataggio pesi del modello autoregressivo

torch.save(autoregressive_model.state_dict(), "pred_from_past_and_pc_geom_autoreg_model")
print("Autoregressive model weights saved in 'pred_from_past_and_pc_geom_autoreg_model'!")
# Out:
# Autoregressive model weights saved in 'pred_from_past_and_pc_geom_autoreg_model'!

# %%
# Istanziamento e fitting del modello one shot

one_shot_model = OneShotModel(input_size=input_size, hidden_size=hidden_size, 
                              output_size=input_size*future_seconds*framerate, num_layers=num_layers, 
                              future_steps=future_seconds*framerate).to(device)

one_shot_optimizer = optim.Adam(one_shot_model.parameters(), lr=lr, weight_decay=1e-5)

print("Fitting one shot model:\n")
one_shot_history = fit(one_shot_model, device, train_loader, test_loader, one_shot_optimizer, epochs, 
                       future_x_std, future_z_std)
# Out:
# Fitting one shot model:
#
# Epoch 1
# Train: MSE Total = 1.989897,  MSE X = 0.567581,  MSE Z = 1.730496
# Test:  MSE Total = 0.760841,  MSE X = 0.444801,  MSE Z = 0.208806
#
# Epoch 2
# Train: MSE Total = 0.859460,  MSE X = 0.498741,  MSE Z = 0.243257
# Test:  MSE Total = 0.715956,  MSE X = 0.420517,  MSE Z = 0.192600
#
# Epoch 3
# Train: MSE Total = 0.656587,  MSE X = 0.354105,  MSE Z = 0.239336
# Test:  MSE Total = 0.407618,  MSE X = 0.205939,  MSE Z = 0.176205
#
# Epoch 4
# Train: MSE Total = 0.509188,  MSE X = 0.260091,  MSE Z = 0.214472
# Test:  MSE Total = 0.382772,  MSE X = 0.196523,  MSE Z = 0.159229
#
# Epoch 5
# Train: MSE Total = 0.456063,  MSE X = 0.231562,  MSE Z = 0.194865
# Test:  MSE Total = 0.458743,  MSE X = 0.227735,  MSE Z = 0.206325
#
# Epoch 6
# Train: MSE Total = 0.438591,  MSE X = 0.225505,  MSE Z = 0.181806
# Test:  MSE Total = 0.349412,  MSE X = 0.165559,  MSE Z = 0.172858
#
# Epoch 7
# Train: MSE Total = 0.409462,  MSE X = 0.207761,  MSE Z = 0.175232
# Test:  MSE Total = 0.327929,  MSE X = 0.163866,  MSE Z = 0.145360
#
# Epoch 8
# Train: MSE Total = 0.400347,  MSE X = 0.201421,  MSE Z = 0.174741
# Test:  MSE Total = 0.331885,  MSE X = 0.167782,  MSE Z = 0.143258
#
# Epoch 9
# Train: MSE Total = 0.402868,  MSE X = 0.203981,  MSE Z = 0.173272
# Test:  MSE Total = 0.298525,  MSE X = 0.146183,  MSE Z = 0.138270
#
# Epoch 10
# Train: MSE Total = 0.383029,  MSE X = 0.191898,  MSE Z = 0.168791
# Test:  MSE Total = 0.322453,  MSE X = 0.160370,  MSE Z = 0.144442
#
# Epoch 11
# Train: MSE Total = 0.377335,  MSE X = 0.189158,  MSE Z = 0.166058
# Test:  MSE Total = 0.337630,  MSE X = 0.152609,  MSE Z = 0.181678
#
# Epoch 12
# Train: MSE Total = 0.378850,  MSE X = 0.188739,  MSE Z = 0.169068
# Test:  MSE Total = 0.392064,  MSE X = 0.192591,  MSE Z = 0.180395
#
# Epoch 13
# Train: MSE Total = 0.367097,  MSE X = 0.182745,  MSE Z = 0.164098
# Test:  MSE Total = 0.378186,  MSE X = 0.199345,  MSE Z = 0.147028
#
# Epoch 14
# Train: MSE Total = 0.360633,  MSE X = 0.180600,  MSE Z = 0.159079
# Test:  MSE Total = 0.299548,  MSE X = 0.152867,  MSE Z = 0.126451
#
# Epoch 15
# Train: MSE Total = 0.361400,  MSE X = 0.183972,  MSE Z = 0.153475
# Test:  MSE Total = 0.308498,  MSE X = 0.158890,  MSE Z = 0.127335
#
# Epoch 16
# Train: MSE Total = 0.367630,  MSE X = 0.186138,  MSE Z = 0.158119
# Test:  MSE Total = 0.312941,  MSE X = 0.151262,  MSE Z = 0.148884
#
# Epoch 17
# Train: MSE Total = 0.346829,  MSE X = 0.174503,  MSE Z = 0.151366
# Test:  MSE Total = 0.291762,  MSE X = 0.142880,  MSE Z = 0.135120
#
# Epoch 18
# Train: MSE Total = 0.341280,  MSE X = 0.169056,  MSE Z = 0.154223
# Test:  MSE Total = 0.289928,  MSE X = 0.140096,  MSE Z = 0.138019
#
# Epoch 19
# Train: MSE Total = 0.368857,  MSE X = 0.186547,  MSE Z = 0.159070
# Test:  MSE Total = 0.318700,  MSE X = 0.163485,  MSE Z = 0.132857
#
# Epoch 20
# Train: MSE Total = 0.348249,  MSE X = 0.174608,  MSE Z = 0.153196
# Test:  MSE Total = 0.325507,  MSE X = 0.162677,  MSE Z = 0.144244
#
# Epoch 21
# Train: MSE Total = 0.329178,  MSE X = 0.162521,  MSE Z = 0.149828
# Test:  MSE Total = 0.275415,  MSE X = 0.135877,  MSE Z = 0.125557
#
# Epoch 22
# Train: MSE Total = 0.320306,  MSE X = 0.156625,  MSE Z = 0.148803
# Test:  MSE Total = 0.300554,  MSE X = 0.139961,  MSE Z = 0.153555
#
# Epoch 23
# Train: MSE Total = 0.317602,  MSE X = 0.154512,  MSE Z = 0.149120
# Test:  MSE Total = 0.343059,  MSE X = 0.170304,  MSE Z = 0.154299
#
# Epoch 24
# Train: MSE Total = 0.319957,  MSE X = 0.157941,  MSE Z = 0.145685
# Test:  MSE Total = 0.312366,  MSE X = 0.163916,  MSE Z = 0.122900
#
# Epoch 25
# Train: MSE Total = 0.312035,  MSE X = 0.151599,  MSE Z = 0.146912
# Test:  MSE Total = 0.359147,  MSE X = 0.187081,  MSE Z = 0.144057
#
# Epoch 26
# Train: MSE Total = 0.315341,  MSE X = 0.154802,  MSE Z = 0.145294
# Test:  MSE Total = 0.327962,  MSE X = 0.169308,  MSE Z = 0.134588
#
# Epoch 27
# Train: MSE Total = 0.304247,  MSE X = 0.145544,  MSE Z = 0.147761
# Test:  MSE Total = 0.344444,  MSE X = 0.184211,  MSE Z = 0.128640
#
# Epoch 28
# Train: MSE Total = 0.301737,  MSE X = 0.147307,  MSE Z = 0.140650
# Test:  MSE Total = 0.283268,  MSE X = 0.140897,  MSE Z = 0.126860
#
# Epoch 29
# Train: MSE Total = 0.289613,  MSE X = 0.139829,  MSE Z = 0.138098
# Test:  MSE Total = 0.298227,  MSE X = 0.156225,  MSE Z = 0.117877
#
# Epoch 30
# Train: MSE Total = 0.284497,  MSE X = 0.137760,  MSE Z = 0.134862
# Test:  MSE Total = 0.293649,  MSE X = 0.148436,  MSE Z = 0.126785
#
# Epoch 31
# Train: MSE Total = 0.282032,  MSE X = 0.134722,  MSE Z = 0.137360
# Test:  MSE Total = 0.288668,  MSE X = 0.147157,  MSE Z = 0.122171
#
# Epoch 32
# Train: MSE Total = 0.279382,  MSE X = 0.133470,  MSE Z = 0.136041
# Test:  MSE Total = 0.360646,  MSE X = 0.190255,  MSE Z = 0.139900
#
# Epoch 33
# Train: MSE Total = 0.266707,  MSE X = 0.126169,  MSE Z = 0.132345
# Test:  MSE Total = 0.335413,  MSE X = 0.181630,  MSE Z = 0.120794
#
# Epoch 34
# Train: MSE Total = 0.277879,  MSE X = 0.132869,  MSE Z = 0.135077
# Test:  MSE Total = 0.317289,  MSE X = 0.168287,  MSE Z = 0.121283
#
# Epoch 35
# Train: MSE Total = 0.268794,  MSE X = 0.127177,  MSE Z = 0.133341
# Test:  MSE Total = 0.374090,  MSE X = 0.202352,  MSE Z = 0.135167
#
# Epoch 36
# Train: MSE Total = 0.266652,  MSE X = 0.125326,  MSE Z = 0.133943
# Test:  MSE Total = 0.300120,  MSE X = 0.155051,  MSE Z = 0.122931
#
# Epoch 37
# Train: MSE Total = 0.254021,  MSE X = 0.118648,  MSE Z = 0.129072
# Test:  MSE Total = 0.339033,  MSE X = 0.178868,  MSE Z = 0.131487
#
# Epoch 38
# Train: MSE Total = 0.285193,  MSE X = 0.139230,  MSE Z = 0.132938
# Test:  MSE Total = 0.299416,  MSE X = 0.154321,  MSE Z = 0.123371
#
# Epoch 39
# Train: MSE Total = 0.253398,  MSE X = 0.118480,  MSE Z = 0.128511
# Test:  MSE Total = 0.308144,  MSE X = 0.157187,  MSE Z = 0.130212
#
# Epoch 40
# Train: MSE Total = 0.239059,  MSE X = 0.109204,  MSE Z = 0.126352
# Test:  MSE Total = 0.342022,  MSE X = 0.176416,  MSE Z = 0.140658
#
# Epoch 41
# Train: MSE Total = 0.252833,  MSE X = 0.119144,  MSE Z = 0.126380
# Test:  MSE Total = 0.346944,  MSE X = 0.181724,  MSE Z = 0.137176
#
# Epoch 42
# Train: MSE Total = 0.232849,  MSE X = 0.106478,  MSE Z = 0.122849
# Test:  MSE Total = 0.378380,  MSE X = 0.201922,  MSE Z = 0.142185
#
# Epoch 43
# Train: MSE Total = 0.224424,  MSE X = 0.104354,  MSE Z = 0.114968
# Test:  MSE Total = 0.326891,  MSE X = 0.168690,  MSE Z = 0.134279
#
# Epoch 44
# Train: MSE Total = 0.242732,  MSE X = 0.115607,  MSE Z = 0.118898
# Test:  MSE Total = 0.341890,  MSE X = 0.179953,  MSE Z = 0.133435
#
# Epoch 45
# Train: MSE Total = 0.230222,  MSE X = 0.105787,  MSE Z = 0.120449
# Test:  MSE Total = 0.323148,  MSE X = 0.170935,  MSE Z = 0.124437
#
# Epoch 46
# Train: MSE Total = 0.221781,  MSE X = 0.099903,  MSE Z = 0.120019
# Test:  MSE Total = 0.325187,  MSE X = 0.161250,  MSE Z = 0.146621
#
# Epoch 47
# Train: MSE Total = 0.225324,  MSE X = 0.104363,  MSE Z = 0.116242
# Test:  MSE Total = 0.309239,  MSE X = 0.149562,  MSE Z = 0.146946
#
# Epoch 48
# Train: MSE Total = 0.217201,  MSE X = 0.098553,  MSE Z = 0.116123
# Test:  MSE Total = 0.377466,  MSE X = 0.202639,  MSE Z = 0.139445
#
# Epoch 49
# Train: MSE Total = 0.213183,  MSE X = 0.096852,  MSE Z = 0.113733
# Test:  MSE Total = 0.339358,  MSE X = 0.172435,  MSE Z = 0.144743
#
# Epoch 50
# Train: MSE Total = 0.200440,  MSE X = 0.090341,  MSE Z = 0.108368
# Test:  MSE Total = 0.438537,  MSE X = 0.230227,  MSE Z = 0.172340
#
# Epoch 51
# Train: MSE Total = 0.222571,  MSE X = 0.102239,  MSE Z = 0.116510
# Test:  MSE Total = 0.311706,  MSE X = 0.159412,  MSE Z = 0.130907
#
# Epoch 52
# Train: MSE Total = 0.202242,  MSE X = 0.091451,  MSE Z = 0.108752
# Test:  MSE Total = 0.293466,  MSE X = 0.149577,  MSE Z = 0.124255
#
# Epoch 53
# Train: MSE Total = 0.219609,  MSE X = 0.101912,  MSE Z = 0.112903
# Test:  MSE Total = 0.450296,  MSE X = 0.249915,  MSE Z = 0.150092
#
# Epoch 54
# Train: MSE Total = 0.201693,  MSE X = 0.092757,  MSE Z = 0.105366
# Test:  MSE Total = 0.372606,  MSE X = 0.183229,  MSE Z = 0.171054
#
# Epoch 55
# Train: MSE Total = 0.189927,  MSE X = 0.084661,  MSE Z = 0.104557
# Test:  MSE Total = 0.351095,  MSE X = 0.169881,  MSE Z = 0.166684
#
# Epoch 56
# Train: MSE Total = 0.197775,  MSE X = 0.089564,  MSE Z = 0.106084
# Test:  MSE Total = 0.387323,  MSE X = 0.205653,  MSE Z = 0.147617
#
# Epoch 57
# Train: MSE Total = 0.188204,  MSE X = 0.084461,  MSE Z = 0.102479
# Test:  MSE Total = 0.348958,  MSE X = 0.179307,  MSE Z = 0.144875
#
# Epoch 58
# Train: MSE Total = 0.193280,  MSE X = 0.088958,  MSE Z = 0.100831
# Test:  MSE Total = 0.328312,  MSE X = 0.160352,  MSE Z = 0.152896
#
# Epoch 59
# Train: MSE Total = 0.208257,  MSE X = 0.097209,  MSE Z = 0.105944
# Test:  MSE Total = 0.427557,  MSE X = 0.225715,  MSE Z = 0.165536
#
# Epoch 60
# Train: MSE Total = 0.177527,  MSE X = 0.077775,  MSE Z = 0.100431
# Test:  MSE Total = 0.356102,  MSE X = 0.177846,  MSE Z = 0.158043
#
# Epoch 61
# Train: MSE Total = 0.178192,  MSE X = 0.080237,  MSE Z = 0.096493
# Test:  MSE Total = 0.345886,  MSE X = 0.166196,  MSE Z = 0.166526
#
# Epoch 62
# Train: MSE Total = 0.167926,  MSE X = 0.074557,  MSE Z = 0.093034
# Test:  MSE Total = 0.361049,  MSE X = 0.187738,  MSE Z = 0.145484
#
# Epoch 63
# Train: MSE Total = 0.170769,  MSE X = 0.076157,  MSE Z = 0.093940
# Test:  MSE Total = 0.408710,  MSE X = 0.211317,  MSE Z = 0.167082
#
# Epoch 64
# Train: MSE Total = 0.182591,  MSE X = 0.082429,  MSE Z = 0.098455
# Test:  MSE Total = 0.380436,  MSE X = 0.179392,  MSE Z = 0.189929
#
# Epoch 65
# Train: MSE Total = 0.181722,  MSE X = 0.082689,  MSE Z = 0.096689
# Test:  MSE Total = 0.357843,  MSE X = 0.172210,  MSE Z = 0.171749
#
# Epoch 66
# Train: MSE Total = 0.197104,  MSE X = 0.092731,  MSE Z = 0.098825
# Test:  MSE Total = 0.360453,  MSE X = 0.182530,  MSE Z = 0.154983
#
# Epoch 67
# Train: MSE Total = 0.182615,  MSE X = 0.085006,  MSE Z = 0.093365
# Test:  MSE Total = 0.357630,  MSE X = 0.175222,  MSE Z = 0.165454
#
# Epoch 68
# Train: MSE Total = 0.155727,  MSE X = 0.067934,  MSE Z = 0.088676
# Test:  MSE Total = 0.381732,  MSE X = 0.199868,  MSE Z = 0.151083
#
# Epoch 69
# Train: MSE Total = 0.153176,  MSE X = 0.067904,  MSE Z = 0.085069
# Test:  MSE Total = 0.338037,  MSE X = 0.162444,  MSE Z = 0.162709
#
# Epoch 70
# Train: MSE Total = 0.167130,  MSE X = 0.074622,  MSE Z = 0.091762
# Test:  MSE Total = 0.404206,  MSE X = 0.194909,  MSE Z = 0.193232
#
# Epoch 71
# Train: MSE Total = 0.197132,  MSE X = 0.091164,  MSE Z = 0.101979
# Test:  MSE Total = 0.339284,  MSE X = 0.162852,  MSE Z = 0.163688
#
# Epoch 72
# Train: MSE Total = 0.144189,  MSE X = 0.062729,  MSE Z = 0.082448
# Test:  MSE Total = 0.381918,  MSE X = 0.191712,  MSE Z = 0.167567
#
# Epoch 73
# Train: MSE Total = 0.140565,  MSE X = 0.060886,  MSE Z = 0.080905
# Test:  MSE Total = 0.359298,  MSE X = 0.174577,  MSE Z = 0.169134
#
# Epoch 74
# Train: MSE Total = 0.144998,  MSE X = 0.063372,  MSE Z = 0.082331
# Test:  MSE Total = 0.421761,  MSE X = 0.213802,  MSE Z = 0.180891
#
# Epoch 75
# Train: MSE Total = 0.147022,  MSE X = 0.065883,  MSE Z = 0.080247
# Test:  MSE Total = 0.337652,  MSE X = 0.149601,  MSE Z = 0.187688
#
# Epoch 76
# Train: MSE Total = 0.144619,  MSE X = 0.065061,  MSE Z = 0.078427
# Test:  MSE Total = 0.356000,  MSE X = 0.173650,  MSE Z = 0.166238
#
# Epoch 77
# Train: MSE Total = 0.149456,  MSE X = 0.067361,  MSE Z = 0.080806
# Test:  MSE Total = 0.416431,  MSE X = 0.204682,  MSE Z = 0.191365
#
# Epoch 78
# Train: MSE Total = 0.138227,  MSE X = 0.059166,  MSE Z = 0.080965
# Test:  MSE Total = 0.361717,  MSE X = 0.171386,  MSE Z = 0.178952
#
# Epoch 79
# Train: MSE Total = 0.131733,  MSE X = 0.055509,  MSE Z = 0.078904
# Test:  MSE Total = 0.352395,  MSE X = 0.171906,  MSE Z = 0.164524
#
# Epoch 80
# Train: MSE Total = 0.132201,  MSE X = 0.058188,  MSE Z = 0.074252
# Test:  MSE Total = 0.353233,  MSE X = 0.167493,  MSE Z = 0.174502
#
# Epoch 81
# Train: MSE Total = 0.124308,  MSE X = 0.053514,  MSE Z = 0.072203
# Test:  MSE Total = 0.384593,  MSE X = 0.188626,  MSE Z = 0.177544
#
# Epoch 82
# Train: MSE Total = 0.142918,  MSE X = 0.064337,  MSE Z = 0.077424
# Test:  MSE Total = 0.342486,  MSE X = 0.162698,  MSE Z = 0.168595
#
# Epoch 83
# Train: MSE Total = 0.128603,  MSE X = 0.056369,  MSE Z = 0.072697
# Test:  MSE Total = 0.389825,  MSE X = 0.198316,  MSE Z = 0.165798
#
# Epoch 84
# Train: MSE Total = 0.117268,  MSE X = 0.050035,  MSE Z = 0.069006
# Test:  MSE Total = 0.345757,  MSE X = 0.162569,  MSE Z = 0.173552
#
# Epoch 85
# Train: MSE Total = 0.127070,  MSE X = 0.057061,  MSE Z = 0.069121
# Test:  MSE Total = 0.361363,  MSE X = 0.171601,  MSE Z = 0.178016
#
# Epoch 86
# Train: MSE Total = 0.113568,  MSE X = 0.049767,  MSE Z = 0.064223
# Test:  MSE Total = 0.334073,  MSE X = 0.157244,  MSE Z = 0.167352
#
# Epoch 87
# Train: MSE Total = 0.122388,  MSE X = 0.054369,  MSE Z = 0.067746
# Test:  MSE Total = 0.376194,  MSE X = 0.186764,  MSE Z = 0.169180
#
# Epoch 88
# Train: MSE Total = 0.113767,  MSE X = 0.049544,  MSE Z = 0.064954
# Test:  MSE Total = 0.374892,  MSE X = 0.178873,  MSE Z = 0.182996
#
# Epoch 89
# Train: MSE Total = 0.108341,  MSE X = 0.046820,  MSE Z = 0.062572
# Test:  MSE Total = 0.394331,  MSE X = 0.196517,  MSE Z = 0.175848
#
# Epoch 90
# Train: MSE Total = 0.104159,  MSE X = 0.045471,  MSE Z = 0.059246
# Test:  MSE Total = 0.400664,  MSE X = 0.201832,  MSE Z = 0.174379
#
# Epoch 91
# Train: MSE Total = 0.122914,  MSE X = 0.053690,  MSE Z = 0.069852
# Test:  MSE Total = 0.348002,  MSE X = 0.168086,  MSE Z = 0.165810
#
# Epoch 92
# Train: MSE Total = 0.109529,  MSE X = 0.047394,  MSE Z = 0.063138
# Test:  MSE Total = 0.349612,  MSE X = 0.175402,  MSE Z = 0.153577
#
# Epoch 93
# Train: MSE Total = 0.107675,  MSE X = 0.046630,  MSE Z = 0.061994
# Test:  MSE Total = 0.361950,  MSE X = 0.168169,  MSE Z = 0.185682
#
# Epoch 94
# Train: MSE Total = 0.107857,  MSE X = 0.045925,  MSE Z = 0.063656
# Test:  MSE Total = 0.361119,  MSE X = 0.176984,  MSE Z = 0.166964
#
# Epoch 95
# Train: MSE Total = 0.101546,  MSE X = 0.043672,  MSE Z = 0.059069
# Test:  MSE Total = 0.349267,  MSE X = 0.170811,  MSE Z = 0.162209
#
# Epoch 96
# Train: MSE Total = 0.096099,  MSE X = 0.040769,  MSE Z = 0.057013
# Test:  MSE Total = 0.349233,  MSE X = 0.169077,  MSE Z = 0.165606
#
# Epoch 97
# Train: MSE Total = 0.097138,  MSE X = 0.040638,  MSE Z = 0.058768
# Test:  MSE Total = 0.385114,  MSE X = 0.196494,  MSE Z = 0.162650
#
# Epoch 98
# Train: MSE Total = 0.095722,  MSE X = 0.040007,  MSE Z = 0.057987
# Test:  MSE Total = 0.359771,  MSE X = 0.183064,  MSE Z = 0.152940
#
# Epoch 99
# Train: MSE Total = 0.097594,  MSE X = 0.042647,  MSE Z = 0.055428
# Test:  MSE Total = 0.394542,  MSE X = 0.194494,  MSE Z = 0.180172
#
# Epoch 100
# Train: MSE Total = 0.093812,  MSE X = 0.040970,  MSE Z = 0.053328
# Test:  MSE Total = 0.374712,  MSE X = 0.183161,  MSE Z = 0.174213
#
# Got the weights of the epoch 21
# Execution time: 3 minutes, 9.76 seconds

# %%
# Plot delle loss del modello one shot

print("One shot model losses:")
plot_loss(epochs, one_shot_history)
# Out:
# One shot model losses:

# %%
# Salvataggio pesi del modello one shot

torch.save(one_shot_model.state_dict(), "pred_from_past_and_pc_geom_oneshot_model")
print("One shot model weights saved in 'pred_from_past_and_pc_geom_oneshot_model'!")
# Out:
# One shot model weights saved in 'pred_from_past_and_pc_geom_oneshot_model'!

# %% [markdown]
# ## Evaluation

# %%
# Funzione che seleziona alcune traiettorie dal test set e le plott­a insieme alle traiettorie future predette
# dal modello

def evaluate_trajectories(model, device, test_loader):

    model.eval()

    examples = []
    batch_indices = 6   # numero batch consecutivi usati
    example_index = [9, 9, 9, 0, 5, 50]

    # Itera sui primi 6 batch del test_loader
    for b_idx, batch in enumerate(test_loader):
        if b_idx >= batch_indices:
            break

        past_batch, future_batch, pc_batch = batch
        
        examples.append((past_batch[example_index[b_idx]], future_batch[example_index[b_idx]], 
                         pc_batch[example_index[b_idx]]))

    examples[3], examples[4], examples[5] = examples[4], examples[5], examples[3]    

    _, axes = plt.subplots(2, 3, figsize=(15, 10))

    for i, (past, future, pc) in enumerate(examples):
        
        all_points = torch.cat((past, future), 0)
        past_np = past.cpu().numpy()
        future_np = future.cpu().numpy()

        # Predizione del modello
        past_tensor = past.unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
        pc_tensor = pc.unsqueeze(0).to(device)
        with torch.no_grad():
            predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e 
                                                                                               # converte in numpy

        row, col = divmod(i, 3)  # Converte i in (riga, colonna)

        # Plot
        axes[row, col].plot(past_np[:, 0], past_np[:, 1], 'g-o', label="Past Trajectory") 
        axes[row, col].plot(future_np[:, 0], future_np[:, 1], 'r-o', label="Real Future Trajectory") 
        axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
        
        axes[row, col].set_xlabel("X")
        axes[row, col].set_ylabel("Z")
        axes[row, col].set_title(f"Case {i+1}")
        axes[row, col].legend()
        axes[row, col].grid()

        x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
        z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
        
        x_min_tick = float(np.floor(float(x_min)))
        x_max_tick = float(np.ceil(float(x_max)))
        z_min_tick = float(np.floor(float(z_min)))
        z_max_tick = float(np.ceil(float(z_max)))

        axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
        axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

    plt.tight_layout()
    plt.show()

# %%
# Funzione che calcola e printa ADE e FDE del modello sul train e sul test set

def performance_measurement(model, device, train_loader, test_loader, label=''):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'{label} model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\n{label} model performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
# Istanzia il modello autoregressivo e ne carica i pesi

autoregressive_model = AutoregressiveModel(input_size=input_size, hidden_size=hidden_size, 
                            output_size=input_size, num_layers=num_layers, 
                            future_steps=future_seconds*framerate).to(device)

autoregressive_model.load_state_dict(torch.load("pred_from_past_and_pc_geom_autoreg_model"))

autoregressive_model.eval()
# Out:
# AutoregressiveModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=128, bias=True)
#   (pc_emb_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
# Evaluation del modello autoregressivo (plot traiettorie + calcolo metriche)

print("Evaluating autoregressive model trajectories:")
evaluate_trajectories(autoregressive_model, device, test_loader)

performance_measurement(autoregressive_model, device, train_loader, test_loader, label="Autoregressive")
# Out:
# Evaluating autoregressive model trajectories:
# Autoregressive model performances on train set:
#
# ADE Total = 0.427022,   ADE X = 0.236665,   ADE Z = 0.305731
# FDE Total = 0.913036,   FDE X = 0.632566,   FDE Z = 0.543130
#
# Autoregressive model performances on test set:
#
# ADE Total = 0.388991,   ADE X = 0.235415,   ADE Z = 0.260713
# FDE Total = 0.867274,   FDE X = 0.636929,   FDE Z = 0.474974

# %%
# Istanzia il modello one shot e ne carica i pesi

one_shot_model = OneShotModel(input_size=input_size, hidden_size=hidden_size, 
                              output_size=input_size*future_seconds*framerate, num_layers=num_layers, 
                              future_steps=future_seconds*framerate).to(device)

one_shot_model.load_state_dict(torch.load("pred_from_past_and_pc_geom_oneshot_model"))

one_shot_model.eval()
# Out:
# OneShotModel(
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=128, bias=True)
#   (pc_emb_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=80, bias=True)
# )

# %%
# Evaluation del modello one shot (plot traiettorie + calcolo metriche)

print("Evaluating one shot model trajectories:")
evaluate_trajectories(one_shot_model, device, test_loader)

performance_measurement(one_shot_model, device, train_loader, test_loader, label="One shot")
# Out:
# Evaluating one shot model trajectories:
# One shot model performances on train set:
#
# ADE Total = 0.385189,   ADE X = 0.234076,   ADE Z = 0.253912
# FDE Total = 0.865675,   FDE X = 0.606897,   FDE Z = 0.497828
#
# One shot model performances on test set:
#
# ADE Total = 0.366299,   ADE X = 0.220494,   ADE Z = 0.246985
# FDE Total = 0.837170,   FDE X = 0.576071,   FDE Z = 0.491083
