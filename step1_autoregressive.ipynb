# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.npz_files = sorted(all_files, key=extract_number)

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32) 

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        #past_trajectory = torch.flip(past_trajectory, [0])

        return past_trajectory, future_trajectory

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.hidden_size  = hidden_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                                 # sequenza (ultimo punto escluso) # ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                          hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                         framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch = batch
print(future_batch.shape)

for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z

all_x_values = []
all_z_values = []

for past, future in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.3510107398033142
# Global variance of the z-coordinate: 4.372647285461426

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    '''
    if(epoch!=1 and test_loss_total - test_losses_total[-1] > 0.6): 
        model.load_state_dict(best_weights)
        print(f"Early stopping applied! Got the weights of the epoch {best_epoch}")
        break
    '''

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.443826,   MSE X = 0.518188,   MSE Z = 1.190228
# Test: MSE Total = 1.102210,   MSE X = 0.536348,   MSE Z = 0.411783
#
#
# Train Epoch 2: MSE Total = 1.012532,   MSE X = 0.513345,   MSE Z = 0.305449
# Test: MSE Total = 1.022639,   MSE X = 0.540224,   MSE Z = 0.231711
#
#
# Train Epoch 3: MSE Total = 0.993522,   MSE X = 0.519707,   MSE Z = 0.243240
# Test: MSE Total = 1.029010,   MSE X = 0.540033,   MSE Z = 0.245707
#
#
# Train Epoch 4: MSE Total = 0.969800,   MSE X = 0.505638,   MSE Z = 0.243290
# Test: MSE Total = 0.989992,   MSE X = 0.516024,   MSE Z = 0.248857
#
#
# Train Epoch 5: MSE Total = 0.839147,   MSE X = 0.403896,   MSE Z = 0.329183
# Test: MSE Total = 0.649162,   MSE X = 0.302834,   MSE Z = 0.288603
#
#
# Train Epoch 6: MSE Total = 0.596578,   MSE X = 0.279369,   MSE Z = 0.261467
# Test: MSE Total = 0.589094,   MSE X = 0.284794,   MSE Z = 0.226669
#
#
# Train Epoch 7: MSE Total = 0.575375,   MSE X = 0.267632,   MSE Z = 0.258555
# Test: MSE Total = 0.612834,   MSE X = 0.296105,   MSE Z = 0.236388
#
#
# Train Epoch 8: MSE Total = 0.531403,   MSE X = 0.249055,   MSE Z = 0.232174
# Test: MSE Total = 0.605445,   MSE X = 0.268846,   MSE Z = 0.317150
#
#
# Train Epoch 9: MSE Total = 0.518264,   MSE X = 0.243875,   MSE Z = 0.222982
# Test: MSE Total = 0.520198,   MSE X = 0.251985,   MSE Z = 0.198401
#
#
# Train Epoch 10: MSE Total = 0.512020,   MSE X = 0.245084,   MSE Z = 0.205656
# Test: MSE Total = 0.523244,   MSE X = 0.248912,   MSE Z = 0.215618
#
#
# Train Epoch 11: MSE Total = 0.510232,   MSE X = 0.241818,   MSE Z = 0.213443
# Test: MSE Total = 0.512677,   MSE X = 0.246970,   MSE Z = 0.200376
#
#
# Train Epoch 12: MSE Total = 0.492375,   MSE X = 0.235581,   MSE Z = 0.198119
# Test: MSE Total = 0.504018,   MSE X = 0.240428,   MSE Z = 0.205357
#
#
# Train Epoch 13: MSE Total = 0.497789,   MSE X = 0.236373,   MSE Z = 0.206643
# Test: MSE Total = 0.566622,   MSE X = 0.279512,   MSE Z = 0.198319
#
#
# Train Epoch 14: MSE Total = 0.504512,   MSE X = 0.241805,   MSE Z = 0.201532
# Test: MSE Total = 0.502753,   MSE X = 0.244747,   MSE Z = 0.187468
#
#
# Train Epoch 15: MSE Total = 0.482773,   MSE X = 0.231748,   MSE Z = 0.191568
# Test: MSE Total = 0.484613,   MSE X = 0.233857,   MSE Z = 0.187971
#
#
# Train Epoch 16: MSE Total = 0.493939,   MSE X = 0.234093,   MSE Z = 0.206642
# Test: MSE Total = 0.525815,   MSE X = 0.249648,   MSE Z = 0.218393
#
#
# Train Epoch 17: MSE Total = 0.484755,   MSE X = 0.230965,   MSE Z = 0.198475
# Test: MSE Total = 0.501110,   MSE X = 0.244464,   MSE Z = 0.185030
#
#
# Train Epoch 18: MSE Total = 0.483857,   MSE X = 0.230394,   MSE Z = 0.198612
# Test: MSE Total = 0.516602,   MSE X = 0.253000,   MSE Z = 0.187299
#
#
# Train Epoch 19: MSE Total = 0.469643,   MSE X = 0.223807,   MSE Z = 0.192137
# Test: MSE Total = 0.493978,   MSE X = 0.238381,   MSE Z = 0.191588
#
#
# Train Epoch 20: MSE Total = 0.477870,   MSE X = 0.225797,   MSE Z = 0.202317
# Test: MSE Total = 0.485898,   MSE X = 0.236917,   MSE Z = 0.179858
#
#
# Train Epoch 21: MSE Total = 0.474146,   MSE X = 0.227713,   MSE Z = 0.187771
# Test: MSE Total = 0.487618,   MSE X = 0.237768,   MSE Z = 0.180452
#
#
# Train Epoch 22: MSE Total = 0.473075,   MSE X = 0.225931,   MSE Z = 0.191822
# Test: MSE Total = 0.546722,   MSE X = 0.271957,   MSE Z = 0.183375
#
#
# Train Epoch 23: MSE Total = 0.487749,   MSE X = 0.232755,   MSE Z = 0.198419
# Test: MSE Total = 0.551424,   MSE X = 0.264096,   MSE Z = 0.220953
#
#
# Train Epoch 24: MSE Total = 0.479250,   MSE X = 0.227618,   MSE Z = 0.198778
# Test: MSE Total = 0.485868,   MSE X = 0.237310,   MSE Z = 0.178411
#
#
# Train Epoch 25: MSE Total = 0.473321,   MSE X = 0.225809,   MSE Z = 0.192764
# Test: MSE Total = 0.523831,   MSE X = 0.255985,   MSE Z = 0.191881
#
#
# Train Epoch 26: MSE Total = 0.484918,   MSE X = 0.231864,   MSE Z = 0.195642
# Test: MSE Total = 0.487448,   MSE X = 0.237145,   MSE Z = 0.182294
#
#
# Train Epoch 27: MSE Total = 0.461256,   MSE X = 0.219879,   MSE Z = 0.188468
# Test: MSE Total = 0.473182,   MSE X = 0.226649,   MSE Z = 0.189511
#
#
# Train Epoch 28: MSE Total = 0.466866,   MSE X = 0.223190,   MSE Z = 0.188511
# Test: MSE Total = 0.475190,   MSE X = 0.228793,   MSE Z = 0.186141
#
#
# Train Epoch 29: MSE Total = 0.468937,   MSE X = 0.223382,   MSE Z = 0.192163
# Test: MSE Total = 0.527600,   MSE X = 0.251115,   MSE Z = 0.216950
#
#
# Train Epoch 30: MSE Total = 0.469968,   MSE X = 0.225350,   MSE Z = 0.187374
# Test: MSE Total = 0.520734,   MSE X = 0.257928,   MSE Z = 0.178547
#
#
# Train Epoch 31: MSE Total = 0.470243,   MSE X = 0.226119,   MSE Z = 0.185233
# Test: MSE Total = 0.489025,   MSE X = 0.234563,   MSE Z = 0.194704
#
#
# Train Epoch 32: MSE Total = 0.469300,   MSE X = 0.223847,   MSE Z = 0.191282
# Test: MSE Total = 0.517125,   MSE X = 0.243564,   MSE Z = 0.221696
#
#
# Train Epoch 33: MSE Total = 0.468943,   MSE X = 0.223321,   MSE Z = 0.192392
# Test: MSE Total = 0.469536,   MSE X = 0.228580,   MSE Z = 0.175071
#
#
# Train Epoch 34: MSE Total = 0.465616,   MSE X = 0.223182,   MSE Z = 0.185926
# Test: MSE Total = 0.481476,   MSE X = 0.232544,   MSE Z = 0.186046
#
#
# Train Epoch 35: MSE Total = 0.466691,   MSE X = 0.225812,   MSE Z = 0.178892
# Test: MSE Total = 0.463764,   MSE X = 0.225816,   MSE Z = 0.172757
#
#
# Train Epoch 36: MSE Total = 0.456452,   MSE X = 0.218528,   MSE Z = 0.183187
# Test: MSE Total = 0.483207,   MSE X = 0.235340,   MSE Z = 0.179797
#
#
# Train Epoch 37: MSE Total = 0.454745,   MSE X = 0.218683,   MSE Z = 0.179072
# Test: MSE Total = 0.483735,   MSE X = 0.238034,   MSE Z = 0.171394
#
#
# Train Epoch 38: MSE Total = 0.461277,   MSE X = 0.221985,   MSE Z = 0.181076
# Test: MSE Total = 0.469519,   MSE X = 0.231022,   MSE Z = 0.166416
#
#
# Train Epoch 39: MSE Total = 0.457970,   MSE X = 0.221922,   MSE Z = 0.174385
# Test: MSE Total = 0.462162,   MSE X = 0.225524,   MSE Z = 0.170437
#
#
# Train Epoch 40: MSE Total = 0.448311,   MSE X = 0.216630,   MSE Z = 0.172863
# Test: MSE Total = 0.465551,   MSE X = 0.226662,   MSE Z = 0.173505
#
#
# Train Epoch 41: MSE Total = 0.454040,   MSE X = 0.218921,   MSE Z = 0.176756
# Test: MSE Total = 0.468679,   MSE X = 0.230689,   MSE Z = 0.165834
#
#
# Train Epoch 42: MSE Total = 0.451387,   MSE X = 0.216915,   MSE Z = 0.178291
# Test: MSE Total = 0.461530,   MSE X = 0.225723,   MSE Z = 0.168411
#
#
# Train Epoch 43: MSE Total = 0.458007,   MSE X = 0.221240,   MSE Z = 0.176870
# Test: MSE Total = 0.460321,   MSE X = 0.226582,   MSE Z = 0.162852
#
#
# Train Epoch 44: MSE Total = 0.454607,   MSE X = 0.218330,   MSE Z = 0.180027
# Test: MSE Total = 0.462287,   MSE X = 0.225136,   MSE Z = 0.172066
#
#
# Train Epoch 45: MSE Total = 0.454231,   MSE X = 0.219426,   MSE Z = 0.175377
# Test: MSE Total = 0.494411,   MSE X = 0.246307,   MSE Z = 0.164519
#
#
# Train Epoch 46: MSE Total = 0.445121,   MSE X = 0.213954,   MSE Z = 0.175639
# Test: MSE Total = 0.474120,   MSE X = 0.230952,   MSE Z = 0.176283
#
#
# Train Epoch 47: MSE Total = 0.463575,   MSE X = 0.222137,   MSE Z = 0.185346
# Test: MSE Total = 0.472403,   MSE X = 0.232134,   MSE Z = 0.168523
#
#
# Train Epoch 48: MSE Total = 0.443395,   MSE X = 0.213580,   MSE Z = 0.173349
# Test: MSE Total = 0.444115,   MSE X = 0.217742,   MSE Z = 0.160167
#
#
# Train Epoch 49: MSE Total = 0.441014,   MSE X = 0.213514,   MSE Z = 0.168603
# Test: MSE Total = 0.488076,   MSE X = 0.235462,   MSE Z = 0.189550
#
#
# Train Epoch 50: MSE Total = 0.448084,   MSE X = 0.215818,   MSE Z = 0.175256
# Test: MSE Total = 0.446969,   MSE X = 0.218155,   MSE Z = 0.164675
#
#
# Train Epoch 51: MSE Total = 0.431821,   MSE X = 0.207893,   MSE Z = 0.169220
# Test: MSE Total = 0.464113,   MSE X = 0.229370,   MSE Z = 0.160941
#
#
# Train Epoch 52: MSE Total = 0.431301,   MSE X = 0.207456,   MSE Z = 0.169673
# Test: MSE Total = 0.440352,   MSE X = 0.216356,   MSE Z = 0.157187
#
#
# Train Epoch 53: MSE Total = 0.437778,   MSE X = 0.210012,   MSE Z = 0.174196
# Test: MSE Total = 0.455237,   MSE X = 0.221018,   MSE Z = 0.171860
#
#
# Train Epoch 54: MSE Total = 0.451260,   MSE X = 0.216062,   MSE Z = 0.181034
# Test: MSE Total = 0.468448,   MSE X = 0.226028,   MSE Z = 0.181802
#
#
# Train Epoch 55: MSE Total = 0.441662,   MSE X = 0.213276,   MSE Z = 0.170797
# Test: MSE Total = 0.462638,   MSE X = 0.228087,   MSE Z = 0.162385
#
#
# Train Epoch 56: MSE Total = 0.428646,   MSE X = 0.205410,   MSE Z = 0.171342
# Test: MSE Total = 0.468064,   MSE X = 0.228662,   MSE Z = 0.171704
#
#
# Train Epoch 57: MSE Total = 0.430102,   MSE X = 0.205232,   MSE Z = 0.175017
# Test: MSE Total = 0.468588,   MSE X = 0.227227,   MSE Z = 0.177863
#
#
# Train Epoch 58: MSE Total = 0.430929,   MSE X = 0.206950,   MSE Z = 0.170680
# Test: MSE Total = 0.448160,   MSE X = 0.217602,   MSE Z = 0.169116
#
#
# Train Epoch 59: MSE Total = 0.420365,   MSE X = 0.201865,   MSE Z = 0.166539
# Test: MSE Total = 0.434110,   MSE X = 0.212285,   MSE Z = 0.158506
#
#
# Train Epoch 60: MSE Total = 0.423660,   MSE X = 0.201641,   MSE Z = 0.174220
# Test: MSE Total = 0.486666,   MSE X = 0.235748,   MSE Z = 0.185590
#
#
# Train Epoch 61: MSE Total = 0.426671,   MSE X = 0.205289,   MSE Z = 0.167641
# Test: MSE Total = 0.483366,   MSE X = 0.238325,   MSE Z = 0.169594
#
#
# Train Epoch 62: MSE Total = 0.425670,   MSE X = 0.205208,   MSE Z = 0.165833
# Test: MSE Total = 0.467740,   MSE X = 0.230102,   MSE Z = 0.165942
#
#
# Train Epoch 63: MSE Total = 0.416327,   MSE X = 0.199669,   MSE Z = 0.165846
# Test: MSE Total = 0.442046,   MSE X = 0.215686,   MSE Z = 0.163094
#
#
# Train Epoch 64: MSE Total = 0.417883,   MSE X = 0.199523,   MSE Z = 0.169613
# Test: MSE Total = 0.429573,   MSE X = 0.210032,   MSE Z = 0.156969
#
#
# Train Epoch 65: MSE Total = 0.412316,   MSE X = 0.196354,   MSE Z = 0.169161
# Test: MSE Total = 0.473531,   MSE X = 0.232154,   MSE Z = 0.170810
#
#
# Train Epoch 66: MSE Total = 0.433444,   MSE X = 0.204327,   MSE Z = 0.185201
# Test: MSE Total = 0.446290,   MSE X = 0.211942,   MSE Z = 0.185184
#
#
# Train Epoch 67: MSE Total = 0.402176,   MSE X = 0.191366,   MSE Z = 0.165559
# Test: MSE Total = 0.446760,   MSE X = 0.219763,   MSE Z = 0.158563
#
#
# Train Epoch 68: MSE Total = 0.418024,   MSE X = 0.199448,   MSE Z = 0.170175
# Test: MSE Total = 0.474443,   MSE X = 0.232675,   MSE Z = 0.170878
#
#
# Train Epoch 69: MSE Total = 0.412607,   MSE X = 0.197726,   MSE Z = 0.164928
# Test: MSE Total = 0.448978,   MSE X = 0.217504,   MSE Z = 0.171175
#
#
# Train Epoch 70: MSE Total = 0.400166,   MSE X = 0.190608,   MSE Z = 0.164033
# Test: MSE Total = 0.421282,   MSE X = 0.205165,   MSE Z = 0.156809
#
#
# Train Epoch 71: MSE Total = 0.390570,   MSE X = 0.186787,   MSE Z = 0.157452
# Test: MSE Total = 0.425121,   MSE X = 0.207940,   MSE Z = 0.155043
#
#
# Train Epoch 72: MSE Total = 0.395221,   MSE X = 0.188505,   MSE Z = 0.161114
# Test: MSE Total = 0.421417,   MSE X = 0.205803,   MSE Z = 0.154840
#
#
# Train Epoch 73: MSE Total = 0.394067,   MSE X = 0.187960,   MSE Z = 0.160627
# Test: MSE Total = 0.427627,   MSE X = 0.209934,   MSE Z = 0.153245
#
#
# Train Epoch 74: MSE Total = 0.410609,   MSE X = 0.196858,   MSE Z = 0.163811
# Test: MSE Total = 0.461485,   MSE X = 0.227169,   MSE Z = 0.163216
#
#
# Train Epoch 75: MSE Total = 0.387966,   MSE X = 0.185693,   MSE Z = 0.155870
# Test: MSE Total = 0.425076,   MSE X = 0.208659,   MSE Z = 0.152412
#
#
# Train Epoch 76: MSE Total = 0.391610,   MSE X = 0.186333,   MSE Z = 0.161232
# Test: MSE Total = 0.431453,   MSE X = 0.204978,   MSE Z = 0.178737
#
#
# Train Epoch 77: MSE Total = 0.392629,   MSE X = 0.186004,   MSE Z = 0.164522
# Test: MSE Total = 0.421018,   MSE X = 0.202582,   MSE Z = 0.165376
#
#
# Train Epoch 78: MSE Total = 0.380059,   MSE X = 0.181700,   MSE Z = 0.153431
# Test: MSE Total = 0.441266,   MSE X = 0.218931,   MSE Z = 0.150011
#
#
# Train Epoch 79: MSE Total = 0.370839,   MSE X = 0.176305,   MSE Z = 0.153190
# Test: MSE Total = 0.437940,   MSE X = 0.209689,   MSE Z = 0.175677
#
#
# Train Epoch 80: MSE Total = 0.383664,   MSE X = 0.181974,   MSE Z = 0.159997
# Test: MSE Total = 0.453227,   MSE X = 0.223505,   MSE Z = 0.158879
#
#
# Train Epoch 81: MSE Total = 0.397096,   MSE X = 0.189893,   MSE Z = 0.160136
# Test: MSE Total = 0.410112,   MSE X = 0.200039,   MSE Z = 0.151544
#
#
# Train Epoch 82: MSE Total = 0.369317,   MSE X = 0.175260,   MSE Z = 0.153695
# Test: MSE Total = 0.453653,   MSE X = 0.220392,   MSE Z = 0.170756
#
#
# Train Epoch 83: MSE Total = 0.393806,   MSE X = 0.187531,   MSE Z = 0.161593
# Test: MSE Total = 0.419029,   MSE X = 0.203344,   MSE Z = 0.158525
#
#
# Train Epoch 84: MSE Total = 0.374603,   MSE X = 0.178687,   MSE Z = 0.152654
# Test: MSE Total = 0.408491,   MSE X = 0.199106,   MSE Z = 0.151446
#
#
# Train Epoch 85: MSE Total = 0.372968,   MSE X = 0.177415,   MSE Z = 0.153726
# Test: MSE Total = 0.413768,   MSE X = 0.202490,   MSE Z = 0.150540
#
#
# Train Epoch 86: MSE Total = 0.366463,   MSE X = 0.173148,   MSE Z = 0.155182
# Test: MSE Total = 0.406646,   MSE X = 0.198356,   MSE Z = 0.150238
#
#
# Train Epoch 87: MSE Total = 0.355433,   MSE X = 0.168559,   MSE Z = 0.148314
# Test: MSE Total = 0.390937,   MSE X = 0.189676,   MSE Z = 0.148022
#
#
# Train Epoch 88: MSE Total = 0.361820,   MSE X = 0.169662,   MSE Z = 0.157777
# Test: MSE Total = 0.447617,   MSE X = 0.220402,   MSE Z = 0.158099
#
#
# Train Epoch 89: MSE Total = 0.374985,   MSE X = 0.177785,   MSE Z = 0.156635
# Test: MSE Total = 0.423391,   MSE X = 0.205239,   MSE Z = 0.160958
#
#
# Train Epoch 90: MSE Total = 0.367680,   MSE X = 0.175770,   MSE Z = 0.148472
# Test: MSE Total = 0.411810,   MSE X = 0.200373,   MSE Z = 0.153919
#
#
# Train Epoch 91: MSE Total = 0.351363,   MSE X = 0.166210,   MSE Z = 0.148095
# Test: MSE Total = 0.425995,   MSE X = 0.208362,   MSE Z = 0.155380
#
#
# Train Epoch 92: MSE Total = 0.371487,   MSE X = 0.177468,   MSE Z = 0.150438
# Test: MSE Total = 0.414813,   MSE X = 0.199257,   MSE Z = 0.164135
#
#
# Train Epoch 93: MSE Total = 0.345398,   MSE X = 0.162228,   MSE Z = 0.149675
# Test: MSE Total = 0.394959,   MSE X = 0.187671,   MSE Z = 0.163511
#
#
# Train Epoch 94: MSE Total = 0.341112,   MSE X = 0.160525,   MSE Z = 0.146722
# Test: MSE Total = 0.403798,   MSE X = 0.194423,   MSE Z = 0.158164
#
#
# Train Epoch 95: MSE Total = 0.351543,   MSE X = 0.166164,   MSE Z = 0.148633
# Test: MSE Total = 0.407237,   MSE X = 0.196501,   MSE Z = 0.158021
#
#
# Train Epoch 96: MSE Total = 0.360236,   MSE X = 0.168315,   MSE Z = 0.159218
# Test: MSE Total = 0.403044,   MSE X = 0.194319,   MSE Z = 0.156955
#
#
# Train Epoch 97: MSE Total = 0.340701,   MSE X = 0.160241,   MSE Z = 0.146866
# Test: MSE Total = 0.386368,   MSE X = 0.185794,   MSE Z = 0.152173
#
#
# Train Epoch 98: MSE Total = 0.338596,   MSE X = 0.158875,   MSE Z = 0.147286
# Test: MSE Total = 0.385205,   MSE X = 0.187351,   MSE Z = 0.144244
#
#
# Train Epoch 99: MSE Total = 0.329918,   MSE X = 0.155216,   MSE Z = 0.142054
# Test: MSE Total = 0.379529,   MSE X = 0.184306,   MSE Z = 0.143123
#
#
# Train Epoch 100: MSE Total = 0.339240,   MSE X = 0.158744,   MSE Z = 0.149095
# Test: MSE Total = 0.380525,   MSE X = 0.183735,   MSE Z = 0.147221
#
#
# Train Epoch 101: MSE Total = 0.327589,   MSE X = 0.153565,   MSE Z = 0.143011
# Test: MSE Total = 0.395244,   MSE X = 0.190766,   MSE Z = 0.153184
#
#
# Train Epoch 102: MSE Total = 0.323218,   MSE X = 0.151341,   MSE Z = 0.141721
# Test: MSE Total = 0.388498,   MSE X = 0.188057,   MSE Z = 0.148638
#
#
# Train Epoch 103: MSE Total = 0.337471,   MSE X = 0.159421,   MSE Z = 0.143006
# Test: MSE Total = 0.410739,   MSE X = 0.199069,   MSE Z = 0.156280
#
#
# Train Epoch 104: MSE Total = 0.321746,   MSE X = 0.150637,   MSE Z = 0.141128
# Test: MSE Total = 0.379728,   MSE X = 0.182571,   MSE Z = 0.149663
#
#
# Train Epoch 105: MSE Total = 0.305596,   MSE X = 0.142294,   MSE Z = 0.136804
# Test: MSE Total = 0.421290,   MSE X = 0.206674,   MSE Z = 0.151500
#
#
# Train Epoch 106: MSE Total = 0.325302,   MSE X = 0.151579,   MSE Z = 0.145239
# Test: MSE Total = 0.360062,   MSE X = 0.172613,   MSE Z = 0.143685
#
#
# Train Epoch 107: MSE Total = 0.306338,   MSE X = 0.143318,   MSE Z = 0.134739
# Test: MSE Total = 0.353007,   MSE X = 0.167413,   MSE Z = 0.147285
#
#
# Train Epoch 108: MSE Total = 0.300982,   MSE X = 0.140028,   MSE Z = 0.135153
# Test: MSE Total = 0.376064,   MSE X = 0.181309,   MSE Z = 0.146454
#
#
# Train Epoch 109: MSE Total = 0.304719,   MSE X = 0.141783,   MSE Z = 0.136772
# Test: MSE Total = 0.370791,   MSE X = 0.177757,   MSE Z = 0.147966
#
#
# Train Epoch 110: MSE Total = 0.307177,   MSE X = 0.143607,   MSE Z = 0.135475
# Test: MSE Total = 0.379145,   MSE X = 0.182160,   MSE Z = 0.149892
#
#
# Train Epoch 111: MSE Total = 0.290767,   MSE X = 0.135215,   MSE Z = 0.130779
# Test: MSE Total = 0.366110,   MSE X = 0.172316,   MSE Z = 0.157380
#
#
# Train Epoch 112: MSE Total = 0.290683,   MSE X = 0.134081,   MSE Z = 0.134608
# Test: MSE Total = 0.382994,   MSE X = 0.185281,   MSE Z = 0.146928
#
#
# Train Epoch 113: MSE Total = 0.277180,   MSE X = 0.127357,   MSE Z = 0.130104
# Test: MSE Total = 0.369022,   MSE X = 0.178275,   MSE Z = 0.142439
#
#
# Train Epoch 114: MSE Total = 0.288781,   MSE X = 0.133217,   MSE Z = 0.133678
# Test: MSE Total = 0.349349,   MSE X = 0.165167,   MSE Z = 0.147564
#
#
# Train Epoch 115: MSE Total = 0.275445,   MSE X = 0.126515,   MSE Z = 0.129446
# Test: MSE Total = 0.375680,   MSE X = 0.180061,   MSE Z = 0.150055
#
#
# Train Epoch 116: MSE Total = 0.271631,   MSE X = 0.124409,   MSE Z = 0.128902
# Test: MSE Total = 0.348258,   MSE X = 0.166610,   MSE Z = 0.140190
#
#
# Train Epoch 117: MSE Total = 0.274632,   MSE X = 0.125809,   MSE Z = 0.130237
# Test: MSE Total = 0.378573,   MSE X = 0.173935,   MSE Z = 0.177728
#
#
# Train Epoch 118: MSE Total = 0.263968,   MSE X = 0.118827,   MSE Z = 0.132579
# Test: MSE Total = 0.344149,   MSE X = 0.162587,   MSE Z = 0.145795
#
#
# Train Epoch 119: MSE Total = 0.270786,   MSE X = 0.123426,   MSE Z = 0.130606
# Test: MSE Total = 0.349333,   MSE X = 0.166734,   MSE Z = 0.142000
#
#
# Train Epoch 120: MSE Total = 0.249781,   MSE X = 0.114393,   MSE Z = 0.118565
# Test: MSE Total = 0.323127,   MSE X = 0.152375,   MSE Z = 0.137881
#
#
# Train Epoch 121: MSE Total = 0.243652,   MSE X = 0.111446,   MSE Z = 0.116148
# Test: MSE Total = 0.318307,   MSE X = 0.146853,   MSE Z = 0.147289
#
#
# Train Epoch 122: MSE Total = 0.254137,   MSE X = 0.115508,   MSE Z = 0.123739
# Test: MSE Total = 0.322918,   MSE X = 0.150166,   MSE Z = 0.145243
#
#
# Train Epoch 123: MSE Total = 0.259329,   MSE X = 0.119100,   MSE Z = 0.121918
# Test: MSE Total = 0.316938,   MSE X = 0.149013,   MSE Z = 0.136805
#
#
# Train Epoch 124: MSE Total = 0.253323,   MSE X = 0.115216,   MSE Z = 0.123065
# Test: MSE Total = 0.375289,   MSE X = 0.176332,   MSE Z = 0.162398
#
#
# Train Epoch 125: MSE Total = 0.265710,   MSE X = 0.121628,   MSE Z = 0.126338
# Test: MSE Total = 0.334614,   MSE X = 0.157441,   MSE Z = 0.144019
#
#
# Train Epoch 126: MSE Total = 0.238001,   MSE X = 0.107497,   MSE Z = 0.118272
# Test: MSE Total = 0.325204,   MSE X = 0.153708,   MSE Z = 0.137518
#
#
# Train Epoch 127: MSE Total = 0.217016,   MSE X = 0.096727,   MSE Z = 0.112401
# Test: MSE Total = 0.313371,   MSE X = 0.146846,   MSE Z = 0.136993
#
#
# Train Epoch 128: MSE Total = 0.217735,   MSE X = 0.097045,   MSE Z = 0.112784
# Test: MSE Total = 0.340016,   MSE X = 0.159122,   MSE Z = 0.149383
#
#
# Train Epoch 129: MSE Total = 0.232962,   MSE X = 0.105464,   MSE Z = 0.114911
# Test: MSE Total = 0.319020,   MSE X = 0.148387,   MSE Z = 0.143367
#
#
# Train Epoch 130: MSE Total = 0.226350,   MSE X = 0.102053,   MSE Z = 0.113123
# Test: MSE Total = 0.328082,   MSE X = 0.155222,   MSE Z = 0.138194
#
#
# Train Epoch 131: MSE Total = 0.224532,   MSE X = 0.100555,   MSE Z = 0.114609
# Test: MSE Total = 0.310455,   MSE X = 0.142577,   MSE Z = 0.145966
#
#
# Train Epoch 132: MSE Total = 0.224775,   MSE X = 0.101200,   MSE Z = 0.112841
# Test: MSE Total = 0.307184,   MSE X = 0.142067,   MSE Z = 0.140925
#
#
# Train Epoch 133: MSE Total = 0.201020,   MSE X = 0.088283,   MSE Z = 0.108756
# Test: MSE Total = 0.310400,   MSE X = 0.143702,   MSE Z = 0.141879
#
#
# Train Epoch 134: MSE Total = 0.204986,   MSE X = 0.090411,   MSE Z = 0.109540
# Test: MSE Total = 0.298763,   MSE X = 0.138329,   MSE Z = 0.136508
#
#
# Train Epoch 135: MSE Total = 0.184604,   MSE X = 0.080566,   MSE Z = 0.101667
# Test: MSE Total = 0.297249,   MSE X = 0.137439,   MSE Z = 0.136484
#
#
# Train Epoch 136: MSE Total = 0.181412,   MSE X = 0.078893,   MSE Z = 0.100897
# Test: MSE Total = 0.299335,   MSE X = 0.138643,   MSE Z = 0.136596
#
#
# Train Epoch 137: MSE Total = 0.183127,   MSE X = 0.079410,   MSE Z = 0.102655
# Test: MSE Total = 0.326552,   MSE X = 0.147995,   MSE Z = 0.160504
#
#
# Train Epoch 138: MSE Total = 0.186228,   MSE X = 0.080385,   MSE Z = 0.105702
# Test: MSE Total = 0.298357,   MSE X = 0.138320,   MSE Z = 0.135693
#
#
# Train Epoch 139: MSE Total = 0.201707,   MSE X = 0.089785,   MSE Z = 0.104891
# Test: MSE Total = 0.293268,   MSE X = 0.135576,   MSE Z = 0.134733
#
#
# Train Epoch 140: MSE Total = 0.177312,   MSE X = 0.077310,   MSE Z = 0.097909
# Test: MSE Total = 0.284299,   MSE X = 0.130205,   MSE Z = 0.134935
#
#
# Train Epoch 141: MSE Total = 0.174556,   MSE X = 0.074484,   MSE Z = 0.102121
# Test: MSE Total = 0.301536,   MSE X = 0.140524,   MSE Z = 0.134561
#
#
# Train Epoch 142: MSE Total = 0.186342,   MSE X = 0.081160,   MSE Z = 0.103205
# Test: MSE Total = 0.323485,   MSE X = 0.152430,   MSE Z = 0.138434
#
#
# Train Epoch 143: MSE Total = 0.168647,   MSE X = 0.072811,   MSE Z = 0.095670
# Test: MSE Total = 0.284580,   MSE X = 0.131871,   MSE Z = 0.129644
#
#
# Train Epoch 144: MSE Total = 0.169788,   MSE X = 0.073801,   MSE Z = 0.094562
# Test: MSE Total = 0.295893,   MSE X = 0.136198,   MSE Z = 0.138028
#
#
# Train Epoch 145: MSE Total = 0.170095,   MSE X = 0.074092,   MSE Z = 0.094175
# Test: MSE Total = 0.299234,   MSE X = 0.139299,   MSE Z = 0.134071
#
#
# Train Epoch 146: MSE Total = 0.157190,   MSE X = 0.066937,   MSE Z = 0.092443
# Test: MSE Total = 0.288556,   MSE X = 0.128101,   MSE Z = 0.151265
#
#
# Train Epoch 147: MSE Total = 0.157023,   MSE X = 0.065307,   MSE Z = 0.097848
# Test: MSE Total = 0.308547,   MSE X = 0.137377,   MSE Z = 0.160329
#
#
# Train Epoch 148: MSE Total = 0.143947,   MSE X = 0.059825,   MSE Z = 0.089854
# Test: MSE Total = 0.271405,   MSE X = 0.121651,   MSE Z = 0.138165
#
#
# Train Epoch 149: MSE Total = 0.140583,   MSE X = 0.058878,   MSE Z = 0.086163
# Test: MSE Total = 0.273859,   MSE X = 0.125157,   MSE Z = 0.130922
#
#
# Train Epoch 150: MSE Total = 0.157852,   MSE X = 0.067852,   MSE Z = 0.090601
# Test: MSE Total = 0.272976,   MSE X = 0.123672,   MSE Z = 0.134320
#
#
# Train Epoch 151: MSE Total = 0.136151,   MSE X = 0.056698,   MSE Z = 0.084590
# Test: MSE Total = 0.257167,   MSE X = 0.116125,   MSE Z = 0.127897
#
#
# Train Epoch 152: MSE Total = 0.139099,   MSE X = 0.057681,   MSE Z = 0.087283
# Test: MSE Total = 0.277161,   MSE X = 0.127611,   MSE Z = 0.129168
#
#
# Train Epoch 153: MSE Total = 0.144306,   MSE X = 0.061398,   MSE Z = 0.085051
# Test: MSE Total = 0.279091,   MSE X = 0.125236,   MSE Z = 0.141585
#
#
# Train Epoch 154: MSE Total = 0.129076,   MSE X = 0.054106,   MSE Z = 0.078941
# Test: MSE Total = 0.260161,   MSE X = 0.117659,   MSE Z = 0.128744
#
#
# Train Epoch 155: MSE Total = 0.135515,   MSE X = 0.057032,   MSE Z = 0.082077
# Test: MSE Total = 0.264047,   MSE X = 0.119561,   MSE Z = 0.130155
#
#
# Train Epoch 156: MSE Total = 0.146157,   MSE X = 0.062966,   MSE Z = 0.083389
# Test: MSE Total = 0.266558,   MSE X = 0.121208,   MSE Z = 0.129595
#
#
# Train Epoch 157: MSE Total = 0.136589,   MSE X = 0.056083,   MSE Z = 0.087676
# Test: MSE Total = 0.274226,   MSE X = 0.123992,   MSE Z = 0.135804
#
#
# Train Epoch 158: MSE Total = 0.149603,   MSE X = 0.062936,   MSE Z = 0.090703
# Test: MSE Total = 0.304402,   MSE X = 0.136843,   MSE Z = 0.153545
#
#
# Train Epoch 159: MSE Total = 0.144996,   MSE X = 0.061164,   MSE Z = 0.087323
# Test: MSE Total = 0.258677,   MSE X = 0.114243,   MSE Z = 0.137698
#
#
# Train Epoch 160: MSE Total = 0.111590,   MSE X = 0.044855,   MSE Z = 0.075029
# Test: MSE Total = 0.265300,   MSE X = 0.122056,   MSE Z = 0.123971
#
#
# Train Epoch 161: MSE Total = 0.121904,   MSE X = 0.050464,   MSE Z = 0.076799
# Test: MSE Total = 0.281347,   MSE X = 0.129508,   MSE Z = 0.131225
#
#
# Train Epoch 162: MSE Total = 0.124767,   MSE X = 0.052349,   MSE Z = 0.076134
# Test: MSE Total = 0.264535,   MSE X = 0.121688,   MSE Z = 0.123670
#
#
# Train Epoch 163: MSE Total = 0.104452,   MSE X = 0.041614,   MSE Z = 0.071543
# Test: MSE Total = 0.245438,   MSE X = 0.111725,   MSE Z = 0.118901
#
#
# Train Epoch 164: MSE Total = 0.091290,   MSE X = 0.035982,   MSE Z = 0.063895
# Test: MSE Total = 0.251366,   MSE X = 0.112289,   MSE Z = 0.129305
#
#
# Train Epoch 165: MSE Total = 0.125863,   MSE X = 0.052477,   MSE Z = 0.077973
# Test: MSE Total = 0.265204,   MSE X = 0.119655,   MSE Z = 0.132246
#
#
# Train Epoch 166: MSE Total = 0.099913,   MSE X = 0.039295,   MSE Z = 0.070234
# Test: MSE Total = 0.252291,   MSE X = 0.115795,   MSE Z = 0.118865
#
#
# Train Epoch 167: MSE Total = 0.130331,   MSE X = 0.054512,   MSE Z = 0.080133
# Test: MSE Total = 0.285466,   MSE X = 0.127823,   MSE Z = 0.145783
#
#
# Train Epoch 168: MSE Total = 0.123067,   MSE X = 0.051191,   MSE Z = 0.076668
# Test: MSE Total = 0.256337,   MSE X = 0.116083,   MSE Z = 0.126309
#
#
# Train Epoch 169: MSE Total = 0.095399,   MSE X = 0.038001,   MSE Z = 0.065363
# Test: MSE Total = 0.249328,   MSE X = 0.112808,   MSE Z = 0.123211
#
#
# Train Epoch 170: MSE Total = 0.093677,   MSE X = 0.037803,   MSE Z = 0.062460
# Test: MSE Total = 0.239572,   MSE X = 0.108901,   MSE Z = 0.116600
#
#
# Train Epoch 171: MSE Total = 0.074932,   MSE X = 0.028300,   MSE Z = 0.056804
# Test: MSE Total = 0.224911,   MSE X = 0.100849,   MSE Z = 0.114362
#
#
# Train Epoch 172: MSE Total = 0.072002,   MSE X = 0.027820,   MSE Z = 0.052373
# Test: MSE Total = 0.231684,   MSE X = 0.104121,   MSE Z = 0.116977
#
#
# Train Epoch 173: MSE Total = 0.075315,   MSE X = 0.029268,   MSE Z = 0.054191
# Test: MSE Total = 0.228575,   MSE X = 0.102149,   MSE Z = 0.117437
#
#
# Train Epoch 174: MSE Total = 0.073959,   MSE X = 0.028396,   MSE Z = 0.054429
# Test: MSE Total = 0.236714,   MSE X = 0.106130,   MSE Z = 0.120405
#
#
# Train Epoch 175: MSE Total = 0.067432,   MSE X = 0.025726,   MSE Z = 0.050204
# Test: MSE Total = 0.231911,   MSE X = 0.103683,   MSE Z = 0.119000
#
#
# Train Epoch 176: MSE Total = 0.067573,   MSE X = 0.025844,   MSE Z = 0.050085
# Test: MSE Total = 0.229597,   MSE X = 0.103496,   MSE Z = 0.114818
#
#
# Train Epoch 177: MSE Total = 0.071254,   MSE X = 0.027515,   MSE Z = 0.051885
# Test: MSE Total = 0.242694,   MSE X = 0.110888,   MSE Z = 0.116116
#
#
# Train Epoch 178: MSE Total = 0.121759,   MSE X = 0.051979,   MSE Z = 0.071150
# Test: MSE Total = 0.264313,   MSE X = 0.123377,   MSE Z = 0.117243
#
#
# Train Epoch 179: MSE Total = 0.081703,   MSE X = 0.032574,   MSE Z = 0.055878
# Test: MSE Total = 0.237458,   MSE X = 0.106032,   MSE Z = 0.122308
#
#
# Train Epoch 180: MSE Total = 0.064983,   MSE X = 0.024975,   MSE Z = 0.047734
# Test: MSE Total = 0.241736,   MSE X = 0.110624,   MSE Z = 0.115044
#
#
# Train Epoch 181: MSE Total = 0.101514,   MSE X = 0.042671,   MSE Z = 0.061668
# Test: MSE Total = 0.274601,   MSE X = 0.128613,   MSE Z = 0.120277
#
#
# Train Epoch 182: MSE Total = 0.097931,   MSE X = 0.041174,   MSE Z = 0.059460
# Test: MSE Total = 0.293790,   MSE X = 0.136150,   MSE Z = 0.133799
#
#
# Train Epoch 183: MSE Total = 0.112096,   MSE X = 0.047286,   MSE Z = 0.067508
# Test: MSE Total = 0.260240,   MSE X = 0.114754,   MSE Z = 0.139160
#
#
# Train Epoch 184: MSE Total = 0.122033,   MSE X = 0.052137,   MSE Z = 0.071165
# Test: MSE Total = 0.267636,   MSE X = 0.122107,   MSE Z = 0.128675
#
#
# Train Epoch 185: MSE Total = 0.107257,   MSE X = 0.044948,   MSE Z = 0.065642
# Test: MSE Total = 0.279003,   MSE X = 0.128399,   MSE Z = 0.130236
#
#
# Train Epoch 186: MSE Total = 0.081497,   MSE X = 0.032706,   MSE Z = 0.054982
# Test: MSE Total = 0.244195,   MSE X = 0.111189,   MSE Z = 0.118192
#
#
# Train Epoch 187: MSE Total = 0.080056,   MSE X = 0.032766,   MSE Z = 0.051757
# Test: MSE Total = 0.286628,   MSE X = 0.132993,   MSE Z = 0.129966
#
#
# Train Epoch 188: MSE Total = 0.108317,   MSE X = 0.046408,   MSE Z = 0.062705
# Test: MSE Total = 0.293455,   MSE X = 0.137319,   MSE Z = 0.128973
#
#
# Train Epoch 189: MSE Total = 0.099533,   MSE X = 0.041205,   MSE Z = 0.062700
# Test: MSE Total = 0.259003,   MSE X = 0.119069,   MSE Z = 0.121345
#
#
# Train Epoch 190: MSE Total = 0.065798,   MSE X = 0.025628,   MSE Z = 0.047133
# Test: MSE Total = 0.230236,   MSE X = 0.103692,   MSE Z = 0.115463
#
#
# Train Epoch 191: MSE Total = 0.059638,   MSE X = 0.023048,   MSE Z = 0.043361
# Test: MSE Total = 0.233938,   MSE X = 0.105499,   MSE Z = 0.116825
#
#
# Train Epoch 192: MSE Total = 0.059997,   MSE X = 0.023003,   MSE Z = 0.044269
# Test: MSE Total = 0.229089,   MSE X = 0.101977,   MSE Z = 0.119120
#
#
# Train Epoch 193: MSE Total = 0.049339,   MSE X = 0.018160,   MSE Z = 0.039076
# Test: MSE Total = 0.216287,   MSE X = 0.096541,   MSE Z = 0.111535
#
#
# Train Epoch 194: MSE Total = 0.044399,   MSE X = 0.016045,   MSE Z = 0.036210
# Test: MSE Total = 0.214153,   MSE X = 0.094192,   MSE Z = 0.115363
#
#
# Train Epoch 195: MSE Total = 0.043375,   MSE X = 0.015400,   MSE Z = 0.036346
# Test: MSE Total = 0.203785,   MSE X = 0.090195,   MSE Z = 0.107789
#
#
# Train Epoch 196: MSE Total = 0.046426,   MSE X = 0.016830,   MSE Z = 0.037680
# Test: MSE Total = 0.217456,   MSE X = 0.097019,   MSE Z = 0.112293
#
#
# Train Epoch 197: MSE Total = 0.066694,   MSE X = 0.026431,   MSE Z = 0.046177
# Test: MSE Total = 0.246780,   MSE X = 0.113145,   MSE Z = 0.116695
#
#
# Train Epoch 198: MSE Total = 0.097857,   MSE X = 0.040605,   MSE Z = 0.061311
# Test: MSE Total = 0.244542,   MSE X = 0.110657,   MSE Z = 0.120795
#
#
# Train Epoch 199: MSE Total = 0.123956,   MSE X = 0.053571,   MSE Z = 0.070125
# Test: MSE Total = 0.292426,   MSE X = 0.134340,   MSE Z = 0.137335
#
#
# Train Epoch 200: MSE Total = 0.114541,   MSE X = 0.048753,   MSE Z = 0.067444
# Test: MSE Total = 0.263597,   MSE X = 0.119949,   MSE Z = 0.127845
#
#
# Got the weights of the epoch 195
# Execution time: 15 minutes, 38.15 seconds

# %%
torch.save(model.state_dict(), "model_weights_step1_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step1_autoregressive"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch = batch  # estrae passato e futuro dal batch

# seleziona tre esempi diversi dal batch
indices = [5, 10, 15, 20, 25, 26]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future) in enumerate(examples):

    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.148078,   ADE X = 0.069886,   ADE Z = 0.114766
# FDE Total = 0.291294,   FDE X = 0.154270,   FDE Z = 0.212902
#
# Model performances on test set:
#
# ADE Total = 0.291991,   ADE X = 0.158144,   ADE Z = 0.207732
# FDE Total = 0.620667,   FDE X = 0.406913,   FDE Z = 0.379670

# %%
def save_prediction(index):
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _ = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim

    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'    

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiunge la nuova coppia chiave-array
    data_dict['step1_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
