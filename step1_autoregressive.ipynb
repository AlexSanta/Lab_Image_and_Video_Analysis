# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 100
lr = 0.001
train_ratio = 0.75
num_layers = 2
hidden_size= 128
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, past_seconds=2, future_seconds=4, framerate=10, train_ratio=0.75, mode='all'):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.train_ratio = train_ratio
        self.mode = mode

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        all_files_sorted = sorted(all_files, key=extract_number)

        split_index = int(len(all_files_sorted) * train_ratio)

        if mode == "train":
            self.npz_files = all_files_sorted[:split_index]
        elif mode == "test":
            self.npz_files = all_files_sorted[split_index:]
        else:
            self.npz_files = all_files_sorted

    def __len__(self):
        return len(self.npz_files)
    
    def local_smoothing(self, future_traj, iterations=1):
        smoothed_traj = future_traj.clone()

        for _ in range(iterations):
            temp_traj = smoothed_traj.clone()

            prev_points = temp_traj[:-2]
            current_points = temp_traj[1:-1]
            next_points = temp_traj[2:]

            smoothed_traj[1:-1] = 0.25*prev_points + 0.5*current_points + 0.25*next_points   
        
        return smoothed_traj

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32) 

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        past_trajectory = torch.flip(past_trajectory, [0])

        if(self.mode == "train"):
            if(np.random.rand() < 0.5):
                n_iterations = np.random.randint(1, 3)
                future_trajectory = self.local_smoothing(future_trajectory, iterations=n_iterations)

            if np.random.rand() < 0.5:
                # Flip orizzontale
                past_trajectory[:, 0] *= -1
                future_trajectory[:, 0] *= -1

        return past_trajectory, future_trajectory

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.hidden_size  = hidden_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                                 # sequenza (ultimo punto escluso) # ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                          hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
original_dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                         framerate=framerate, mode="all")
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_set = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                        framerate=framerate, train_ratio=train_ratio, mode="train")

test_set = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds,
                        framerate=framerate, train_ratio=train_ratio, mode="test")

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch = batch
print(future_batch.shape)

for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z nel futuro

all_x_values = []
all_z_values = []

for past, future in original_dataset:
    all_x_values.append(future[:, 0])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_var = torch.var(all_x_values)
global_z_var = torch.var(all_z_values)

global_x_std = global_x_var ** 0.5
global_z_std = global_z_var ** 0.5

print(f"Global variance of the future x-coordinate: {global_x_var.item()}")
print(f"Global variance of the future z-coordinate: {global_z_var.item()}")
# Out:
# Global variance of the future x-coordinate: 0.5222423076629639
# Global variance of the future z-coordinate: 2.0641021728515625

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    '''
    if(epoch!=1 and test_loss_total - test_losses_total[-1] > 0.6): 
        model.load_state_dict(best_weights)
        print(f"Early stopping applied! Got the weights of the epoch {best_epoch}")
        break
    '''

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.941505,   MSE X = 0.561670,   MSE Z = 1.672723
# Test: MSE Total = 0.828737,   MSE X = 0.443919,   MSE Z = 0.308109
#
#
# Train Epoch 2: MSE Total = 0.988600,   MSE X = 0.562075,   MSE Z = 0.302881
# Test: MSE Total = 0.796334,   MSE X = 0.454221,   MSE Z = 0.241072
#
#
# Train Epoch 3: MSE Total = 0.937842,   MSE X = 0.556949,   MSE Z = 0.240148
# Test: MSE Total = 0.736525,   MSE X = 0.444530,   MSE Z = 0.174412
#
#
# Train Epoch 4: MSE Total = 0.921036,   MSE X = 0.557048,   MSE Z = 0.215806
# Test: MSE Total = 0.750438,   MSE X = 0.449115,   MSE Z = 0.185286
#
#
# Train Epoch 5: MSE Total = 0.911923,   MSE X = 0.555337,   MSE Z = 0.206116
# Test: MSE Total = 0.734701,   MSE X = 0.445328,   MSE Z = 0.170204
#
#
# Train Epoch 6: MSE Total = 0.918973,   MSE X = 0.555088,   MSE Z = 0.216740
# Test: MSE Total = 0.749233,   MSE X = 0.450009,   MSE Z = 0.181777
#
#
# Train Epoch 7: MSE Total = 0.927727,   MSE X = 0.557152,   MSE Z = 0.225211
# Test: MSE Total = 0.719543,   MSE X = 0.443180,   MSE Z = 0.152698
#
#
# Train Epoch 8: MSE Total = 0.921502,   MSE X = 0.561582,   MSE Z = 0.207461
# Test: MSE Total = 0.736940,   MSE X = 0.461033,   MSE Z = 0.142199
#
#
# Train Epoch 9: MSE Total = 0.922289,   MSE X = 0.565715,   MSE Z = 0.200376
# Test: MSE Total = 0.713930,   MSE X = 0.446076,   MSE Z = 0.138875
#
#
# Train Epoch 10: MSE Total = 0.900177,   MSE X = 0.553066,   MSE Z = 0.193755
# Test: MSE Total = 0.747575,   MSE X = 0.447533,   MSE Z = 0.184316
#
#
# Train Epoch 11: MSE Total = 0.904070,   MSE X = 0.548008,   MSE Z = 0.209403
# Test: MSE Total = 0.727917,   MSE X = 0.428054,   MSE Z = 0.194800
#
#
# Train Epoch 12: MSE Total = 0.823584,   MSE X = 0.464914,   MSE Z = 0.258965
# Test: MSE Total = 0.577291,   MSE X = 0.293743,   MSE Z = 0.245413
#
#
# Train Epoch 13: MSE Total = 0.673897,   MSE X = 0.352548,   MSE Z = 0.267300
# Test: MSE Total = 0.597165,   MSE X = 0.330871,   MSE Z = 0.200156
#
#
# Train Epoch 14: MSE Total = 0.585877,   MSE X = 0.304329,   MSE Z = 0.236703
# Test: MSE Total = 0.396939,   MSE X = 0.186057,   MSE Z = 0.200388
#
#
# Train Epoch 15: MSE Total = 0.560777,   MSE X = 0.290451,   MSE Z = 0.228233
# Test: MSE Total = 0.459520,   MSE X = 0.223176,   MSE Z = 0.216503
#
#
# Train Epoch 16: MSE Total = 0.549391,   MSE X = 0.284312,   MSE Z = 0.224079
# Test: MSE Total = 0.357851,   MSE X = 0.174305,   MSE Z = 0.167595
#
#
# Train Epoch 17: MSE Total = 0.532299,   MSE X = 0.280030,   MSE Z = 0.208036
# Test: MSE Total = 0.450328,   MSE X = 0.233794,   MSE Z = 0.182190
#
#
# Train Epoch 18: MSE Total = 0.539034,   MSE X = 0.284674,   MSE Z = 0.208479
# Test: MSE Total = 0.341495,   MSE X = 0.171976,   MSE Z = 0.148726
#
#
# Train Epoch 19: MSE Total = 0.524523,   MSE X = 0.275785,   MSE Z = 0.205305
# Test: MSE Total = 0.521764,   MSE X = 0.291976,   MSE Z = 0.169152
#
#
# Train Epoch 20: MSE Total = 0.548324,   MSE X = 0.282419,   MSE Z = 0.226310
# Test: MSE Total = 0.355676,   MSE X = 0.175629,   MSE Z = 0.161838
#
#
# Train Epoch 21: MSE Total = 0.524140,   MSE X = 0.279494,   MSE Z = 0.197380
# Test: MSE Total = 0.326837,   MSE X = 0.163593,   MSE Z = 0.144333
#
#
# Train Epoch 22: MSE Total = 0.516643,   MSE X = 0.276766,   MSE Z = 0.192032
# Test: MSE Total = 0.360169,   MSE X = 0.171165,   MSE Z = 0.177168
#
#
# Train Epoch 23: MSE Total = 0.514267,   MSE X = 0.274549,   MSE Z = 0.193026
# Test: MSE Total = 0.392727,   MSE X = 0.195185,   MSE Z = 0.176191
#
#
# Train Epoch 24: MSE Total = 0.530147,   MSE X = 0.282120,   MSE Z = 0.200791
# Test: MSE Total = 0.357219,   MSE X = 0.180320,   MSE Z = 0.154728
#
#
# Train Epoch 25: MSE Total = 0.504590,   MSE X = 0.269456,   MSE Z = 0.189249
# Test: MSE Total = 0.329471,   MSE X = 0.168597,   MSE Z = 0.138168
#
#
# Train Epoch 26: MSE Total = 0.501178,   MSE X = 0.268022,   MSE Z = 0.187199
# Test: MSE Total = 0.357479,   MSE X = 0.177240,   MSE Z = 0.161226
#
#
# Train Epoch 27: MSE Total = 0.511737,   MSE X = 0.272565,   MSE Z = 0.193335
# Test: MSE Total = 0.361469,   MSE X = 0.184454,   MSE Z = 0.152616
#
#
# Train Epoch 28: MSE Total = 0.507814,   MSE X = 0.270980,   MSE Z = 0.190853
# Test: MSE Total = 0.361637,   MSE X = 0.163886,   MSE Z = 0.193747
#
#
# Train Epoch 29: MSE Total = 0.494330,   MSE X = 0.264576,   MSE Z = 0.184210
# Test: MSE Total = 0.320830,   MSE X = 0.159322,   MSE Z = 0.144194
#
#
# Train Epoch 30: MSE Total = 0.505520,   MSE X = 0.268698,   MSE Z = 0.192093
# Test: MSE Total = 0.326231,   MSE X = 0.165313,   MSE Z = 0.140043
#
#
# Train Epoch 31: MSE Total = 0.497276,   MSE X = 0.266321,   MSE Z = 0.184973
# Test: MSE Total = 0.341706,   MSE X = 0.178387,   MSE Z = 0.136284
#
#
# Train Epoch 32: MSE Total = 0.500420,   MSE X = 0.267044,   MSE Z = 0.188052
# Test: MSE Total = 0.334000,   MSE X = 0.169427,   MSE Z = 0.143026
#
#
# Train Epoch 33: MSE Total = 0.505541,   MSE X = 0.269330,   MSE Z = 0.190866
# Test: MSE Total = 0.410373,   MSE X = 0.215264,   MSE Z = 0.161624
#
#
# Train Epoch 34: MSE Total = 0.510332,   MSE X = 0.272464,   MSE Z = 0.191518
# Test: MSE Total = 0.401349,   MSE X = 0.188099,   MSE Z = 0.202664
#
#
# Train Epoch 35: MSE Total = 0.510832,   MSE X = 0.273270,   MSE Z = 0.190634
# Test: MSE Total = 0.369494,   MSE X = 0.161796,   MSE Z = 0.209191
#
#
# Train Epoch 36: MSE Total = 0.507447,   MSE X = 0.269132,   MSE Z = 0.193997
# Test: MSE Total = 0.320107,   MSE X = 0.161455,   MSE Z = 0.138914
#
#
# Train Epoch 37: MSE Total = 0.515019,   MSE X = 0.274531,   MSE Z = 0.194143
# Test: MSE Total = 0.332484,   MSE X = 0.168319,   MSE Z = 0.143050
#
#
# Train Epoch 38: MSE Total = 0.507142,   MSE X = 0.268351,   MSE Z = 0.195112
# Test: MSE Total = 0.358404,   MSE X = 0.185921,   MSE Z = 0.145296
#
#
# Train Epoch 39: MSE Total = 0.503938,   MSE X = 0.268534,   MSE Z = 0.190145
# Test: MSE Total = 0.323245,   MSE X = 0.162704,   MSE Z = 0.140940
#
#
# Train Epoch 40: MSE Total = 0.493727,   MSE X = 0.265025,   MSE Z = 0.182450
# Test: MSE Total = 0.361626,   MSE X = 0.166307,   MSE Z = 0.188920
#
#
# Train Epoch 41: MSE Total = 0.498172,   MSE X = 0.264945,   MSE Z = 0.188997
# Test: MSE Total = 0.315938,   MSE X = 0.159105,   MSE Z = 0.137596
#
#
# Train Epoch 42: MSE Total = 0.497492,   MSE X = 0.265489,   MSE Z = 0.186937
# Test: MSE Total = 0.356621,   MSE X = 0.165596,   MSE Z = 0.183141
#
#
# Train Epoch 43: MSE Total = 0.497058,   MSE X = 0.266067,   MSE Z = 0.185165
# Test: MSE Total = 0.342120,   MSE X = 0.165651,   MSE Z = 0.162200
#
#
# Train Epoch 44: MSE Total = 0.502900,   MSE X = 0.267986,   MSE Z = 0.189744
# Test: MSE Total = 0.327962,   MSE X = 0.162006,   MSE Z = 0.149105
#
#
# Train Epoch 45: MSE Total = 0.510503,   MSE X = 0.272160,   MSE Z = 0.192369
# Test: MSE Total = 0.324175,   MSE X = 0.157033,   MSE Z = 0.153550
#
#
# Train Epoch 46: MSE Total = 0.500582,   MSE X = 0.267720,   MSE Z = 0.186941
# Test: MSE Total = 0.342084,   MSE X = 0.159801,   MSE Z = 0.173778
#
#
# Train Epoch 47: MSE Total = 0.497859,   MSE X = 0.266008,   MSE Z = 0.186432
# Test: MSE Total = 0.325421,   MSE X = 0.165734,   MSE Z = 0.138043
#
#
# Train Epoch 48: MSE Total = 0.492780,   MSE X = 0.262196,   MSE Z = 0.186714
# Test: MSE Total = 0.394431,   MSE X = 0.196181,   MSE Z = 0.176658
#
#
# Train Epoch 49: MSE Total = 0.508398,   MSE X = 0.272824,   MSE Z = 0.188024
# Test: MSE Total = 0.351765,   MSE X = 0.185403,   MSE Z = 0.136787
#
#
# Train Epoch 50: MSE Total = 0.502268,   MSE X = 0.262534,   MSE Z = 0.199675
# Test: MSE Total = 0.350769,   MSE X = 0.180214,   MSE Z = 0.145672
#
#
# Train Epoch 51: MSE Total = 0.499839,   MSE X = 0.265763,   MSE Z = 0.189765
# Test: MSE Total = 0.350805,   MSE X = 0.177586,   MSE Z = 0.150950
#
#
# Train Epoch 52: MSE Total = 0.486723,   MSE X = 0.262062,   MSE Z = 0.178279
# Test: MSE Total = 0.309530,   MSE X = 0.156344,   MSE Z = 0.133879
#
#
# Train Epoch 53: MSE Total = 0.497744,   MSE X = 0.265035,   MSE Z = 0.188202
# Test: MSE Total = 0.320774,   MSE X = 0.159251,   MSE Z = 0.144254
#
#
# Train Epoch 54: MSE Total = 0.484720,   MSE X = 0.260807,   MSE Z = 0.177895
# Test: MSE Total = 0.321238,   MSE X = 0.163755,   MSE Z = 0.135966
#
#
# Train Epoch 55: MSE Total = 0.497893,   MSE X = 0.266930,   MSE Z = 0.184649
# Test: MSE Total = 0.364350,   MSE X = 0.192590,   MSE Z = 0.140581
#
#
# Train Epoch 56: MSE Total = 0.489442,   MSE X = 0.263060,   MSE Z = 0.180202
# Test: MSE Total = 0.314477,   MSE X = 0.158971,   MSE Z = 0.135764
#
#
# Train Epoch 57: MSE Total = 0.491422,   MSE X = 0.264023,   MSE Z = 0.181131
# Test: MSE Total = 0.319967,   MSE X = 0.162529,   MSE Z = 0.136578
#
#
# Train Epoch 58: MSE Total = 0.495148,   MSE X = 0.264730,   MSE Z = 0.185079
# Test: MSE Total = 0.313534,   MSE X = 0.155762,   MSE Z = 0.140790
#
#
# Train Epoch 59: MSE Total = 0.488142,   MSE X = 0.262741,   MSE Z = 0.178967
# Test: MSE Total = 0.366953,   MSE X = 0.167011,   MSE Z = 0.195173
#
#
# Train Epoch 60: MSE Total = 0.489878,   MSE X = 0.263406,   MSE Z = 0.180140
# Test: MSE Total = 0.339659,   MSE X = 0.176566,   MSE Z = 0.136964
#
#
# Train Epoch 61: MSE Total = 0.485170,   MSE X = 0.260471,   MSE Z = 0.179210
# Test: MSE Total = 0.328337,   MSE X = 0.155770,   MSE Z = 0.162042
#
#
# Train Epoch 62: MSE Total = 0.492337,   MSE X = 0.264621,   MSE Z = 0.181258
# Test: MSE Total = 0.371585,   MSE X = 0.160176,   MSE Z = 0.215416
#
#
# Train Epoch 63: MSE Total = 0.497020,   MSE X = 0.266758,   MSE Z = 0.183738
# Test: MSE Total = 0.350434,   MSE X = 0.175334,   MSE Z = 0.154893
#
#
# Train Epoch 64: MSE Total = 0.484417,   MSE X = 0.261178,   MSE Z = 0.176725
# Test: MSE Total = 0.338467,   MSE X = 0.173527,   MSE Z = 0.141293
#
#
# Train Epoch 65: MSE Total = 0.494266,   MSE X = 0.265125,   MSE Z = 0.183026
# Test: MSE Total = 0.319855,   MSE X = 0.162591,   MSE Z = 0.136295
#
#
# Train Epoch 66: MSE Total = 0.490386,   MSE X = 0.263576,   MSE Z = 0.180532
# Test: MSE Total = 0.318711,   MSE X = 0.160187,   MSE Z = 0.139431
#
#
# Train Epoch 67: MSE Total = 0.485817,   MSE X = 0.260798,   MSE Z = 0.179491
# Test: MSE Total = 0.339357,   MSE X = 0.175902,   MSE Z = 0.137851
#
#
# Train Epoch 68: MSE Total = 0.487590,   MSE X = 0.263712,   MSE Z = 0.176244
# Test: MSE Total = 0.365452,   MSE X = 0.158430,   MSE Z = 0.210076
#
#
# Train Epoch 69: MSE Total = 0.489996,   MSE X = 0.261851,   MSE Z = 0.183401
# Test: MSE Total = 0.323209,   MSE X = 0.161263,   MSE Z = 0.143752
#
#
# Train Epoch 70: MSE Total = 0.494910,   MSE X = 0.265447,   MSE Z = 0.183311
# Test: MSE Total = 0.340915,   MSE X = 0.156344,   MSE Z = 0.178970
#
#
# Train Epoch 71: MSE Total = 0.481545,   MSE X = 0.258577,   MSE Z = 0.177767
# Test: MSE Total = 0.340748,   MSE X = 0.164225,   MSE Z = 0.163062
#
#
# Train Epoch 72: MSE Total = 0.485473,   MSE X = 0.258740,   MSE Z = 0.183089
# Test: MSE Total = 0.384359,   MSE X = 0.180806,   MSE Z = 0.192754
#
#
# Train Epoch 73: MSE Total = 0.495962,   MSE X = 0.264434,   MSE Z = 0.186837
# Test: MSE Total = 0.335671,   MSE X = 0.160905,   MSE Z = 0.162369
#
#
# Train Epoch 74: MSE Total = 0.492365,   MSE X = 0.261415,   MSE Z = 0.187672
# Test: MSE Total = 0.330100,   MSE X = 0.169029,   MSE Z = 0.138214
#
#
# Train Epoch 75: MSE Total = 0.481106,   MSE X = 0.259231,   MSE Z = 0.175836
# Test: MSE Total = 0.332111,   MSE X = 0.157189,   MSE Z = 0.164643
#
#
# Train Epoch 76: MSE Total = 0.490261,   MSE X = 0.263334,   MSE Z = 0.180834
# Test: MSE Total = 0.307615,   MSE X = 0.155514,   MSE Z = 0.132778
#
#
# Train Epoch 77: MSE Total = 0.486107,   MSE X = 0.258332,   MSE Z = 0.184809
# Test: MSE Total = 0.308806,   MSE X = 0.153597,   MSE Z = 0.138302
#
#
# Train Epoch 78: MSE Total = 0.477585,   MSE X = 0.256630,   MSE Z = 0.175949
# Test: MSE Total = 0.366051,   MSE X = 0.187697,   MSE Z = 0.152751
#
#
# Train Epoch 79: MSE Total = 0.479262,   MSE X = 0.256180,   MSE Z = 0.179253
# Test: MSE Total = 0.316580,   MSE X = 0.153206,   MSE Z = 0.150247
#
#
# Train Epoch 80: MSE Total = 0.480361,   MSE X = 0.257782,   MSE Z = 0.177648
# Test: MSE Total = 0.313265,   MSE X = 0.158008,   MSE Z = 0.135938
#
#
# Train Epoch 81: MSE Total = 0.479899,   MSE X = 0.256013,   MSE Z = 0.180502
# Test: MSE Total = 0.337982,   MSE X = 0.173815,   MSE Z = 0.140023
#
#
# Train Epoch 82: MSE Total = 0.477837,   MSE X = 0.257209,   MSE Z = 0.175160
# Test: MSE Total = 0.311030,   MSE X = 0.154753,   MSE Z = 0.139198
#
#
# Train Epoch 83: MSE Total = 0.475747,   MSE X = 0.253875,   MSE Z = 0.178785
# Test: MSE Total = 0.328452,   MSE X = 0.158606,   MSE Z = 0.156568
#
#
# Train Epoch 84: MSE Total = 0.475507,   MSE X = 0.257450,   MSE Z = 0.171334
# Test: MSE Total = 0.325271,   MSE X = 0.167014,   MSE Z = 0.135282
#
#
# Train Epoch 85: MSE Total = 0.478856,   MSE X = 0.254742,   MSE Z = 0.181529
# Test: MSE Total = 0.331714,   MSE X = 0.163417,   MSE Z = 0.151690
#
#
# Train Epoch 86: MSE Total = 0.481669,   MSE X = 0.261372,   MSE Z = 0.172389
# Test: MSE Total = 0.339889,   MSE X = 0.178314,   MSE Z = 0.133819
#
#
# Train Epoch 87: MSE Total = 0.475910,   MSE X = 0.258103,   MSE Z = 0.170614
# Test: MSE Total = 0.347543,   MSE X = 0.176365,   MSE Z = 0.148691
#
#
# Train Epoch 88: MSE Total = 0.475628,   MSE X = 0.255503,   MSE Z = 0.175377
# Test: MSE Total = 0.346659,   MSE X = 0.162563,   MSE Z = 0.174859
#
#
# Train Epoch 89: MSE Total = 0.479073,   MSE X = 0.254998,   MSE Z = 0.181331
# Test: MSE Total = 0.311459,   MSE X = 0.159067,   MSE Z = 0.131237
#
#
# Train Epoch 90: MSE Total = 0.472915,   MSE X = 0.253378,   MSE Z = 0.175706
# Test: MSE Total = 0.364247,   MSE X = 0.168671,   MSE Z = 0.187985
#
#
# Train Epoch 91: MSE Total = 0.470160,   MSE X = 0.253883,   MSE Z = 0.170743
# Test: MSE Total = 0.323696,   MSE X = 0.168191,   MSE Z = 0.130680
#
#
# Train Epoch 92: MSE Total = 0.469627,   MSE X = 0.252833,   MSE Z = 0.172065
# Test: MSE Total = 0.301822,   MSE X = 0.150685,   MSE Z = 0.134057
#
#
# Train Epoch 93: MSE Total = 0.467237,   MSE X = 0.251853,   MSE Z = 0.170580
# Test: MSE Total = 0.311243,   MSE X = 0.158180,   MSE Z = 0.132690
#
#
# Train Epoch 94: MSE Total = 0.467009,   MSE X = 0.252810,   MSE Z = 0.168350
# Test: MSE Total = 0.313928,   MSE X = 0.157896,   MSE Z = 0.137113
#
#
# Train Epoch 95: MSE Total = 0.470229,   MSE X = 0.252451,   MSE Z = 0.173691
# Test: MSE Total = 0.359291,   MSE X = 0.158646,   MSE Z = 0.200795
#
#
# Train Epoch 96: MSE Total = 0.465871,   MSE X = 0.248303,   MSE Z = 0.175675
# Test: MSE Total = 0.310699,   MSE X = 0.154921,   MSE Z = 0.138387
#
#
# Train Epoch 97: MSE Total = 0.477593,   MSE X = 0.256307,   MSE Z = 0.176605
# Test: MSE Total = 0.368806,   MSE X = 0.186888,   MSE Z = 0.158317
#
#
# Train Epoch 98: MSE Total = 0.484273,   MSE X = 0.262931,   MSE Z = 0.173031
# Test: MSE Total = 0.316961,   MSE X = 0.158922,   MSE Z = 0.139430
#
#
# Train Epoch 99: MSE Total = 0.475101,   MSE X = 0.257935,   MSE Z = 0.169787
# Test: MSE Total = 0.319096,   MSE X = 0.160493,   MSE Z = 0.139374
#
#
# Train Epoch 100: MSE Total = 0.468470,   MSE X = 0.252578,   MSE Z = 0.170910
# Test: MSE Total = 0.326927,   MSE X = 0.168050,   MSE Z = 0.135601
#
#
# Got the weights of the epoch 92
# Execution time: 6 minutes, 56.09 seconds

# %%
torch.save(model.state_dict(), "model_weights_step1_autoregressive")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step1_autoregressive"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
model.eval()

examples = []
batch_indices = 6   # numero batch consecutivi usati
example_index = [9, 9, 9, 0, 5, 50]

# Itera sui primi 6 batch del test_loader
for b_idx, batch in enumerate(test_loader):
    if b_idx >= batch_indices:
        break

    past_batch, future_batch = batch
    
    examples.append((past_batch[example_index[b_idx]], future_batch[example_index[b_idx]]))

examples[3], examples[4], examples[5] = examples[4], examples[5], examples[3]    

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future) in enumerate(examples):

    all_points = torch.cat((past, future), 0)
    past_np = past.cpu().numpy()
    future_np = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past.unsqueeze(0).to(device)  # aggiunge batch dim
    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past_np[:, 0], past_np[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future_np[:, 0], future_np[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.469224,   ADE X = 0.293926,   ADE Z = 0.296536
# FDE Total = 1.084724,   FDE X = 0.803876,   FDE Z = 0.574703
#
# Model performances on test set:
#
# ADE Total = 0.392344,   ADE X = 0.226580,   ADE Z = 0.265514
# FDE Total = 0.924205,   FDE X = 0.638244,   FDE Z = 0.528342

# %%
def save_prediction(index):
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _ = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim

    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'    

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiunge la nuova coppia chiave-array
    data_dict['step1_autoregressive'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
