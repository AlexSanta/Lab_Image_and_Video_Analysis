# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from pytorch3d.ops import sample_farthest_points

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
embedding_dim = 32
hidden_size= 256
input_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])

# %% [markdown]
# ## Calcolo e salvataggio subsampling delle nuvole di punti

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

point_clouds_subsampled = []

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e la mette su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).to(device)

        # Calcola la nuvola di punti sottocampionata
        sampled_pc = sample_farthest_points(point_cloud, K=1024)[0].squeeze(0).cpu().numpy()

        # Salva la nuvola sottocampionata nella lista
        point_clouds_subsampled.append(sampled_pc)

# Salva le nuvole sottocampionate in un file NPZ
np.savez_compressed("point_clouds_subsampled.npz", subsampling=np.array(point_clouds_subsampled))

print("Subsampled point clouds saved in 'point_clouds_subsampled.npz'!")

# %% [markdown]
# ## Annotazione dei punti delle nuvole sottocampionate

# %%
original_res = (376, 672) # risoluzione originale (H, W) delle immagini catturate

# matrice intrinseca K della camera per la risoluzione originale
K = np.array([
    [357.1, 0.0, 335.4],
    [0.0, 357.1, 180.2],
    [0.0, 0.0, 1.0]
])

# %%
import sys
sys.path.append("./Mask2Former")  # locazione di Mask2Former

from detectron2.utils.logger import setup_logger
setup_logger(name="mask2former")

from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.projects.deeplab import add_deeplab_config
from mask2former import add_maskformer2_config
# Out:
# /data01/iva24alesan/miniconda3/envs/IVA/lib/python3.13/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /data01/iva24alesan/Lab_IVA/Mask2Former/mask2former/modeling/pixel_decoder/msdeformattn.py:314: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)

# %%
cfg = get_cfg()
add_deeplab_config(cfg)
add_maskformer2_config(cfg)

cfg.merge_from_file("Mask2Former/configs/coco/panoptic-segmentation/swin/maskformer2_swin_small_bs16_50ep.yaml")
cfg.MODEL.WEIGHTS = 'https://dl.fbaipublicfiles.com/maskformer/mask2former/coco/panoptic/maskformer2_swin_small_bs16_50ep/model_final_a407fd.pkl'
cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
cfg.MODEL.MASK_FORMER.TEST.SEMANTIC_ON = True
cfg.MODEL.MASK_FORMER.TEST.INSTANCE_ON = False
cfg.MODEL.MASK_FORMER.TEST.PANOPTIC_ON = False

predictor = DefaultPredictor(cfg)
# Out:
# /data01/iva24alesan/miniconda3/envs/IVA/lib/python3.13/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# WARNING [06/01 12:49:39 mask2former.modeling.transformer_decoder.mask2former_transformer_decoder]: Weight format of MultiScaleMaskedTransformerDecoder have changed! Please upgrade your models. Applying automatic conversion now ...

# %%
# Scala la matrice intrinseca K dalla risoluzione originale a quella corrente

def scale_intrinsic_matrix(K, original_res, current_res):
    orig_h, orig_w = original_res
    curr_h, curr_w = current_res

    scale_x = curr_w / orig_w
    scale_y = curr_h / orig_h

    K_scaled = K.copy()
    K_scaled[0, 0] *= scale_x  # fx
    K_scaled[0, 2] *= scale_x  # cx
    K_scaled[1, 1] *= scale_y  # fy
    K_scaled[1, 2] *= scale_y  # cy

    return K_scaled

# %%
# Proietta una nuvola di punti nell'immagine RGB usando la matrice intrinseca K

def project_points_to_image(pc, K):

    # Estrae i singoli assi
    X, Y, Z = pc[:, 0], pc[:, 1], pc[:, 2]
    valid_mask = Z > 0  # considera solo i punti davanti alla camera

    X, Y, Z = X[valid_mask], Y[valid_mask], Z[valid_mask]

    fx, fy = K[0, 0], K[1, 1]
    cx, cy = K[0, 2], K[1, 2]

    u = (X * fx / Z + cx).astype(int)
    v = (Y * fy / Z + cy).astype(int)

    valid_pixels = np.stack([u, v], axis=1)
    valid_indices = np.where(valid_mask)[0]

    return valid_pixels, valid_indices

# %%
# Annota ciascun punto della nuvola concatenando alle coordinate spaziali l'indice della classe del rispettivo
# pixel nell'immagine RGB. La nuvola di punti, quindi, da dimensione [N, 3] passerà a dimensione [N, 4]

def annotate_point_cloud_with_semantics(pc, sem_seg, K, original_res, current_res):
    pc_np = pc.numpy()
    
    # Scala, se necessario, la matrice intrinseca
    K_scaled = scale_intrinsic_matrix(K, original_res, current_res)

    # Usa la funzione di proiezione
    valid_pixels, valid_indices = project_points_to_image(pc_np, K_scaled)

    H, W = sem_seg.shape
    u, v = valid_pixels[:, 0], valid_pixels[:, 1]

    # Maschera per filtrare i pixel proiettati che cadono fuori dall'immagine
    inside_mask = (u >= 0) & (u < W) & (v >= 0) & (v < H)

    class_indices = np.full(len(pc_np), -1, dtype=np.int32)  # default -1
    valid_inside_indices = valid_indices[inside_mask]
    class_indices[valid_inside_indices] = sem_seg[v[inside_mask], u[inside_mask]]

    # Concatenazione come tensore PyTorch
    annotated_pc = torch.cat([
        pc,
        torch.tensor(class_indices, dtype=torch.float32).unsqueeze(1)
    ], dim=1)

    return annotated_pc

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

# Carica le nuvole di punti sottocampionate
loaded_pc_subsampled = np.load("point_clouds_subsampled.npz")
point_clouds_subsampled = [subsampling for subsampling in loaded_pc_subsampled["subsampling"]]

# Carica le immagini RGB
loaded_images = [np.load(os.path.join(folder_path, f))["rgb_frame"] for f in npz_files]

image_maps = []

for rgb_image in loaded_images:
    rgb_image = np.flipud(rgb_image) # prende l'immagine e la mette sopra-sotto
    bgr_image = rgb_image[:, :, ::-1] # conversione dell'immagine da RGB a BGR

    with torch.no_grad():  
        outputs = predictor(bgr_image)
    sem_seg = outputs["sem_seg"].argmax(dim=0) #mappa 2D dove ogni pixel ha un valore intero corrispondente all’indice 
                                               #della classe predetta
    sem_seg = sem_seg.cpu().numpy() # NON ricapovolge la mappa semantica

    image_maps.append(sem_seg)

# %%
annotated_point_clouds = []

#Annota tutte le nuvole di punti sottocampionate
for pc, sem_seg in zip(point_clouds_subsampled, image_maps):
    pc_tensor = torch.tensor(pc, dtype=torch.float32)    

    annotated_pc = annotate_point_cloud_with_semantics(
        pc_tensor,
        sem_seg,
        K=K, 
        original_res=(376, 672),
        current_res=sem_seg.shape
    )

    annotated_point_clouds.append(annotated_pc.numpy())

# Salva tutte le nuvole di punti annotate in un unico file .npz
np.savez_compressed(
    "point_clouds_subsampled_annotated.npz",
    annotated_subsampling=np.stack(annotated_point_clouds)
)

print("Annotated subsampled point clouds saved in 'point_clouds_subsampled_annotated.npz'!")
# Out:
# Annotated subsampled point clouds saved in 'point_clouds_subsampled_annotated.npz'!

# %%
# Funzione per visualizzare un'immagine con sopra i punti della rispettiva nuvola proiettati

def visualize_annotated_projection_on_image(rgb_image, annotated_pc, K, original_res, current_res, class_colors=None):
    # Separa coordinate 3D e classi
    coords = annotated_pc[:, :3]
    class_ids = annotated_pc[:, 3].astype(int)

    # Scala, se necessario, la matrice intrinseca
    K_scaled = scale_intrinsic_matrix(K, original_res, current_res)

    # Proiezione dei punti della nuvola sull'immagine
    projected_pixels, valid_indices = project_points_to_image(coords, K_scaled)

    H, W, _ = rgb_image.shape
    u, v = projected_pixels[:, 0], projected_pixels[:, 1]

    # Filtra i punti dentro l'immagine
    inside_mask = (u >= 0) & (u < W) & (v >= 0) & (v < H)
    u, v = u[inside_mask], v[inside_mask]
    valid_class_ids = class_ids[valid_indices][inside_mask]

    # Mappa classi → colori (se non fornita)
    if class_colors is None:
        num_classes = valid_class_ids.max() + 1
        cmap = plt.cm.get_cmap('tab20', num_classes)
        class_colors = [cmap(i) for i in range(num_classes)]

    # Ottiene i colori
    point_colors = [class_colors[i] if i >= 0 else (0, 0, 0, 0.5) for i in valid_class_ids]

    # Plot
    plt.figure(figsize=(10, 6))
    plt.imshow(np.flipud(rgb_image))
    plt.scatter(u, v, c=point_colors, s=2)
    plt.title("An image with the cloud points projected")
    plt.axis('off')
    plt.show()

# %%
all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]        
npz_files = sorted(all_files, key=extract_number)

# Carica le nuvole di punti annotate e le immagini. Prende poi una nuvola con la rispettiva immagine, e richiama la 
# funzione per visualizzare l'immagine con i punti della nuvola proiettati

annotated_data = np.load("point_clouds_subsampled_annotated.npz", allow_pickle=True)
annotated_point_clouds = annotated_data["annotated_subsampling"]
loaded_images = [np.load(os.path.join(folder_path, f))["rgb_frame"] for f in npz_files]

idx = 0  # indice del frame da visualizzare

annotated_pc = annotated_point_clouds[idx]
rgb_image = loaded_images[idx]

visualize_annotated_projection_on_image(
    rgb_image=rgb_image,
    annotated_pc=annotated_pc,
    K=K,
    original_res=(376, 672),
    current_res=rgb_image.shape[:2]
)
# Out:
# /tmp/ipykernel_1501516/4012935824.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab20', num_classes)

# %% [markdown]
# ## Sezione addestramento del modello

# %%
class PointNetfeat(nn.Module):
    def __init__(self, embedding_dim):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3+embedding_dim, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        return x

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_clouds_annotated, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_clouds_annotated = point_clouds_annotated

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.npz_files = sorted(all_files, key=extract_number)

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_clouds_annotated = (self.point_clouds_annotated[idx])

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_clouds_annotated

# %%
class MyModel(nn.Module):
    def __init__(self, class_to_emb_idx, embedding_dim=32, input_size=2, hidden_size=256, output_size=2*40, 
                 num_layers=3, future_steps=40):
        super(MyModel, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        self.class_to_emb_idx = class_to_emb_idx
        self.embedding_dim = embedding_dim
        self.class_mapping = torch.full((max(class_to_emb_idx.keys()) + 1,), -1, dtype=torch.long)
        for cls, idx in class_to_emb_idx.items():
            self.class_mapping[cls] = idx

        self.embedding_layer = nn.Embedding(num_embeddings=len(self.class_to_emb_idx), embedding_dim=self.embedding_dim)
        self.pointnet = PointNetfeat(embedding_dim=self.embedding_dim)
        self.pc_emb_proj = nn.Linear(1024, self.hidden_size)
        self.pc_emb_norm = nn.LayerNorm(self.hidden_size)
        self.gru = nn.GRU(self.input_size, self.hidden_size, self.num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, past, point_clouds):
        all_coord = point_clouds[:, :, :3]
        all_classes = point_clouds[:, :, 3].long()
        mapped_indices = self.class_mapping.to(past.device)[all_classes]
        all_idx_emb = self.embedding_layer(mapped_indices)
        new_point_clouds = torch.cat((all_coord, all_idx_emb), dim=2)
        
        new_point_clouds_emb = self.pointnet(new_point_clouds)
        new_point_clouds_emb = self.pc_emb_norm(self.pc_emb_proj(new_point_clouds_emb))

        h0 = new_point_clouds_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(past.device)
        
        _, h = self.gru(past, h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                                 # sequenza ed ha quindi dimensione [batch_size, seq_length, hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        last_hidden = h[-1]  # [batch_size, hidden_size]
        future_points = self.fc(last_hidden)  # [batch_size, 2*future_steps]
        future_points = future_points.view(past.size(0), self.future_steps, self.input_size)
             
        return future_points

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc in train_loader: # iterazione sui batch
        past, future, pc = past.to(device), future.to(device), pc.to(device) #spostamento dati sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z  
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')

    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_annotated = np.load("point_clouds_subsampled_annotated.npz")
point_clouds_annotated = [torch.tensor(pc, dtype=torch.float32) for pc in 
                           loaded_pc_annotated["annotated_subsampling"]]

dataset = CustomDataset(folder_path=folder_path, point_clouds_annotated=point_clouds_annotated, past_seconds=past_seconds, 
                        future_seconds=future_seconds, framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)  
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 1024, 4])

# %%
#Prende tutte le classi valide dei punti delle nelle nuvole di e costruisce un dizionario dove le chiavi sono le classi e
#i valori rappresentano i rispettivi indici 

all_classes = set()

for _, _, pc in dataset:
    pc_annotations = pc[:, 3].tolist()
    valid_classes = [int(c) for c in pc_annotations if c >= 0]
    all_classes.update(valid_classes)

all_classes = list(all_classes)
all_classes.sort()
num_embeddings = len(all_classes)
class_to_emb_idx = {cl : i for i, cl in enumerate(all_classes)}

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.3510107398033142
# Global variance of the z-coordinate: 4.372647285461426

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyModel(class_to_emb_idx=class_to_emb_idx, embedding_dim=embedding_dim, 
                input_size=input_size, hidden_size=hidden_size, output_size=input_size*future_seconds*framerate, 
                num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.332571,   MSE X = 0.495981,   MSE Z = 1.035964
# Test: MSE Total = 0.810908,   MSE X = 0.410980,   MSE Z = 0.245129
#
#
# Train Epoch 2: MSE Total = 0.706674,   MSE X = 0.351638,   MSE Z = 0.236614
# Test: MSE Total = 0.781137,   MSE X = 0.400111,   MSE Z = 0.221240
#
#
# Train Epoch 3: MSE Total = 0.636306,   MSE X = 0.313477,   MSE Z = 0.224156
# Test: MSE Total = 0.591741,   MSE X = 0.290753,   MSE Z = 0.211174
#
#
# Train Epoch 4: MSE Total = 0.592685,   MSE X = 0.290813,   MSE Z = 0.212934
# Test: MSE Total = 0.564387,   MSE X = 0.277230,   MSE Z = 0.201704
#
#
# Train Epoch 5: MSE Total = 0.530432,   MSE X = 0.255141,   MSE Z = 0.208660
# Test: MSE Total = 0.572533,   MSE X = 0.280535,   MSE Z = 0.207070
#
#
# Train Epoch 6: MSE Total = 0.524797,   MSE X = 0.252740,   MSE Z = 0.205353
# Test: MSE Total = 0.499979,   MSE X = 0.240884,   MSE Z = 0.195302
#
#
# Train Epoch 7: MSE Total = 0.421231,   MSE X = 0.195209,   MSE Z = 0.191841
# Test: MSE Total = 0.428320,   MSE X = 0.201377,   MSE Z = 0.184896
#
#
# Train Epoch 8: MSE Total = 0.380296,   MSE X = 0.170793,   MSE Z = 0.192421
# Test: MSE Total = 0.548042,   MSE X = 0.273998,   MSE Z = 0.178929
#
#
# Train Epoch 9: MSE Total = 0.495356,   MSE X = 0.235753,   MSE Z = 0.203745
# Test: MSE Total = 0.442512,   MSE X = 0.207821,   MSE Z = 0.191829
#
#
# Train Epoch 10: MSE Total = 0.357316,   MSE X = 0.156663,   MSE Z = 0.194238
# Test: MSE Total = 0.407674,   MSE X = 0.188957,   MSE Z = 0.185559
#
#
# Train Epoch 11: MSE Total = 0.351847,   MSE X = 0.156720,   MSE Z = 0.182600
# Test: MSE Total = 0.388123,   MSE X = 0.175467,   MSE Z = 0.192292
#
#
# Train Epoch 12: MSE Total = 0.313897,   MSE X = 0.138209,   MSE Z = 0.168581
# Test: MSE Total = 0.329318,   MSE X = 0.141782,   MSE Z = 0.188214
#
#
# Train Epoch 13: MSE Total = 0.291479,   MSE X = 0.124844,   MSE Z = 0.168874
# Test: MSE Total = 0.437857,   MSE X = 0.212979,   MSE Z = 0.163890
#
#
# Train Epoch 14: MSE Total = 0.272994,   MSE X = 0.116757,   MSE Z = 0.158762
# Test: MSE Total = 0.447389,   MSE X = 0.211494,   MSE Z = 0.189063
#
#
# Train Epoch 15: MSE Total = 0.266967,   MSE X = 0.113587,   MSE Z = 0.157346
# Test: MSE Total = 0.449312,   MSE X = 0.222690,   MSE Z = 0.153570
#
#
# Train Epoch 16: MSE Total = 0.349528,   MSE X = 0.153051,   MSE Z = 0.190701
# Test: MSE Total = 0.301354,   MSE X = 0.131267,   MSE Z = 0.166853
#
#
# Train Epoch 17: MSE Total = 0.225975,   MSE X = 0.090944,   MSE Z = 0.151549
# Test: MSE Total = 0.277192,   MSE X = 0.123776,   MSE Z = 0.142767
#
#
# Train Epoch 18: MSE Total = 0.191229,   MSE X = 0.075187,   MSE Z = 0.134504
# Test: MSE Total = 0.266055,   MSE X = 0.117351,   MSE Z = 0.142155
#
#
# Train Epoch 19: MSE Total = 0.168934,   MSE X = 0.063890,   MSE Z = 0.127755
# Test: MSE Total = 0.231254,   MSE X = 0.098828,   MSE Z = 0.134760
#
#
# Train Epoch 20: MSE Total = 0.187703,   MSE X = 0.074327,   MSE Z = 0.130166
# Test: MSE Total = 0.228976,   MSE X = 0.099464,   MSE Z = 0.127750
#
#
# Train Epoch 21: MSE Total = 0.150554,   MSE X = 0.055674,   MSE Z = 0.118321
# Test: MSE Total = 0.220467,   MSE X = 0.095382,   MSE Z = 0.124367
#
#
# Train Epoch 22: MSE Total = 0.152906,   MSE X = 0.060769,   MSE Z = 0.105254
# Test: MSE Total = 0.217847,   MSE X = 0.091095,   MSE Z = 0.134018
#
#
# Train Epoch 23: MSE Total = 0.534911,   MSE X = 0.271636,   MSE Z = 0.159808
# Test: MSE Total = 0.431613,   MSE X = 0.210746,   MSE Z = 0.158715
#
#
# Train Epoch 24: MSE Total = 0.311659,   MSE X = 0.142196,   MSE Z = 0.149826
# Test: MSE Total = 0.301182,   MSE X = 0.140480,   MSE Z = 0.133976
#
#
# Train Epoch 25: MSE Total = 0.293365,   MSE X = 0.132997,   MSE Z = 0.144041
# Test: MSE Total = 0.291026,   MSE X = 0.135570,   MSE Z = 0.130067
#
#
# Train Epoch 26: MSE Total = 0.232512,   MSE X = 0.103260,   MSE Z = 0.121745
# Test: MSE Total = 0.227713,   MSE X = 0.099764,   MSE Z = 0.124050
#
#
# Train Epoch 27: MSE Total = 0.150095,   MSE X = 0.059395,   MSE Z = 0.104228
# Test: MSE Total = 0.219104,   MSE X = 0.093150,   MSE Z = 0.129395
#
#
# Train Epoch 28: MSE Total = 0.133110,   MSE X = 0.052443,   MSE Z = 0.093246
# Test: MSE Total = 0.205415,   MSE X = 0.091845,   MSE Z = 0.105372
#
#
# Train Epoch 29: MSE Total = 0.142988,   MSE X = 0.060674,   MSE Z = 0.084852
# Test: MSE Total = 0.236036,   MSE X = 0.109230,   MSE Z = 0.108046
#
#
# Train Epoch 30: MSE Total = 0.139140,   MSE X = 0.058566,   MSE Z = 0.084247
# Test: MSE Total = 0.237820,   MSE X = 0.109037,   MSE Z = 0.112458
#
#
# Train Epoch 31: MSE Total = 0.268102,   MSE X = 0.122511,   MSE Z = 0.128225
# Test: MSE Total = 0.223122,   MSE X = 0.101163,   MSE Z = 0.109515
#
#
# Train Epoch 32: MSE Total = 0.152519,   MSE X = 0.062991,   MSE Z = 0.096606
# Test: MSE Total = 0.199530,   MSE X = 0.087693,   MSE Z = 0.107725
#
#
# Train Epoch 33: MSE Total = 0.108732,   MSE X = 0.041066,   MSE Z = 0.082426
# Test: MSE Total = 0.188302,   MSE X = 0.082467,   MSE Z = 0.102692
#
#
# Train Epoch 34: MSE Total = 0.102675,   MSE X = 0.039066,   MSE Z = 0.076819
# Test: MSE Total = 0.175996,   MSE X = 0.078414,   MSE Z = 0.091264
#
#
# Train Epoch 35: MSE Total = 0.086007,   MSE X = 0.032268,   MSE Z = 0.065956
# Test: MSE Total = 0.176320,   MSE X = 0.075404,   MSE Z = 0.102563
#
#
# Train Epoch 36: MSE Total = 0.091525,   MSE X = 0.034714,   MSE Z = 0.068864
# Test: MSE Total = 0.179070,   MSE X = 0.079249,   MSE Z = 0.094743
#
#
# Train Epoch 37: MSE Total = 0.084027,   MSE X = 0.030968,   MSE Z = 0.066407
# Test: MSE Total = 0.171550,   MSE X = 0.073972,   MSE Z = 0.097642
#
#
# Train Epoch 38: MSE Total = 0.082422,   MSE X = 0.031139,   MSE Z = 0.062446
# Test: MSE Total = 0.164862,   MSE X = 0.072669,   MSE Z = 0.088258
#
#
# Train Epoch 39: MSE Total = 0.086505,   MSE X = 0.033524,   MSE Z = 0.062567
# Test: MSE Total = 0.166633,   MSE X = 0.069484,   MSE Z = 0.103202
#
#
# Train Epoch 40: MSE Total = 0.078331,   MSE X = 0.028606,   MSE Z = 0.062832
# Test: MSE Total = 0.146469,   MSE X = 0.063734,   MSE Z = 0.081330
#
#
# Train Epoch 41: MSE Total = 0.070039,   MSE X = 0.026284,   MSE Z = 0.053690
# Test: MSE Total = 0.153735,   MSE X = 0.069022,   MSE Z = 0.077862
#
#
# Train Epoch 42: MSE Total = 0.100048,   MSE X = 0.042399,   MSE Z = 0.059562
# Test: MSE Total = 0.196273,   MSE X = 0.091495,   MSE Z = 0.087493
#
#
# Train Epoch 43: MSE Total = 0.166029,   MSE X = 0.077876,   MSE Z = 0.072320
# Test: MSE Total = 0.428030,   MSE X = 0.215164,   MSE Z = 0.135627
#
#
# Train Epoch 44: MSE Total = 0.193781,   MSE X = 0.085651,   MSE Z = 0.102909
# Test: MSE Total = 0.206269,   MSE X = 0.086424,   MSE Z = 0.126296
#
#
# Train Epoch 45: MSE Total = 0.099865,   MSE X = 0.039473,   MSE Z = 0.069508
# Test: MSE Total = 0.172968,   MSE X = 0.077751,   MSE Z = 0.087270
#
#
# Train Epoch 46: MSE Total = 0.079998,   MSE X = 0.031372,   MSE Z = 0.056555
# Test: MSE Total = 0.171915,   MSE X = 0.077007,   MSE Z = 0.087694
#
#
# Train Epoch 47: MSE Total = 0.077228,   MSE X = 0.027704,   MSE Z = 0.063708
# Test: MSE Total = 0.184209,   MSE X = 0.068513,   MSE Z = 0.143383
#
#
# Train Epoch 48: MSE Total = 0.069245,   MSE X = 0.026482,   MSE Z = 0.051329
# Test: MSE Total = 0.160974,   MSE X = 0.070766,   MSE Z = 0.086845
#
#
# Train Epoch 49: MSE Total = 0.065914,   MSE X = 0.025257,   MSE Z = 0.048686
# Test: MSE Total = 0.147959,   MSE X = 0.065338,   MSE Z = 0.078785
#
#
# Train Epoch 50: MSE Total = 0.058003,   MSE X = 0.022180,   MSE Z = 0.043007
# Test: MSE Total = 0.158141,   MSE X = 0.072255,   MSE Z = 0.075663
#
#
# Train Epoch 51: MSE Total = 0.056877,   MSE X = 0.021900,   MSE Z = 0.041641
# Test: MSE Total = 0.184092,   MSE X = 0.084260,   MSE Z = 0.087556
#
#
# Train Epoch 52: MSE Total = 0.057750,   MSE X = 0.021700,   MSE Z = 0.044169
# Test: MSE Total = 0.144517,   MSE X = 0.063196,   MSE Z = 0.079147
#
#
# Train Epoch 53: MSE Total = 0.055379,   MSE X = 0.020286,   MSE Z = 0.044201
# Test: MSE Total = 0.136133,   MSE X = 0.060031,   MSE Z = 0.072788
#
#
# Train Epoch 54: MSE Total = 0.054893,   MSE X = 0.020647,   MSE Z = 0.041912
# Test: MSE Total = 0.149679,   MSE X = 0.067028,   MSE Z = 0.076417
#
#
# Train Epoch 55: MSE Total = 0.052252,   MSE X = 0.020080,   MSE Z = 0.038392
# Test: MSE Total = 0.138829,   MSE X = 0.062087,   MSE Z = 0.071167
#
#
# Train Epoch 56: MSE Total = 0.048144,   MSE X = 0.017501,   MSE Z = 0.038903
# Test: MSE Total = 0.138841,   MSE X = 0.060821,   MSE Z = 0.075663
#
#
# Train Epoch 57: MSE Total = 0.059455,   MSE X = 0.022775,   MSE Z = 0.043941
# Test: MSE Total = 0.146165,   MSE X = 0.065716,   MSE Z = 0.073701
#
#
# Train Epoch 58: MSE Total = 0.053538,   MSE X = 0.020818,   MSE Z = 0.038476
# Test: MSE Total = 0.160793,   MSE X = 0.074013,   MSE Z = 0.075004
#
#
# Train Epoch 59: MSE Total = 0.052301,   MSE X = 0.020780,   MSE Z = 0.036022
# Test: MSE Total = 0.149347,   MSE X = 0.068346,   MSE Z = 0.071070
#
#
# Train Epoch 60: MSE Total = 0.046547,   MSE X = 0.017930,   MSE Z = 0.034050
# Test: MSE Total = 0.131235,   MSE X = 0.056823,   MSE Z = 0.073866
#
#
# Train Epoch 61: MSE Total = 0.048225,   MSE X = 0.018339,   MSE Z = 0.036116
# Test: MSE Total = 0.134311,   MSE X = 0.057357,   MSE Z = 0.078414
#
#
# Train Epoch 62: MSE Total = 0.042689,   MSE X = 0.015930,   MSE Z = 0.033040
# Test: MSE Total = 0.140111,   MSE X = 0.062816,   MSE Z = 0.071274
#
#
# Train Epoch 63: MSE Total = 0.039728,   MSE X = 0.014679,   MSE Z = 0.031267
# Test: MSE Total = 0.138712,   MSE X = 0.062065,   MSE Z = 0.071002
#
#
# Train Epoch 64: MSE Total = 0.047927,   MSE X = 0.018852,   MSE Z = 0.033683
# Test: MSE Total = 0.140065,   MSE X = 0.062053,   MSE Z = 0.073873
#
#
# Train Epoch 65: MSE Total = 0.049299,   MSE X = 0.019322,   MSE Z = 0.034890
# Test: MSE Total = 0.130925,   MSE X = 0.056966,   MSE Z = 0.072716
#
#
# Train Epoch 66: MSE Total = 0.042026,   MSE X = 0.015579,   MSE Z = 0.032895
# Test: MSE Total = 0.133734,   MSE X = 0.060320,   MSE Z = 0.066752
#
#
# Train Epoch 67: MSE Total = 0.042931,   MSE X = 0.015546,   MSE Z = 0.034903
# Test: MSE Total = 0.143086,   MSE X = 0.065589,   MSE Z = 0.067710
#
#
# Train Epoch 68: MSE Total = 0.036743,   MSE X = 0.012973,   MSE Z = 0.031044
# Test: MSE Total = 0.133032,   MSE X = 0.055193,   MSE Z = 0.083379
#
#
# Train Epoch 69: MSE Total = 0.037634,   MSE X = 0.013797,   MSE Z = 0.030000
# Test: MSE Total = 0.138431,   MSE X = 0.063569,   MSE Z = 0.065104
#
#
# Train Epoch 70: MSE Total = 0.036634,   MSE X = 0.013253,   MSE Z = 0.029831
# Test: MSE Total = 0.141314,   MSE X = 0.064001,   MSE Z = 0.069607
#
#
# Train Epoch 71: MSE Total = 0.195200,   MSE X = 0.087762,   MSE Z = 0.098427
# Test: MSE Total = 0.208616,   MSE X = 0.087110,   MSE Z = 0.128782
#
#
# Train Epoch 72: MSE Total = 0.101184,   MSE X = 0.041683,   MSE Z = 0.064465
# Test: MSE Total = 0.235858,   MSE X = 0.115586,   MSE Z = 0.085239
#
#
# Train Epoch 73: MSE Total = 0.148158,   MSE X = 0.069328,   MSE Z = 0.065117
# Test: MSE Total = 0.192511,   MSE X = 0.083974,   MSE Z = 0.106172
#
#
# Train Epoch 74: MSE Total = 0.074859,   MSE X = 0.029168,   MSE Z = 0.053590
# Test: MSE Total = 0.142479,   MSE X = 0.064203,   MSE Z = 0.071334
#
#
# Train Epoch 75: MSE Total = 0.069691,   MSE X = 0.027231,   MSE Z = 0.049618
# Test: MSE Total = 0.139265,   MSE X = 0.061394,   MSE Z = 0.074524
#
#
# Train Epoch 76: MSE Total = 0.047445,   MSE X = 0.016990,   MSE Z = 0.039246
# Test: MSE Total = 0.127803,   MSE X = 0.056530,   MSE Z = 0.067726
#
#
# Train Epoch 77: MSE Total = 0.038564,   MSE X = 0.014554,   MSE Z = 0.029275
# Test: MSE Total = 0.122417,   MSE X = 0.052786,   MSE Z = 0.069678
#
#
# Train Epoch 78: MSE Total = 0.035183,   MSE X = 0.012495,   MSE Z = 0.029471
# Test: MSE Total = 0.125584,   MSE X = 0.054670,   MSE Z = 0.069651
#
#
# Train Epoch 79: MSE Total = 0.038418,   MSE X = 0.014545,   MSE Z = 0.029001
# Test: MSE Total = 0.137406,   MSE X = 0.062787,   MSE Z = 0.065719
#
#
# Train Epoch 80: MSE Total = 0.036095,   MSE X = 0.013176,   MSE Z = 0.028975
# Test: MSE Total = 0.116331,   MSE X = 0.049900,   MSE Z = 0.067137
#
#
# Train Epoch 81: MSE Total = 0.031303,   MSE X = 0.011164,   MSE Z = 0.026052
# Test: MSE Total = 0.115258,   MSE X = 0.051189,   MSE Z = 0.060342
#
#
# Train Epoch 82: MSE Total = 0.031049,   MSE X = 0.011493,   MSE Z = 0.024362
# Test: MSE Total = 0.127361,   MSE X = 0.052461,   MSE Z = 0.081162
#
#
# Train Epoch 83: MSE Total = 0.029488,   MSE X = 0.010674,   MSE Z = 0.023987
# Test: MSE Total = 0.123658,   MSE X = 0.055455,   MSE Z = 0.062853
#
#
# Train Epoch 84: MSE Total = 0.032644,   MSE X = 0.013072,   MSE Z = 0.022126
# Test: MSE Total = 0.121236,   MSE X = 0.054370,   MSE Z = 0.061615
#
#
# Train Epoch 85: MSE Total = 0.028664,   MSE X = 0.010174,   MSE Z = 0.024029
# Test: MSE Total = 0.120012,   MSE X = 0.053342,   MSE Z = 0.062686
#
#
# Train Epoch 86: MSE Total = 0.025603,   MSE X = 0.009285,   MSE Z = 0.020764
# Test: MSE Total = 0.119569,   MSE X = 0.053110,   MSE Z = 0.062580
#
#
# Train Epoch 87: MSE Total = 0.031232,   MSE X = 0.010460,   MSE Z = 0.028389
# Test: MSE Total = 0.121026,   MSE X = 0.049584,   MSE Z = 0.078069
#
#
# Train Epoch 88: MSE Total = 0.029724,   MSE X = 0.010034,   MSE Z = 0.026741
# Test: MSE Total = 0.125979,   MSE X = 0.055251,   MSE Z = 0.068425
#
#
# Train Epoch 89: MSE Total = 0.027034,   MSE X = 0.008523,   MSE Z = 0.026449
# Test: MSE Total = 0.126607,   MSE X = 0.050641,   MSE Z = 0.086011
#
#
# Train Epoch 90: MSE Total = 0.024778,   MSE X = 0.008086,   MSE Z = 0.023272
# Test: MSE Total = 0.115325,   MSE X = 0.051299,   MSE Z = 0.060095
#
#
# Train Epoch 91: MSE Total = 0.022555,   MSE X = 0.007961,   MSE Z = 0.019068
# Test: MSE Total = 0.118415,   MSE X = 0.053703,   MSE Z = 0.058070
#
#
# Train Epoch 92: MSE Total = 0.033508,   MSE X = 0.013040,   MSE Z = 0.024042
# Test: MSE Total = 0.128264,   MSE X = 0.058134,   MSE Z = 0.063027
#
#
# Train Epoch 93: MSE Total = 0.035236,   MSE X = 0.013793,   MSE Z = 0.024999
# Test: MSE Total = 0.124486,   MSE X = 0.055490,   MSE Z = 0.064460
#
#
# Train Epoch 94: MSE Total = 0.029321,   MSE X = 0.009730,   MSE Z = 0.026971
# Test: MSE Total = 0.124577,   MSE X = 0.052035,   MSE Z = 0.076845
#
#
# Train Epoch 95: MSE Total = 0.029770,   MSE X = 0.010047,   MSE Z = 0.026791
# Test: MSE Total = 0.127071,   MSE X = 0.049193,   MSE Z = 0.092091
#
#
# Train Epoch 96: MSE Total = 0.028404,   MSE X = 0.010229,   MSE Z = 0.023291
# Test: MSE Total = 0.118995,   MSE X = 0.053240,   MSE Z = 0.060919
#
#
# Train Epoch 97: MSE Total = 0.024081,   MSE X = 0.008362,   MSE Z = 0.020842
# Test: MSE Total = 0.112474,   MSE X = 0.049841,   MSE Z = 0.059281
#
#
# Train Epoch 98: MSE Total = 0.022696,   MSE X = 0.008216,   MSE Z = 0.018460
# Test: MSE Total = 0.104077,   MSE X = 0.045711,   MSE Z = 0.056297
#
#
# Train Epoch 99: MSE Total = 0.021580,   MSE X = 0.007860,   MSE Z = 0.017385
# Test: MSE Total = 0.119024,   MSE X = 0.054635,   MSE Z = 0.056056
#
#
# Train Epoch 100: MSE Total = 0.018616,   MSE X = 0.006587,   MSE Z = 0.015679
# Test: MSE Total = 0.102675,   MSE X = 0.045113,   MSE Z = 0.055477
#
#
# Train Epoch 101: MSE Total = 0.019413,   MSE X = 0.007259,   MSE Z = 0.014974
# Test: MSE Total = 0.110667,   MSE X = 0.048815,   MSE Z = 0.059123
#
#
# Train Epoch 102: MSE Total = 0.021130,   MSE X = 0.008058,   MSE Z = 0.015743
# Test: MSE Total = 0.117573,   MSE X = 0.052167,   MSE Z = 0.061734
#
#
# Train Epoch 103: MSE Total = 0.023658,   MSE X = 0.009391,   MSE Z = 0.016326
# Test: MSE Total = 0.133090,   MSE X = 0.060179,   MSE Z = 0.065900
#
#
# Train Epoch 104: MSE Total = 0.021985,   MSE X = 0.008047,   MSE Z = 0.017570
# Test: MSE Total = 0.103726,   MSE X = 0.045795,   MSE Z = 0.055266
#
#
# Train Epoch 105: MSE Total = 0.020676,   MSE X = 0.006741,   MSE Z = 0.019440
# Test: MSE Total = 0.113382,   MSE X = 0.050071,   MSE Z = 0.060366
#
#
# Train Epoch 106: MSE Total = 0.018835,   MSE X = 0.006870,   MSE Z = 0.015137
# Test: MSE Total = 0.115572,   MSE X = 0.052206,   MSE Z = 0.057411
#
#
# Train Epoch 107: MSE Total = 0.019302,   MSE X = 0.007027,   MSE Z = 0.015559
# Test: MSE Total = 0.125069,   MSE X = 0.058370,   MSE Z = 0.055515
#
#
# Train Epoch 108: MSE Total = 0.021897,   MSE X = 0.007965,   MSE Z = 0.017677
# Test: MSE Total = 0.121516,   MSE X = 0.053116,   MSE Z = 0.066626
#
#
# Train Epoch 109: MSE Total = 0.020972,   MSE X = 0.007597,   MSE Z = 0.017041
# Test: MSE Total = 0.115850,   MSE X = 0.052975,   MSE Z = 0.055277
#
#
# Train Epoch 110: MSE Total = 0.022635,   MSE X = 0.008625,   MSE Z = 0.016888
# Test: MSE Total = 0.135082,   MSE X = 0.062638,   MSE Z = 0.061389
#
#
# Train Epoch 111: MSE Total = 0.024978,   MSE X = 0.009369,   MSE Z = 0.019162
# Test: MSE Total = 0.120661,   MSE X = 0.052185,   MSE Z = 0.068124
#
#
# Train Epoch 112: MSE Total = 0.163331,   MSE X = 0.072654,   MSE Z = 0.085109
# Test: MSE Total = 0.176138,   MSE X = 0.076496,   MSE Z = 0.098329
#
#
# Train Epoch 113: MSE Total = 0.096716,   MSE X = 0.040971,   MSE Z = 0.057637
# Test: MSE Total = 0.133010,   MSE X = 0.060558,   MSE Z = 0.064396
#
#
# Train Epoch 114: MSE Total = 0.053944,   MSE X = 0.022729,   MSE Z = 0.032578
# Test: MSE Total = 0.104789,   MSE X = 0.045239,   MSE Z = 0.059452
#
#
# Train Epoch 115: MSE Total = 0.041060,   MSE X = 0.016729,   MSE Z = 0.026815
# Test: MSE Total = 0.107790,   MSE X = 0.047126,   MSE Z = 0.059067
#
#
# Train Epoch 116: MSE Total = 0.036781,   MSE X = 0.014430,   MSE Z = 0.025983
# Test: MSE Total = 0.105972,   MSE X = 0.045924,   MSE Z = 0.059509
#
#
# Train Epoch 117: MSE Total = 0.032804,   MSE X = 0.013200,   MSE Z = 0.022006
# Test: MSE Total = 0.103530,   MSE X = 0.045268,   MSE Z = 0.056717
#
#
# Train Epoch 118: MSE Total = 0.026714,   MSE X = 0.010591,   MSE Z = 0.018482
# Test: MSE Total = 0.112209,   MSE X = 0.050217,   MSE Z = 0.057396
#
#
# Train Epoch 119: MSE Total = 0.040470,   MSE X = 0.017174,   MSE Z = 0.024011
# Test: MSE Total = 0.106910,   MSE X = 0.045827,   MSE Z = 0.061812
#
#
# Train Epoch 120: MSE Total = 0.030610,   MSE X = 0.011446,   MSE Z = 0.023610
# Test: MSE Total = 0.104131,   MSE X = 0.042877,   MSE Z = 0.066411
#
#
# Train Epoch 121: MSE Total = 0.024082,   MSE X = 0.008752,   MSE Z = 0.019467
# Test: MSE Total = 0.096508,   MSE X = 0.041023,   MSE Z = 0.057015
#
#
# Train Epoch 122: MSE Total = 0.019866,   MSE X = 0.007182,   MSE Z = 0.016193
# Test: MSE Total = 0.096719,   MSE X = 0.041797,   MSE Z = 0.054727
#
#
# Train Epoch 123: MSE Total = 0.018807,   MSE X = 0.006792,   MSE Z = 0.015355
# Test: MSE Total = 0.092459,   MSE X = 0.039023,   MSE Z = 0.055609
#
#
# Train Epoch 124: MSE Total = 0.018466,   MSE X = 0.006558,   MSE Z = 0.015470
# Test: MSE Total = 0.090697,   MSE X = 0.038793,   MSE Z = 0.052737
#
#
# Train Epoch 125: MSE Total = 0.017143,   MSE X = 0.006243,   MSE Z = 0.013813
# Test: MSE Total = 0.089661,   MSE X = 0.038698,   MSE Z = 0.050904
#
#
# Train Epoch 126: MSE Total = 0.015438,   MSE X = 0.005573,   MSE Z = 0.012611
# Test: MSE Total = 0.087970,   MSE X = 0.037516,   MSE Z = 0.051542
#
#
# Train Epoch 127: MSE Total = 0.017361,   MSE X = 0.006030,   MSE Z = 0.015019
# Test: MSE Total = 0.096309,   MSE X = 0.041284,   MSE Z = 0.055677
#
#
# Train Epoch 128: MSE Total = 0.016026,   MSE X = 0.005582,   MSE Z = 0.013810
# Test: MSE Total = 0.085852,   MSE X = 0.036565,   MSE Z = 0.050468
#
#
# Train Epoch 129: MSE Total = 0.015131,   MSE X = 0.005129,   MSE Z = 0.013539
# Test: MSE Total = 0.091876,   MSE X = 0.039546,   MSE Z = 0.052543
#
#
# Train Epoch 130: MSE Total = 0.013897,   MSE X = 0.004432,   MSE Z = 0.013419
# Test: MSE Total = 0.086248,   MSE X = 0.036966,   MSE Z = 0.049882
#
#
# Train Epoch 131: MSE Total = 0.015636,   MSE X = 0.005571,   MSE Z = 0.013034
# Test: MSE Total = 0.090653,   MSE X = 0.037923,   MSE Z = 0.055714
#
#
# Train Epoch 132: MSE Total = 0.013605,   MSE X = 0.004631,   MSE Z = 0.012103
# Test: MSE Total = 0.090195,   MSE X = 0.038917,   MSE Z = 0.051249
#
#
# Train Epoch 133: MSE Total = 0.016923,   MSE X = 0.005368,   MSE Z = 0.016442
# Test: MSE Total = 0.083643,   MSE X = 0.035349,   MSE Z = 0.050140
#
#
# Train Epoch 134: MSE Total = 0.016011,   MSE X = 0.005860,   MSE Z = 0.012799
# Test: MSE Total = 0.095077,   MSE X = 0.040199,   MSE Z = 0.056932
#
#
# Train Epoch 135: MSE Total = 0.014434,   MSE X = 0.005252,   MSE Z = 0.011646
# Test: MSE Total = 0.089560,   MSE X = 0.038158,   MSE Z = 0.052599
#
#
# Train Epoch 136: MSE Total = 0.014663,   MSE X = 0.004602,   MSE Z = 0.014419
# Test: MSE Total = 0.094023,   MSE X = 0.039715,   MSE Z = 0.056435
#
#
# Train Epoch 137: MSE Total = 0.014676,   MSE X = 0.005457,   MSE Z = 0.011428
# Test: MSE Total = 0.094956,   MSE X = 0.042049,   MSE Z = 0.050150
#
#
# Train Epoch 138: MSE Total = 0.016064,   MSE X = 0.006154,   MSE Z = 0.011873
# Test: MSE Total = 0.087979,   MSE X = 0.037472,   MSE Z = 0.051717
#
#
# Train Epoch 139: MSE Total = 0.012684,   MSE X = 0.004419,   MSE Z = 0.010926
# Test: MSE Total = 0.084203,   MSE X = 0.035710,   MSE Z = 0.050038
#
#
# Train Epoch 140: MSE Total = 0.012687,   MSE X = 0.004569,   MSE Z = 0.010405
# Test: MSE Total = 0.090300,   MSE X = 0.039279,   MSE Z = 0.050190
#
#
# Train Epoch 141: MSE Total = 0.013667,   MSE X = 0.004809,   MSE Z = 0.011608
# Test: MSE Total = 0.091350,   MSE X = 0.039237,   MSE Z = 0.052534
#
#
# Train Epoch 142: MSE Total = 0.023476,   MSE X = 0.009669,   MSE Z = 0.014965
# Test: MSE Total = 0.106635,   MSE X = 0.046894,   MSE Z = 0.057471
#
#
# Train Epoch 143: MSE Total = 0.023138,   MSE X = 0.009408,   MSE Z = 0.015177
# Test: MSE Total = 0.088990,   MSE X = 0.038407,   MSE Z = 0.050527
#
#
# Train Epoch 144: MSE Total = 0.016633,   MSE X = 0.005915,   MSE Z = 0.013905
# Test: MSE Total = 0.092153,   MSE X = 0.040768,   MSE Z = 0.048808
#
#
# Train Epoch 145: MSE Total = 0.013719,   MSE X = 0.005002,   MSE Z = 0.011034
# Test: MSE Total = 0.084681,   MSE X = 0.036238,   MSE Z = 0.049174
#
#
# Train Epoch 146: MSE Total = 0.012708,   MSE X = 0.004393,   MSE Z = 0.011068
# Test: MSE Total = 0.088865,   MSE X = 0.038680,   MSE Z = 0.049305
#
#
# Train Epoch 147: MSE Total = 0.014013,   MSE X = 0.004800,   MSE Z = 0.012362
# Test: MSE Total = 0.086533,   MSE X = 0.037215,   MSE Z = 0.049597
#
#
# Train Epoch 148: MSE Total = 0.012829,   MSE X = 0.004724,   MSE Z = 0.010153
# Test: MSE Total = 0.087945,   MSE X = 0.034100,   MSE Z = 0.063547
#
#
# Train Epoch 149: MSE Total = 0.012151,   MSE X = 0.004343,   MSE Z = 0.010080
# Test: MSE Total = 0.085121,   MSE X = 0.036017,   MSE Z = 0.050873
#
#
# Train Epoch 150: MSE Total = 0.011395,   MSE X = 0.004121,   MSE Z = 0.009280
# Test: MSE Total = 0.085525,   MSE X = 0.034657,   MSE Z = 0.056519
#
#
# Train Epoch 151: MSE Total = 0.014265,   MSE X = 0.004821,   MSE Z = 0.012816
# Test: MSE Total = 0.089876,   MSE X = 0.037920,   MSE Z = 0.054099
#
#
# Train Epoch 152: MSE Total = 0.013545,   MSE X = 0.004614,   MSE Z = 0.012039
# Test: MSE Total = 0.104425,   MSE X = 0.044671,   MSE Z = 0.060698
#
#
# Train Epoch 153: MSE Total = 0.017224,   MSE X = 0.006729,   MSE Z = 0.012267
# Test: MSE Total = 0.098909,   MSE X = 0.043431,   MSE Z = 0.053538
#
#
# Train Epoch 154: MSE Total = 0.014888,   MSE X = 0.005432,   MSE Z = 0.011960
# Test: MSE Total = 0.087640,   MSE X = 0.036694,   MSE Z = 0.053752
#
#
# Train Epoch 155: MSE Total = 0.013422,   MSE X = 0.004835,   MSE Z = 0.011000
# Test: MSE Total = 0.090060,   MSE X = 0.038481,   MSE Z = 0.052504
#
#
# Train Epoch 156: MSE Total = 0.014798,   MSE X = 0.005562,   MSE Z = 0.011315
# Test: MSE Total = 0.082466,   MSE X = 0.035229,   MSE Z = 0.048103
#
#
# Train Epoch 157: MSE Total = 0.020011,   MSE X = 0.007397,   MSE Z = 0.015735
# Test: MSE Total = 0.151334,   MSE X = 0.061538,   MSE Z = 0.099254
#
#
# Train Epoch 158: MSE Total = 0.178017,   MSE X = 0.082318,   MSE Z = 0.081709
# Test: MSE Total = 0.182563,   MSE X = 0.077443,   MSE Z = 0.108419
#
#
# Train Epoch 159: MSE Total = 0.123269,   MSE X = 0.056603,   MSE Z = 0.057988
# Test: MSE Total = 0.152832,   MSE X = 0.067162,   MSE Z = 0.082537
#
#
# Train Epoch 160: MSE Total = 0.059206,   MSE X = 0.024774,   MSE Z = 0.036364
# Test: MSE Total = 0.105752,   MSE X = 0.040209,   MSE Z = 0.079218
#
#
# Train Epoch 161: MSE Total = 0.034093,   MSE X = 0.013430,   MSE Z = 0.023889
# Test: MSE Total = 0.085758,   MSE X = 0.034893,   MSE Z = 0.056175
#
#
# Train Epoch 162: MSE Total = 0.023693,   MSE X = 0.008959,   MSE Z = 0.017924
# Test: MSE Total = 0.078889,   MSE X = 0.031391,   MSE Z = 0.054170
#
#
# Train Epoch 163: MSE Total = 0.019654,   MSE X = 0.006362,   MSE Z = 0.018645
# Test: MSE Total = 0.083807,   MSE X = 0.033775,   MSE Z = 0.056039
#
#
# Train Epoch 164: MSE Total = 0.015693,   MSE X = 0.005756,   MSE Z = 0.012501
# Test: MSE Total = 0.078437,   MSE X = 0.030346,   MSE Z = 0.056913
#
#
# Train Epoch 165: MSE Total = 0.016234,   MSE X = 0.005632,   MSE Z = 0.014069
# Test: MSE Total = 0.083705,   MSE X = 0.035159,   MSE Z = 0.050940
#
#
# Train Epoch 166: MSE Total = 0.013270,   MSE X = 0.004823,   MSE Z = 0.010727
# Test: MSE Total = 0.078667,   MSE X = 0.031964,   MSE Z = 0.051684
#
#
# Train Epoch 167: MSE Total = 0.012326,   MSE X = 0.004306,   MSE Z = 0.010577
# Test: MSE Total = 0.077751,   MSE X = 0.032554,   MSE Z = 0.047684
#
#
# Train Epoch 168: MSE Total = 0.012157,   MSE X = 0.004313,   MSE Z = 0.010197
# Test: MSE Total = 0.074871,   MSE X = 0.029696,   MSE Z = 0.051750
#
#
# Train Epoch 169: MSE Total = 0.012726,   MSE X = 0.004128,   MSE Z = 0.012041
# Test: MSE Total = 0.076303,   MSE X = 0.031042,   MSE Z = 0.049995
#
#
# Train Epoch 170: MSE Total = 0.012660,   MSE X = 0.004463,   MSE Z = 0.010721
# Test: MSE Total = 0.074178,   MSE X = 0.029655,   MSE Z = 0.050446
#
#
# Train Epoch 171: MSE Total = 0.012330,   MSE X = 0.004555,   MSE Z = 0.009708
# Test: MSE Total = 0.076036,   MSE X = 0.030016,   MSE Z = 0.053057
#
#
# Train Epoch 172: MSE Total = 0.010962,   MSE X = 0.003713,   MSE Z = 0.009818
# Test: MSE Total = 0.073212,   MSE X = 0.028601,   MSE Z = 0.052144
#
#
# Train Epoch 173: MSE Total = 0.009751,   MSE X = 0.003408,   MSE Z = 0.008363
# Test: MSE Total = 0.075322,   MSE X = 0.031177,   MSE Z = 0.047466
#
#
# Train Epoch 174: MSE Total = 0.009674,   MSE X = 0.003078,   MSE Z = 0.009365
# Test: MSE Total = 0.078917,   MSE X = 0.033027,   MSE Z = 0.048454
#
#
# Train Epoch 175: MSE Total = 0.009343,   MSE X = 0.003072,   MSE Z = 0.008692
# Test: MSE Total = 0.077955,   MSE X = 0.031705,   MSE Z = 0.051108
#
#
# Train Epoch 176: MSE Total = 0.010637,   MSE X = 0.003898,   MSE Z = 0.008485
# Test: MSE Total = 0.076747,   MSE X = 0.031629,   MSE Z = 0.048851
#
#
# Train Epoch 177: MSE Total = 0.009813,   MSE X = 0.003486,   MSE Z = 0.008215
# Test: MSE Total = 0.074620,   MSE X = 0.030442,   MSE Z = 0.048593
#
#
# Train Epoch 178: MSE Total = 0.009861,   MSE X = 0.003085,   MSE Z = 0.009731
# Test: MSE Total = 0.071558,   MSE X = 0.028642,   MSE Z = 0.048544
#
#
# Train Epoch 179: MSE Total = 0.009562,   MSE X = 0.003236,   MSE Z = 0.008575
# Test: MSE Total = 0.075094,   MSE X = 0.030863,   MSE Z = 0.048099
#
#
# Train Epoch 180: MSE Total = 0.008291,   MSE X = 0.002804,   MSE Z = 0.007441
# Test: MSE Total = 0.073136,   MSE X = 0.029250,   MSE Z = 0.049697
#
#
# Train Epoch 181: MSE Total = 0.012582,   MSE X = 0.004920,   MSE Z = 0.008946
# Test: MSE Total = 0.075888,   MSE X = 0.031168,   MSE Z = 0.048682
#
#
# Train Epoch 182: MSE Total = 0.009281,   MSE X = 0.003331,   MSE Z = 0.007651
# Test: MSE Total = 0.073088,   MSE X = 0.029741,   MSE Z = 0.047865
#
#
# Train Epoch 183: MSE Total = 0.008966,   MSE X = 0.003140,   MSE Z = 0.007665
# Test: MSE Total = 0.076973,   MSE X = 0.031649,   MSE Z = 0.049252
#
#
# Train Epoch 184: MSE Total = 0.009381,   MSE X = 0.003255,   MSE Z = 0.008129
# Test: MSE Total = 0.069697,   MSE X = 0.027887,   MSE Z = 0.047314
#
#
# Train Epoch 185: MSE Total = 0.037885,   MSE X = 0.017164,   MSE Z = 0.018641
# Test: MSE Total = 0.123509,   MSE X = 0.044868,   MSE Z = 0.099908
#
#
# Train Epoch 186: MSE Total = 0.051887,   MSE X = 0.020528,   MSE Z = 0.036047
# Test: MSE Total = 0.101630,   MSE X = 0.042482,   MSE Z = 0.062579
#
#
# Train Epoch 187: MSE Total = 0.041012,   MSE X = 0.016264,   MSE Z = 0.028358
# Test: MSE Total = 0.094491,   MSE X = 0.040057,   MSE Z = 0.056208
#
#
# Train Epoch 188: MSE Total = 0.029358,   MSE X = 0.011864,   MSE Z = 0.019516
# Test: MSE Total = 0.090987,   MSE X = 0.034323,   MSE Z = 0.069119
#
#
# Train Epoch 189: MSE Total = 0.034791,   MSE X = 0.013676,   MSE Z = 0.024480
# Test: MSE Total = 0.084850,   MSE X = 0.033311,   MSE Z = 0.059858
#
#
# Train Epoch 190: MSE Total = 0.016061,   MSE X = 0.005736,   MSE Z = 0.013339
# Test: MSE Total = 0.075384,   MSE X = 0.028303,   MSE Z = 0.057739
#
#
# Train Epoch 191: MSE Total = 0.013950,   MSE X = 0.004772,   MSE Z = 0.012327
# Test: MSE Total = 0.078554,   MSE X = 0.032387,   MSE Z = 0.049956
#
#
# Train Epoch 192: MSE Total = 0.011818,   MSE X = 0.004423,   MSE Z = 0.009102
# Test: MSE Total = 0.070359,   MSE X = 0.027271,   MSE Z = 0.050874
#
#
# Train Epoch 193: MSE Total = 0.010810,   MSE X = 0.003687,   MSE Z = 0.009594
# Test: MSE Total = 0.068834,   MSE X = 0.026965,   MSE Z = 0.048765
#
#
# Train Epoch 194: MSE Total = 0.009346,   MSE X = 0.003143,   MSE Z = 0.008451
# Test: MSE Total = 0.063996,   MSE X = 0.024268,   MSE Z = 0.048165
#
#
# Train Epoch 195: MSE Total = 0.008551,   MSE X = 0.002633,   MSE Z = 0.008588
# Test: MSE Total = 0.063755,   MSE X = 0.024409,   MSE Z = 0.047167
#
#
# Train Epoch 196: MSE Total = 0.009216,   MSE X = 0.003190,   MSE Z = 0.008013
# Test: MSE Total = 0.072136,   MSE X = 0.029408,   MSE Z = 0.047049
#
#
# Train Epoch 197: MSE Total = 0.008600,   MSE X = 0.002952,   MSE Z = 0.007563
# Test: MSE Total = 0.067671,   MSE X = 0.027288,   MSE Z = 0.045193
#
#
# Train Epoch 198: MSE Total = 0.007769,   MSE X = 0.002596,   MSE Z = 0.007082
# Test: MSE Total = 0.068375,   MSE X = 0.027560,   MSE Z = 0.045707
#
#
# Train Epoch 199: MSE Total = 0.007824,   MSE X = 0.002619,   MSE Z = 0.007118
# Test: MSE Total = 0.063265,   MSE X = 0.024171,   MSE Z = 0.046980
#
#
# Train Epoch 200: MSE Total = 0.007920,   MSE X = 0.002674,   MSE Z = 0.007121
# Test: MSE Total = 0.070223,   MSE X = 0.028546,   MSE Z = 0.046091
#
#
# Got the weights of the epoch 199
# Execution time: 7 minutes, 43.84 seconds

# %%
torch.save(model.state_dict(), "model_weights_step3_one_shot")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyModel(class_to_emb_idx=class_to_emb_idx, embedding_dim=embedding_dim,
                input_size=input_size, hidden_size=hidden_size, output_size=input_size*future_seconds*framerate, 
                num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step3_one_shot"))

model.eval()
# Out:
# MyModel(
#   (embedding_layer): Embedding(59, 32)
#   (pointnet): PointNetfeat(
#     (conv1): Conv1d(35, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pc_emb_proj): Linear(in_features=1024, out_features=256, bias=True)
#   (pc_emb_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=80, bias=True)
# )

# %%
model.eval()

batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [5, 10, 15, 20, 25, 26]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc in train_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc in test_loader:
            past, future, pc = past.to(device), future.to(device), pc.to(device)
            future_pred = model(past, pc)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.073192,   ADE X = 0.032081,   ADE Z = 0.058910
# FDE Total = 0.117244,   FDE X = 0.056102,   FDE Z = 0.091002
#
# Model performances on test set:
#
# ADE Total = 0.165686,   ADE X = 0.083029,   ADE Z = 0.124030
# FDE Total = 0.303399,   FDE X = 0.185502,   FDE Z = 0.198709

# %%
def save_prediction(index):    
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _, pc_batch = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_tensor = pc_batch[index].unsqueeze(0).to(device)

    with torch.no_grad():
        predicted_future = model(past_tensor, pc_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'

    with np.load(file_name) as data:
        data_dict = dict(data)

    # Aggiungi la nuova coppia chiave-array
    data_dict['step3_one_shot'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
