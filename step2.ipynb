# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio embedding delle nuvole di punti

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.ln1 = nn.LayerNorm(64)
        self.ln2 = nn.LayerNorm(128)
        self.ln3 = nn.LayerNorm(1024)
        self.fc_reduce = nn.Linear(1024, 256)  # nuovo layer per la riduzione a 256
        self.ln_reduce = nn.LayerNorm(256)  # normalizzazione output ridotto

    def forward(self, x):
        x = F.relu(self.ln1(self.conv1(x).transpose(1, 2))).transpose(1, 2)
        x = F.relu(self.ln2(self.conv2(x).transpose(1, 2))).transpose(1, 2)
        x = self.ln3(self.conv3(x).transpose(1, 2)).transpose(1, 2)
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)
        x = self.ln_reduce(self.fc_reduce(x))

        return x

# %%
torch.manual_seed(42)
pointnet = PointNetfeat()
pointnet.to(device)
pointnet.eval()

npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]

point_cloud_embeddings = [] # lista per salvare gli embedding

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e mettila su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).transpose(1, 2).to(device)

        # Calcola l'embedding
        embedding = pointnet(point_cloud).squeeze(0).cpu().numpy()

        # Salva l'embedding nella lista
        point_cloud_embeddings.append(embedding)

# Salva gli embedding in un file NPZ
np.savez_compressed("point_cloud_embeddings.npz", embeddings=np.array(point_cloud_embeddings))

print("Embeddings saved in 'point_cloud_embeddings.npz'!")
# Out:
# Embeddings saved in 'point_cloud_embeddings.npz'!

# %% [markdown]
# ## Sezione addestramento della GRU

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_cloud_embeddings, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_cloud_embeddings = point_cloud_embeddings

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_cloud_embedding = self.point_cloud_embeddings[idx]

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_cloud_embedding

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.hidden_size  = hidden_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc_emb):
        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_variance, global_z_variance):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc_emb in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc_emb) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_variance, global_z_variance):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc_emb in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc_emb)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_embs = np.load("point_cloud_embeddings.npz")
point_cloud_embeddings = [torch.tensor(emb, dtype=torch.float32) for emb in loaded_pc_embs["embeddings"]]

dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                        framerate=framerate, point_cloud_embeddings=point_cloud_embeddings)

torch.manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25])
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 256])

# %%
#Calcolo della varianza globale di x e di z lungo le traiettore

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

# concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.37383729219436646
# Global variance of the z-coordinate: 4.3598480224609375

# %%
batch = next(iter(test_loader))  # Prendi un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = 1000

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_variance, global_z_variance)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_variance, global_z_variance)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.281697,   MSE X = 0.563974,   MSE Z = 0.750227
# Test: MSE Total = 1.000065,   MSE X = 0.549524,   MSE Z = 0.211521
#
#
# Train Epoch 2: MSE Total = 1.012144,   MSE X = 0.552801,   MSE Z = 0.225553
# Test: MSE Total = 1.003946,   MSE X = 0.553570,   MSE Z = 0.205808
#
#
# Train Epoch 3: MSE Total = 0.931908,   MSE X = 0.487462,   MSE Z = 0.281151
# Test: MSE Total = 0.733516,   MSE X = 0.370602,   MSE Z = 0.265983
#
#
# Train Epoch 4: MSE Total = 0.633018,   MSE X = 0.312629,   MSE Z = 0.254121
# Test: MSE Total = 0.530079,   MSE X = 0.257184,   MSE Z = 0.228528
#
#
# Train Epoch 5: MSE Total = 0.561321,   MSE X = 0.274876,   MSE Z = 0.233341
# Test: MSE Total = 0.504025,   MSE X = 0.253271,   MSE Z = 0.187489
#
#
# Train Epoch 6: MSE Total = 0.531386,   MSE X = 0.258560,   MSE Z = 0.226555
# Test: MSE Total = 0.525352,   MSE X = 0.266205,   MSE Z = 0.187850
#
#
# Train Epoch 7: MSE Total = 0.502857,   MSE X = 0.247734,   MSE Z = 0.203958
# Test: MSE Total = 0.635352,   MSE X = 0.328762,   MSE Z = 0.203898
#
#
# Train Epoch 8: MSE Total = 0.489916,   MSE X = 0.241710,   MSE Z = 0.197508
# Test: MSE Total = 0.601479,   MSE X = 0.313581,   MSE Z = 0.185013
#
#
# Train Epoch 9: MSE Total = 0.491926,   MSE X = 0.241625,   MSE Z = 0.201996
# Test: MSE Total = 0.432165,   MSE X = 0.213277,   MSE Z = 0.174025
#
#
# Train Epoch 10: MSE Total = 0.474515,   MSE X = 0.231227,   MSE Z = 0.201153
# Test: MSE Total = 0.471338,   MSE X = 0.227000,   MSE Z = 0.208953
#
#
# Train Epoch 11: MSE Total = 0.466778,   MSE X = 0.224066,   MSE Z = 0.209451
# Test: MSE Total = 0.428814,   MSE X = 0.209704,   MSE Z = 0.179228
#
#
# Train Epoch 12: MSE Total = 0.450609,   MSE X = 0.217816,   MSE Z = 0.197036
# Test: MSE Total = 0.413322,   MSE X = 0.194148,   MSE Z = 0.200006
#
#
# Train Epoch 13: MSE Total = 0.431073,   MSE X = 0.207340,   MSE Z = 0.192020
# Test: MSE Total = 0.585369,   MSE X = 0.267838,   MSE Z = 0.307590
#
#
# Train Epoch 14: MSE Total = 0.446002,   MSE X = 0.212096,   MSE Z = 0.206948
# Test: MSE Total = 0.380972,   MSE X = 0.184586,   MSE Z = 0.165112
#
#
# Train Epoch 15: MSE Total = 0.431848,   MSE X = 0.207918,   MSE Z = 0.191663
# Test: MSE Total = 0.435365,   MSE X = 0.208671,   MSE Z = 0.196434
#
#
# Train Epoch 16: MSE Total = 0.409366,   MSE X = 0.195254,   MSE Z = 0.187967
# Test: MSE Total = 0.374558,   MSE X = 0.180009,   MSE Z = 0.167352
#
#
# Train Epoch 17: MSE Total = 0.402565,   MSE X = 0.190771,   MSE Z = 0.189078
# Test: MSE Total = 0.381032,   MSE X = 0.176418,   MSE Z = 0.193132
#
#
# Train Epoch 18: MSE Total = 0.400714,   MSE X = 0.192063,   MSE Z = 0.180800
# Test: MSE Total = 0.355035,   MSE X = 0.167812,   MSE Z = 0.168241
#
#
# Train Epoch 19: MSE Total = 0.396394,   MSE X = 0.189640,   MSE Z = 0.180054
# Test: MSE Total = 0.401340,   MSE X = 0.191296,   MSE Z = 0.184728
#
#
# Train Epoch 20: MSE Total = 0.390160,   MSE X = 0.184918,   MSE Z = 0.183162
# Test: MSE Total = 0.385418,   MSE X = 0.184395,   MSE Z = 0.175049
#
#
# Train Epoch 21: MSE Total = 0.381270,   MSE X = 0.183774,   MSE Z = 0.168508
# Test: MSE Total = 0.344778,   MSE X = 0.165644,   MSE Z = 0.154226
#
#
# Train Epoch 22: MSE Total = 0.360744,   MSE X = 0.171830,   MSE Z = 0.166439
# Test: MSE Total = 0.367060,   MSE X = 0.178069,   MSE Z = 0.158321
#
#
# Train Epoch 23: MSE Total = 0.361984,   MSE X = 0.172589,   MSE Z = 0.166435
# Test: MSE Total = 0.342643,   MSE X = 0.157592,   MSE Z = 0.177265
#
#
# Train Epoch 24: MSE Total = 0.350222,   MSE X = 0.166673,   MSE Z = 0.162078
# Test: MSE Total = 0.310886,   MSE X = 0.140908,   MSE Z = 0.167931
#
#
# Train Epoch 25: MSE Total = 0.354011,   MSE X = 0.166428,   MSE Z = 0.170825
# Test: MSE Total = 0.332231,   MSE X = 0.157414,   MSE Z = 0.156133
#
#
# Train Epoch 26: MSE Total = 0.337693,   MSE X = 0.159355,   MSE Z = 0.160908
# Test: MSE Total = 0.354193,   MSE X = 0.174666,   MSE Z = 0.143073
#
#
# Train Epoch 27: MSE Total = 0.324729,   MSE X = 0.152365,   MSE Z = 0.157711
# Test: MSE Total = 0.325950,   MSE X = 0.159214,   MSE Z = 0.136871
#
#
# Train Epoch 28: MSE Total = 0.330093,   MSE X = 0.155901,   MSE Z = 0.156837
# Test: MSE Total = 0.312986,   MSE X = 0.150562,   MSE Z = 0.139351
#
#
# Train Epoch 29: MSE Total = 0.308193,   MSE X = 0.144074,   MSE Z = 0.151497
# Test: MSE Total = 0.297366,   MSE X = 0.137470,   MSE Z = 0.151444
#
#
# Train Epoch 30: MSE Total = 0.302995,   MSE X = 0.140184,   MSE Z = 0.153928
# Test: MSE Total = 0.277827,   MSE X = 0.129541,   MSE Z = 0.137724
#
#
# Train Epoch 31: MSE Total = 0.287252,   MSE X = 0.132918,   MSE Z = 0.145869
# Test: MSE Total = 0.273516,   MSE X = 0.125527,   MSE Z = 0.142429
#
#
# Train Epoch 32: MSE Total = 0.294416,   MSE X = 0.137078,   MSE Z = 0.146623
# Test: MSE Total = 0.290146,   MSE X = 0.135066,   MSE Z = 0.144578
#
#
# Train Epoch 33: MSE Total = 0.286423,   MSE X = 0.133155,   MSE Z = 0.143331
# Test: MSE Total = 0.254912,   MSE X = 0.120365,   MSE Z = 0.121214
#
#
# Train Epoch 34: MSE Total = 0.265793,   MSE X = 0.122511,   MSE Z = 0.136603
# Test: MSE Total = 0.246799,   MSE X = 0.112997,   MSE Z = 0.129436
#
#
# Train Epoch 35: MSE Total = 0.263786,   MSE X = 0.120257,   MSE Z = 0.140112
# Test: MSE Total = 0.269137,   MSE X = 0.127133,   MSE Z = 0.127801
#
#
# Train Epoch 36: MSE Total = 0.262057,   MSE X = 0.119277,   MSE Z = 0.139845
# Test: MSE Total = 0.238702,   MSE X = 0.110820,   MSE Z = 0.119963
#
#
# Train Epoch 37: MSE Total = 0.267332,   MSE X = 0.123318,   MSE Z = 0.137060
# Test: MSE Total = 0.282437,   MSE X = 0.128193,   MSE Z = 0.151953
#
#
# Train Epoch 38: MSE Total = 0.257897,   MSE X = 0.118036,   MSE Z = 0.135400
# Test: MSE Total = 0.324020,   MSE X = 0.152097,   MSE Z = 0.157147
#
#
# Train Epoch 39: MSE Total = 0.245130,   MSE X = 0.110701,   MSE Z = 0.133792
# Test: MSE Total = 0.231686,   MSE X = 0.109184,   MSE Z = 0.110899
#
#
# Train Epoch 40: MSE Total = 0.244188,   MSE X = 0.111137,   MSE Z = 0.130337
# Test: MSE Total = 0.260208,   MSE X = 0.124164,   MSE Z = 0.119299
#
#
# Train Epoch 41: MSE Total = 0.223979,   MSE X = 0.101079,   MSE Z = 0.122484
# Test: MSE Total = 0.228435,   MSE X = 0.107791,   MSE Z = 0.108867
#
#
# Train Epoch 42: MSE Total = 0.217836,   MSE X = 0.098423,   MSE Z = 0.118729
# Test: MSE Total = 0.219258,   MSE X = 0.100938,   MSE Z = 0.113112
#
#
# Train Epoch 43: MSE Total = 0.205915,   MSE X = 0.091742,   MSE Z = 0.116654
# Test: MSE Total = 0.197689,   MSE X = 0.091455,   MSE Z = 0.100458
#
#
# Train Epoch 44: MSE Total = 0.218192,   MSE X = 0.097615,   MSE Z = 0.122231
# Test: MSE Total = 0.269058,   MSE X = 0.128006,   MSE Z = 0.124657
#
#
# Train Epoch 45: MSE Total = 0.225097,   MSE X = 0.101017,   MSE Z = 0.125030
# Test: MSE Total = 0.243407,   MSE X = 0.102767,   MSE Z = 0.157288
#
#
# Train Epoch 46: MSE Total = 0.204354,   MSE X = 0.090278,   MSE Z = 0.118396
# Test: MSE Total = 0.208914,   MSE X = 0.090661,   MSE Z = 0.126607
#
#
# Train Epoch 47: MSE Total = 0.177881,   MSE X = 0.077083,   MSE Z = 0.108181
# Test: MSE Total = 0.175022,   MSE X = 0.078732,   MSE Z = 0.096579
#
#
# Train Epoch 48: MSE Total = 0.171777,   MSE X = 0.074120,   MSE Z = 0.105554
# Test: MSE Total = 0.175551,   MSE X = 0.076076,   MSE Z = 0.106754
#
#
# Train Epoch 49: MSE Total = 0.187896,   MSE X = 0.083295,   MSE Z = 0.107878
# Test: MSE Total = 0.223670,   MSE X = 0.106638,   MSE Z = 0.102858
#
#
# Train Epoch 50: MSE Total = 0.174684,   MSE X = 0.077120,   MSE Z = 0.101378
# Test: MSE Total = 0.154961,   MSE X = 0.069292,   MSE Z = 0.086927
#
#
# Train Epoch 51: MSE Total = 0.148558,   MSE X = 0.063443,   MSE Z = 0.093533
# Test: MSE Total = 0.184041,   MSE X = 0.076952,   MSE Z = 0.121488
#
#
# Train Epoch 52: MSE Total = 0.156328,   MSE X = 0.067191,   MSE Z = 0.096960
# Test: MSE Total = 0.156245,   MSE X = 0.069516,   MSE Z = 0.088845
#
#
# Train Epoch 53: MSE Total = 0.142758,   MSE X = 0.060955,   MSE Z = 0.089919
# Test: MSE Total = 0.196115,   MSE X = 0.087932,   MSE Z = 0.109204
#
#
# Train Epoch 54: MSE Total = 0.138457,   MSE X = 0.059079,   MSE Z = 0.087345
# Test: MSE Total = 0.140774,   MSE X = 0.061774,   MSE Z = 0.082980
#
#
# Train Epoch 55: MSE Total = 0.128413,   MSE X = 0.055251,   MSE Z = 0.079444
# Test: MSE Total = 0.142386,   MSE X = 0.063556,   MSE Z = 0.080259
#
#
# Train Epoch 56: MSE Total = 0.126844,   MSE X = 0.053861,   MSE Z = 0.080916
# Test: MSE Total = 0.127601,   MSE X = 0.054783,   MSE Z = 0.079349
#
#
# Train Epoch 57: MSE Total = 0.126524,   MSE X = 0.053981,   MSE Z = 0.079838
# Test: MSE Total = 0.147701,   MSE X = 0.063818,   MSE Z = 0.090464
#
#
# Train Epoch 58: MSE Total = 0.128962,   MSE X = 0.054433,   MSE Z = 0.083385
# Test: MSE Total = 0.147828,   MSE X = 0.066029,   MSE Z = 0.083176
#
#
# Train Epoch 59: MSE Total = 0.137245,   MSE X = 0.059630,   MSE Z = 0.082931
# Test: MSE Total = 0.198771,   MSE X = 0.088056,   MSE Z = 0.114326
#
#
# Train Epoch 60: MSE Total = 0.170564,   MSE X = 0.075242,   MSE Z = 0.099188
# Test: MSE Total = 0.130362,   MSE X = 0.058239,   MSE Z = 0.073311
#
#
# Train Epoch 61: MSE Total = 0.100097,   MSE X = 0.041569,   MSE Z = 0.067044
# Test: MSE Total = 0.111884,   MSE X = 0.049645,   MSE Z = 0.064077
#
#
# Train Epoch 62: MSE Total = 0.114979,   MSE X = 0.049211,   MSE Z = 0.072022
# Test: MSE Total = 0.120573,   MSE X = 0.052854,   MSE Z = 0.071260
#
#
# Train Epoch 63: MSE Total = 0.102748,   MSE X = 0.043084,   MSE Z = 0.067408
# Test: MSE Total = 0.118536,   MSE X = 0.052702,   MSE Z = 0.067529
#
#
# Train Epoch 64: MSE Total = 0.092119,   MSE X = 0.038575,   MSE Z = 0.060612
# Test: MSE Total = 0.102998,   MSE X = 0.042555,   MSE Z = 0.069735
#
#
# Train Epoch 65: MSE Total = 0.079707,   MSE X = 0.032761,   MSE Z = 0.054553
# Test: MSE Total = 0.097985,   MSE X = 0.040799,   MSE Z = 0.065267
#
#
# Train Epoch 66: MSE Total = 0.086881,   MSE X = 0.036265,   MSE Z = 0.057565
# Test: MSE Total = 0.099041,   MSE X = 0.041612,   MSE Z = 0.064692
#
#
# Train Epoch 67: MSE Total = 0.076123,   MSE X = 0.030543,   MSE Z = 0.054641
# Test: MSE Total = 0.101679,   MSE X = 0.044110,   MSE Z = 0.061671
#
#
# Train Epoch 68: MSE Total = 0.086075,   MSE X = 0.035406,   MSE Z = 0.058813
# Test: MSE Total = 0.120653,   MSE X = 0.053421,   MSE Z = 0.069491
#
#
# Train Epoch 69: MSE Total = 0.081471,   MSE X = 0.033325,   MSE Z = 0.056308
# Test: MSE Total = 0.124565,   MSE X = 0.053896,   MSE Z = 0.076039
#
#
# Train Epoch 70: MSE Total = 0.077633,   MSE X = 0.031972,   MSE Z = 0.052914
# Test: MSE Total = 0.082965,   MSE X = 0.035235,   MSE Z = 0.052904
#
#
# Train Epoch 71: MSE Total = 0.068565,   MSE X = 0.027296,   MSE Z = 0.049949
# Test: MSE Total = 0.084433,   MSE X = 0.032406,   MSE Z = 0.065631
#
#
# Train Epoch 72: MSE Total = 0.076674,   MSE X = 0.030588,   MSE Z = 0.055638
# Test: MSE Total = 0.093817,   MSE X = 0.041336,   MSE Z = 0.054729
#
#
# Train Epoch 73: MSE Total = 0.067856,   MSE X = 0.027378,   MSE Z = 0.048190
# Test: MSE Total = 0.071428,   MSE X = 0.029917,   MSE Z = 0.046976
#
#
# Train Epoch 74: MSE Total = 0.073518,   MSE X = 0.030982,   MSE Z = 0.047701
# Test: MSE Total = 0.120028,   MSE X = 0.052858,   MSE Z = 0.070108
#
#
# Train Epoch 75: MSE Total = 0.099836,   MSE X = 0.043156,   MSE Z = 0.061080
# Test: MSE Total = 0.236380,   MSE X = 0.111871,   MSE Z = 0.111525
#
#
# Train Epoch 76: MSE Total = 0.112463,   MSE X = 0.048661,   MSE Z = 0.068648
# Test: MSE Total = 0.115496,   MSE X = 0.052895,   MSE Z = 0.060519
#
#
# Train Epoch 77: MSE Total = 0.074275,   MSE X = 0.031289,   MSE Z = 0.048236
# Test: MSE Total = 0.066152,   MSE X = 0.027704,   MSE Z = 0.043516
#
#
# Train Epoch 78: MSE Total = 0.079965,   MSE X = 0.032084,   MSE Z = 0.057401
# Test: MSE Total = 0.107731,   MSE X = 0.041387,   MSE Z = 0.083609
#
#
# Train Epoch 79: MSE Total = 0.058125,   MSE X = 0.023464,   MSE Z = 0.041236
# Test: MSE Total = 0.064914,   MSE X = 0.026551,   MSE Z = 0.044870
#
#
# Train Epoch 80: MSE Total = 0.053073,   MSE X = 0.021027,   MSE Z = 0.039009
# Test: MSE Total = 0.059170,   MSE X = 0.024070,   MSE Z = 0.041348
#
#
# Train Epoch 81: MSE Total = 0.041983,   MSE X = 0.016065,   MSE Z = 0.032797
# Test: MSE Total = 0.050097,   MSE X = 0.020009,   MSE Z = 0.036272
#
#
# Train Epoch 82: MSE Total = 0.054766,   MSE X = 0.021964,   MSE Z = 0.039345
# Test: MSE Total = 0.096449,   MSE X = 0.042846,   MSE Z = 0.055068
#
#
# Train Epoch 83: MSE Total = 0.052210,   MSE X = 0.020813,   MSE Z = 0.037940
# Test: MSE Total = 0.059859,   MSE X = 0.025990,   MSE Z = 0.036230
#
#
# Train Epoch 84: MSE Total = 0.051554,   MSE X = 0.020583,   MSE Z = 0.037354
# Test: MSE Total = 0.062393,   MSE X = 0.026516,   MSE Z = 0.039724
#
#
# Train Epoch 85: MSE Total = 0.043349,   MSE X = 0.016156,   MSE Z = 0.035342
# Test: MSE Total = 0.070966,   MSE X = 0.031031,   MSE Z = 0.042205
#
#
# Train Epoch 86: MSE Total = 0.046102,   MSE X = 0.018733,   MSE Z = 0.032288
# Test: MSE Total = 0.059007,   MSE X = 0.022256,   MSE Z = 0.047201
#
#
# Train Epoch 87: MSE Total = 0.048693,   MSE X = 0.019257,   MSE Z = 0.035910
# Test: MSE Total = 0.052159,   MSE X = 0.020665,   MSE Z = 0.038339
#
#
# Train Epoch 88: MSE Total = 0.060357,   MSE X = 0.025304,   MSE Z = 0.039614
# Test: MSE Total = 0.076464,   MSE X = 0.033380,   MSE Z = 0.045665
#
#
# Train Epoch 89: MSE Total = 0.047464,   MSE X = 0.018813,   MSE Z = 0.034861
# Test: MSE Total = 0.058020,   MSE X = 0.025019,   MSE Z = 0.035705
#
#
# Train Epoch 90: MSE Total = 0.033304,   MSE X = 0.012554,   MSE Z = 0.026669
# Test: MSE Total = 0.055492,   MSE X = 0.023942,   MSE Z = 0.034108
#
#
# Train Epoch 91: MSE Total = 0.036879,   MSE X = 0.014014,   MSE Z = 0.029146
# Test: MSE Total = 0.050923,   MSE X = 0.021800,   MSE Z = 0.031881
#
#
# Train Epoch 92: MSE Total = 0.052141,   MSE X = 0.021212,   MSE Z = 0.036432
# Test: MSE Total = 0.056034,   MSE X = 0.023533,   MSE Z = 0.036634
#
#
# Train Epoch 93: MSE Total = 0.035401,   MSE X = 0.013788,   MSE Z = 0.026831
# Test: MSE Total = 0.067128,   MSE X = 0.029012,   MSE Z = 0.041087
#
#
# Train Epoch 94: MSE Total = 0.051486,   MSE X = 0.021167,   MSE Z = 0.035220
# Test: MSE Total = 0.052206,   MSE X = 0.022029,   MSE Z = 0.033779
#
#
# Train Epoch 95: MSE Total = 0.035871,   MSE X = 0.013460,   MSE Z = 0.028932
# Test: MSE Total = 0.052896,   MSE X = 0.022460,   MSE Z = 0.033748
#
#
# Train Epoch 96: MSE Total = 0.067403,   MSE X = 0.027566,   MSE Z = 0.046600
# Test: MSE Total = 0.110878,   MSE X = 0.047486,   MSE Z = 0.069348
#
#
# Train Epoch 97: MSE Total = 0.061189,   MSE X = 0.025368,   MSE Z = 0.041134
# Test: MSE Total = 0.064799,   MSE X = 0.026853,   MSE Z = 0.043598
#
#
# Train Epoch 98: MSE Total = 0.065294,   MSE X = 0.026566,   MSE Z = 0.045612
# Test: MSE Total = 0.055206,   MSE X = 0.022949,   MSE Z = 0.036898
#
#
# Train Epoch 99: MSE Total = 0.042483,   MSE X = 0.017030,   MSE Z = 0.030548
# Test: MSE Total = 0.084608,   MSE X = 0.036476,   MSE Z = 0.052096
#
#
# Train Epoch 100: MSE Total = 0.039549,   MSE X = 0.015686,   MSE Z = 0.029011
# Test: MSE Total = 0.052560,   MSE X = 0.022356,   MSE Z = 0.033401
#
#
# Train Epoch 101: MSE Total = 0.029918,   MSE X = 0.011409,   MSE Z = 0.023508
# Test: MSE Total = 0.047078,   MSE X = 0.020112,   MSE Z = 0.029617
#
#
# Train Epoch 102: MSE Total = 0.029640,   MSE X = 0.011417,   MSE Z = 0.022901
# Test: MSE Total = 0.038351,   MSE X = 0.015514,   MSE Z = 0.027097
#
#
# Train Epoch 103: MSE Total = 0.019615,   MSE X = 0.007067,   MSE Z = 0.016823
# Test: MSE Total = 0.034928,   MSE X = 0.014276,   MSE Z = 0.024178
#
#
# Train Epoch 104: MSE Total = 0.116998,   MSE X = 0.055893,   MSE Z = 0.053418
# Test: MSE Total = 0.226804,   MSE X = 0.106127,   MSE Z = 0.111146
#
#
# Train Epoch 105: MSE Total = 0.149096,   MSE X = 0.067246,   MSE Z = 0.081668
# Test: MSE Total = 0.136263,   MSE X = 0.061306,   MSE Z = 0.075159
#
#
# Train Epoch 106: MSE Total = 0.056289,   MSE X = 0.022400,   MSE Z = 0.041035
# Test: MSE Total = 0.052063,   MSE X = 0.022252,   MSE Z = 0.032718
#
#
# Train Epoch 107: MSE Total = 0.033237,   MSE X = 0.012301,   MSE Z = 0.027394
# Test: MSE Total = 0.041633,   MSE X = 0.017387,   MSE Z = 0.027552
#
#
# Train Epoch 108: MSE Total = 0.026128,   MSE X = 0.009562,   MSE Z = 0.021903
# Test: MSE Total = 0.038677,   MSE X = 0.016203,   MSE Z = 0.025425
#
#
# Train Epoch 109: MSE Total = 0.042293,   MSE X = 0.017890,   MSE Z = 0.027214
# Test: MSE Total = 0.170029,   MSE X = 0.087880,   MSE Z = 0.054911
#
#
# Train Epoch 110: MSE Total = 0.089507,   MSE X = 0.038923,   MSE Z = 0.053971
# Test: MSE Total = 0.123880,   MSE X = 0.055957,   MSE Z = 0.067570
#
#
# Train Epoch 111: MSE Total = 0.064181,   MSE X = 0.027142,   MSE Z = 0.041322
# Test: MSE Total = 0.057934,   MSE X = 0.023568,   MSE Z = 0.040482
#
#
# Train Epoch 112: MSE Total = 0.040586,   MSE X = 0.016505,   MSE Z = 0.028381
# Test: MSE Total = 0.055323,   MSE X = 0.024651,   MSE Z = 0.031329
#
#
# Train Epoch 113: MSE Total = 0.029743,   MSE X = 0.011063,   MSE Z = 0.024323
# Test: MSE Total = 0.031668,   MSE X = 0.012274,   MSE Z = 0.024210
#
#
# Train Epoch 114: MSE Total = 0.023653,   MSE X = 0.008433,   MSE Z = 0.020587
# Test: MSE Total = 0.032445,   MSE X = 0.011353,   MSE Z = 0.028976
#
#
# Train Epoch 115: MSE Total = 0.022585,   MSE X = 0.008091,   MSE Z = 0.019526
# Test: MSE Total = 0.030105,   MSE X = 0.010987,   MSE Z = 0.025340
#
#
# Train Epoch 116: MSE Total = 0.018155,   MSE X = 0.006506,   MSE Z = 0.015689
# Test: MSE Total = 0.028492,   MSE X = 0.011130,   MSE Z = 0.021483
#
#
# Train Epoch 117: MSE Total = 0.016485,   MSE X = 0.005767,   MSE Z = 0.014725
# Test: MSE Total = 0.026211,   MSE X = 0.010170,   MSE Z = 0.019999
#
#
# Train Epoch 118: MSE Total = 0.015565,   MSE X = 0.005486,   MSE Z = 0.013764
# Test: MSE Total = 0.030466,   MSE X = 0.010689,   MSE Z = 0.027109
#
#
# Train Epoch 119: MSE Total = 0.016984,   MSE X = 0.006026,   MSE Z = 0.014885
# Test: MSE Total = 0.027148,   MSE X = 0.010249,   MSE Z = 0.021684
#
#
# Train Epoch 120: MSE Total = 0.015769,   MSE X = 0.005563,   MSE Z = 0.013928
# Test: MSE Total = 0.026529,   MSE X = 0.009999,   MSE Z = 0.021248
#
#
# Train Epoch 121: MSE Total = 0.016235,   MSE X = 0.005778,   MSE Z = 0.014167
# Test: MSE Total = 0.034881,   MSE X = 0.014501,   MSE Z = 0.023313
#
#
# Train Epoch 122: MSE Total = 0.029413,   MSE X = 0.011676,   MSE Z = 0.021541
# Test: MSE Total = 0.036237,   MSE X = 0.014786,   MSE Z = 0.025170
#
#
# Train Epoch 123: MSE Total = 0.025788,   MSE X = 0.009639,   MSE Z = 0.020930
# Test: MSE Total = 0.039220,   MSE X = 0.013739,   MSE Z = 0.034974
#
#
# Train Epoch 124: MSE Total = 0.044459,   MSE X = 0.018639,   MSE Z = 0.029181
# Test: MSE Total = 0.095829,   MSE X = 0.043933,   MSE Z = 0.050060
#
#
# Train Epoch 125: MSE Total = 0.109419,   MSE X = 0.049552,   MSE Z = 0.059249
# Test: MSE Total = 0.149396,   MSE X = 0.066467,   MSE Z = 0.084957
#
#
# Train Epoch 126: MSE Total = 0.081790,   MSE X = 0.035060,   MSE Z = 0.051049
# Test: MSE Total = 0.065754,   MSE X = 0.028189,   MSE Z = 0.041030
#
#
# Train Epoch 127: MSE Total = 0.054487,   MSE X = 0.022647,   MSE Z = 0.036431
# Test: MSE Total = 0.054852,   MSE X = 0.022285,   MSE Z = 0.038429
#
#
# Train Epoch 128: MSE Total = 0.048794,   MSE X = 0.020231,   MSE Z = 0.032792
# Test: MSE Total = 0.039879,   MSE X = 0.015930,   MSE Z = 0.028867
#
#
# Train Epoch 129: MSE Total = 0.028658,   MSE X = 0.011229,   MSE Z = 0.021491
# Test: MSE Total = 0.032031,   MSE X = 0.011999,   MSE Z = 0.025903
#
#
# Train Epoch 130: MSE Total = 0.019887,   MSE X = 0.007200,   MSE Z = 0.016938
# Test: MSE Total = 0.028822,   MSE X = 0.010576,   MSE Z = 0.024065
#
#
# Train Epoch 131: MSE Total = 0.024999,   MSE X = 0.009733,   MSE Z = 0.018960
# Test: MSE Total = 0.035104,   MSE X = 0.013601,   MSE Z = 0.026851
#
#
# Train Epoch 132: MSE Total = 0.019184,   MSE X = 0.006792,   MSE Z = 0.016862
# Test: MSE Total = 0.023734,   MSE X = 0.008466,   MSE Z = 0.020647
#
#
# Train Epoch 133: MSE Total = 0.018360,   MSE X = 0.006853,   MSE Z = 0.014934
# Test: MSE Total = 0.034154,   MSE X = 0.012236,   MSE Z = 0.029528
#
#
# Train Epoch 134: MSE Total = 0.019139,   MSE X = 0.007202,   MSE Z = 0.015368
# Test: MSE Total = 0.029046,   MSE X = 0.011218,   MSE Z = 0.022338
#
#
# Train Epoch 135: MSE Total = 0.014252,   MSE X = 0.005040,   MSE Z = 0.012548
# Test: MSE Total = 0.022958,   MSE X = 0.007920,   MSE Z = 0.020890
#
#
# Train Epoch 136: MSE Total = 0.012742,   MSE X = 0.004432,   MSE Z = 0.011470
# Test: MSE Total = 0.022412,   MSE X = 0.007788,   MSE Z = 0.020201
#
#
# Train Epoch 137: MSE Total = 0.012753,   MSE X = 0.004380,   MSE Z = 0.011672
# Test: MSE Total = 0.022179,   MSE X = 0.007776,   MSE Z = 0.019753
#
#
# Train Epoch 138: MSE Total = 0.012953,   MSE X = 0.004417,   MSE Z = 0.011963
# Test: MSE Total = 0.020765,   MSE X = 0.007360,   MSE Z = 0.018222
#
#
# Train Epoch 139: MSE Total = 0.011476,   MSE X = 0.003896,   MSE Z = 0.010657
# Test: MSE Total = 0.020991,   MSE X = 0.007911,   MSE Z = 0.016812
#
#
# Train Epoch 140: MSE Total = 0.013181,   MSE X = 0.004439,   MSE Z = 0.012363
# Test: MSE Total = 0.026189,   MSE X = 0.010325,   MSE Z = 0.019422
#
#
# Train Epoch 141: MSE Total = 0.012883,   MSE X = 0.004536,   MSE Z = 0.011410
# Test: MSE Total = 0.021053,   MSE X = 0.008192,   MSE Z = 0.015984
#
#
# Train Epoch 142: MSE Total = 0.012465,   MSE X = 0.004316,   MSE Z = 0.011288
# Test: MSE Total = 0.022888,   MSE X = 0.008684,   MSE Z = 0.018136
#
#
# Train Epoch 143: MSE Total = 0.019225,   MSE X = 0.007313,   MSE Z = 0.015169
# Test: MSE Total = 0.051027,   MSE X = 0.020539,   MSE Z = 0.036403
#
#
# Train Epoch 144: MSE Total = 0.099548,   MSE X = 0.045272,   MSE Z = 0.053252
# Test: MSE Total = 0.150838,   MSE X = 0.063734,   MSE Z = 0.097301
#
#
# Train Epoch 145: MSE Total = 0.128184,   MSE X = 0.056498,   MSE Z = 0.074711
# Test: MSE Total = 0.097286,   MSE X = 0.038769,   MSE Z = 0.070739
#
#
# Train Epoch 146: MSE Total = 0.058480,   MSE X = 0.023427,   MSE Z = 0.042106
# Test: MSE Total = 0.089409,   MSE X = 0.038810,   MSE Z = 0.054150
#
#
# Train Epoch 147: MSE Total = 0.034529,   MSE X = 0.013696,   MSE Z = 0.025325
# Test: MSE Total = 0.039920,   MSE X = 0.017582,   MSE Z = 0.023309
#
#
# Train Epoch 148: MSE Total = 0.018887,   MSE X = 0.007025,   MSE Z = 0.015445
# Test: MSE Total = 0.033832,   MSE X = 0.014073,   MSE Z = 0.022583
#
#
# Train Epoch 149: MSE Total = 0.017262,   MSE X = 0.006445,   MSE Z = 0.014033
# Test: MSE Total = 0.034725,   MSE X = 0.015047,   MSE Z = 0.021122
#
#
# Train Epoch 150: MSE Total = 0.014072,   MSE X = 0.005046,   MSE Z = 0.012149
# Test: MSE Total = 0.033050,   MSE X = 0.013237,   MSE Z = 0.023804
#
#
# Train Epoch 151: MSE Total = 0.013666,   MSE X = 0.004806,   MSE Z = 0.012122
# Test: MSE Total = 0.032153,   MSE X = 0.013871,   MSE Z = 0.019767
#
#
# Train Epoch 152: MSE Total = 0.012306,   MSE X = 0.004283,   MSE Z = 0.011071
# Test: MSE Total = 0.029236,   MSE X = 0.012993,   MSE Z = 0.016676
#
#
# Train Epoch 153: MSE Total = 0.011503,   MSE X = 0.003981,   MSE Z = 0.010422
# Test: MSE Total = 0.029154,   MSE X = 0.012801,   MSE Z = 0.017157
#
#
# Train Epoch 154: MSE Total = 0.011368,   MSE X = 0.003901,   MSE Z = 0.010414
# Test: MSE Total = 0.034521,   MSE X = 0.014187,   MSE Z = 0.023631
#
#
# Train Epoch 155: MSE Total = 0.042071,   MSE X = 0.017758,   MSE Z = 0.027203
# Test: MSE Total = 0.110244,   MSE X = 0.048852,   MSE Z = 0.063362
#
#
# Train Epoch 156: MSE Total = 0.040175,   MSE X = 0.015872,   MSE Z = 0.029684
# Test: MSE Total = 0.070417,   MSE X = 0.029235,   MSE Z = 0.047195
#
#
# Train Epoch 157: MSE Total = 0.027320,   MSE X = 0.010997,   MSE Z = 0.019488
# Test: MSE Total = 0.029420,   MSE X = 0.012416,   MSE Z = 0.019027
#
#
# Train Epoch 158: MSE Total = 0.020909,   MSE X = 0.008122,   MSE Z = 0.015920
# Test: MSE Total = 0.037316,   MSE X = 0.016844,   MSE Z = 0.020393
#
#
# Train Epoch 159: MSE Total = 0.031218,   MSE X = 0.013407,   MSE Z = 0.019400
# Test: MSE Total = 0.068508,   MSE X = 0.030815,   MSE Z = 0.037811
#
#
# Train Epoch 160: MSE Total = 0.060068,   MSE X = 0.025744,   MSE Z = 0.037506
# Test: MSE Total = 0.104617,   MSE X = 0.046660,   MSE Z = 0.059097
#
#
# Train Epoch 161: MSE Total = 0.076772,   MSE X = 0.034183,   MSE Z = 0.043566
# Test: MSE Total = 0.098455,   MSE X = 0.041319,   MSE Z = 0.064471
#
#
# Train Epoch 162: MSE Total = 0.058916,   MSE X = 0.024368,   MSE Z = 0.039800
# Test: MSE Total = 0.052216,   MSE X = 0.022403,   MSE Z = 0.032520
#
#
# Train Epoch 163: MSE Total = 0.025867,   MSE X = 0.009725,   MSE Z = 0.020798
# Test: MSE Total = 0.030919,   MSE X = 0.012284,   MSE Z = 0.022609
#
#
# Train Epoch 164: MSE Total = 0.016318,   MSE X = 0.005819,   MSE Z = 0.014200
# Test: MSE Total = 0.029024,   MSE X = 0.010538,   MSE Z = 0.024615
#
#
# Train Epoch 165: MSE Total = 0.014909,   MSE X = 0.005305,   MSE Z = 0.013014
# Test: MSE Total = 0.030217,   MSE X = 0.011664,   MSE Z = 0.023261
#
#
# Train Epoch 166: MSE Total = 0.012554,   MSE X = 0.004376,   MSE Z = 0.011269
# Test: MSE Total = 0.025882,   MSE X = 0.010306,   MSE Z = 0.018849
#
#
# Train Epoch 167: MSE Total = 0.011093,   MSE X = 0.003831,   MSE Z = 0.010080
# Test: MSE Total = 0.025899,   MSE X = 0.009649,   MSE Z = 0.021127
#
#
# Train Epoch 168: MSE Total = 0.010888,   MSE X = 0.003811,   MSE Z = 0.009718
# Test: MSE Total = 0.024599,   MSE X = 0.010100,   MSE Z = 0.016869
#
#
# Train Epoch 169: MSE Total = 0.010233,   MSE X = 0.003492,   MSE Z = 0.009441
# Test: MSE Total = 0.023923,   MSE X = 0.009486,   MSE Z = 0.017559
#
#
# Train Epoch 170: MSE Total = 0.009963,   MSE X = 0.003394,   MSE Z = 0.009213
# Test: MSE Total = 0.023814,   MSE X = 0.009412,   MSE Z = 0.017582
#
#
# Train Epoch 171: MSE Total = 0.010119,   MSE X = 0.003466,   MSE Z = 0.009294
# Test: MSE Total = 0.025602,   MSE X = 0.009524,   MSE Z = 0.020935
#
#
# Train Epoch 172: MSE Total = 0.009394,   MSE X = 0.003204,   MSE Z = 0.008672
# Test: MSE Total = 0.025920,   MSE X = 0.010676,   MSE Z = 0.017662
#
#
# Train Epoch 173: MSE Total = 0.009780,   MSE X = 0.003347,   MSE Z = 0.008992
# Test: MSE Total = 0.021938,   MSE X = 0.009099,   MSE Z = 0.014734
#
#
# Train Epoch 174: MSE Total = 0.009542,   MSE X = 0.003315,   MSE Z = 0.008603
# Test: MSE Total = 0.025521,   MSE X = 0.010091,   MSE Z = 0.018828
#
#
# Train Epoch 175: MSE Total = 0.010347,   MSE X = 0.003540,   MSE Z = 0.009517
# Test: MSE Total = 0.025908,   MSE X = 0.011667,   MSE Z = 0.014254
#
#
# Train Epoch 176: MSE Total = 0.010737,   MSE X = 0.003945,   MSE Z = 0.008948
# Test: MSE Total = 0.022418,   MSE X = 0.009158,   MSE Z = 0.015536
#
#
# Train Epoch 177: MSE Total = 0.010032,   MSE X = 0.003459,   MSE Z = 0.009133
# Test: MSE Total = 0.026344,   MSE X = 0.011087,   MSE Z = 0.017144
#
#
# Train Epoch 178: MSE Total = 0.009010,   MSE X = 0.003124,   MSE Z = 0.008145
# Test: MSE Total = 0.025167,   MSE X = 0.010139,   MSE Z = 0.017924
#
#
# Train Epoch 179: MSE Total = 0.008996,   MSE X = 0.003104,   MSE Z = 0.008184
# Test: MSE Total = 0.025576,   MSE X = 0.010914,   MSE Z = 0.016133
#
#
# Train Epoch 180: MSE Total = 0.008705,   MSE X = 0.002978,   MSE Z = 0.008007
# Test: MSE Total = 0.027515,   MSE X = 0.011267,   MSE Z = 0.018975
#
#
# Train Epoch 181: MSE Total = 0.008355,   MSE X = 0.002814,   MSE Z = 0.007837
# Test: MSE Total = 0.025226,   MSE X = 0.010851,   MSE Z = 0.015618
#
#
# Train Epoch 182: MSE Total = 0.009392,   MSE X = 0.003364,   MSE Z = 0.008123
# Test: MSE Total = 0.024428,   MSE X = 0.009553,   MSE Z = 0.018383
#
#
# Train Epoch 183: MSE Total = 0.008873,   MSE X = 0.003095,   MSE Z = 0.007956
# Test: MSE Total = 0.022701,   MSE X = 0.009784,   MSE Z = 0.013988
#
#
# Train Epoch 184: MSE Total = 0.009322,   MSE X = 0.003208,   MSE Z = 0.008508
# Test: MSE Total = 0.023415,   MSE X = 0.010219,   MSE Z = 0.013995
#
#
# Train Epoch 185: MSE Total = 0.012764,   MSE X = 0.004702,   MSE Z = 0.010593
# Test: MSE Total = 0.030686,   MSE X = 0.012454,   MSE Z = 0.021543
#
#
# Train Epoch 186: MSE Total = 0.011209,   MSE X = 0.003875,   MSE Z = 0.010172
# Test: MSE Total = 0.040019,   MSE X = 0.016542,   MSE Z = 0.027071
#
#
# Train Epoch 187: MSE Total = 0.054072,   MSE X = 0.022726,   MSE Z = 0.035294
# Test: MSE Total = 0.137436,   MSE X = 0.062265,   MSE Z = 0.074334
#
#
# Train Epoch 188: MSE Total = 0.115324,   MSE X = 0.049454,   MSE Z = 0.071914
# Test: MSE Total = 0.071890,   MSE X = 0.029828,   MSE Z = 0.048246
#
#
# Train Epoch 189: MSE Total = 0.084528,   MSE X = 0.036887,   MSE Z = 0.050525
# Test: MSE Total = 0.047372,   MSE X = 0.019005,   MSE Z = 0.034011
#
#
# Train Epoch 190: MSE Total = 0.040456,   MSE X = 0.015922,   MSE Z = 0.030099
# Test: MSE Total = 0.050554,   MSE X = 0.019998,   MSE Z = 0.037266
#
#
# Train Epoch 191: MSE Total = 0.026881,   MSE X = 0.010617,   MSE Z = 0.019870
# Test: MSE Total = 0.035085,   MSE X = 0.014563,   MSE Z = 0.023524
#
#
# Train Epoch 192: MSE Total = 0.024538,   MSE X = 0.009857,   MSE Z = 0.017573
# Test: MSE Total = 0.028582,   MSE X = 0.010697,   MSE Z = 0.023150
#
#
# Train Epoch 193: MSE Total = 0.017975,   MSE X = 0.006747,   MSE Z = 0.014492
# Test: MSE Total = 0.026737,   MSE X = 0.009560,   MSE Z = 0.023179
#
#
# Train Epoch 194: MSE Total = 0.012654,   MSE X = 0.004355,   MSE Z = 0.011550
# Test: MSE Total = 0.022464,   MSE X = 0.008246,   MSE Z = 0.018745
#
#
# Train Epoch 195: MSE Total = 0.010865,   MSE X = 0.003752,   MSE Z = 0.009875
# Test: MSE Total = 0.022598,   MSE X = 0.008718,   MSE Z = 0.017412
#
#
# Train Epoch 196: MSE Total = 0.009686,   MSE X = 0.003319,   MSE Z = 0.008889
# Test: MSE Total = 0.020624,   MSE X = 0.008219,   MSE Z = 0.014996
#
#
# Train Epoch 197: MSE Total = 0.009090,   MSE X = 0.003072,   MSE Z = 0.008490
# Test: MSE Total = 0.020820,   MSE X = 0.008124,   MSE Z = 0.015728
#
#
# Train Epoch 198: MSE Total = 0.008988,   MSE X = 0.003054,   MSE Z = 0.008338
# Test: MSE Total = 0.021169,   MSE X = 0.008447,   MSE Z = 0.015356
#
#
# Train Epoch 199: MSE Total = 0.013230,   MSE X = 0.004468,   MSE Z = 0.012366
# Test: MSE Total = 0.034596,   MSE X = 0.012730,   MSE Z = 0.028764
#
#
# Train Epoch 200: MSE Total = 0.017161,   MSE X = 0.006091,   MSE Z = 0.015032
# Test: MSE Total = 0.026970,   MSE X = 0.010542,   MSE Z = 0.020315
#
#
# Got the weights of the epoch 196
# Execution time: 32 minutes, 51.04 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
model.load_state_dict(torch.load("model_weights_step2"))

model.eval()
batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_emb_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [14, 20, 32, 35, 40, 50]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_emb_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc_emb) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_emb_tensor = pc_emb_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_emb_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()
