# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio embedding delle nuvole di punti

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.ln1 = nn.LayerNorm(64)
        self.ln2 = nn.LayerNorm(128)
        self.ln3 = nn.LayerNorm(1024)
        self.fc_reduce = nn.Linear(1024, 256)  # nuovo layer per la riduzione a 256
        self.ln_reduce = nn.LayerNorm(256)  # normalizzazione output ridotto

    def forward(self, x):
        x = F.relu(self.ln1(self.conv1(x).transpose(1, 2))).transpose(1, 2)
        x = F.relu(self.ln2(self.conv2(x).transpose(1, 2))).transpose(1, 2)
        x = self.ln3(self.conv3(x).transpose(1, 2)).transpose(1, 2)
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)
        x = self.ln_reduce(self.fc_reduce(x))

        return x

# %%
torch.manual_seed(42)
pointnet = PointNetfeat()
pointnet.to(device)
pointnet.eval()

npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]

point_cloud_embeddings = [] # lista per salvare gli embedding

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e mettila su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).transpose(1, 2).to(device)

        # Calcola l'embedding
        embedding = pointnet(point_cloud).squeeze(0).cpu().numpy()

        # Salva l'embedding nella lista
        point_cloud_embeddings.append(embedding)

# Salva gli embedding in un file NPZ
np.savez_compressed("point_cloud_embeddings.npz", embeddings=np.array(point_cloud_embeddings))

print("Embeddings saved in 'point_cloud_embeddings.npz'!")
# Out:
# Embeddings saved in 'point_cloud_embeddings.npz'!

# %% [markdown]
# ## Sezione addestramento della GRU

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_cloud_embeddings, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_cloud_embeddings = point_cloud_embeddings

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_cloud_embedding = self.point_cloud_embeddings[idx]

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_cloud_embedding

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.hidden_size  = hidden_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc_emb):
        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_variance, global_z_variance):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc_emb in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc_emb) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_variance, global_z_variance):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc_emb in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc_emb)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_embs = np.load("point_cloud_embeddings.npz")
point_cloud_embeddings = [torch.tensor(emb, dtype=torch.float32) for emb in loaded_pc_embs["embeddings"]]

dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                         framerate=framerate, point_cloud_embeddings=point_cloud_embeddings)
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 256])

# %%
#Calcolo della varianza globale di x e di z lungo le traiettore

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

# concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.37383729219436646
# Global variance of the z-coordinate: 4.3598480224609375

# %%
batch = next(iter(test_loader))  # Prendi un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = 1000

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_variance, global_z_variance)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_variance, global_z_variance)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.283548,   MSE X = 0.568669,   MSE Z = 0.738060
# Test: MSE Total = 0.991645,   MSE X = 0.540597,   MSE Z = 0.224425
#
#
# Train Epoch 2: MSE Total = 1.036231,   MSE X = 0.568701,   MSE Z = 0.221547
# Test: MSE Total = 1.018755,   MSE X = 0.522442,   MSE Z = 0.343033
#
#
# Train Epoch 3: MSE Total = 1.006537,   MSE X = 0.553672,   MSE Z = 0.210870
# Test: MSE Total = 0.894750,   MSE X = 0.482227,   MSE Z = 0.221440
#
#
# Train Epoch 4: MSE Total = 0.744810,   MSE X = 0.378017,   MSE Z = 0.264244
# Test: MSE Total = 0.546925,   MSE X = 0.270461,   MSE Z = 0.218363
#
#
# Train Epoch 5: MSE Total = 0.573838,   MSE X = 0.283979,   MSE Z = 0.228392
# Test: MSE Total = 0.537250,   MSE X = 0.258512,   MSE Z = 0.238966
#
#
# Train Epoch 6: MSE Total = 0.521167,   MSE X = 0.260284,   MSE Z = 0.199334
# Test: MSE Total = 0.471339,   MSE X = 0.236402,   MSE Z = 0.176847
#
#
# Train Epoch 7: MSE Total = 0.487414,   MSE X = 0.241155,   MSE Z = 0.194182
# Test: MSE Total = 0.456785,   MSE X = 0.222119,   MSE Z = 0.195237
#
#
# Train Epoch 8: MSE Total = 0.501831,   MSE X = 0.247960,   MSE Z = 0.201046
# Test: MSE Total = 0.561698,   MSE X = 0.286493,   MSE Z = 0.194457
#
#
# Train Epoch 9: MSE Total = 0.471817,   MSE X = 0.231249,   MSE Z = 0.195443
# Test: MSE Total = 0.447535,   MSE X = 0.211728,   MSE Z = 0.211406
#
#
# Train Epoch 10: MSE Total = 0.456794,   MSE X = 0.222163,   MSE Z = 0.195106
# Test: MSE Total = 0.445530,   MSE X = 0.221395,   MSE Z = 0.174208
#
#
# Train Epoch 11: MSE Total = 0.455716,   MSE X = 0.223492,   MSE Z = 0.188315
# Test: MSE Total = 0.443211,   MSE X = 0.217034,   MSE Z = 0.184258
#
#
# Train Epoch 12: MSE Total = 0.425054,   MSE X = 0.203900,   MSE Z = 0.191199
# Test: MSE Total = 0.441347,   MSE X = 0.216682,   MSE Z = 0.181569
#
#
# Train Epoch 13: MSE Total = 0.419144,   MSE X = 0.200957,   MSE Z = 0.188910
# Test: MSE Total = 0.415535,   MSE X = 0.199744,   MSE Z = 0.185518
#
#
# Train Epoch 14: MSE Total = 0.414233,   MSE X = 0.197522,   MSE Z = 0.190384
# Test: MSE Total = 0.480830,   MSE X = 0.231181,   MSE Z = 0.214496
#
#
# Train Epoch 15: MSE Total = 0.397167,   MSE X = 0.189041,   MSE Z = 0.183714
# Test: MSE Total = 0.390361,   MSE X = 0.179759,   MSE Z = 0.201204
#
#
# Train Epoch 16: MSE Total = 0.392901,   MSE X = 0.187579,   MSE Z = 0.179801
# Test: MSE Total = 0.362884,   MSE X = 0.170177,   MSE Z = 0.176553
#
#
# Train Epoch 17: MSE Total = 0.388429,   MSE X = 0.183854,   MSE Z = 0.183182
# Test: MSE Total = 0.479997,   MSE X = 0.239886,   MSE Z = 0.183026
#
#
# Train Epoch 18: MSE Total = 0.385647,   MSE X = 0.183579,   MSE Z = 0.178312
# Test: MSE Total = 0.379908,   MSE X = 0.181591,   MSE Z = 0.173120
#
#
# Train Epoch 19: MSE Total = 0.358310,   MSE X = 0.168464,   MSE Z = 0.172849
# Test: MSE Total = 0.369951,   MSE X = 0.176173,   MSE Z = 0.170832
#
#
# Train Epoch 20: MSE Total = 0.354534,   MSE X = 0.165252,   MSE Z = 0.175935
# Test: MSE Total = 0.351946,   MSE X = 0.165052,   MSE Z = 0.171215
#
#
# Train Epoch 21: MSE Total = 0.358720,   MSE X = 0.169201,   MSE Z = 0.171189
# Test: MSE Total = 0.332921,   MSE X = 0.149618,   MSE Z = 0.184198
#
#
# Train Epoch 22: MSE Total = 0.346813,   MSE X = 0.163102,   MSE Z = 0.167156
# Test: MSE Total = 0.370048,   MSE X = 0.175218,   MSE Z = 0.174293
#
#
# Train Epoch 23: MSE Total = 0.339258,   MSE X = 0.159322,   MSE Z = 0.164290
# Test: MSE Total = 0.346064,   MSE X = 0.159555,   MSE Z = 0.177705
#
#
# Train Epoch 24: MSE Total = 0.338635,   MSE X = 0.158064,   MSE Z = 0.167285
# Test: MSE Total = 0.324147,   MSE X = 0.153433,   MSE Z = 0.152851
#
#
# Train Epoch 25: MSE Total = 0.310264,   MSE X = 0.143613,   MSE Z = 0.157396
# Test: MSE Total = 0.362914,   MSE X = 0.173353,   MSE Z = 0.165769
#
#
# Train Epoch 26: MSE Total = 0.308424,   MSE X = 0.141695,   MSE Z = 0.160104
# Test: MSE Total = 0.295145,   MSE X = 0.135369,   MSE Z = 0.153981
#
#
# Train Epoch 27: MSE Total = 0.299222,   MSE X = 0.138296,   MSE Z = 0.152497
# Test: MSE Total = 0.344037,   MSE X = 0.159174,   MSE Z = 0.174772
#
#
# Train Epoch 28: MSE Total = 0.314283,   MSE X = 0.147350,   MSE Z = 0.153027
# Test: MSE Total = 0.269433,   MSE X = 0.123763,   MSE Z = 0.139928
#
#
# Train Epoch 29: MSE Total = 0.298433,   MSE X = 0.137354,   MSE Z = 0.154067
# Test: MSE Total = 0.274143,   MSE X = 0.124954,   MSE Z = 0.145697
#
#
# Train Epoch 30: MSE Total = 0.286473,   MSE X = 0.131873,   MSE Z = 0.147813
# Test: MSE Total = 0.281655,   MSE X = 0.130881,   MSE Z = 0.141140
#
#
# Train Epoch 31: MSE Total = 0.286684,   MSE X = 0.132552,   MSE Z = 0.145935
# Test: MSE Total = 0.302480,   MSE X = 0.139145,   MSE Z = 0.156402
#
#
# Train Epoch 32: MSE Total = 0.266326,   MSE X = 0.122105,   MSE Z = 0.139102
# Test: MSE Total = 0.275292,   MSE X = 0.120575,   MSE Z = 0.163050
#
#
# Train Epoch 33: MSE Total = 0.262987,   MSE X = 0.119505,   MSE Z = 0.141012
# Test: MSE Total = 0.268996,   MSE X = 0.122923,   MSE Z = 0.141883
#
#
# Train Epoch 34: MSE Total = 0.259156,   MSE X = 0.116924,   MSE Z = 0.141824
# Test: MSE Total = 0.261338,   MSE X = 0.118316,   MSE Z = 0.141629
#
#
# Train Epoch 35: MSE Total = 0.254785,   MSE X = 0.114706,   MSE Z = 0.140276
# Test: MSE Total = 0.281124,   MSE X = 0.132436,   MSE Z = 0.134721
#
#
# Train Epoch 36: MSE Total = 0.252738,   MSE X = 0.115201,   MSE Z = 0.134310
# Test: MSE Total = 0.242873,   MSE X = 0.106710,   MSE Z = 0.142706
#
#
# Train Epoch 37: MSE Total = 0.231009,   MSE X = 0.103756,   MSE Z = 0.128021
# Test: MSE Total = 0.220273,   MSE X = 0.096323,   MSE Z = 0.130990
#
#
# Train Epoch 38: MSE Total = 0.222125,   MSE X = 0.098795,   MSE Z = 0.126415
# Test: MSE Total = 0.229288,   MSE X = 0.103132,   MSE Z = 0.126561
#
#
# Train Epoch 39: MSE Total = 0.205461,   MSE X = 0.090828,   MSE Z = 0.118828
# Test: MSE Total = 0.217704,   MSE X = 0.098177,   MSE Z = 0.119293
#
#
# Train Epoch 40: MSE Total = 0.229659,   MSE X = 0.102229,   MSE Z = 0.130417
# Test: MSE Total = 0.197786,   MSE X = 0.084601,   MSE Z = 0.124067
#
#
# Train Epoch 41: MSE Total = 0.239996,   MSE X = 0.108605,   MSE Z = 0.130230
# Test: MSE Total = 0.225547,   MSE X = 0.101260,   MSE Z = 0.125143
#
#
# Train Epoch 42: MSE Total = 0.212126,   MSE X = 0.094334,   MSE Z = 0.120773
# Test: MSE Total = 0.228384,   MSE X = 0.101691,   MSE Z = 0.129592
#
#
# Train Epoch 43: MSE Total = 0.202268,   MSE X = 0.088143,   MSE Z = 0.121328
# Test: MSE Total = 0.203481,   MSE X = 0.089660,   MSE Z = 0.118684
#
#
# Train Epoch 44: MSE Total = 0.179020,   MSE X = 0.077271,   MSE Z = 0.109914
# Test: MSE Total = 0.195705,   MSE X = 0.086785,   MSE Z = 0.112263
#
#
# Train Epoch 45: MSE Total = 0.176266,   MSE X = 0.075780,   MSE Z = 0.109257
# Test: MSE Total = 0.175559,   MSE X = 0.076050,   MSE Z = 0.106857
#
#
# Train Epoch 46: MSE Total = 0.158399,   MSE X = 0.067269,   MSE Z = 0.101016
# Test: MSE Total = 0.168997,   MSE X = 0.073680,   MSE Z = 0.101251
#
#
# Train Epoch 47: MSE Total = 0.155918,   MSE X = 0.066743,   MSE Z = 0.097632
# Test: MSE Total = 0.166608,   MSE X = 0.068167,   MSE Z = 0.115090
#
#
# Train Epoch 48: MSE Total = 0.151433,   MSE X = 0.063136,   MSE Z = 0.100584
# Test: MSE Total = 0.216865,   MSE X = 0.101882,   MSE Z = 0.104890
#
#
# Train Epoch 49: MSE Total = 0.148153,   MSE X = 0.063059,   MSE Z = 0.094001
# Test: MSE Total = 0.227251,   MSE X = 0.105750,   MSE Z = 0.113367
#
#
# Train Epoch 50: MSE Total = 0.135484,   MSE X = 0.055822,   MSE Z = 0.092260
# Test: MSE Total = 0.134824,   MSE X = 0.055642,   MSE Z = 0.091498
#
#
# Train Epoch 51: MSE Total = 0.144984,   MSE X = 0.061838,   MSE Z = 0.091550
# Test: MSE Total = 0.242880,   MSE X = 0.114232,   MSE Z = 0.117033
#
#
# Train Epoch 52: MSE Total = 0.168469,   MSE X = 0.074314,   MSE Z = 0.097982
# Test: MSE Total = 0.131928,   MSE X = 0.055662,   MSE Z = 0.085382
#
#
# Train Epoch 53: MSE Total = 0.120040,   MSE X = 0.049859,   MSE Z = 0.080376
# Test: MSE Total = 0.133327,   MSE X = 0.058665,   MSE Z = 0.078049
#
#
# Train Epoch 54: MSE Total = 0.119391,   MSE X = 0.049471,   MSE Z = 0.080345
# Test: MSE Total = 0.127425,   MSE X = 0.053574,   MSE Z = 0.083111
#
#
# Train Epoch 55: MSE Total = 0.099983,   MSE X = 0.040128,   MSE Z = 0.071729
# Test: MSE Total = 0.113054,   MSE X = 0.048791,   MSE Z = 0.069437
#
#
# Train Epoch 56: MSE Total = 0.117203,   MSE X = 0.049578,   MSE Z = 0.075413
# Test: MSE Total = 0.145171,   MSE X = 0.063787,   MSE Z = 0.085284
#
#
# Train Epoch 57: MSE Total = 0.107468,   MSE X = 0.044728,   MSE Z = 0.071649
# Test: MSE Total = 0.103634,   MSE X = 0.043112,   MSE Z = 0.069161
#
#
# Train Epoch 58: MSE Total = 0.152010,   MSE X = 0.067334,   MSE Z = 0.087454
# Test: MSE Total = 0.138966,   MSE X = 0.061838,   MSE Z = 0.078986
#
#
# Train Epoch 59: MSE Total = 0.093462,   MSE X = 0.037416,   MSE Z = 0.067374
# Test: MSE Total = 0.096694,   MSE X = 0.039003,   MSE Z = 0.068703
#
#
# Train Epoch 60: MSE Total = 0.088486,   MSE X = 0.034953,   MSE Z = 0.065395
# Test: MSE Total = 0.108114,   MSE X = 0.043352,   MSE Z = 0.077697
#
#
# Train Epoch 61: MSE Total = 0.082296,   MSE X = 0.031971,   MSE Z = 0.062655
# Test: MSE Total = 0.095023,   MSE X = 0.037422,   MSE Z = 0.070613
#
#
# Train Epoch 62: MSE Total = 0.072125,   MSE X = 0.027797,   MSE Z = 0.055669
# Test: MSE Total = 0.105536,   MSE X = 0.043619,   MSE Z = 0.071400
#
#
# Train Epoch 63: MSE Total = 0.094587,   MSE X = 0.038309,   MSE Z = 0.066675
# Test: MSE Total = 0.082728,   MSE X = 0.032289,   MSE Z = 0.062471
#
#
# Train Epoch 64: MSE Total = 0.074182,   MSE X = 0.028648,   MSE Z = 0.057058
# Test: MSE Total = 0.078725,   MSE X = 0.031301,   MSE Z = 0.057485
#
#
# Train Epoch 65: MSE Total = 0.085505,   MSE X = 0.034777,   MSE Z = 0.059774
# Test: MSE Total = 0.109025,   MSE X = 0.045724,   MSE Z = 0.071500
#
#
# Train Epoch 66: MSE Total = 0.110526,   MSE X = 0.046268,   MSE Z = 0.072775
# Test: MSE Total = 0.086560,   MSE X = 0.034470,   MSE Z = 0.063023
#
#
# Train Epoch 67: MSE Total = 0.075257,   MSE X = 0.029911,   MSE Z = 0.054992
# Test: MSE Total = 0.085972,   MSE X = 0.034878,   MSE Z = 0.060403
#
#
# Train Epoch 68: MSE Total = 0.062382,   MSE X = 0.024236,   MSE Z = 0.047489
# Test: MSE Total = 0.091841,   MSE X = 0.039016,   MSE Z = 0.058525
#
#
# Train Epoch 69: MSE Total = 0.068417,   MSE X = 0.027215,   MSE Z = 0.049917
# Test: MSE Total = 0.117217,   MSE X = 0.052105,   MSE Z = 0.066810
#
#
# Train Epoch 70: MSE Total = 0.101508,   MSE X = 0.043049,   MSE Z = 0.064939
# Test: MSE Total = 0.083877,   MSE X = 0.035200,   MSE Z = 0.054928
#
#
# Train Epoch 71: MSE Total = 0.073581,   MSE X = 0.029374,   MSE Z = 0.053327
# Test: MSE Total = 0.073595,   MSE X = 0.030836,   MSE Z = 0.048361
#
#
# Train Epoch 72: MSE Total = 0.048244,   MSE X = 0.017917,   MSE Z = 0.039549
# Test: MSE Total = 0.058918,   MSE X = 0.023162,   MSE Z = 0.043924
#
#
# Train Epoch 73: MSE Total = 0.049902,   MSE X = 0.018917,   MSE Z = 0.039594
# Test: MSE Total = 0.064034,   MSE X = 0.025475,   MSE Z = 0.046707
#
#
# Train Epoch 74: MSE Total = 0.043600,   MSE X = 0.015999,   MSE Z = 0.036402
# Test: MSE Total = 0.056030,   MSE X = 0.021861,   MSE Z = 0.042338
#
#
# Train Epoch 75: MSE Total = 0.040551,   MSE X = 0.014708,   MSE Z = 0.034445
# Test: MSE Total = 0.055284,   MSE X = 0.022769,   MSE Z = 0.037677
#
#
# Train Epoch 76: MSE Total = 0.039553,   MSE X = 0.014353,   MSE Z = 0.033572
# Test: MSE Total = 0.053977,   MSE X = 0.021194,   MSE Z = 0.040326
#
#
# Train Epoch 77: MSE Total = 0.046196,   MSE X = 0.017338,   MSE Z = 0.037248
# Test: MSE Total = 0.063264,   MSE X = 0.025198,   MSE Z = 0.046044
#
#
# Train Epoch 78: MSE Total = 0.046325,   MSE X = 0.017500,   MSE Z = 0.036967
# Test: MSE Total = 0.059495,   MSE X = 0.024935,   MSE Z = 0.039071
#
#
# Train Epoch 79: MSE Total = 0.042434,   MSE X = 0.016075,   MSE Z = 0.033707
# Test: MSE Total = 0.051512,   MSE X = 0.019924,   MSE Z = 0.039517
#
#
# Train Epoch 80: MSE Total = 0.036819,   MSE X = 0.013580,   MSE Z = 0.030504
# Test: MSE Total = 0.045297,   MSE X = 0.017915,   MSE Z = 0.033402
#
#
# Train Epoch 81: MSE Total = 0.071682,   MSE X = 0.029695,   MSE Z = 0.048265
# Test: MSE Total = 0.114587,   MSE X = 0.049680,   MSE Z = 0.069599
#
#
# Train Epoch 82: MSE Total = 0.077774,   MSE X = 0.032032,   MSE Z = 0.053003
# Test: MSE Total = 0.105226,   MSE X = 0.039789,   MSE Z = 0.083834
#
#
# Train Epoch 83: MSE Total = 0.149249,   MSE X = 0.066806,   MSE Z = 0.083489
# Test: MSE Total = 0.107468,   MSE X = 0.047459,   MSE Z = 0.062322
#
#
# Train Epoch 84: MSE Total = 0.062341,   MSE X = 0.025121,   MSE Z = 0.044381
# Test: MSE Total = 0.098138,   MSE X = 0.041229,   MSE Z = 0.064116
#
#
# Train Epoch 85: MSE Total = 0.071031,   MSE X = 0.028808,   MSE Z = 0.049935
# Test: MSE Total = 0.068555,   MSE X = 0.025056,   MSE Z = 0.057580
#
#
# Train Epoch 86: MSE Total = 0.044598,   MSE X = 0.016133,   MSE Z = 0.038028
# Test: MSE Total = 0.053613,   MSE X = 0.021588,   MSE Z = 0.038222
#
#
# Train Epoch 87: MSE Total = 0.033573,   MSE X = 0.012370,   MSE Z = 0.027859
# Test: MSE Total = 0.058586,   MSE X = 0.024085,   MSE Z = 0.040078
#
#
# Train Epoch 88: MSE Total = 0.033137,   MSE X = 0.011918,   MSE Z = 0.028489
# Test: MSE Total = 0.045091,   MSE X = 0.018312,   MSE Z = 0.031616
#
#
# Train Epoch 89: MSE Total = 0.031406,   MSE X = 0.011495,   MSE Z = 0.026321
# Test: MSE Total = 0.056870,   MSE X = 0.024381,   MSE Z = 0.035482
#
#
# Train Epoch 90: MSE Total = 0.036085,   MSE X = 0.013626,   MSE Z = 0.028813
# Test: MSE Total = 0.062259,   MSE X = 0.026762,   MSE Z = 0.038606
#
#
# Train Epoch 91: MSE Total = 0.056921,   MSE X = 0.022602,   MSE Z = 0.041665
# Test: MSE Total = 0.111424,   MSE X = 0.049151,   MSE Z = 0.064806
#
#
# Train Epoch 92: MSE Total = 0.045757,   MSE X = 0.017640,   MSE Z = 0.035301
# Test: MSE Total = 0.045475,   MSE X = 0.018483,   MSE Z = 0.031832
#
#
# Train Epoch 93: MSE Total = 0.030593,   MSE X = 0.011052,   MSE Z = 0.026137
# Test: MSE Total = 0.048780,   MSE X = 0.019751,   MSE Z = 0.034406
#
#
# Train Epoch 94: MSE Total = 0.035963,   MSE X = 0.013546,   MSE Z = 0.028833
# Test: MSE Total = 0.044973,   MSE X = 0.017946,   MSE Z = 0.032620
#
#
# Train Epoch 95: MSE Total = 0.031586,   MSE X = 0.011273,   MSE Z = 0.027455
# Test: MSE Total = 0.038189,   MSE X = 0.014751,   MSE Z = 0.029366
#
#
# Train Epoch 96: MSE Total = 0.023896,   MSE X = 0.008360,   MSE Z = 0.021345
# Test: MSE Total = 0.038484,   MSE X = 0.014970,   MSE Z = 0.029234
#
#
# Train Epoch 97: MSE Total = 0.023373,   MSE X = 0.008285,   MSE Z = 0.020510
# Test: MSE Total = 0.036882,   MSE X = 0.014926,   MSE Z = 0.026037
#
#
# Train Epoch 98: MSE Total = 0.028431,   MSE X = 0.010400,   MSE Z = 0.023847
# Test: MSE Total = 0.045368,   MSE X = 0.018447,   MSE Z = 0.031734
#
#
# Train Epoch 99: MSE Total = 0.030075,   MSE X = 0.011038,   MSE Z = 0.025104
# Test: MSE Total = 0.051880,   MSE X = 0.019021,   MSE Z = 0.043369
#
#
# Train Epoch 100: MSE Total = 0.025022,   MSE X = 0.008597,   MSE Z = 0.022887
# Test: MSE Total = 0.037087,   MSE X = 0.014146,   MSE Z = 0.029130
#
#
# Train Epoch 101: MSE Total = 0.023047,   MSE X = 0.008084,   MSE Z = 0.020517
# Test: MSE Total = 0.036637,   MSE X = 0.014314,   MSE Z = 0.027615
#
#
# Train Epoch 102: MSE Total = 0.022467,   MSE X = 0.008106,   MSE Z = 0.019231
# Test: MSE Total = 0.037527,   MSE X = 0.014433,   MSE Z = 0.029067
#
#
# Train Epoch 103: MSE Total = 0.026203,   MSE X = 0.009599,   MSE Z = 0.021930
# Test: MSE Total = 0.047191,   MSE X = 0.019961,   MSE Z = 0.030368
#
#
# Train Epoch 104: MSE Total = 0.034703,   MSE X = 0.013594,   MSE Z = 0.026037
# Test: MSE Total = 0.042242,   MSE X = 0.017844,   MSE Z = 0.027264
#
#
# Train Epoch 105: MSE Total = 0.025740,   MSE X = 0.009252,   MSE Z = 0.022150
# Test: MSE Total = 0.034284,   MSE X = 0.013592,   MSE Z = 0.025168
#
#
# Train Epoch 106: MSE Total = 0.021916,   MSE X = 0.007696,   MSE Z = 0.019478
# Test: MSE Total = 0.034906,   MSE X = 0.014338,   MSE Z = 0.023919
#
#
# Train Epoch 107: MSE Total = 0.020326,   MSE X = 0.007331,   MSE Z = 0.017405
# Test: MSE Total = 0.042668,   MSE X = 0.017196,   MSE Z = 0.030369
#
#
# Train Epoch 108: MSE Total = 0.028487,   MSE X = 0.010777,   MSE Z = 0.022677
# Test: MSE Total = 0.046515,   MSE X = 0.019722,   MSE Z = 0.029773
#
#
# Train Epoch 109: MSE Total = 0.053963,   MSE X = 0.021166,   MSE Z = 0.040392
# Test: MSE Total = 0.090632,   MSE X = 0.041180,   MSE Z = 0.048609
#
#
# Train Epoch 110: MSE Total = 0.057549,   MSE X = 0.023549,   MSE Z = 0.039742
# Test: MSE Total = 0.089151,   MSE X = 0.036372,   MSE Z = 0.061938
#
#
# Train Epoch 111: MSE Total = 0.109649,   MSE X = 0.047121,   MSE Z = 0.068030
# Test: MSE Total = 0.078385,   MSE X = 0.031811,   MSE Z = 0.055036
#
#
# Train Epoch 112: MSE Total = 0.065929,   MSE X = 0.027316,   MSE Z = 0.044375
# Test: MSE Total = 0.082300,   MSE X = 0.034739,   MSE Z = 0.053210
#
#
# Train Epoch 113: MSE Total = 0.063142,   MSE X = 0.026357,   MSE Z = 0.041831
# Test: MSE Total = 0.084967,   MSE X = 0.034551,   MSE Z = 0.059421
#
#
# Train Epoch 114: MSE Total = 0.044268,   MSE X = 0.016987,   MSE Z = 0.034422
# Test: MSE Total = 0.037428,   MSE X = 0.015278,   MSE Z = 0.025974
#
#
# Train Epoch 115: MSE Total = 0.022321,   MSE X = 0.007733,   MSE Z = 0.020199
# Test: MSE Total = 0.038856,   MSE X = 0.016181,   MSE Z = 0.025874
#
#
# Train Epoch 116: MSE Total = 0.018538,   MSE X = 0.006385,   MSE Z = 0.016904
# Test: MSE Total = 0.034625,   MSE X = 0.014195,   MSE Z = 0.023823
#
#
# Train Epoch 117: MSE Total = 0.018543,   MSE X = 0.006578,   MSE Z = 0.016252
# Test: MSE Total = 0.032291,   MSE X = 0.013109,   MSE Z = 0.022655
#
#
# Train Epoch 118: MSE Total = 0.018076,   MSE X = 0.006259,   MSE Z = 0.016368
# Test: MSE Total = 0.028491,   MSE X = 0.011217,   MSE Z = 0.021184
#
#
# Train Epoch 119: MSE Total = 0.015439,   MSE X = 0.005142,   MSE Z = 0.014677
# Test: MSE Total = 0.031970,   MSE X = 0.012993,   MSE Z = 0.022382
#
#
# Train Epoch 120: MSE Total = 0.014671,   MSE X = 0.004909,   MSE Z = 0.013869
# Test: MSE Total = 0.028096,   MSE X = 0.011381,   MSE Z = 0.019798
#
#
# Train Epoch 121: MSE Total = 0.014587,   MSE X = 0.004881,   MSE Z = 0.013789
# Test: MSE Total = 0.029043,   MSE X = 0.012361,   MSE Z = 0.018428
#
#
# Train Epoch 122: MSE Total = 0.014356,   MSE X = 0.004801,   MSE Z = 0.013580
# Test: MSE Total = 0.029306,   MSE X = 0.012302,   MSE Z = 0.019180
#
#
# Train Epoch 123: MSE Total = 0.015197,   MSE X = 0.005287,   MSE Z = 0.013677
# Test: MSE Total = 0.030002,   MSE X = 0.011969,   MSE Z = 0.021771
#
#
# Train Epoch 124: MSE Total = 0.013923,   MSE X = 0.004723,   MSE Z = 0.012942
# Test: MSE Total = 0.033106,   MSE X = 0.013347,   MSE Z = 0.023546
#
#
# Train Epoch 125: MSE Total = 0.014152,   MSE X = 0.004768,   MSE Z = 0.013266
# Test: MSE Total = 0.029081,   MSE X = 0.011450,   MSE Z = 0.021619
#
#
# Train Epoch 126: MSE Total = 0.015870,   MSE X = 0.005555,   MSE Z = 0.014169
# Test: MSE Total = 0.034987,   MSE X = 0.013765,   MSE Z = 0.026046
#
#
# Train Epoch 127: MSE Total = 0.021879,   MSE X = 0.008538,   MSE Z = 0.016527
# Test: MSE Total = 0.065882,   MSE X = 0.028664,   MSE Z = 0.039676
#
#
# Train Epoch 128: MSE Total = 0.135670,   MSE X = 0.060845,   MSE Z = 0.075495
# Test: MSE Total = 0.142598,   MSE X = 0.064860,   MSE Z = 0.076250
#
#
# Train Epoch 129: MSE Total = 0.050198,   MSE X = 0.019858,   MSE Z = 0.036998
# Test: MSE Total = 0.074815,   MSE X = 0.034731,   MSE Z = 0.037608
#
#
# Train Epoch 130: MSE Total = 0.054967,   MSE X = 0.022289,   MSE Z = 0.038654
# Test: MSE Total = 0.042896,   MSE X = 0.016726,   MSE Z = 0.032447
#
#
# Train Epoch 131: MSE Total = 0.022335,   MSE X = 0.007866,   MSE Z = 0.019774
# Test: MSE Total = 0.031849,   MSE X = 0.012805,   MSE Z = 0.022771
#
#
# Train Epoch 132: MSE Total = 0.018018,   MSE X = 0.006333,   MSE Z = 0.015995
# Test: MSE Total = 0.030385,   MSE X = 0.011831,   MSE Z = 0.023042
#
#
# Train Epoch 133: MSE Total = 0.015731,   MSE X = 0.005373,   MSE Z = 0.014497
# Test: MSE Total = 0.026655,   MSE X = 0.010801,   MSE Z = 0.018770
#
#
# Train Epoch 134: MSE Total = 0.016044,   MSE X = 0.005574,   MSE Z = 0.014466
# Test: MSE Total = 0.033849,   MSE X = 0.013951,   MSE Z = 0.023032
#
#
# Train Epoch 135: MSE Total = 0.015235,   MSE X = 0.005280,   MSE Z = 0.013777
# Test: MSE Total = 0.027326,   MSE X = 0.010568,   MSE Z = 0.020968
#
#
# Train Epoch 136: MSE Total = 0.013481,   MSE X = 0.004602,   MSE Z = 0.012434
# Test: MSE Total = 0.025696,   MSE X = 0.010384,   MSE Z = 0.018191
#
#
# Train Epoch 137: MSE Total = 0.015734,   MSE X = 0.005511,   MSE Z = 0.014033
# Test: MSE Total = 0.026308,   MSE X = 0.010252,   MSE Z = 0.019922
#
#
# Train Epoch 138: MSE Total = 0.014404,   MSE X = 0.004800,   MSE Z = 0.013685
# Test: MSE Total = 0.031267,   MSE X = 0.012599,   MSE Z = 0.022261
#
#
# Train Epoch 139: MSE Total = 0.016724,   MSE X = 0.005844,   MSE Z = 0.014964
# Test: MSE Total = 0.026487,   MSE X = 0.010657,   MSE Z = 0.018911
#
#
# Train Epoch 140: MSE Total = 0.057818,   MSE X = 0.025876,   MSE Z = 0.032358
# Test: MSE Total = 0.286923,   MSE X = 0.137338,   MSE Z = 0.130088
#
#
# Train Epoch 141: MSE Total = 0.133433,   MSE X = 0.058876,   MSE Z = 0.077548
# Test: MSE Total = 0.075342,   MSE X = 0.030730,   MSE Z = 0.052371
#
#
# Train Epoch 142: MSE Total = 0.049065,   MSE X = 0.019511,   MSE Z = 0.035819
# Test: MSE Total = 0.049247,   MSE X = 0.020348,   MSE Z = 0.033339
#
#
# Train Epoch 143: MSE Total = 0.033395,   MSE X = 0.013031,   MSE Z = 0.025227
# Test: MSE Total = 0.037711,   MSE X = 0.016143,   MSE Z = 0.023613
#
#
# Train Epoch 144: MSE Total = 0.018059,   MSE X = 0.006394,   MSE Z = 0.015872
# Test: MSE Total = 0.030095,   MSE X = 0.011645,   MSE Z = 0.023069
#
#
# Train Epoch 145: MSE Total = 0.015224,   MSE X = 0.005237,   MSE Z = 0.013902
# Test: MSE Total = 0.025172,   MSE X = 0.010113,   MSE Z = 0.018023
#
#
# Train Epoch 146: MSE Total = 0.013533,   MSE X = 0.004632,   MSE Z = 0.012439
# Test: MSE Total = 0.029265,   MSE X = 0.011935,   MSE Z = 0.020346
#
#
# Train Epoch 147: MSE Total = 0.012542,   MSE X = 0.004101,   MSE Z = 0.012183
# Test: MSE Total = 0.026331,   MSE X = 0.010580,   MSE Z = 0.018848
#
#
# Train Epoch 148: MSE Total = 0.011181,   MSE X = 0.003758,   MSE Z = 0.010515
# Test: MSE Total = 0.026262,   MSE X = 0.010809,   MSE Z = 0.017924
#
#
# Train Epoch 149: MSE Total = 0.012670,   MSE X = 0.004085,   MSE Z = 0.012504
# Test: MSE Total = 0.026411,   MSE X = 0.010608,   MSE Z = 0.018919
#
#
# Train Epoch 150: MSE Total = 0.012181,   MSE X = 0.004140,   MSE Z = 0.011296
# Test: MSE Total = 0.028390,   MSE X = 0.011767,   MSE Z = 0.019095
#
#
# Train Epoch 151: MSE Total = 0.013209,   MSE X = 0.004558,   MSE Z = 0.012015
# Test: MSE Total = 0.026052,   MSE X = 0.010809,   MSE Z = 0.017484
#
#
# Train Epoch 152: MSE Total = 0.011007,   MSE X = 0.003763,   MSE Z = 0.010132
# Test: MSE Total = 0.024466,   MSE X = 0.010013,   MSE Z = 0.016889
#
#
# Train Epoch 153: MSE Total = 0.015980,   MSE X = 0.005777,   MSE Z = 0.013638
# Test: MSE Total = 0.025145,   MSE X = 0.010240,   MSE Z = 0.017532
#
#
# Train Epoch 154: MSE Total = 0.013052,   MSE X = 0.004660,   MSE Z = 0.011339
# Test: MSE Total = 0.025262,   MSE X = 0.010557,   MSE Z = 0.016693
#
#
# Train Epoch 155: MSE Total = 0.012390,   MSE X = 0.004176,   MSE Z = 0.011609
# Test: MSE Total = 0.025470,   MSE X = 0.010908,   MSE Z = 0.015930
#
#
# Train Epoch 156: MSE Total = 0.010906,   MSE X = 0.003753,   MSE Z = 0.009956
# Test: MSE Total = 0.024469,   MSE X = 0.010447,   MSE Z = 0.015415
#
#
# Train Epoch 157: MSE Total = 0.009671,   MSE X = 0.003197,   MSE Z = 0.009273
# Test: MSE Total = 0.023971,   MSE X = 0.010013,   MSE Z = 0.015855
#
#
# Train Epoch 158: MSE Total = 0.010234,   MSE X = 0.003414,   MSE Z = 0.009709
# Test: MSE Total = 0.027976,   MSE X = 0.011204,   MSE Z = 0.020151
#
#
# Train Epoch 159: MSE Total = 0.023872,   MSE X = 0.009142,   MSE Z = 0.018626
# Test: MSE Total = 0.094312,   MSE X = 0.039090,   MSE Z = 0.063431
#
#
# Train Epoch 160: MSE Total = 0.110285,   MSE X = 0.046430,   MSE Z = 0.071716
# Test: MSE Total = 0.123442,   MSE X = 0.050308,   MSE Z = 0.085947
#
#
# Train Epoch 161: MSE Total = 0.090757,   MSE X = 0.039176,   MSE Z = 0.055716
# Test: MSE Total = 0.076252,   MSE X = 0.032441,   MSE Z = 0.048430
#
#
# Train Epoch 162: MSE Total = 0.088239,   MSE X = 0.037317,   MSE Z = 0.056806
# Test: MSE Total = 0.177416,   MSE X = 0.085756,   MSE Z = 0.077592
#
#
# Train Epoch 163: MSE Total = 0.077756,   MSE X = 0.033952,   MSE Z = 0.046410
# Test: MSE Total = 0.054312,   MSE X = 0.021059,   MSE Z = 0.041488
#
#
# Train Epoch 164: MSE Total = 0.024998,   MSE X = 0.008752,   MSE Z = 0.022310
# Test: MSE Total = 0.036940,   MSE X = 0.015371,   MSE Z = 0.024638
#
#
# Train Epoch 165: MSE Total = 0.019987,   MSE X = 0.007250,   MSE Z = 0.016974
# Test: MSE Total = 0.035158,   MSE X = 0.014088,   MSE Z = 0.025300
#
#
# Train Epoch 166: MSE Total = 0.015780,   MSE X = 0.005254,   MSE Z = 0.015006
# Test: MSE Total = 0.025643,   MSE X = 0.010509,   MSE Z = 0.017655
#
#
# Train Epoch 167: MSE Total = 0.012598,   MSE X = 0.004221,   MSE Z = 0.011890
# Test: MSE Total = 0.023026,   MSE X = 0.009337,   MSE Z = 0.016192
#
#
# Train Epoch 168: MSE Total = 0.012168,   MSE X = 0.004109,   MSE Z = 0.011374
# Test: MSE Total = 0.022878,   MSE X = 0.009198,   MSE Z = 0.016357
#
#
# Train Epoch 169: MSE Total = 0.011747,   MSE X = 0.003885,   MSE Z = 0.011261
# Test: MSE Total = 0.022394,   MSE X = 0.009084,   MSE Z = 0.015736
#
#
# Train Epoch 170: MSE Total = 0.011372,   MSE X = 0.003754,   MSE Z = 0.010924
# Test: MSE Total = 0.022626,   MSE X = 0.009209,   MSE Z = 0.015793
#
#
# Train Epoch 171: MSE Total = 0.010562,   MSE X = 0.003642,   MSE Z = 0.009616
# Test: MSE Total = 0.021473,   MSE X = 0.008861,   MSE Z = 0.014575
#
#
# Train Epoch 172: MSE Total = 0.009726,   MSE X = 0.003250,   MSE Z = 0.009210
# Test: MSE Total = 0.021560,   MSE X = 0.008654,   MSE Z = 0.015464
#
#
# Train Epoch 173: MSE Total = 0.009538,   MSE X = 0.003139,   MSE Z = 0.009195
# Test: MSE Total = 0.020936,   MSE X = 0.008830,   MSE Z = 0.013558
#
#
# Train Epoch 174: MSE Total = 0.009546,   MSE X = 0.003239,   MSE Z = 0.008871
# Test: MSE Total = 0.022374,   MSE X = 0.009553,   MSE Z = 0.014092
#
#
# Train Epoch 175: MSE Total = 0.009443,   MSE X = 0.003138,   MSE Z = 0.009000
# Test: MSE Total = 0.020869,   MSE X = 0.008402,   MSE Z = 0.014884
#
#
# Train Epoch 176: MSE Total = 0.008851,   MSE X = 0.002932,   MSE Z = 0.008468
# Test: MSE Total = 0.020865,   MSE X = 0.008778,   MSE Z = 0.013588
#
#
# Train Epoch 177: MSE Total = 0.008765,   MSE X = 0.002994,   MSE Z = 0.008075
# Test: MSE Total = 0.021172,   MSE X = 0.008646,   MSE Z = 0.014682
#
#
# Train Epoch 178: MSE Total = 0.009083,   MSE X = 0.003100,   MSE Z = 0.008380
# Test: MSE Total = 0.020054,   MSE X = 0.008105,   MSE Z = 0.014193
#
#
# Train Epoch 179: MSE Total = 0.009642,   MSE X = 0.003222,   MSE Z = 0.009130
# Test: MSE Total = 0.022239,   MSE X = 0.009264,   MSE Z = 0.014801
#
#
# Train Epoch 180: MSE Total = 0.018556,   MSE X = 0.006987,   MSE Z = 0.014882
# Test: MSE Total = 0.038841,   MSE X = 0.016304,   MSE Z = 0.025423
#
#
# Train Epoch 181: MSE Total = 0.080921,   MSE X = 0.033845,   MSE Z = 0.053385
# Test: MSE Total = 0.076501,   MSE X = 0.032685,   MSE Z = 0.048116
#
#
# Train Epoch 182: MSE Total = 0.086666,   MSE X = 0.038246,   MSE Z = 0.050350
# Test: MSE Total = 0.071384,   MSE X = 0.030673,   MSE Z = 0.044302
#
#
# Train Epoch 183: MSE Total = 0.044008,   MSE X = 0.017641,   MSE Z = 0.031647
# Test: MSE Total = 0.034527,   MSE X = 0.013505,   MSE Z = 0.025974
#
#
# Train Epoch 184: MSE Total = 0.017570,   MSE X = 0.006292,   MSE Z = 0.015199
# Test: MSE Total = 0.041843,   MSE X = 0.018589,   MSE Z = 0.023885
#
#
# Train Epoch 185: MSE Total = 0.017595,   MSE X = 0.006563,   MSE Z = 0.014326
# Test: MSE Total = 0.024646,   MSE X = 0.009815,   MSE Z = 0.017943
#
#
# Train Epoch 186: MSE Total = 0.011489,   MSE X = 0.003964,   MSE Z = 0.010451
# Test: MSE Total = 0.027828,   MSE X = 0.011516,   MSE Z = 0.018779
#
#
# Train Epoch 187: MSE Total = 0.025232,   MSE X = 0.009875,   MSE Z = 0.018962
# Test: MSE Total = 0.046913,   MSE X = 0.019779,   MSE Z = 0.030409
#
#
# Train Epoch 188: MSE Total = 0.025233,   MSE X = 0.009397,   MSE Z = 0.020596
# Test: MSE Total = 0.026735,   MSE X = 0.010847,   MSE Z = 0.018781
#
#
# Train Epoch 189: MSE Total = 0.012404,   MSE X = 0.004174,   MSE Z = 0.011647
# Test: MSE Total = 0.027509,   MSE X = 0.010474,   MSE Z = 0.021672
#
#
# Train Epoch 190: MSE Total = 0.011015,   MSE X = 0.003606,   MSE Z = 0.010684
# Test: MSE Total = 0.021002,   MSE X = 0.008312,   MSE Z = 0.015466
#
#
# Train Epoch 191: MSE Total = 0.009938,   MSE X = 0.003239,   MSE Z = 0.009690
# Test: MSE Total = 0.023253,   MSE X = 0.009367,   MSE Z = 0.016565
#
#
# Train Epoch 192: MSE Total = 0.009386,   MSE X = 0.003169,   MSE Z = 0.008775
# Test: MSE Total = 0.022806,   MSE X = 0.009446,   MSE Z = 0.015359
#
#
# Train Epoch 193: MSE Total = 0.008489,   MSE X = 0.002850,   MSE Z = 0.007993
# Test: MSE Total = 0.020791,   MSE X = 0.008525,   MSE Z = 0.014300
#
#
# Train Epoch 194: MSE Total = 0.008871,   MSE X = 0.002910,   MSE Z = 0.008587
# Test: MSE Total = 0.020151,   MSE X = 0.007807,   MSE Z = 0.015413
#
#
# Train Epoch 195: MSE Total = 0.008014,   MSE X = 0.002612,   MSE Z = 0.007813
# Test: MSE Total = 0.020441,   MSE X = 0.008488,   MSE Z = 0.013695
#
#
# Train Epoch 196: MSE Total = 0.007555,   MSE X = 0.002513,   MSE Z = 0.007193
# Test: MSE Total = 0.020801,   MSE X = 0.008934,   MSE Z = 0.012922
#
#
# Train Epoch 197: MSE Total = 0.007953,   MSE X = 0.002675,   MSE Z = 0.007468
# Test: MSE Total = 0.023638,   MSE X = 0.009823,   MSE Z = 0.015811
#
#
# Train Epoch 198: MSE Total = 0.007837,   MSE X = 0.002638,   MSE Z = 0.007356
# Test: MSE Total = 0.021064,   MSE X = 0.008805,   MSE Z = 0.013914
#
#
# Train Epoch 199: MSE Total = 0.007341,   MSE X = 0.002484,   MSE Z = 0.006846
# Test: MSE Total = 0.021311,   MSE X = 0.009011,   MSE Z = 0.013726
#
#
# Train Epoch 200: MSE Total = 0.007530,   MSE X = 0.002476,   MSE Z = 0.007266
# Test: MSE Total = 0.019916,   MSE X = 0.008037,   MSE Z = 0.014139
#
#
# Got the weights of the epoch 200
# Execution time: 33 minutes, 43.48 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
model.load_state_dict(torch.load("model_weights_step2"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_emb_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [14, 20, 32, 35, 50, 60]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_emb_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc_emb) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_emb_tensor = pc_emb_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_emb_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future, pc_emb in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc_emb)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future, pc_emb in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc_emb)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.069490,   ADE X = 0.028221,   ADE Z = 0.057514
# FDE Total = 0.116395,   FDE X = 0.056951,   FDE Z = 0.089224
#
# Model performances on test set:
#
# ADE Total = 0.094632,   ADE X = 0.041413,   ADE Z = 0.075428
# FDE Total = 0.160066,   FDE X = 0.087237,   FDE Z = 0.114962
