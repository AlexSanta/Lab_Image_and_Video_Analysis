# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 200
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
output_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %% [markdown]
# ## Calcolo e salvataggio embedding delle nuvole di punti

# %%
class PointNetfeat(nn.Module):
    def __init__(self):
        super(PointNetfeat, self).__init__()
        self.conv1 = torch.nn.Conv1d(3, 64, 1)
        self.conv2 = torch.nn.Conv1d(64, 128, 1)
        self.conv3 = torch.nn.Conv1d(128, 1024, 1)
        self.ln1 = nn.LayerNorm(64)
        self.ln2 = nn.LayerNorm(128)
        self.ln3 = nn.LayerNorm(1024)
        self.fc_reduce = nn.Linear(1024, 256)  # nuovo layer per la riduzione a 256
        self.ln_reduce = nn.LayerNorm(256)  # normalizzazione output ridotto

    def forward(self, x):
        x = F.relu(self.ln1(self.conv1(x).transpose(1, 2))).transpose(1, 2)
        x = F.relu(self.ln2(self.conv2(x).transpose(1, 2))).transpose(1, 2)
        x = self.ln3(self.conv3(x).transpose(1, 2)).transpose(1, 2)
        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)
        x = self.ln_reduce(self.fc_reduce(x))

        return x

# %%
torch.manual_seed(42)
pointnet = PointNetfeat()
pointnet.to(device)
pointnet.eval()

npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]

point_cloud_embeddings = [] # lista per salvare gli embedding

with torch.no_grad():
    for file_name in npz_files:
        file_path = os.path.join(folder_path, file_name)
        data = np.load(file_path)

        # Prende la nuvola di punti e mettila su GPU
        point_cloud = torch.tensor(data["point_cloud"], dtype=torch.float32).unsqueeze(0).transpose(1, 2).to(device)

        # Calcola l'embedding
        embedding = pointnet(point_cloud).squeeze(0).cpu().numpy()

        # Salva l'embedding nella lista
        point_cloud_embeddings.append(embedding)

# Salva gli embedding in un file NPZ
np.savez_compressed("point_cloud_embeddings.npz", embeddings=np.array(point_cloud_embeddings))

print("Embeddings saved in 'point_cloud_embeddings.npz'!")
# Out:
# Embeddings saved in 'point_cloud_embeddings.npz'!

# %% [markdown]
# ## Sezione addestramento della GRU

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, point_cloud_embeddings, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.point_cloud_embeddings = point_cloud_embeddings

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32)
        point_cloud_embedding = self.point_cloud_embeddings[idx]

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        return past_trajectory, future_trajectory, point_cloud_embedding

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.hidden_size  = hidden_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, pc_emb):
        h0 = pc_emb.unsqueeze(0).repeat(self.num_layers, 1, 1).to(x.device)
        
        out, h = self.gru(x[:, :-1, :], h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la
                                 # sequenza (ultimo punto escluso) ed ha quindi dimensione [batch_size, seq_length-1,
                                 #                                                                        hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        future_trajectory_pred = []
        last_input = x[:, -1, :]  # ultimo punto della traiettoria passata ([batch_size, input_size])

        for _ in range(self.future_steps): 
            last_input = last_input.unsqueeze(1) #la dimensione ora è [batch_size, 1, input_size]
            out, h = self.gru(last_input, h)
            future_point = self.fc(out.squeeze(1)) # predizione punto successivo
            future_trajectory_pred.append(future_point)
            last_input = future_point # il punto successivo predetto diventa l'ultimo input
             
        return torch.stack(future_trajectory_pred, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_variance, global_z_variance):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future, pc_emb in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past, pc_emb) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_variance, global_z_variance):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future, pc_emb in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past, pc_emb)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(20, epochs + 1, 20)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
loaded_pc_embs = np.load("point_cloud_embeddings.npz")
point_cloud_embeddings = [torch.tensor(emb, dtype=torch.float32) for emb in loaded_pc_embs["embeddings"]]

dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                        framerate=framerate, point_cloud_embeddings=point_cloud_embeddings)

torch.manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25])
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
for past, future, pc in train_loader:
    print(past.shape)
    print(future.shape)
    print(pc.shape)
    break
# Out:
# torch.Size([64, 20, 2])
# torch.Size([64, 40, 2])
# torch.Size([64, 256])

# %%
#Calcolo della varianza globale di x e di z lungo le traiettore

all_x_values = []
all_z_values = []

for past, future, _ in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

# concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.37383729219436646
# Global variance of the z-coordinate: 4.3598480224609375

# %%
batch = next(iter(test_loader))  # Prendi un batch dal test_loader
past_batch, future_batch, _ = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = 1000

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_variance, global_z_variance)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_variance, global_z_variance)

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.261310,   MSE X = 0.561648,   MSE Z = 0.715603
# Test: MSE Total = 1.018641,   MSE X = 0.564626,   MSE Z = 0.198736
#
#
# Train Epoch 2: MSE Total = 1.018776,   MSE X = 0.557247,   MSE Z = 0.224215
# Test: MSE Total = 0.987241,   MSE X = 0.549959,   MSE Z = 0.183259
#
#
# Train Epoch 3: MSE Total = 0.944648,   MSE X = 0.502818,   MSE Z = 0.255311
# Test: MSE Total = 0.849103,   MSE X = 0.443465,   MSE Z = 0.258503
#
#
# Train Epoch 4: MSE Total = 0.639517,   MSE X = 0.313849,   MSE Z = 0.263523
# Test: MSE Total = 0.631223,   MSE X = 0.301819,   MSE Z = 0.287291
#
#
# Train Epoch 5: MSE Total = 0.510013,   MSE X = 0.248069,   MSE Z = 0.217755
# Test: MSE Total = 0.533892,   MSE X = 0.272583,   MSE Z = 0.183899
#
#
# Train Epoch 6: MSE Total = 0.510862,   MSE X = 0.248968,   MSE Z = 0.216458
# Test: MSE Total = 0.457847,   MSE X = 0.221233,   MSE Z = 0.200478
#
#
# Train Epoch 7: MSE Total = 0.468573,   MSE X = 0.227691,   MSE Z = 0.200819
# Test: MSE Total = 0.425220,   MSE X = 0.209087,   MSE Z = 0.173831
#
#
# Train Epoch 8: MSE Total = 0.455241,   MSE X = 0.221691,   MSE Z = 0.193473
# Test: MSE Total = 0.462350,   MSE X = 0.229552,   MSE Z = 0.181471
#
#
# Train Epoch 9: MSE Total = 0.444933,   MSE X = 0.213412,   MSE Z = 0.200224
# Test: MSE Total = 0.420331,   MSE X = 0.206168,   MSE Z = 0.173592
#
#
# Train Epoch 10: MSE Total = 0.423833,   MSE X = 0.203315,   MSE Z = 0.190646
# Test: MSE Total = 0.445033,   MSE X = 0.218102,   MSE Z = 0.184417
#
#
# Train Epoch 11: MSE Total = 0.423738,   MSE X = 0.202325,   MSE Z = 0.193830
# Test: MSE Total = 0.368075,   MSE X = 0.169909,   MSE Z = 0.188305
#
#
# Train Epoch 12: MSE Total = 0.394422,   MSE X = 0.185081,   MSE Z = 0.191506
# Test: MSE Total = 0.359563,   MSE X = 0.162981,   MSE Z = 0.194192
#
#
# Train Epoch 13: MSE Total = 0.363587,   MSE X = 0.170407,   MSE Z = 0.177234
# Test: MSE Total = 0.444895,   MSE X = 0.225624,   MSE Z = 0.158437
#
#
# Train Epoch 14: MSE Total = 0.364305,   MSE X = 0.172135,   MSE Z = 0.172832
# Test: MSE Total = 0.336788,   MSE X = 0.159718,   MSE Z = 0.157778
#
#
# Train Epoch 15: MSE Total = 0.351413,   MSE X = 0.162843,   MSE Z = 0.177646
# Test: MSE Total = 0.324359,   MSE X = 0.152957,   MSE Z = 0.154918
#
#
# Train Epoch 16: MSE Total = 0.320875,   MSE X = 0.149216,   MSE Z = 0.160419
# Test: MSE Total = 0.341990,   MSE X = 0.163572,   MSE Z = 0.155480
#
#
# Train Epoch 17: MSE Total = 0.332514,   MSE X = 0.155634,   MSE Z = 0.162803
# Test: MSE Total = 0.313714,   MSE X = 0.139121,   MSE Z = 0.179942
#
#
# Train Epoch 18: MSE Total = 0.321251,   MSE X = 0.149960,   MSE Z = 0.158662
# Test: MSE Total = 0.273551,   MSE X = 0.124981,   MSE Z = 0.144366
#
#
# Train Epoch 19: MSE Total = 0.313722,   MSE X = 0.144537,   MSE Z = 0.161460
# Test: MSE Total = 0.296791,   MSE X = 0.138614,   MSE Z = 0.146335
#
#
# Train Epoch 20: MSE Total = 0.297661,   MSE X = 0.137623,   MSE Z = 0.151538
# Test: MSE Total = 0.275469,   MSE X = 0.129069,   MSE Z = 0.134411
#
#
# Train Epoch 21: MSE Total = 0.294268,   MSE X = 0.136665,   MSE Z = 0.147724
# Test: MSE Total = 0.297729,   MSE X = 0.141844,   MSE Z = 0.137264
#
#
# Train Epoch 22: MSE Total = 0.285207,   MSE X = 0.131703,   MSE Z = 0.145750
# Test: MSE Total = 0.316751,   MSE X = 0.154337,   MSE Z = 0.134319
#
#
# Train Epoch 23: MSE Total = 0.278629,   MSE X = 0.128570,   MSE Z = 0.142712
# Test: MSE Total = 0.277729,   MSE X = 0.126546,   MSE Z = 0.147745
#
#
# Train Epoch 24: MSE Total = 0.255203,   MSE X = 0.115261,   MSE Z = 0.139251
# Test: MSE Total = 0.252788,   MSE X = 0.116348,   MSE Z = 0.130496
#
#
# Train Epoch 25: MSE Total = 0.261189,   MSE X = 0.118969,   MSE Z = 0.139089
# Test: MSE Total = 0.255739,   MSE X = 0.116225,   MSE Z = 0.137078
#
#
# Train Epoch 26: MSE Total = 0.241237,   MSE X = 0.109011,   MSE Z = 0.131434
# Test: MSE Total = 0.257333,   MSE X = 0.116474,   MSE Z = 0.139555
#
#
# Train Epoch 27: MSE Total = 0.246678,   MSE X = 0.110596,   MSE Z = 0.137382
# Test: MSE Total = 0.234803,   MSE X = 0.107600,   MSE Z = 0.122816
#
#
# Train Epoch 28: MSE Total = 0.227885,   MSE X = 0.101526,   MSE Z = 0.129115
# Test: MSE Total = 0.264875,   MSE X = 0.120250,   MSE Z = 0.142411
#
#
# Train Epoch 29: MSE Total = 0.230108,   MSE X = 0.104007,   MSE Z = 0.125284
# Test: MSE Total = 0.235152,   MSE X = 0.104795,   MSE Z = 0.133125
#
#
# Train Epoch 30: MSE Total = 0.203021,   MSE X = 0.088933,   MSE Z = 0.120205
# Test: MSE Total = 0.218059,   MSE X = 0.095029,   MSE Z = 0.130786
#
#
# Train Epoch 31: MSE Total = 0.207874,   MSE X = 0.092151,   MSE Z = 0.119347
# Test: MSE Total = 0.201914,   MSE X = 0.090755,   MSE Z = 0.111670
#
#
# Train Epoch 32: MSE Total = 0.228685,   MSE X = 0.103489,   MSE Z = 0.124082
# Test: MSE Total = 0.205398,   MSE X = 0.091013,   MSE Z = 0.118064
#
#
# Train Epoch 33: MSE Total = 0.184584,   MSE X = 0.081132,   MSE Z = 0.108348
# Test: MSE Total = 0.196285,   MSE X = 0.087257,   MSE Z = 0.111861
#
#
# Train Epoch 34: MSE Total = 0.190279,   MSE X = 0.083418,   MSE Z = 0.112433
# Test: MSE Total = 0.261042,   MSE X = 0.122512,   MSE Z = 0.126682
#
#
# Train Epoch 35: MSE Total = 0.195058,   MSE X = 0.085015,   MSE Z = 0.116958
# Test: MSE Total = 0.236235,   MSE X = 0.101054,   MSE Z = 0.148163
#
#
# Train Epoch 36: MSE Total = 0.184640,   MSE X = 0.080890,   MSE Z = 0.109291
# Test: MSE Total = 0.217213,   MSE X = 0.102281,   MSE Z = 0.104251
#
#
# Train Epoch 37: MSE Total = 0.185260,   MSE X = 0.080191,   MSE Z = 0.112974
# Test: MSE Total = 0.176424,   MSE X = 0.080166,   MSE Z = 0.094608
#
#
# Train Epoch 38: MSE Total = 0.159112,   MSE X = 0.068330,   MSE Z = 0.098883
# Test: MSE Total = 0.173841,   MSE X = 0.076946,   MSE Z = 0.100213
#
#
# Train Epoch 39: MSE Total = 0.145255,   MSE X = 0.060958,   MSE Z = 0.095124
# Test: MSE Total = 0.166723,   MSE X = 0.074263,   MSE Z = 0.094510
#
#
# Train Epoch 40: MSE Total = 0.148192,   MSE X = 0.062895,   MSE Z = 0.094639
# Test: MSE Total = 0.195201,   MSE X = 0.083761,   MSE Z = 0.121539
#
#
# Train Epoch 41: MSE Total = 0.152163,   MSE X = 0.065045,   MSE Z = 0.095589
# Test: MSE Total = 0.151740,   MSE X = 0.066692,   MSE Z = 0.089082
#
#
# Train Epoch 42: MSE Total = 0.132361,   MSE X = 0.055768,   MSE Z = 0.085925
# Test: MSE Total = 0.161950,   MSE X = 0.073607,   MSE Z = 0.086786
#
#
# Train Epoch 43: MSE Total = 0.136608,   MSE X = 0.058269,   MSE Z = 0.086250
# Test: MSE Total = 0.144993,   MSE X = 0.064928,   MSE Z = 0.081018
#
#
# Train Epoch 44: MSE Total = 0.132253,   MSE X = 0.056092,   MSE Z = 0.084591
# Test: MSE Total = 0.192248,   MSE X = 0.090798,   MSE Z = 0.091340
#
#
# Train Epoch 45: MSE Total = 0.170649,   MSE X = 0.075673,   MSE Z = 0.097894
# Test: MSE Total = 0.153549,   MSE X = 0.067101,   MSE Z = 0.091463
#
#
# Train Epoch 46: MSE Total = 0.132261,   MSE X = 0.056435,   MSE Z = 0.083438
# Test: MSE Total = 0.151278,   MSE X = 0.063920,   MSE Z = 0.097583
#
#
# Train Epoch 47: MSE Total = 0.108767,   MSE X = 0.044727,   MSE Z = 0.074364
# Test: MSE Total = 0.118874,   MSE X = 0.050753,   MSE Z = 0.074889
#
#
# Train Epoch 48: MSE Total = 0.098523,   MSE X = 0.039649,   MSE Z = 0.070316
# Test: MSE Total = 0.127516,   MSE X = 0.054351,   MSE Z = 0.080646
#
#
# Train Epoch 49: MSE Total = 0.098259,   MSE X = 0.040105,   MSE Z = 0.068207
# Test: MSE Total = 0.118755,   MSE X = 0.051001,   MSE Z = 0.073795
#
#
# Train Epoch 50: MSE Total = 0.092300,   MSE X = 0.037542,   MSE Z = 0.064518
# Test: MSE Total = 0.111099,   MSE X = 0.047504,   MSE Z = 0.069751
#
#
# Train Epoch 51: MSE Total = 0.084058,   MSE X = 0.033852,   MSE Z = 0.059909
# Test: MSE Total = 0.094186,   MSE X = 0.041353,   MSE Z = 0.055439
#
#
# Train Epoch 52: MSE Total = 0.088034,   MSE X = 0.035623,   MSE Z = 0.062161
# Test: MSE Total = 0.110899,   MSE X = 0.048899,   MSE Z = 0.064567
#
#
# Train Epoch 53: MSE Total = 0.132906,   MSE X = 0.057889,   MSE Z = 0.079819
# Test: MSE Total = 0.149044,   MSE X = 0.064719,   MSE Z = 0.090189
#
#
# Train Epoch 54: MSE Total = 0.107143,   MSE X = 0.045165,   MSE Z = 0.069478
# Test: MSE Total = 0.107501,   MSE X = 0.047116,   MSE Z = 0.063563
#
#
# Train Epoch 55: MSE Total = 0.076331,   MSE X = 0.030449,   MSE Z = 0.055398
# Test: MSE Total = 0.100953,   MSE X = 0.041909,   MSE Z = 0.067671
#
#
# Train Epoch 56: MSE Total = 0.065954,   MSE X = 0.025526,   MSE Z = 0.050541
# Test: MSE Total = 0.086236,   MSE X = 0.036985,   MSE Z = 0.053756
#
#
# Train Epoch 57: MSE Total = 0.064342,   MSE X = 0.024739,   MSE Z = 0.049864
# Test: MSE Total = 0.098798,   MSE X = 0.042880,   MSE Z = 0.059857
#
#
# Train Epoch 58: MSE Total = 0.069865,   MSE X = 0.027668,   MSE Z = 0.051392
# Test: MSE Total = 0.093833,   MSE X = 0.041076,   MSE Z = 0.055651
#
#
# Train Epoch 59: MSE Total = 0.139433,   MSE X = 0.061938,   MSE Z = 0.079620
# Test: MSE Total = 0.148326,   MSE X = 0.065519,   MSE Z = 0.085958
#
#
# Train Epoch 60: MSE Total = 0.084793,   MSE X = 0.034573,   MSE Z = 0.058982
# Test: MSE Total = 0.092329,   MSE X = 0.040593,   MSE Z = 0.054159
#
#
# Train Epoch 61: MSE Total = 0.056080,   MSE X = 0.021564,   MSE Z = 0.043456
# Test: MSE Total = 0.079130,   MSE X = 0.033899,   MSE Z = 0.049458
#
#
# Train Epoch 62: MSE Total = 0.067079,   MSE X = 0.026929,   MSE Z = 0.048098
# Test: MSE Total = 0.119637,   MSE X = 0.051135,   MSE Z = 0.075178
#
#
# Train Epoch 63: MSE Total = 0.075835,   MSE X = 0.031173,   MSE Z = 0.051888
# Test: MSE Total = 0.097815,   MSE X = 0.043129,   MSE Z = 0.056954
#
#
# Train Epoch 64: MSE Total = 0.056809,   MSE X = 0.022084,   MSE Z = 0.043201
# Test: MSE Total = 0.081903,   MSE X = 0.034948,   MSE Z = 0.051666
#
#
# Train Epoch 65: MSE Total = 0.056610,   MSE X = 0.022360,   MSE Z = 0.041843
# Test: MSE Total = 0.080019,   MSE X = 0.033673,   MSE Z = 0.052089
#
#
# Train Epoch 66: MSE Total = 0.047200,   MSE X = 0.017754,   MSE Z = 0.037925
# Test: MSE Total = 0.063049,   MSE X = 0.026672,   MSE Z = 0.040563
#
#
# Train Epoch 67: MSE Total = 0.063705,   MSE X = 0.025148,   MSE Z = 0.047138
# Test: MSE Total = 0.078404,   MSE X = 0.031711,   MSE Z = 0.055416
#
#
# Train Epoch 68: MSE Total = 0.044964,   MSE X = 0.016705,   MSE Z = 0.036840
# Test: MSE Total = 0.071067,   MSE X = 0.029721,   MSE Z = 0.046889
#
#
# Train Epoch 69: MSE Total = 0.046026,   MSE X = 0.017501,   MSE Z = 0.036337
# Test: MSE Total = 0.085794,   MSE X = 0.032382,   MSE Z = 0.068557
#
#
# Train Epoch 70: MSE Total = 0.041352,   MSE X = 0.015523,   MSE Z = 0.033332
# Test: MSE Total = 0.061112,   MSE X = 0.025593,   MSE Z = 0.040203
#
#
# Train Epoch 71: MSE Total = 0.043397,   MSE X = 0.016457,   MSE Z = 0.034413
# Test: MSE Total = 0.075263,   MSE X = 0.031498,   MSE Z = 0.049587
#
#
# Train Epoch 72: MSE Total = 0.045408,   MSE X = 0.017293,   MSE Z = 0.035758
# Test: MSE Total = 0.081188,   MSE X = 0.034242,   MSE Z = 0.052584
#
#
# Train Epoch 73: MSE Total = 0.060158,   MSE X = 0.023363,   MSE Z = 0.045828
# Test: MSE Total = 0.136214,   MSE X = 0.063551,   MSE Z = 0.067391
#
#
# Train Epoch 74: MSE Total = 0.090516,   MSE X = 0.037896,   MSE Z = 0.059583
# Test: MSE Total = 0.155489,   MSE X = 0.067633,   MSE Z = 0.093695
#
#
# Train Epoch 75: MSE Total = 0.063513,   MSE X = 0.024999,   MSE Z = 0.047243
# Test: MSE Total = 0.062683,   MSE X = 0.025977,   MSE Z = 0.042174
#
#
# Train Epoch 76: MSE Total = 0.041492,   MSE X = 0.015290,   MSE Z = 0.034421
# Test: MSE Total = 0.067577,   MSE X = 0.027947,   MSE Z = 0.045665
#
#
# Train Epoch 77: MSE Total = 0.066357,   MSE X = 0.026967,   MSE Z = 0.046463
# Test: MSE Total = 0.077941,   MSE X = 0.033063,   MSE Z = 0.049830
#
#
# Train Epoch 78: MSE Total = 0.048181,   MSE X = 0.018189,   MSE Z = 0.038486
# Test: MSE Total = 0.069072,   MSE X = 0.029025,   MSE Z = 0.045103
#
#
# Train Epoch 79: MSE Total = 0.037424,   MSE X = 0.013788,   MSE Z = 0.031055
# Test: MSE Total = 0.064265,   MSE X = 0.027969,   MSE Z = 0.038671
#
#
# Train Epoch 80: MSE Total = 0.034707,   MSE X = 0.012901,   MSE Z = 0.028413
# Test: MSE Total = 0.063902,   MSE X = 0.026632,   MSE Z = 0.042479
#
#
# Train Epoch 81: MSE Total = 0.036556,   MSE X = 0.013758,   MSE Z = 0.029346
# Test: MSE Total = 0.047340,   MSE X = 0.019297,   MSE Z = 0.032946
#
#
# Train Epoch 82: MSE Total = 0.027975,   MSE X = 0.009679,   MSE Z = 0.025358
# Test: MSE Total = 0.048282,   MSE X = 0.020178,   MSE Z = 0.031906
#
#
# Train Epoch 83: MSE Total = 0.028319,   MSE X = 0.010291,   MSE Z = 0.023985
# Test: MSE Total = 0.059606,   MSE X = 0.025115,   MSE Z = 0.038690
#
#
# Train Epoch 84: MSE Total = 0.029323,   MSE X = 0.010671,   MSE Z = 0.024787
# Test: MSE Total = 0.050955,   MSE X = 0.021718,   MSE Z = 0.032226
#
#
# Train Epoch 85: MSE Total = 0.025703,   MSE X = 0.009267,   MSE Z = 0.022021
# Test: MSE Total = 0.045154,   MSE X = 0.019252,   MSE Z = 0.028537
#
#
# Train Epoch 86: MSE Total = 0.037633,   MSE X = 0.014874,   MSE Z = 0.027782
# Test: MSE Total = 0.067323,   MSE X = 0.029527,   MSE Z = 0.039735
#
#
# Train Epoch 87: MSE Total = 0.048042,   MSE X = 0.019165,   MSE Z = 0.034862
# Test: MSE Total = 0.096126,   MSE X = 0.040622,   MSE Z = 0.061990
#
#
# Train Epoch 88: MSE Total = 0.103854,   MSE X = 0.044544,   MSE Z = 0.064730
# Test: MSE Total = 0.155327,   MSE X = 0.067346,   MSE Z = 0.094337
#
#
# Train Epoch 89: MSE Total = 0.090759,   MSE X = 0.038093,   MSE Z = 0.059420
# Test: MSE Total = 0.151322,   MSE X = 0.061377,   MSE Z = 0.106359
#
#
# Train Epoch 90: MSE Total = 0.095671,   MSE X = 0.040113,   MSE Z = 0.062777
# Test: MSE Total = 0.065821,   MSE X = 0.027796,   MSE Z = 0.042512
#
#
# Train Epoch 91: MSE Total = 0.044967,   MSE X = 0.017419,   MSE Z = 0.034403
# Test: MSE Total = 0.159435,   MSE X = 0.071216,   MSE Z = 0.089700
#
#
# Train Epoch 92: MSE Total = 0.057206,   MSE X = 0.022813,   MSE Z = 0.041542
# Test: MSE Total = 0.060929,   MSE X = 0.025659,   MSE Z = 0.039595
#
#
# Train Epoch 93: MSE Total = 0.069603,   MSE X = 0.030779,   MSE Z = 0.040222
# Test: MSE Total = 0.138056,   MSE X = 0.061894,   MSE Z = 0.076892
#
#
# Train Epoch 94: MSE Total = 0.069467,   MSE X = 0.029199,   MSE Z = 0.045332
# Test: MSE Total = 0.052240,   MSE X = 0.022233,   MSE Z = 0.033152
#
#
# Train Epoch 95: MSE Total = 0.028700,   MSE X = 0.010215,   MSE Z = 0.025040
# Test: MSE Total = 0.049260,   MSE X = 0.020339,   MSE Z = 0.033400
#
#
# Train Epoch 96: MSE Total = 0.023364,   MSE X = 0.008262,   MSE Z = 0.020569
# Test: MSE Total = 0.043645,   MSE X = 0.018188,   MSE Z = 0.029018
#
#
# Train Epoch 97: MSE Total = 0.022596,   MSE X = 0.007948,   MSE Z = 0.020038
# Test: MSE Total = 0.043261,   MSE X = 0.018553,   MSE Z = 0.026970
#
#
# Train Epoch 98: MSE Total = 0.020237,   MSE X = 0.006928,   MSE Z = 0.018595
# Test: MSE Total = 0.042629,   MSE X = 0.017986,   MSE Z = 0.027588
#
#
# Train Epoch 99: MSE Total = 0.019794,   MSE X = 0.006759,   MSE Z = 0.018247
# Test: MSE Total = 0.040979,   MSE X = 0.017002,   MSE Z = 0.027504
#
#
# Train Epoch 100: MSE Total = 0.020272,   MSE X = 0.007185,   MSE Z = 0.017792
# Test: MSE Total = 0.040650,   MSE X = 0.016758,   MSE Z = 0.027648
#
#
# Train Epoch 101: MSE Total = 0.018434,   MSE X = 0.006297,   MSE Z = 0.016986
# Test: MSE Total = 0.038055,   MSE X = 0.016141,   MSE Z = 0.024339
#
#
# Train Epoch 102: MSE Total = 0.017383,   MSE X = 0.005846,   MSE Z = 0.016333
# Test: MSE Total = 0.036673,   MSE X = 0.015550,   MSE Z = 0.023472
#
#
# Train Epoch 103: MSE Total = 0.016363,   MSE X = 0.005481,   MSE Z = 0.015448
# Test: MSE Total = 0.038961,   MSE X = 0.016932,   MSE Z = 0.023530
#
#
# Train Epoch 104: MSE Total = 0.018311,   MSE X = 0.006509,   MSE Z = 0.016007
# Test: MSE Total = 0.050750,   MSE X = 0.022620,   MSE Z = 0.028721
#
#
# Train Epoch 105: MSE Total = 0.019381,   MSE X = 0.006889,   MSE Z = 0.016942
# Test: MSE Total = 0.047836,   MSE X = 0.019855,   MSE Z = 0.032077
#
#
# Train Epoch 106: MSE Total = 0.019306,   MSE X = 0.006699,   MSE Z = 0.017432
# Test: MSE Total = 0.039227,   MSE X = 0.017055,   MSE Z = 0.023663
#
#
# Train Epoch 107: MSE Total = 0.021509,   MSE X = 0.007418,   MSE Z = 0.019578
# Test: MSE Total = 0.042601,   MSE X = 0.018663,   MSE Z = 0.025217
#
#
# Train Epoch 108: MSE Total = 0.017411,   MSE X = 0.006101,   MSE Z = 0.015520
# Test: MSE Total = 0.037356,   MSE X = 0.015954,   MSE Z = 0.023516
#
#
# Train Epoch 109: MSE Total = 0.025323,   MSE X = 0.009426,   MSE Z = 0.020686
# Test: MSE Total = 0.061926,   MSE X = 0.026193,   MSE Z = 0.039853
#
#
# Train Epoch 110: MSE Total = 0.039076,   MSE X = 0.015098,   MSE Z = 0.030031
# Test: MSE Total = 0.063578,   MSE X = 0.026775,   MSE Z = 0.041314
#
#
# Train Epoch 111: MSE Total = 0.033865,   MSE X = 0.013447,   MSE Z = 0.024790
# Test: MSE Total = 0.042807,   MSE X = 0.018218,   MSE Z = 0.027166
#
#
# Train Epoch 112: MSE Total = 0.023371,   MSE X = 0.009307,   MSE Z = 0.017015
# Test: MSE Total = 0.037411,   MSE X = 0.016027,   MSE Z = 0.023382
#
#
# Train Epoch 113: MSE Total = 0.017343,   MSE X = 0.005966,   MSE Z = 0.015839
# Test: MSE Total = 0.039443,   MSE X = 0.016661,   MSE Z = 0.025459
#
#
# Train Epoch 114: MSE Total = 0.018925,   MSE X = 0.006569,   MSE Z = 0.017082
# Test: MSE Total = 0.072706,   MSE X = 0.031262,   MSE Z = 0.045049
#
#
# Train Epoch 115: MSE Total = 0.121329,   MSE X = 0.051359,   MSE Z = 0.077946
# Test: MSE Total = 0.193133,   MSE X = 0.089019,   MSE Z = 0.099265
#
#
# Train Epoch 116: MSE Total = 0.106769,   MSE X = 0.045650,   MSE Z = 0.067039
# Test: MSE Total = 0.087420,   MSE X = 0.039553,   MSE Z = 0.047461
#
#
# Train Epoch 117: MSE Total = 0.040338,   MSE X = 0.015571,   MSE Z = 0.031052
# Test: MSE Total = 0.048233,   MSE X = 0.020505,   MSE Z = 0.030685
#
#
# Train Epoch 118: MSE Total = 0.023599,   MSE X = 0.008487,   MSE Z = 0.020291
# Test: MSE Total = 0.037977,   MSE X = 0.014855,   MSE Z = 0.028567
#
#
# Train Epoch 119: MSE Total = 0.075982,   MSE X = 0.032692,   MSE Z = 0.047008
# Test: MSE Total = 0.150418,   MSE X = 0.070985,   MSE Z = 0.071661
#
#
# Train Epoch 120: MSE Total = 0.091535,   MSE X = 0.039779,   MSE Z = 0.055279
# Test: MSE Total = 0.093354,   MSE X = 0.038930,   MSE Z = 0.061980
#
#
# Train Epoch 121: MSE Total = 0.043733,   MSE X = 0.017239,   MSE Z = 0.032444
# Test: MSE Total = 0.049775,   MSE X = 0.021399,   MSE Z = 0.030854
#
#
# Train Epoch 122: MSE Total = 0.024559,   MSE X = 0.009158,   MSE Z = 0.020004
# Test: MSE Total = 0.041156,   MSE X = 0.016229,   MSE Z = 0.030513
#
#
# Train Epoch 123: MSE Total = 0.027424,   MSE X = 0.010503,   MSE Z = 0.021394
# Test: MSE Total = 0.049021,   MSE X = 0.020737,   MSE Z = 0.031540
#
#
# Train Epoch 124: MSE Total = 0.023628,   MSE X = 0.008908,   MSE Z = 0.018916
# Test: MSE Total = 0.039596,   MSE X = 0.016504,   MSE Z = 0.026318
#
#
# Train Epoch 125: MSE Total = 0.018362,   MSE X = 0.006623,   MSE Z = 0.015721
# Test: MSE Total = 0.034865,   MSE X = 0.014069,   MSE Z = 0.024753
#
#
# Train Epoch 126: MSE Total = 0.016952,   MSE X = 0.006145,   MSE Z = 0.014410
# Test: MSE Total = 0.034140,   MSE X = 0.014738,   MSE Z = 0.020953
#
#
# Train Epoch 127: MSE Total = 0.014974,   MSE X = 0.005089,   MSE Z = 0.013888
# Test: MSE Total = 0.034429,   MSE X = 0.014763,   MSE Z = 0.021472
#
#
# Train Epoch 128: MSE Total = 0.017857,   MSE X = 0.006322,   MSE Z = 0.015695
# Test: MSE Total = 0.038380,   MSE X = 0.016566,   MSE Z = 0.023563
#
#
# Train Epoch 129: MSE Total = 0.015143,   MSE X = 0.005236,   MSE Z = 0.013736
# Test: MSE Total = 0.035818,   MSE X = 0.014341,   MSE Z = 0.025816
#
#
# Train Epoch 130: MSE Total = 0.016357,   MSE X = 0.005776,   MSE Z = 0.014427
# Test: MSE Total = 0.036814,   MSE X = 0.014795,   MSE Z = 0.026341
#
#
# Train Epoch 131: MSE Total = 0.013203,   MSE X = 0.004459,   MSE Z = 0.012341
# Test: MSE Total = 0.031725,   MSE X = 0.013165,   MSE Z = 0.021284
#
#
# Train Epoch 132: MSE Total = 0.012670,   MSE X = 0.004288,   MSE Z = 0.011811
# Test: MSE Total = 0.030611,   MSE X = 0.013158,   MSE Z = 0.018983
#
#
# Train Epoch 133: MSE Total = 0.019119,   MSE X = 0.007070,   MSE Z = 0.015777
# Test: MSE Total = 0.032617,   MSE X = 0.013046,   MSE Z = 0.023555
#
#
# Train Epoch 134: MSE Total = 0.015488,   MSE X = 0.005407,   MSE Z = 0.013873
# Test: MSE Total = 0.040750,   MSE X = 0.016739,   MSE Z = 0.027925
#
#
# Train Epoch 135: MSE Total = 0.041514,   MSE X = 0.016946,   MSE Z = 0.028811
# Test: MSE Total = 0.065076,   MSE X = 0.028270,   MSE Z = 0.039339
#
#
# Train Epoch 136: MSE Total = 0.029464,   MSE X = 0.011414,   MSE Z = 0.022541
# Test: MSE Total = 0.049498,   MSE X = 0.019976,   MSE Z = 0.035136
#
#
# Train Epoch 137: MSE Total = 0.019382,   MSE X = 0.007006,   MSE Z = 0.016546
# Test: MSE Total = 0.034729,   MSE X = 0.015243,   MSE Z = 0.020460
#
#
# Train Epoch 138: MSE Total = 0.014458,   MSE X = 0.005051,   MSE Z = 0.012939
# Test: MSE Total = 0.035389,   MSE X = 0.014082,   MSE Z = 0.025802
#
#
# Train Epoch 139: MSE Total = 0.016994,   MSE X = 0.006044,   MSE Z = 0.014845
# Test: MSE Total = 0.033332,   MSE X = 0.014042,   MSE Z = 0.021643
#
#
# Train Epoch 140: MSE Total = 0.012696,   MSE X = 0.004274,   MSE Z = 0.011915
# Test: MSE Total = 0.032679,   MSE X = 0.014429,   MSE Z = 0.018958
#
#
# Train Epoch 141: MSE Total = 0.019541,   MSE X = 0.007092,   MSE Z = 0.016583
# Test: MSE Total = 0.037224,   MSE X = 0.016175,   MSE Z = 0.022487
#
#
# Train Epoch 142: MSE Total = 0.015261,   MSE X = 0.005151,   MSE Z = 0.014276
# Test: MSE Total = 0.031046,   MSE X = 0.012663,   MSE Z = 0.021581
#
#
# Train Epoch 143: MSE Total = 0.018984,   MSE X = 0.007346,   MSE Z = 0.014552
# Test: MSE Total = 0.061928,   MSE X = 0.028083,   MSE Z = 0.033403
#
#
# Train Epoch 144: MSE Total = 0.026943,   MSE X = 0.010186,   MSE Z = 0.021471
# Test: MSE Total = 0.038574,   MSE X = 0.015676,   MSE Z = 0.027011
#
#
# Train Epoch 145: MSE Total = 0.015809,   MSE X = 0.005507,   MSE Z = 0.014202
# Test: MSE Total = 0.032128,   MSE X = 0.013430,   MSE Z = 0.021219
#
#
# Train Epoch 146: MSE Total = 0.012973,   MSE X = 0.004500,   MSE Z = 0.011720
# Test: MSE Total = 0.031070,   MSE X = 0.012245,   MSE Z = 0.023059
#
#
# Train Epoch 147: MSE Total = 0.013186,   MSE X = 0.004434,   MSE Z = 0.012391
# Test: MSE Total = 0.026935,   MSE X = 0.010748,   MSE Z = 0.019534
#
#
# Train Epoch 148: MSE Total = 0.012337,   MSE X = 0.004181,   MSE Z = 0.011481
# Test: MSE Total = 0.028348,   MSE X = 0.011766,   MSE Z = 0.019009
#
#
# Train Epoch 149: MSE Total = 0.013236,   MSE X = 0.004527,   MSE Z = 0.012176
# Test: MSE Total = 0.031071,   MSE X = 0.012799,   MSE Z = 0.021169
#
#
# Train Epoch 150: MSE Total = 0.011843,   MSE X = 0.004066,   MSE Z = 0.010843
# Test: MSE Total = 0.028949,   MSE X = 0.011761,   MSE Z = 0.020283
#
#
# Train Epoch 151: MSE Total = 0.065924,   MSE X = 0.027932,   MSE Z = 0.042264
# Test: MSE Total = 0.242104,   MSE X = 0.116607,   MSE Z = 0.107302
#
#
# Train Epoch 152: MSE Total = 0.146008,   MSE X = 0.066884,   MSE Z = 0.076458
# Test: MSE Total = 0.078221,   MSE X = 0.034845,   MSE Z = 0.044330
#
#
# Train Epoch 153: MSE Total = 0.035925,   MSE X = 0.013732,   MSE Z = 0.028117
# Test: MSE Total = 0.037530,   MSE X = 0.015303,   MSE Z = 0.026103
#
#
# Train Epoch 154: MSE Total = 0.021369,   MSE X = 0.007873,   MSE Z = 0.017735
# Test: MSE Total = 0.035200,   MSE X = 0.014702,   MSE Z = 0.023292
#
#
# Train Epoch 155: MSE Total = 0.015731,   MSE X = 0.005568,   MSE Z = 0.013833
# Test: MSE Total = 0.035164,   MSE X = 0.015178,   MSE Z = 0.021589
#
#
# Train Epoch 156: MSE Total = 0.013944,   MSE X = 0.004781,   MSE Z = 0.012789
# Test: MSE Total = 0.027629,   MSE X = 0.011724,   MSE Z = 0.017652
#
#
# Train Epoch 157: MSE Total = 0.013901,   MSE X = 0.004952,   MSE Z = 0.012114
# Test: MSE Total = 0.036377,   MSE X = 0.014610,   MSE Z = 0.026062
#
#
# Train Epoch 158: MSE Total = 0.012781,   MSE X = 0.004377,   MSE Z = 0.011740
# Test: MSE Total = 0.032242,   MSE X = 0.014216,   MSE Z = 0.018772
#
#
# Train Epoch 159: MSE Total = 0.014668,   MSE X = 0.004998,   MSE Z = 0.013558
# Test: MSE Total = 0.031192,   MSE X = 0.013170,   MSE Z = 0.020153
#
#
# Train Epoch 160: MSE Total = 0.017377,   MSE X = 0.006420,   MSE Z = 0.014357
# Test: MSE Total = 0.033210,   MSE X = 0.013381,   MSE Z = 0.023647
#
#
# Train Epoch 161: MSE Total = 0.012265,   MSE X = 0.004207,   MSE Z = 0.011244
# Test: MSE Total = 0.027309,   MSE X = 0.011767,   MSE Z = 0.016838
#
#
# Train Epoch 162: MSE Total = 0.010404,   MSE X = 0.003537,   MSE Z = 0.009644
# Test: MSE Total = 0.026524,   MSE X = 0.011338,   MSE Z = 0.016662
#
#
# Train Epoch 163: MSE Total = 0.012006,   MSE X = 0.004246,   MSE Z = 0.010567
# Test: MSE Total = 0.027806,   MSE X = 0.011971,   MSE Z = 0.017179
#
#
# Train Epoch 164: MSE Total = 0.011784,   MSE X = 0.004089,   MSE Z = 0.010643
# Test: MSE Total = 0.028758,   MSE X = 0.011717,   MSE Z = 0.020034
#
#
# Train Epoch 165: MSE Total = 0.010877,   MSE X = 0.003552,   MSE Z = 0.010579
# Test: MSE Total = 0.026853,   MSE X = 0.011382,   MSE Z = 0.017201
#
#
# Train Epoch 166: MSE Total = 0.009535,   MSE X = 0.003180,   MSE Z = 0.009051
# Test: MSE Total = 0.024388,   MSE X = 0.009946,   MSE Z = 0.016956
#
#
# Train Epoch 167: MSE Total = 0.009178,   MSE X = 0.002996,   MSE Z = 0.008932
# Test: MSE Total = 0.028292,   MSE X = 0.011719,   MSE Z = 0.019055
#
#
# Train Epoch 168: MSE Total = 0.009215,   MSE X = 0.003043,   MSE Z = 0.008850
# Test: MSE Total = 0.023478,   MSE X = 0.009933,   MSE Z = 0.015100
#
#
# Train Epoch 169: MSE Total = 0.008994,   MSE X = 0.003015,   MSE Z = 0.008485
# Test: MSE Total = 0.024329,   MSE X = 0.010179,   MSE Z = 0.016039
#
#
# Train Epoch 170: MSE Total = 0.008946,   MSE X = 0.002976,   MSE Z = 0.008515
# Test: MSE Total = 0.025036,   MSE X = 0.010300,   MSE Z = 0.017100
#
#
# Train Epoch 171: MSE Total = 0.008950,   MSE X = 0.002979,   MSE Z = 0.008515
# Test: MSE Total = 0.023994,   MSE X = 0.010289,   MSE Z = 0.014965
#
#
# Train Epoch 172: MSE Total = 0.055110,   MSE X = 0.023815,   MSE Z = 0.033741
# Test: MSE Total = 0.138837,   MSE X = 0.062570,   MSE Z = 0.076216
#
#
# Train Epoch 173: MSE Total = 0.136813,   MSE X = 0.061078,   MSE Z = 0.077086
# Test: MSE Total = 0.160633,   MSE X = 0.074572,   MSE Z = 0.080739
#
#
# Train Epoch 174: MSE Total = 0.098107,   MSE X = 0.042334,   MSE Z = 0.060279
# Test: MSE Total = 0.077067,   MSE X = 0.032413,   MSE Z = 0.050224
#
#
# Train Epoch 175: MSE Total = 0.037671,   MSE X = 0.014524,   MSE Z = 0.029060
# Test: MSE Total = 0.054466,   MSE X = 0.023010,   MSE Z = 0.035147
#
#
# Train Epoch 176: MSE Total = 0.068074,   MSE X = 0.028430,   MSE Z = 0.045052
# Test: MSE Total = 0.045598,   MSE X = 0.018953,   MSE Z = 0.030483
#
#
# Train Epoch 177: MSE Total = 0.025107,   MSE X = 0.008960,   MSE Z = 0.021827
# Test: MSE Total = 0.036880,   MSE X = 0.015880,   MSE Z = 0.022775
#
#
# Train Epoch 178: MSE Total = 0.015328,   MSE X = 0.005326,   MSE Z = 0.013817
# Test: MSE Total = 0.033198,   MSE X = 0.014159,   MSE Z = 0.020965
#
#
# Train Epoch 179: MSE Total = 0.013802,   MSE X = 0.004713,   MSE Z = 0.012723
# Test: MSE Total = 0.034720,   MSE X = 0.014975,   MSE Z = 0.021355
#
#
# Train Epoch 180: MSE Total = 0.014393,   MSE X = 0.005007,   MSE Z = 0.012952
# Test: MSE Total = 0.029181,   MSE X = 0.012278,   MSE Z = 0.019001
#
#
# Train Epoch 181: MSE Total = 0.012583,   MSE X = 0.004341,   MSE Z = 0.011450
# Test: MSE Total = 0.030139,   MSE X = 0.012409,   MSE Z = 0.020553
#
#
# Train Epoch 182: MSE Total = 0.010225,   MSE X = 0.003406,   MSE Z = 0.009717
# Test: MSE Total = 0.027929,   MSE X = 0.011858,   MSE Z = 0.017820
#
#
# Train Epoch 183: MSE Total = 0.010655,   MSE X = 0.003466,   MSE Z = 0.010412
# Test: MSE Total = 0.027765,   MSE X = 0.011992,   MSE Z = 0.017021
#
#
# Train Epoch 184: MSE Total = 0.009797,   MSE X = 0.003235,   MSE Z = 0.009408
# Test: MSE Total = 0.027826,   MSE X = 0.012221,   MSE Z = 0.016365
#
#
# Train Epoch 185: MSE Total = 0.008851,   MSE X = 0.002928,   MSE Z = 0.008481
# Test: MSE Total = 0.027714,   MSE X = 0.011815,   MSE Z = 0.017519
#
#
# Train Epoch 186: MSE Total = 0.009309,   MSE X = 0.003129,   MSE Z = 0.008754
# Test: MSE Total = 0.031779,   MSE X = 0.013392,   MSE Z = 0.020621
#
#
# Train Epoch 187: MSE Total = 0.011502,   MSE X = 0.004057,   MSE Z = 0.010161
# Test: MSE Total = 0.026612,   MSE X = 0.011746,   MSE Z = 0.015454
#
#
# Train Epoch 188: MSE Total = 0.009267,   MSE X = 0.003227,   MSE Z = 0.008331
# Test: MSE Total = 0.026301,   MSE X = 0.011348,   MSE Z = 0.016164
#
#
# Train Epoch 189: MSE Total = 0.008895,   MSE X = 0.003015,   MSE Z = 0.008277
# Test: MSE Total = 0.025523,   MSE X = 0.010788,   MSE Z = 0.016450
#
#
# Train Epoch 190: MSE Total = 0.008374,   MSE X = 0.002757,   MSE Z = 0.008070
# Test: MSE Total = 0.024784,   MSE X = 0.010735,   MSE Z = 0.015089
#
#
# Train Epoch 191: MSE Total = 0.008335,   MSE X = 0.002805,   MSE Z = 0.007826
# Test: MSE Total = 0.027378,   MSE X = 0.011895,   MSE Z = 0.016542
#
#
# Train Epoch 192: MSE Total = 0.007856,   MSE X = 0.002578,   MSE Z = 0.007599
# Test: MSE Total = 0.028629,   MSE X = 0.012459,   MSE Z = 0.017231
#
#
# Train Epoch 193: MSE Total = 0.007887,   MSE X = 0.002571,   MSE Z = 0.007689
# Test: MSE Total = 0.023314,   MSE X = 0.009931,   MSE Z = 0.014766
#
#
# Train Epoch 194: MSE Total = 0.007653,   MSE X = 0.002537,   MSE Z = 0.007315
# Test: MSE Total = 0.027403,   MSE X = 0.011883,   MSE Z = 0.016637
#
#
# Train Epoch 195: MSE Total = 0.008468,   MSE X = 0.002761,   MSE Z = 0.008253
# Test: MSE Total = 0.026019,   MSE X = 0.011414,   MSE Z = 0.015349
#
#
# Train Epoch 196: MSE Total = 0.007730,   MSE X = 0.002593,   MSE Z = 0.007287
# Test: MSE Total = 0.026701,   MSE X = 0.012001,   MSE Z = 0.014770
#
#
# Train Epoch 197: MSE Total = 0.008402,   MSE X = 0.002796,   MSE Z = 0.007994
# Test: MSE Total = 0.027716,   MSE X = 0.012609,   MSE Z = 0.014811
#
#
# Train Epoch 198: MSE Total = 0.008998,   MSE X = 0.003070,   MSE Z = 0.008304
# Test: MSE Total = 0.030629,   MSE X = 0.013451,   MSE Z = 0.018018
#
#
# Train Epoch 199: MSE Total = 0.008699,   MSE X = 0.002997,   MSE Z = 0.007928
# Test: MSE Total = 0.026208,   MSE X = 0.011410,   MSE Z = 0.015759
#
#
# Train Epoch 200: MSE Total = 0.075447,   MSE X = 0.033467,   MSE Z = 0.043243
# Test: MSE Total = 0.189541,   MSE X = 0.087898,   MSE Z = 0.095592
#
#
# Got the weights of the epoch 193
# Execution time: 34 minutes, 45.51 seconds

# %%
torch.save(model.state_dict(), "model_weights_step2")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              num_layers=num_layers).to(device=device)
model.load_state_dict(torch.load("model_weights_step2"))

model.eval()
batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch, pc_emb_batch = batch  # estrae passato, futuro e embedding della point-cloud dal batch

# seleziona tre esempi diversi dal batch
indices = [14, 20, 32, 35, 40, 50]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i], pc_emb_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future, pc_emb) in enumerate(examples):
    
    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    pc_emb_tensor = pc_emb_batch[indices[i]].unsqueeze(0).to(device)
    with torch.no_grad():
        predicted_future = model(past_tensor, pc_emb_tensor).squeeze(0).cpu().detach().numpy() # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()
