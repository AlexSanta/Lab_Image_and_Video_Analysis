# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split

# %%
folder_path = "samples_data"
batch_size = 64
epochs = 1000
lr = 0.001
num_layers = 3
hidden_size= 256
input_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, past_seconds=2, future_seconds=4, framerate=10):
        self.folder_path = folder_path
        self.npz_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds

    def __len__(self):
        return len(self.npz_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32) 

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        #past_trajectory = torch.flip(past_trajectory, [0])
        
        # Normalizza i punti in modo che il punto corrente dove si trova la macchina corrisponda a (0, 0)
        '''
        shift = past_trajectory[-1, :].clone()
        past_trajectory = past_trajectory - shift
        future_trajectory = future_trajectory - shift
        '''

        return past_trajectory, future_trajectory

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2*40, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        _, h = self.gru(x, h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                                 # sequenza ed ha quindi dimensione [batch_size, seq_length, hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        last_hidden = h[-1]  # [batch_size, hidden_size]
        future_points = self.fc(last_hidden)  # [batch_size, 2*future_steps]
        future_points = future_points.view(x.size(0), self.future_steps, self.input_size)
             
        return future_points

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_variance, global_z_variance):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    if (epoch==1 or epoch%5 == 0):
        print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_variance, global_z_variance):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_variance**0.5
    lambda_z = 1./global_z_variance**0.5
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(100, epochs + 1, 100)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(100, epochs + 1, 100)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(100, epochs + 1, 100)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                         framerate=framerate)

generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_size = int(0.75 * len(dataset))

train_set = Subset(dataset, list(range(train_size)))
test_set = Subset(dataset, list(range(train_size, len(dataset))))
'''
train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
#Calcolo della varianza globale di x e di z

all_x_values = []
all_z_values = []

for past, future in train_set + test_set:
    all_x_values.append(past[:, 0])
    all_x_values.append(future[:, 0])
    all_z_values.append(past[:, 1])
    all_z_values.append(future[:, 1])

# concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

print(f"Global variance of the x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the x-coordinate: 0.37383729219436646
# Global variance of the z-coordinate: 4.3598480224609375

# %%
batch = next(iter(test_loader))  # Prendi un batch dal test_loader
past_batch, future_batch = batch

for points in past_batch:
    print(points.shape)
    print(points[0])


for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=input_size * 40, 
              num_layers=num_layers).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = 1000

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_variance, global_z_variance)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_variance, global_z_variance)
    if(epoch==1 or epoch%5 == 0):
        print(f'Test: MSE Total = {test_loss_total:.6f},   MSE X = {test_loss_x:.6f},   MSE Z = {test_loss_z:.6f}')
        print("\n")

    '''
    if(epoch!=1 and test_loss_total - test_losses_total[-1] > 0.6): 
        model.load_state_dict(best_weights)
        print(f"Early stopping applied! Got the weights of the epoch {best_epoch}")
        break
    '''

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.229515,   MSE X = 0.557986,   MSE Z = 0.661719
# Test: MSE Total = 1.027459,   MSE X = 0.551971,   MSE Z = 0.260363
#
#
# Train Epoch 5: MSE Total = 1.037467,   MSE X = 0.554683,   MSE Z = 0.272000
# Test: MSE Total = 1.058344,   MSE X = 0.570841,   MSE Z = 0.260409
#
#
# Train Epoch 10: MSE Total = 1.037367,   MSE X = 0.555211,   MSE Z = 0.269986
# Test: MSE Total = 1.071242,   MSE X = 0.574392,   MSE Z = 0.275216
#
#
# Train Epoch 15: MSE Total = 1.041648,   MSE X = 0.557586,   MSE Z = 0.270814
# Test: MSE Total = 1.024661,   MSE X = 0.549934,   MSE Z = 0.261476
#
#
# Train Epoch 20: MSE Total = 0.892770,   MSE X = 0.468703,   MSE Z = 0.263492
# Test: MSE Total = 0.657275,   MSE X = 0.327543,   MSE Z = 0.253837
#
#
# Train Epoch 25: MSE Total = 0.563729,   MSE X = 0.268131,   MSE Z = 0.261405
# Test: MSE Total = 0.515559,   MSE X = 0.243243,   MSE Z = 0.245818
#
#
# Train Epoch 30: MSE Total = 0.520058,   MSE X = 0.250100,   MSE Z = 0.231794
# Test: MSE Total = 0.481772,   MSE X = 0.237308,   MSE Z = 0.195537
#
#
# Train Epoch 35: MSE Total = 0.475385,   MSE X = 0.235220,   MSE Z = 0.189333
# Test: MSE Total = 0.484637,   MSE X = 0.246198,   MSE Z = 0.171161
#
#
# Train Epoch 40: MSE Total = 0.458284,   MSE X = 0.227672,   MSE Z = 0.179402
# Test: MSE Total = 0.428407,   MSE X = 0.213489,   MSE Z = 0.165453
#
#
# Train Epoch 45: MSE Total = 0.447496,   MSE X = 0.221778,   MSE Z = 0.177004
# Test: MSE Total = 0.423025,   MSE X = 0.210556,   MSE Z = 0.164233
#
#
# Train Epoch 50: MSE Total = 0.435646,   MSE X = 0.215272,   MSE Z = 0.174479
# Test: MSE Total = 0.413586,   MSE X = 0.206168,   MSE Z = 0.159509
#
#
# Train Epoch 55: MSE Total = 0.419423,   MSE X = 0.206463,   MSE Z = 0.170690
# Test: MSE Total = 0.399063,   MSE X = 0.197350,   MSE Z = 0.159297
#
#
# Train Epoch 60: MSE Total = 0.410498,   MSE X = 0.202870,   MSE Z = 0.164325
# Test: MSE Total = 0.392372,   MSE X = 0.194386,   MSE Z = 0.155450
#
#
# Train Epoch 65: MSE Total = 0.398282,   MSE X = 0.195688,   MSE Z = 0.163343
# Test: MSE Total = 0.392188,   MSE X = 0.196047,   MSE Z = 0.149393
#
#
# Train Epoch 70: MSE Total = 0.406625,   MSE X = 0.201105,   MSE Z = 0.162264
# Test: MSE Total = 0.389041,   MSE X = 0.187425,   MSE Z = 0.172264
#
#
# Train Epoch 75: MSE Total = 0.386524,   MSE X = 0.189450,   MSE Z = 0.160097
# Test: MSE Total = 0.382495,   MSE X = 0.189924,   MSE Z = 0.150064
#
#
# Train Epoch 80: MSE Total = 0.370806,   MSE X = 0.180495,   MSE Z = 0.157856
# Test: MSE Total = 0.373295,   MSE X = 0.181702,   MSE Z = 0.158932
#
#
# Train Epoch 85: MSE Total = 0.374780,   MSE X = 0.183366,   MSE Z = 0.156348
# Test: MSE Total = 0.367009,   MSE X = 0.180874,   MSE Z = 0.148636
#
#
# Train Epoch 90: MSE Total = 0.362197,   MSE X = 0.175411,   MSE Z = 0.157243
# Test: MSE Total = 0.377359,   MSE X = 0.188398,   MSE Z = 0.144551
#
#
# Train Epoch 95: MSE Total = 0.361536,   MSE X = 0.176375,   MSE Z = 0.152570
# Test: MSE Total = 0.355451,   MSE X = 0.175808,   MSE Z = 0.141802
#
#
# Train Epoch 100: MSE Total = 0.350811,   MSE X = 0.169993,   MSE Z = 0.151971
# Test: MSE Total = 0.347870,   MSE X = 0.171415,   MSE Z = 0.140976
#
#
# Train Epoch 105: MSE Total = 0.340551,   MSE X = 0.164165,   MSE Z = 0.150453
# Test: MSE Total = 0.351291,   MSE X = 0.174379,   MSE Z = 0.137994
#
#
# Train Epoch 110: MSE Total = 0.340345,   MSE X = 0.164191,   MSE Z = 0.149932
# Test: MSE Total = 0.349902,   MSE X = 0.171374,   MSE Z = 0.145355
#
#
# Train Epoch 115: MSE Total = 0.335138,   MSE X = 0.161721,   MSE Z = 0.147496
# Test: MSE Total = 0.333870,   MSE X = 0.163965,   MSE Z = 0.137182
#
#
# Train Epoch 120: MSE Total = 0.323027,   MSE X = 0.154859,   MSE Z = 0.145640
# Test: MSE Total = 0.320999,   MSE X = 0.156673,   MSE Z = 0.135211
#
#
# Train Epoch 125: MSE Total = 0.318938,   MSE X = 0.152709,   MSE Z = 0.144446
# Test: MSE Total = 0.314376,   MSE X = 0.152774,   MSE Z = 0.134696
#
#
# Train Epoch 130: MSE Total = 0.307370,   MSE X = 0.146287,   MSE Z = 0.142224
# Test: MSE Total = 0.320530,   MSE X = 0.156442,   MSE Z = 0.135021
#
#
# Train Epoch 135: MSE Total = 0.299724,   MSE X = 0.142621,   MSE Z = 0.138777
# Test: MSE Total = 0.346609,   MSE X = 0.171081,   MSE Z = 0.139481
#
#
# Train Epoch 140: MSE Total = 0.294303,   MSE X = 0.139596,   MSE Z = 0.137789
# Test: MSE Total = 0.313385,   MSE X = 0.152838,   MSE Z = 0.132409
#
#
# Train Epoch 145: MSE Total = 0.284992,   MSE X = 0.134260,   MSE Z = 0.136568
# Test: MSE Total = 0.295173,   MSE X = 0.140568,   MSE Z = 0.136287
#
#
# Train Epoch 150: MSE Total = 0.282326,   MSE X = 0.133214,   MSE Z = 0.134573
# Test: MSE Total = 0.286582,   MSE X = 0.137773,   MSE Z = 0.127890
#
#
# Train Epoch 155: MSE Total = 0.272126,   MSE X = 0.126667,   MSE Z = 0.135632
# Test: MSE Total = 0.290742,   MSE X = 0.140521,   MSE Z = 0.127191
#
#
# Train Epoch 160: MSE Total = 0.262883,   MSE X = 0.121981,   MSE Z = 0.132337
# Test: MSE Total = 0.301265,   MSE X = 0.146232,   MSE Z = 0.129662
#
#
# Train Epoch 165: MSE Total = 0.259236,   MSE X = 0.120126,   MSE Z = 0.131056
# Test: MSE Total = 0.291034,   MSE X = 0.137490,   MSE Z = 0.138153
#
#
# Train Epoch 170: MSE Total = 0.253524,   MSE X = 0.117108,   MSE Z = 0.129436
# Test: MSE Total = 0.272617,   MSE X = 0.127247,   MSE Z = 0.134681
#
#
# Train Epoch 175: MSE Total = 0.256893,   MSE X = 0.119450,   MSE Z = 0.128474
# Test: MSE Total = 0.267363,   MSE X = 0.127454,   MSE Z = 0.122999
#
#
# Train Epoch 180: MSE Total = 0.235105,   MSE X = 0.106788,   MSE Z = 0.126220
# Test: MSE Total = 0.267944,   MSE X = 0.128554,   MSE Z = 0.120457
#
#
# Train Epoch 185: MSE Total = 0.236215,   MSE X = 0.107766,   MSE Z = 0.125200
# Test: MSE Total = 0.314521,   MSE X = 0.154717,   MSE Z = 0.128365
#
#
# Train Epoch 190: MSE Total = 0.224153,   MSE X = 0.100233,   MSE Z = 0.125740
# Test: MSE Total = 0.264224,   MSE X = 0.125669,   MSE Z = 0.122544
#
#
# Train Epoch 195: MSE Total = 0.204687,   MSE X = 0.090193,   MSE Z = 0.119380
# Test: MSE Total = 0.249519,   MSE X = 0.118132,   MSE Z = 0.117579
#
#
# Train Epoch 200: MSE Total = 0.207077,   MSE X = 0.091360,   MSE Z = 0.120386
# Test: MSE Total = 0.238405,   MSE X = 0.110515,   MSE Z = 0.120383
#
#
# Train Epoch 205: MSE Total = 0.195357,   MSE X = 0.085336,   MSE Z = 0.116485
# Test: MSE Total = 0.232199,   MSE X = 0.107393,   MSE Z = 0.118088
#
#
# Train Epoch 210: MSE Total = 0.188475,   MSE X = 0.081141,   MSE Z = 0.116441
# Test: MSE Total = 0.237166,   MSE X = 0.111744,   MSE Z = 0.113601
#
#
# Train Epoch 215: MSE Total = 0.186580,   MSE X = 0.080679,   MSE Z = 0.114063
# Test: MSE Total = 0.212443,   MSE X = 0.096356,   MSE Z = 0.114527
#
#
# Train Epoch 220: MSE Total = 0.178667,   MSE X = 0.076965,   MSE Z = 0.110224
# Test: MSE Total = 0.223098,   MSE X = 0.104054,   MSE Z = 0.110489
#
#
# Train Epoch 225: MSE Total = 0.175696,   MSE X = 0.074848,   MSE Z = 0.111251
# Test: MSE Total = 0.212296,   MSE X = 0.097159,   MSE Z = 0.111479
#
#
# Train Epoch 230: MSE Total = 0.160796,   MSE X = 0.067256,   MSE Z = 0.106066
# Test: MSE Total = 0.213076,   MSE X = 0.099061,   MSE Z = 0.106611
#
#
# Train Epoch 235: MSE Total = 0.152305,   MSE X = 0.062675,   MSE Z = 0.103979
# Test: MSE Total = 0.219289,   MSE X = 0.101917,   MSE Z = 0.109833
#
#
# Train Epoch 240: MSE Total = 0.145523,   MSE X = 0.058990,   MSE Z = 0.102402
# Test: MSE Total = 0.202187,   MSE X = 0.089935,   MSE Z = 0.115040
#
#
# Train Epoch 245: MSE Total = 0.139666,   MSE X = 0.055858,   MSE Z = 0.100868
# Test: MSE Total = 0.185324,   MSE X = 0.082114,   MSE Z = 0.106538
#
#
# Train Epoch 250: MSE Total = 0.137784,   MSE X = 0.055544,   MSE Z = 0.098011
# Test: MSE Total = 0.184428,   MSE X = 0.082436,   MSE Z = 0.103569
#
#
# Train Epoch 255: MSE Total = 0.126763,   MSE X = 0.049519,   MSE Z = 0.095574
# Test: MSE Total = 0.178321,   MSE X = 0.079233,   MSE Z = 0.101756
#
#
# Train Epoch 260: MSE Total = 0.127545,   MSE X = 0.050124,   MSE Z = 0.095140
# Test: MSE Total = 0.182602,   MSE X = 0.081779,   MSE Z = 0.101998
#
#
# Train Epoch 265: MSE Total = 0.115850,   MSE X = 0.044392,   MSE Z = 0.090299
# Test: MSE Total = 0.168682,   MSE X = 0.074315,   MSE Z = 0.098425
#
#
# Train Epoch 270: MSE Total = 0.119231,   MSE X = 0.046479,   MSE Z = 0.090229
# Test: MSE Total = 0.164694,   MSE X = 0.072235,   MSE Z = 0.097200
#
#
# Train Epoch 275: MSE Total = 0.112557,   MSE X = 0.043247,   MSE Z = 0.087334
# Test: MSE Total = 0.163302,   MSE X = 0.071892,   MSE Z = 0.095466
#
#
# Train Epoch 280: MSE Total = 0.112082,   MSE X = 0.043590,   MSE Z = 0.085169
# Test: MSE Total = 0.191143,   MSE X = 0.087631,   MSE Z = 0.099848
#
#
# Train Epoch 285: MSE Total = 0.104498,   MSE X = 0.039882,   MSE Z = 0.081997
# Test: MSE Total = 0.162456,   MSE X = 0.070253,   MSE Z = 0.099296
#
#
# Train Epoch 290: MSE Total = 0.104364,   MSE X = 0.039244,   MSE Z = 0.083894
# Test: MSE Total = 0.157536,   MSE X = 0.067340,   MSE Z = 0.098972
#
#
# Train Epoch 295: MSE Total = 0.103422,   MSE X = 0.039610,   MSE Z = 0.080678
# Test: MSE Total = 0.163279,   MSE X = 0.071299,   MSE Z = 0.097441
#
#
# Train Epoch 300: MSE Total = 0.124820,   MSE X = 0.050947,   MSE Z = 0.086642
# Test: MSE Total = 0.159699,   MSE X = 0.071395,   MSE Z = 0.089639
#
#
# Train Epoch 305: MSE Total = 0.101953,   MSE X = 0.038401,   MSE Z = 0.081740
# Test: MSE Total = 0.147377,   MSE X = 0.063411,   MSE Z = 0.091175
#
#
# Train Epoch 310: MSE Total = 0.093203,   MSE X = 0.033978,   MSE Z = 0.078572
# Test: MSE Total = 0.160883,   MSE X = 0.069405,   MSE Z = 0.098906
#
#
# Train Epoch 315: MSE Total = 0.090342,   MSE X = 0.034116,   MSE Z = 0.072131
# Test: MSE Total = 0.145349,   MSE X = 0.062272,   MSE Z = 0.090830
#
#
# Train Epoch 320: MSE Total = 0.108118,   MSE X = 0.042656,   MSE Z = 0.080082
# Test: MSE Total = 0.165949,   MSE X = 0.070209,   MSE Z = 0.106742
#
#
# Train Epoch 325: MSE Total = 0.084141,   MSE X = 0.031186,   MSE Z = 0.069188
# Test: MSE Total = 0.138058,   MSE X = 0.057902,   MSE Z = 0.090529
#
#
# Train Epoch 330: MSE Total = 0.074844,   MSE X = 0.026932,   MSE Z = 0.064303
# Test: MSE Total = 0.153049,   MSE X = 0.068215,   MSE Z = 0.086614
#
#
# Train Epoch 335: MSE Total = 0.082822,   MSE X = 0.030756,   MSE Z = 0.067902
# Test: MSE Total = 0.146620,   MSE X = 0.064523,   MSE Z = 0.085799
#
#
# Train Epoch 340: MSE Total = 0.079240,   MSE X = 0.029458,   MSE Z = 0.064857
# Test: MSE Total = 0.136393,   MSE X = 0.058635,   MSE Z = 0.084551
#
#
# Train Epoch 345: MSE Total = 0.094595,   MSE X = 0.036627,   MSE Z = 0.072434
# Test: MSE Total = 0.164584,   MSE X = 0.074066,   MSE Z = 0.090716
#
#
# Train Epoch 350: MSE Total = 0.071648,   MSE X = 0.026574,   MSE Z = 0.058853
# Test: MSE Total = 0.141631,   MSE X = 0.061588,   MSE Z = 0.085405
#
#
# Train Epoch 355: MSE Total = 0.069204,   MSE X = 0.024614,   MSE Z = 0.060444
# Test: MSE Total = 0.140649,   MSE X = 0.061212,   MSE Z = 0.084638
#
#
# Train Epoch 360: MSE Total = 0.071833,   MSE X = 0.026170,   MSE Z = 0.060619
# Test: MSE Total = 0.139555,   MSE X = 0.061584,   MSE Z = 0.081081
#
#
# Train Epoch 365: MSE Total = 0.066254,   MSE X = 0.023848,   MSE Z = 0.056897
# Test: MSE Total = 0.129637,   MSE X = 0.056960,   MSE Z = 0.076166
#
#
# Train Epoch 370: MSE Total = 0.070275,   MSE X = 0.025627,   MSE Z = 0.059217
# Test: MSE Total = 0.128557,   MSE X = 0.055270,   MSE Z = 0.079682
#
#
# Train Epoch 375: MSE Total = 0.063395,   MSE X = 0.022879,   MSE Z = 0.054239
# Test: MSE Total = 0.134987,   MSE X = 0.059021,   MSE Z = 0.080298
#
#
# Train Epoch 380: MSE Total = 0.061958,   MSE X = 0.022563,   MSE Z = 0.052316
# Test: MSE Total = 0.129446,   MSE X = 0.056484,   MSE Z = 0.077394
#
#
# Train Epoch 385: MSE Total = 0.059960,   MSE X = 0.021314,   MSE Z = 0.052410
# Test: MSE Total = 0.136232,   MSE X = 0.058825,   MSE Z = 0.083568
#
#
# Train Epoch 390: MSE Total = 0.059491,   MSE X = 0.021315,   MSE Z = 0.051427
# Test: MSE Total = 0.127410,   MSE X = 0.055763,   MSE Z = 0.075602
#
#
# Train Epoch 395: MSE Total = 0.078464,   MSE X = 0.030991,   MSE Z = 0.058002
# Test: MSE Total = 0.138961,   MSE X = 0.060390,   MSE Z = 0.083919
#
#
# Train Epoch 400: MSE Total = 0.058953,   MSE X = 0.021141,   MSE Z = 0.050898
# Test: MSE Total = 0.130533,   MSE X = 0.057682,   MSE Z = 0.075571
#
#
# Train Epoch 405: MSE Total = 0.052338,   MSE X = 0.018463,   MSE Z = 0.046233
# Test: MSE Total = 0.124105,   MSE X = 0.053934,   MSE Z = 0.074946
#
#
# Train Epoch 410: MSE Total = 0.053403,   MSE X = 0.019074,   MSE Z = 0.046368
# Test: MSE Total = 0.123482,   MSE X = 0.052577,   MSE Z = 0.078282
#
#
# Train Epoch 415: MSE Total = 0.065252,   MSE X = 0.024678,   MSE Z = 0.051972
# Test: MSE Total = 0.136976,   MSE X = 0.061116,   MSE Z = 0.077297
#
#
# Train Epoch 420: MSE Total = 0.049946,   MSE X = 0.017604,   MSE Z = 0.044169
# Test: MSE Total = 0.131190,   MSE X = 0.056502,   MSE Z = 0.080971
#
#
# Train Epoch 425: MSE Total = 0.056508,   MSE X = 0.020936,   MSE Z = 0.046494
# Test: MSE Total = 0.119316,   MSE X = 0.051351,   MSE Z = 0.073770
#
#
# Train Epoch 430: MSE Total = 0.055190,   MSE X = 0.020606,   MSE Z = 0.044868
# Test: MSE Total = 0.122088,   MSE X = 0.051775,   MSE Z = 0.078111
#
#
# Train Epoch 435: MSE Total = 0.051169,   MSE X = 0.018523,   MSE Z = 0.043585
# Test: MSE Total = 0.117394,   MSE X = 0.050949,   MSE Z = 0.071130
#
#
# Train Epoch 440: MSE Total = 0.051487,   MSE X = 0.019132,   MSE Z = 0.042170
# Test: MSE Total = 0.126642,   MSE X = 0.055160,   MSE Z = 0.076057
#
#
# Train Epoch 445: MSE Total = 0.046976,   MSE X = 0.016578,   MSE Z = 0.041473
# Test: MSE Total = 0.120565,   MSE X = 0.053148,   MSE Z = 0.070241
#
#
# Train Epoch 450: MSE Total = 0.050622,   MSE X = 0.018220,   MSE Z = 0.043476
# Test: MSE Total = 0.116929,   MSE X = 0.050547,   MSE Z = 0.071530
#
#
# Train Epoch 455: MSE Total = 0.046365,   MSE X = 0.016700,   MSE Z = 0.039778
# Test: MSE Total = 0.113983,   MSE X = 0.050324,   MSE Z = 0.066142
#
#
# Train Epoch 460: MSE Total = 0.062393,   MSE X = 0.024214,   MSE Z = 0.047585
# Test: MSE Total = 0.117381,   MSE X = 0.051634,   MSE Z = 0.068760
#
#
# Train Epoch 465: MSE Total = 0.047025,   MSE X = 0.017528,   MSE Z = 0.038329
# Test: MSE Total = 0.117843,   MSE X = 0.051946,   MSE Z = 0.068660
#
#
# Train Epoch 470: MSE Total = 0.039359,   MSE X = 0.013525,   MSE Z = 0.035994
# Test: MSE Total = 0.113860,   MSE X = 0.050631,   MSE Z = 0.064837
#
#
# Train Epoch 475: MSE Total = 0.046017,   MSE X = 0.016623,   MSE Z = 0.039317
# Test: MSE Total = 0.116467,   MSE X = 0.050497,   MSE Z = 0.070736
#
#
# Train Epoch 480: MSE Total = 0.039306,   MSE X = 0.013668,   MSE Z = 0.035395
# Test: MSE Total = 0.111781,   MSE X = 0.049829,   MSE Z = 0.063232
#
#
# Train Epoch 485: MSE Total = 0.042337,   MSE X = 0.015346,   MSE Z = 0.035995
# Test: MSE Total = 0.112055,   MSE X = 0.048448,   MSE Z = 0.068523
#
#
# Train Epoch 490: MSE Total = 0.043080,   MSE X = 0.015465,   MSE Z = 0.037139
# Test: MSE Total = 0.108945,   MSE X = 0.048342,   MSE Z = 0.062389
#
#
# Train Epoch 495: MSE Total = 0.042620,   MSE X = 0.015061,   MSE Z = 0.037558
# Test: MSE Total = 0.112099,   MSE X = 0.049780,   MSE Z = 0.064067
#
#
# Train Epoch 500: MSE Total = 0.038968,   MSE X = 0.013191,   MSE Z = 0.036319
# Test: MSE Total = 0.108862,   MSE X = 0.047857,   MSE Z = 0.063873
#
#
# Train Epoch 505: MSE Total = 0.040366,   MSE X = 0.014588,   MSE Z = 0.034467
# Test: MSE Total = 0.120756,   MSE X = 0.053307,   MSE Z = 0.070097
#
#
# Train Epoch 510: MSE Total = 0.065728,   MSE X = 0.026637,   MSE Z = 0.046277
# Test: MSE Total = 0.118937,   MSE X = 0.052578,   MSE Z = 0.068788
#
#
# Train Epoch 515: MSE Total = 0.033757,   MSE X = 0.011747,   MSE Z = 0.030371
# Test: MSE Total = 0.112520,   MSE X = 0.048156,   MSE Z = 0.070492
#
#
# Train Epoch 520: MSE Total = 0.034948,   MSE X = 0.012246,   MSE Z = 0.031152
# Test: MSE Total = 0.108971,   MSE X = 0.048075,   MSE Z = 0.063359
#
#
# Train Epoch 525: MSE Total = 0.054187,   MSE X = 0.021154,   MSE Z = 0.040900
# Test: MSE Total = 0.148471,   MSE X = 0.068071,   MSE Z = 0.077544
#
#
# Train Epoch 530: MSE Total = 0.037232,   MSE X = 0.013035,   MSE Z = 0.033226
# Test: MSE Total = 0.113992,   MSE X = 0.051339,   MSE Z = 0.062695
#
#
# Train Epoch 535: MSE Total = 0.032191,   MSE X = 0.011098,   MSE Z = 0.029316
# Test: MSE Total = 0.111576,   MSE X = 0.050702,   MSE Z = 0.059824
#
#
# Train Epoch 540: MSE Total = 0.039965,   MSE X = 0.014429,   MSE Z = 0.034172
# Test: MSE Total = 0.133073,   MSE X = 0.060045,   MSE Z = 0.072805
#
#
# Train Epoch 545: MSE Total = 0.032741,   MSE X = 0.011385,   MSE Z = 0.029484
# Test: MSE Total = 0.114707,   MSE X = 0.051565,   MSE Z = 0.063417
#
#
# Train Epoch 550: MSE Total = 0.032224,   MSE X = 0.011551,   MSE Z = 0.027838
# Test: MSE Total = 0.113916,   MSE X = 0.051640,   MSE Z = 0.061507
#
#
# Train Epoch 555: MSE Total = 0.037434,   MSE X = 0.013539,   MSE Z = 0.031928
# Test: MSE Total = 0.114999,   MSE X = 0.051349,   MSE Z = 0.064763
#
#
# Train Epoch 560: MSE Total = 0.044623,   MSE X = 0.016286,   MSE Z = 0.037555
# Test: MSE Total = 0.114587,   MSE X = 0.051447,   MSE Z = 0.063568
#
#
# Train Epoch 565: MSE Total = 0.031334,   MSE X = 0.010866,   MSE Z = 0.028321
# Test: MSE Total = 0.112562,   MSE X = 0.050564,   MSE Z = 0.062356
#
#
# Train Epoch 570: MSE Total = 0.029989,   MSE X = 0.010404,   MSE Z = 0.027088
# Test: MSE Total = 0.109158,   MSE X = 0.048757,   MSE Z = 0.061418
#
#
# Train Epoch 575: MSE Total = 0.031507,   MSE X = 0.011075,   MSE Z = 0.027965
# Test: MSE Total = 0.106325,   MSE X = 0.047672,   MSE Z = 0.059206
#
#
# Train Epoch 580: MSE Total = 0.031676,   MSE X = 0.010703,   MSE Z = 0.029589
# Test: MSE Total = 0.113814,   MSE X = 0.051711,   MSE Z = 0.061051
#
#
# Train Epoch 585: MSE Total = 0.061334,   MSE X = 0.024861,   MSE Z = 0.043164
# Test: MSE Total = 0.116403,   MSE X = 0.052098,   MSE Z = 0.065138
#
#
# Train Epoch 590: MSE Total = 0.031552,   MSE X = 0.011405,   MSE Z = 0.026934
# Test: MSE Total = 0.108408,   MSE X = 0.047243,   MSE Z = 0.065022
#
#
# Train Epoch 595: MSE Total = 0.031346,   MSE X = 0.011164,   MSE Z = 0.027326
# Test: MSE Total = 0.109377,   MSE X = 0.049141,   MSE Z = 0.060565
#
#
# Train Epoch 600: MSE Total = 0.029138,   MSE X = 0.010122,   MSE Z = 0.026275
# Test: MSE Total = 0.105640,   MSE X = 0.047950,   MSE Z = 0.056829
#
#
# Train Epoch 605: MSE Total = 0.035640,   MSE X = 0.012789,   MSE Z = 0.030743
# Test: MSE Total = 0.106397,   MSE X = 0.047007,   MSE Z = 0.061629
#
#
# Train Epoch 610: MSE Total = 0.030612,   MSE X = 0.010634,   MSE Z = 0.027604
# Test: MSE Total = 0.104446,   MSE X = 0.046519,   MSE Z = 0.059221
#
#
# Train Epoch 615: MSE Total = 0.030461,   MSE X = 0.010725,   MSE Z = 0.026976
# Test: MSE Total = 0.104372,   MSE X = 0.046657,   MSE Z = 0.058595
#
#
# Train Epoch 620: MSE Total = 0.047387,   MSE X = 0.018667,   MSE Z = 0.035197
# Test: MSE Total = 0.112565,   MSE X = 0.050223,   MSE Z = 0.063525
#
#
# Train Epoch 625: MSE Total = 0.040100,   MSE X = 0.015883,   MSE Z = 0.029488
# Test: MSE Total = 0.143465,   MSE X = 0.068226,   MSE Z = 0.066563
#
#
# Train Epoch 630: MSE Total = 0.026426,   MSE X = 0.009053,   MSE Z = 0.024263
# Test: MSE Total = 0.105530,   MSE X = 0.047635,   MSE Z = 0.057675
#
#
# Train Epoch 635: MSE Total = 0.025318,   MSE X = 0.008646,   MSE Z = 0.023339
# Test: MSE Total = 0.107570,   MSE X = 0.048666,   MSE Z = 0.058413
#
#
# Train Epoch 640: MSE Total = 0.026230,   MSE X = 0.009235,   MSE Z = 0.023231
# Test: MSE Total = 0.100548,   MSE X = 0.045281,   MSE Z = 0.055310
#
#
# Train Epoch 645: MSE Total = 0.026378,   MSE X = 0.009194,   MSE Z = 0.023681
# Test: MSE Total = 0.100442,   MSE X = 0.044713,   MSE Z = 0.057027
#
#
# Train Epoch 650: MSE Total = 0.056441,   MSE X = 0.022759,   MSE Z = 0.040127
# Test: MSE Total = 0.116329,   MSE X = 0.050898,   MSE Z = 0.069079
#
#
# Train Epoch 655: MSE Total = 0.024878,   MSE X = 0.008635,   MSE Z = 0.022456
# Test: MSE Total = 0.103687,   MSE X = 0.045949,   MSE Z = 0.059584
#
#
# Train Epoch 660: MSE Total = 0.023993,   MSE X = 0.008232,   MSE Z = 0.021986
# Test: MSE Total = 0.099454,   MSE X = 0.044425,   MSE Z = 0.055951
#
#
# Train Epoch 665: MSE Total = 0.026340,   MSE X = 0.009300,   MSE Z = 0.023238
# Test: MSE Total = 0.106383,   MSE X = 0.048631,   MSE Z = 0.056056
#
#
# Train Epoch 670: MSE Total = 0.027479,   MSE X = 0.009670,   MSE Z = 0.024353
# Test: MSE Total = 0.112060,   MSE X = 0.050322,   MSE Z = 0.062135
#
#
# Train Epoch 675: MSE Total = 0.028364,   MSE X = 0.010208,   MSE Z = 0.024362
# Test: MSE Total = 0.104584,   MSE X = 0.047113,   MSE Z = 0.057484
#
#
# Train Epoch 680: MSE Total = 0.023278,   MSE X = 0.008173,   MSE Z = 0.020693
# Test: MSE Total = 0.102817,   MSE X = 0.046191,   MSE Z = 0.056942
#
#
# Train Epoch 685: MSE Total = 0.023277,   MSE X = 0.008157,   MSE Z = 0.020748
# Test: MSE Total = 0.102302,   MSE X = 0.045440,   MSE Z = 0.058430
#
#
# Train Epoch 690: MSE Total = 0.023788,   MSE X = 0.008184,   MSE Z = 0.021720
# Test: MSE Total = 0.096122,   MSE X = 0.042983,   MSE Z = 0.053919
#
#
# Train Epoch 695: MSE Total = 0.028175,   MSE X = 0.010225,   MSE Z = 0.023912
# Test: MSE Total = 0.100913,   MSE X = 0.044956,   MSE Z = 0.057182
#
#
# Train Epoch 700: MSE Total = 0.023625,   MSE X = 0.008171,   MSE Z = 0.021426
# Test: MSE Total = 0.095976,   MSE X = 0.042062,   MSE Z = 0.056759
#
#
# Train Epoch 705: MSE Total = 0.021785,   MSE X = 0.007632,   MSE Z = 0.019426
# Test: MSE Total = 0.097502,   MSE X = 0.043720,   MSE Z = 0.054281
#
#
# Train Epoch 710: MSE Total = 0.026491,   MSE X = 0.009393,   MSE Z = 0.023239
# Test: MSE Total = 0.102038,   MSE X = 0.045747,   MSE Z = 0.056830
#
#
# Train Epoch 715: MSE Total = 0.023141,   MSE X = 0.008116,   MSE Z = 0.020603
# Test: MSE Total = 0.099992,   MSE X = 0.044824,   MSE Z = 0.055711
#
#
# Train Epoch 720: MSE Total = 0.055143,   MSE X = 0.022544,   MSE Z = 0.038153
# Test: MSE Total = 0.129564,   MSE X = 0.059716,   MSE Z = 0.066600
#
#
# Train Epoch 725: MSE Total = 0.022475,   MSE X = 0.007856,   MSE Z = 0.020101
# Test: MSE Total = 0.097299,   MSE X = 0.043888,   MSE Z = 0.053283
#
#
# Train Epoch 730: MSE Total = 0.020311,   MSE X = 0.006904,   MSE Z = 0.018834
# Test: MSE Total = 0.100434,   MSE X = 0.044054,   MSE Z = 0.059262
#
#
# Train Epoch 735: MSE Total = 0.021709,   MSE X = 0.007645,   MSE Z = 0.019220
# Test: MSE Total = 0.102612,   MSE X = 0.046506,   MSE Z = 0.055439
#
#
# Train Epoch 740: MSE Total = 0.029963,   MSE X = 0.011000,   MSE Z = 0.024999
# Test: MSE Total = 0.105121,   MSE X = 0.047337,   MSE Z = 0.057839
#
#
# Train Epoch 745: MSE Total = 0.019701,   MSE X = 0.006817,   MSE Z = 0.017854
# Test: MSE Total = 0.101937,   MSE X = 0.046494,   MSE Z = 0.054070
#
#
# Train Epoch 750: MSE Total = 0.115159,   MSE X = 0.051031,   MSE Z = 0.066183
# Test: MSE Total = 0.136587,   MSE X = 0.062357,   MSE Z = 0.072247
#
#
# Train Epoch 755: MSE Total = 0.023002,   MSE X = 0.008097,   MSE Z = 0.020377
# Test: MSE Total = 0.108287,   MSE X = 0.050455,   MSE Z = 0.053801
#
#
# Train Epoch 760: MSE Total = 0.019858,   MSE X = 0.006858,   MSE Z = 0.018044
# Test: MSE Total = 0.099612,   MSE X = 0.045650,   MSE Z = 0.052097
#
#
# Train Epoch 765: MSE Total = 0.020480,   MSE X = 0.007216,   MSE Z = 0.018120
# Test: MSE Total = 0.098709,   MSE X = 0.044839,   MSE Z = 0.052982
#
#
# Train Epoch 770: MSE Total = 0.021391,   MSE X = 0.007393,   MSE Z = 0.019416
# Test: MSE Total = 0.105979,   MSE X = 0.049095,   MSE Z = 0.053627
#
#
# Train Epoch 775: MSE Total = 0.021426,   MSE X = 0.007595,   MSE Z = 0.018800
# Test: MSE Total = 0.100107,   MSE X = 0.045654,   MSE Z = 0.053117
#
#
# Train Epoch 780: MSE Total = 0.025787,   MSE X = 0.009421,   MSE Z = 0.021672
# Test: MSE Total = 0.107858,   MSE X = 0.049507,   MSE Z = 0.056143
#
#
# Train Epoch 785: MSE Total = 0.019367,   MSE X = 0.006789,   MSE Z = 0.017252
# Test: MSE Total = 0.102073,   MSE X = 0.047130,   MSE Z = 0.052180
#
#
# Train Epoch 790: MSE Total = 0.020390,   MSE X = 0.007090,   MSE Z = 0.018364
# Test: MSE Total = 0.105415,   MSE X = 0.048402,   MSE Z = 0.054816
#
#
# Train Epoch 795: MSE Total = 0.044096,   MSE X = 0.017712,   MSE Z = 0.031586
# Test: MSE Total = 0.116581,   MSE X = 0.053492,   MSE Z = 0.060749
#
#
# Train Epoch 800: MSE Total = 0.021420,   MSE X = 0.007818,   MSE Z = 0.018027
# Test: MSE Total = 0.102868,   MSE X = 0.045854,   MSE Z = 0.058200
#
#
# Train Epoch 805: MSE Total = 0.018492,   MSE X = 0.006374,   MSE Z = 0.016846
# Test: MSE Total = 0.100668,   MSE X = 0.045930,   MSE Z = 0.053346
#
#
# Train Epoch 810: MSE Total = 0.020299,   MSE X = 0.007203,   MSE Z = 0.017787
# Test: MSE Total = 0.104458,   MSE X = 0.047339,   MSE Z = 0.056448
#
#
# Train Epoch 815: MSE Total = 0.019003,   MSE X = 0.006744,   MSE Z = 0.016650
# Test: MSE Total = 0.097247,   MSE X = 0.044226,   MSE Z = 0.052020
#
#
# Train Epoch 820: MSE Total = 0.080827,   MSE X = 0.035332,   MSE Z = 0.048108
# Test: MSE Total = 0.193797,   MSE X = 0.091708,   MSE Z = 0.091466
#
#
# Train Epoch 825: MSE Total = 0.027289,   MSE X = 0.010455,   MSE Z = 0.021276
# Test: MSE Total = 0.103008,   MSE X = 0.045933,   MSE Z = 0.058220
#
#
# Train Epoch 830: MSE Total = 0.017946,   MSE X = 0.006273,   MSE Z = 0.016049
# Test: MSE Total = 0.101629,   MSE X = 0.046269,   MSE Z = 0.054193
#
#
# Train Epoch 835: MSE Total = 0.018985,   MSE X = 0.006659,   MSE Z = 0.016902
# Test: MSE Total = 0.102529,   MSE X = 0.046913,   MSE Z = 0.053874
#
#
# Train Epoch 840: MSE Total = 0.022341,   MSE X = 0.008240,   MSE Z = 0.018510
# Test: MSE Total = 0.101661,   MSE X = 0.045926,   MSE Z = 0.055433
#
#
# Train Epoch 845: MSE Total = 0.017085,   MSE X = 0.005897,   MSE Z = 0.015536
# Test: MSE Total = 0.101065,   MSE X = 0.046711,   MSE Z = 0.051508
#
#
# Train Epoch 850: MSE Total = 0.032302,   MSE X = 0.012751,   MSE Z = 0.023900
# Test: MSE Total = 0.113398,   MSE X = 0.051783,   MSE Z = 0.059939
#
#
# Train Epoch 855: MSE Total = 0.031489,   MSE X = 0.012005,   MSE Z = 0.024752
# Test: MSE Total = 0.106124,   MSE X = 0.047746,   MSE Z = 0.058537
#
#
# Train Epoch 860: MSE Total = 0.018097,   MSE X = 0.006316,   MSE Z = 0.016218
# Test: MSE Total = 0.102301,   MSE X = 0.047260,   MSE Z = 0.052213
#
#
# Train Epoch 865: MSE Total = 0.017593,   MSE X = 0.006150,   MSE Z = 0.015733
# Test: MSE Total = 0.098045,   MSE X = 0.044890,   MSE Z = 0.051418
#
#
# Train Epoch 870: MSE Total = 0.021312,   MSE X = 0.007346,   MSE Z = 0.019414
# Test: MSE Total = 0.097020,   MSE X = 0.044408,   MSE Z = 0.050926
#
#
# Train Epoch 875: MSE Total = 0.065869,   MSE X = 0.028410,   MSE Z = 0.040515
# Test: MSE Total = 0.113048,   MSE X = 0.051467,   MSE Z = 0.060286
#
#
# Train Epoch 880: MSE Total = 0.018569,   MSE X = 0.006682,   MSE Z = 0.015954
# Test: MSE Total = 0.099424,   MSE X = 0.045991,   MSE Z = 0.050540
#
#
# Train Epoch 885: MSE Total = 0.016654,   MSE X = 0.005798,   MSE Z = 0.014975
# Test: MSE Total = 0.099006,   MSE X = 0.045512,   MSE Z = 0.051303
#
#
# Train Epoch 890: MSE Total = 0.016952,   MSE X = 0.005834,   MSE Z = 0.015474
# Test: MSE Total = 0.100605,   MSE X = 0.047056,   MSE Z = 0.049367
#
#
# Train Epoch 895: MSE Total = 0.023083,   MSE X = 0.008415,   MSE Z = 0.019462
# Test: MSE Total = 0.106130,   MSE X = 0.048460,   MSE Z = 0.056110
#
#
# Train Epoch 900: MSE Total = 0.027542,   MSE X = 0.010261,   MSE Z = 0.022466
# Test: MSE Total = 0.104054,   MSE X = 0.047792,   MSE Z = 0.054056
#
#
# Train Epoch 905: MSE Total = 0.022043,   MSE X = 0.007990,   MSE Z = 0.018739
# Test: MSE Total = 0.105189,   MSE X = 0.048210,   MSE Z = 0.054998
#
#
# Train Epoch 910: MSE Total = 0.028777,   MSE X = 0.011188,   MSE Z = 0.021880
# Test: MSE Total = 0.125608,   MSE X = 0.059930,   MSE Z = 0.057611
#
#
# Train Epoch 915: MSE Total = 0.017318,   MSE X = 0.006048,   MSE Z = 0.015505
# Test: MSE Total = 0.098075,   MSE X = 0.044666,   MSE Z = 0.052248
#
#
# Train Epoch 920: MSE Total = 0.016056,   MSE X = 0.005623,   MSE Z = 0.014322
# Test: MSE Total = 0.100188,   MSE X = 0.046017,   MSE Z = 0.052044
#
#
# Train Epoch 925: MSE Total = 0.017154,   MSE X = 0.005937,   MSE Z = 0.015542
# Test: MSE Total = 0.099044,   MSE X = 0.045236,   MSE Z = 0.052325
#
#
# Train Epoch 930: MSE Total = 0.081373,   MSE X = 0.037141,   MSE Z = 0.043071
# Test: MSE Total = 0.233500,   MSE X = 0.107386,   MSE Z = 0.120827
#
#
# Train Epoch 935: MSE Total = 0.019745,   MSE X = 0.006865,   MSE Z = 0.017785
# Test: MSE Total = 0.104345,   MSE X = 0.048403,   MSE Z = 0.052579
#
#
# Train Epoch 940: MSE Total = 0.016455,   MSE X = 0.005778,   MSE Z = 0.014628
# Test: MSE Total = 0.102513,   MSE X = 0.046906,   MSE Z = 0.053865
#
#
# Train Epoch 945: MSE Total = 0.015862,   MSE X = 0.005295,   MSE Z = 0.015037
# Test: MSE Total = 0.101988,   MSE X = 0.047387,   MSE Z = 0.051128
#
#
# Train Epoch 950: MSE Total = 0.025000,   MSE X = 0.009506,   MSE Z = 0.019736
# Test: MSE Total = 0.106005,   MSE X = 0.047041,   MSE Z = 0.060694
#
#
# Train Epoch 955: MSE Total = 0.020522,   MSE X = 0.007627,   MSE Z = 0.016803
# Test: MSE Total = 0.106963,   MSE X = 0.048967,   MSE Z = 0.056118
#
#
# Train Epoch 960: MSE Total = 0.017363,   MSE X = 0.006144,   MSE Z = 0.015274
# Test: MSE Total = 0.099585,   MSE X = 0.045553,   MSE Z = 0.052370
#
#
# Train Epoch 965: MSE Total = 0.018054,   MSE X = 0.006546,   MSE Z = 0.015341
# Test: MSE Total = 0.104109,   MSE X = 0.047827,   MSE Z = 0.054050
#
#
# Train Epoch 970: MSE Total = 0.096522,   MSE X = 0.044705,   MSE Z = 0.048872
# Test: MSE Total = 0.173803,   MSE X = 0.083405,   MSE Z = 0.078074
#
#
# Train Epoch 975: MSE Total = 0.018170,   MSE X = 0.006497,   MSE Z = 0.015754
# Test: MSE Total = 0.101612,   MSE X = 0.046285,   MSE Z = 0.054103
#
#
# Train Epoch 980: MSE Total = 0.015483,   MSE X = 0.005529,   MSE Z = 0.013447
# Test: MSE Total = 0.097795,   MSE X = 0.045166,   MSE Z = 0.049955
#
#
# Train Epoch 985: MSE Total = 0.016278,   MSE X = 0.005751,   MSE Z = 0.014348
# Test: MSE Total = 0.099997,   MSE X = 0.046132,   MSE Z = 0.051253
#
#
# Train Epoch 990: MSE Total = 0.026505,   MSE X = 0.010471,   MSE Z = 0.019583
# Test: MSE Total = 0.143404,   MSE X = 0.066148,   MSE Z = 0.073534
#
#
# Train Epoch 995: MSE Total = 0.019944,   MSE X = 0.007256,   MSE Z = 0.016864
# Test: MSE Total = 0.104884,   MSE X = 0.048844,   MSE Z = 0.052199
#
#
# Train Epoch 1000: MSE Total = 0.015930,   MSE X = 0.005530,   MSE Z = 0.014377
# Test: MSE Total = 0.103052,   MSE X = 0.048157,   MSE Z = 0.050717
#
#
# Got the weights of the epoch 864
# Execution time: 39 minutes, 40.32 seconds

# %%
torch.save(model.state_dict(), "model_weights_step1_one_shot")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=input_size * 40, 
              num_layers=num_layers).to(device=device)
model.load_state_dict(torch.load("model_weights_step1_one_shot"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 256, num_layers=3, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=256, out_features=80, bias=True)
# )

# %%
batch = next(iter(test_loader)) # prende un batch dal test_loader
past_batch, future_batch = batch  # estrae passato e futuro dal batch

# seleziona tre esempi diversi dal batch
indices = [14, 20, 32, 35, 40, 50]  # indici di sei campioni
examples = [(past_batch[i], future_batch[i]) for i in indices]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future) in enumerate(examples):

    all_points = torch.cat((past, future), 0)
    past = past.cpu().numpy()
    future = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past_batch[indices[i]].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim
    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past[:, 0], past[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future[:, 0], future[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'Model performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, test_loader=test_loader)
# Out:
# Model performances on test set:
#
# ADE Total = 0.169767,   ADE X = 0.089670,   ADE Z = 0.125232
# FDE Total = 0.366202,   FDE X = 0.228258,   FDE Z = 0.241603
