# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, random_split

# %%
folder_path = "samples_data"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
epochs = 100
lr = 0.001
train_ratio = 0.75
num_layers = 2
hidden_size= 128
input_size = 2 #non si considera la y
past_seconds = 2
future_seconds = 4
framerate = 10

# %%
class CustomDataset(Dataset):
    def __init__(self, folder_path, past_seconds=2, future_seconds=4, framerate=10, train_ratio=0.75, mode='all'):
        self.folder_path = folder_path
        self.past_frames = framerate * past_seconds
        self.future_frames = framerate * future_seconds
        self.train_ratio = train_ratio
        self.mode = mode

        def extract_number(filename):
            return int(filename.split('_')[1].split('.')[0])

        all_files = [f for f in os.listdir(folder_path) if f.endswith('.npz')]
        all_files_sorted = sorted(all_files, key=extract_number)

        split_index = int(len(all_files_sorted) * train_ratio)

        if mode == "train":
            self.npz_files = all_files_sorted[:split_index]
        elif mode == "test":
            self.npz_files = all_files_sorted[split_index:]
        else:
            self.npz_files = all_files_sorted

    def __len__(self):
        return len(self.npz_files)
    
    def local_smoothing(self, future_traj, iterations=1):
        smoothed_traj = future_traj.clone()

        for _ in range(iterations):
            temp_traj = smoothed_traj.clone()

            prev_points = temp_traj[:-2]
            current_points = temp_traj[1:-1]
            next_points = temp_traj[2:]

            smoothed_traj[1:-1] = 0.25*prev_points + 0.5*current_points + 0.25*next_points   
        
        return smoothed_traj

    def __getitem__(self, idx):
        file_path = os.path.join(self.folder_path, self.npz_files[idx])
        data = np.load(file_path)

        # Converte i dati in tensori PyTorch
        past_trajectory = torch.tensor(np.delete(data["past_trajectory"], 1, 1), dtype=torch.float32)
        future_trajectory = torch.tensor(np.delete(data["future_trajectory"], 1, 1), dtype=torch.float32) 

        past_trajectory = past_trajectory[:self.past_frames]
        future_trajectory = future_trajectory[:self.future_frames]

        #past_trajectory = torch.flip(past_trajectory, [0])

        if(self.mode == "train"):
            if(np.random.rand() < 0.5):
                n_iterations = np.random.randint(1, 3)
                future_trajectory = self.local_smoothing(future_trajectory, iterations=n_iterations)

            if np.random.rand() < 0.5:
                # Flip orizzontale
                past_trajectory[:, 0] *= -1
                future_trajectory[:, 0] *= -1

        return past_trajectory, future_trajectory

# %%
class MyGRU(nn.Module):
    def __init__(self, input_size=2, hidden_size=256, output_size=2*40, num_layers=3, future_steps=40):
        super(MyGRU, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.future_steps = future_steps
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, dropout=0.3, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        _, h = self.gru(x, h0) # out contiene tutti gli hidden state (dell'ultimo layer della GRU) di tutta la 
                                 # sequenza ed ha quindi dimensione [batch_size, seq_length, hidden_dim]
                                 # h contiene l'ultimo hidden state della sequenza di ogni layer della GRU, ed ha dimensione
                                 # [num_layers, batch_size, hidden_dim]
        
        last_hidden = h[-1]  # [batch_size, hidden_size]
        future_points = self.fc(last_hidden)  # [batch_size, 2*future_steps]
        future_points = future_points.view(x.size(0), self.future_steps, self.input_size)
             
        return future_points

# %%
def train(model, device, train_loader, optimizer, epoch, global_x_std, global_z_std):
    model.train() # setta il modello in training mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    train_mse_x = 0
    train_mse_z = 0
    train_mse_total = 0
    total_samples = 0

    for past, future in train_loader: # iterazione sui batch
        past, future = past.to(device), future.to(device) #spostamento traiettoria passata e futura sulla GPU
        optimizer.zero_grad() #azzera i gradienti

        future_pred = model(past) #viene eseguito il forward

        #calcolo delle loss, con la somma per normalizzare
        loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum') # MSE su x
        loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum') # MSE su z
        loss_total = lambda_x * loss_x + lambda_z * loss_z   
        
        train_mse_x += loss_x.item()
        train_mse_z += loss_z.item()
        train_mse_total += loss_total.item()

        loss_total.backward() # calcola i gradienti
        optimizer.step() # aggiorna i pesi

        total_samples += future.size(0) * future.size(1)  # numero totale di punti della traiettoria

    # normalizzazione per ottenere la media
    train_mse_x /= total_samples
    train_mse_z /= total_samples
    train_mse_total /= total_samples

    print(f'Train Epoch {epoch}: MSE Total = {train_mse_total:.6f},   MSE X = {train_mse_x:.6f},   MSE Z = {train_mse_z:.6f}')
    
    return train_mse_total, train_mse_x, train_mse_z

# %%
def test(model, device, test_loader, global_x_std, global_z_std):
    model.eval() #setta il modello in evaluation mode
    
    lambda_x = 1./global_x_std
    lambda_z = 1./global_z_std
    
    test_mse_x, test_mse_z, test_mse_total = 0, 0, 0
    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            loss_x = F.mse_loss(future_pred[:, :, 0], future[:, :, 0], reduction='sum')  # MSE su x
            loss_z = F.mse_loss(future_pred[:, :, -1], future[:, :, -1], reduction='sum')  # MSE su z
            loss_total = lambda_x * loss_x + lambda_z * loss_z  
            
            test_mse_x += loss_x.item()
            test_mse_z += loss_z.item()
            test_mse_total += loss_total.item()

            total_samples += future.size(0) * future.size(1)

    # normalizzazione per ottenere la media
    test_mse_x /= total_samples
    test_mse_z /= total_samples
    test_mse_total /= total_samples

    print(f'Test: MSE Total = {test_mse_total:.6f},   MSE X = {test_mse_x:.6f},   MSE Z = {test_mse_z:.6f}')
    return test_mse_total, test_mse_x, test_mse_z

# %%
def plot_loss(epochs, train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, test_losses_z):
    _, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 riga, 3 colonne

    # Plot per la loss totale
    axes[0].plot(range(1, epochs + 1), train_losses_total, marker='o', color='red', label="Train Total loss")
    axes[0].plot(range(1, epochs + 1), test_losses_total, marker='o', color='blue', label="Test Total loss")
    axes[0].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].set_title('Total Loss')

    # Plot per la loss su X
    axes[1].plot(range(1, epochs + 1), train_losses_x, marker='o', color='red', label="Train X loss")
    axes[1].plot(range(1, epochs + 1), test_losses_x, marker='o', color='blue', label="Test X loss")
    axes[1].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].set_title('X Loss')

    # Plot per la loss su Z
    axes[2].plot(range(1, epochs + 1), train_losses_z, marker='o', color='red', label="Train Z loss")
    axes[2].plot(range(1, epochs + 1), test_losses_z, marker='o', color='blue', label="Test Z loss")
    axes[2].set_xticks([1] + list(range(10, epochs + 1, 10)))
    axes[2].set_xlabel('Epochs')
    axes[2].set_ylabel('Loss')
    axes[2].legend()
    axes[2].set_title('Z Loss')

    plt.tight_layout()  # Per evitare sovrapposizioni
    plt.show()

# %%
original_dataset = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                         framerate=framerate, mode="all")
'''
generator = torch.Generator().manual_seed(42) # per avere lo stesso split di train/test ad ogni esecuzione
train_set, test_set = random_split(dataset, [0.75, 0.25], generator=generator)
'''
train_set = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds, 
                        framerate=framerate, train_ratio=train_ratio, mode="train")

test_set = CustomDataset(folder_path=folder_path, past_seconds=past_seconds, future_seconds=future_seconds,
                        framerate=framerate, train_ratio=train_ratio, mode="test")

train_loader = DataLoader(train_set, num_workers=2, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, num_workers=2, batch_size=batch_size, shuffle=False)

# %%
#Calcolo della varianza e della deviazione standard globali di x e di z nel futuro

all_x_values = []
all_z_values = []

for past, future in original_dataset:
    all_x_values.append(future[:, 0])
    all_z_values.append(future[:, 1])

#Concatenazione di tutti i punti
all_x_values = torch.cat(all_x_values)
all_z_values = torch.cat(all_z_values)

global_x_variance = torch.var(all_x_values)
global_z_variance = torch.var(all_z_values)

global_x_std = global_x_variance ** 0.5
global_z_std = global_z_variance ** 0.5

print(f"Global variance of the future x-coordinate: {global_x_variance.item()}")
print(f"Global variance of the future z-coordinate: {global_z_variance.item()}")
# Out:
# Global variance of the future x-coordinate: 0.5187198519706726
# Global variance of the future z-coordinate: 2.072277069091797

# %%
batch = next(iter(test_loader))  # Prende un batch dal test_loader
past_batch, future_batch = batch
print(future_batch.shape)

for i in range(2):  # Plotta solo 2 esempi
    past = past_batch[i].numpy()
    future = future_batch[i].numpy()

    plt.figure(figsize=(5, 5))
    plt.plot(past[:, 0], past[:, 1], 'go-', label='Past Trajectory')
    plt.plot(future[:, 0], future[:, 1], 'ro-', label='Future Trajectory')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axvline(0, color='gray', linestyle='--')
    plt.legend()
    plt.title(f"Sample {i+1}")
    plt.show()

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=input_size*future_seconds*framerate, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

best_weights = copy.deepcopy(model.state_dict())
best_epoch = 0
best_test_loss = float("inf")

train_losses_x = []
train_losses_z = []
train_losses_total = []
test_losses_x = []
test_losses_z = []
test_losses_total = []

start_time = time.time()

for epoch in range(1, epochs + 1):
    #esegue un'epoca di training
    train_loss_total, train_loss_x, train_loss_z = train(model, device, train_loader, optimizer, epoch,
                                                         global_x_std, global_z_std)
    test_loss_total, test_loss_x, test_loss_z = test(model, device, test_loader, global_x_std, global_z_std)

    '''
    if(epoch!=1 and test_loss_total - test_losses_total[-1] > 0.6): 
        model.load_state_dict(best_weights)
        print(f"Early stopping applied! Got the weights of the epoch {best_epoch}")
        break
    '''

    if(test_loss_total < best_test_loss):
        best_epoch = epoch
        best_test_loss = test_loss_total
        best_weights = copy.deepcopy(model.state_dict()) 

    train_losses_total.append(train_loss_total)
    train_losses_x.append(train_loss_x)
    train_losses_z.append(train_loss_z)
    test_losses_total.append(test_loss_total)
    test_losses_x.append(test_loss_x)
    test_losses_z.append(test_loss_z)
    print("\n")

model.load_state_dict(best_weights)
print(f"Got the weights of the epoch {best_epoch}")

end_time = time.time()

execution_time = end_time - start_time

minutes, seconds = divmod(execution_time, 60) #converte il tempo in minuti e secondi

print(f"Execution time: {int(minutes)} minutes, {seconds:.2f} seconds")
# Out:
# Train Epoch 1: MSE Total = 1.956880,   MSE X = 0.556480,   MSE Z = 1.704747
# Test: MSE Total = 0.792237,   MSE X = 0.458455,   MSE Z = 0.224121
#
#
# Train Epoch 2: MSE Total = 0.954717,   MSE X = 0.552503,   MSE Z = 0.270041
# Test: MSE Total = 0.772236,   MSE X = 0.447880,   MSE Z = 0.216468
#
#
# Train Epoch 3: MSE Total = 0.954530,   MSE X = 0.553559,   MSE Z = 0.267661
# Test: MSE Total = 0.761290,   MSE X = 0.443331,   MSE Z = 0.209803
#
#
# Train Epoch 4: MSE Total = 0.953507,   MSE X = 0.552346,   MSE Z = 0.268613
# Test: MSE Total = 0.758271,   MSE X = 0.438595,   MSE Z = 0.214921
#
#
# Train Epoch 5: MSE Total = 0.951496,   MSE X = 0.551070,   MSE Z = 0.268269
# Test: MSE Total = 0.749646,   MSE X = 0.431878,   MSE Z = 0.215931
#
#
# Train Epoch 6: MSE Total = 0.868124,   MSE X = 0.491844,   MSE Z = 0.266629
# Test: MSE Total = 0.586561,   MSE X = 0.317318,   MSE Z = 0.210141
#
#
# Train Epoch 7: MSE Total = 0.721439,   MSE X = 0.385968,   MSE Z = 0.267089
# Test: MSE Total = 0.500170,   MSE X = 0.253189,   MSE Z = 0.213955
#
#
# Train Epoch 8: MSE Total = 0.647058,   MSE X = 0.331324,   MSE Z = 0.269233
# Test: MSE Total = 0.448627,   MSE X = 0.214862,   MSE Z = 0.216361
#
#
# Train Epoch 9: MSE Total = 0.605594,   MSE X = 0.302284,   MSE Z = 0.267589
# Test: MSE Total = 0.408499,   MSE X = 0.189979,   MSE Z = 0.208330
#
#
# Train Epoch 10: MSE Total = 0.588341,   MSE X = 0.290521,   MSE Z = 0.266262
# Test: MSE Total = 0.412854,   MSE X = 0.188107,   MSE Z = 0.218343
#
#
# Train Epoch 11: MSE Total = 0.587214,   MSE X = 0.291216,   MSE Z = 0.263252
# Test: MSE Total = 0.412439,   MSE X = 0.192346,   MSE Z = 0.209272
#
#
# Train Epoch 12: MSE Total = 0.563275,   MSE X = 0.280764,   MSE Z = 0.249682
# Test: MSE Total = 0.397987,   MSE X = 0.194513,   MSE Z = 0.184136
#
#
# Train Epoch 13: MSE Total = 0.535564,   MSE X = 0.277013,   MSE Z = 0.217287
# Test: MSE Total = 0.359220,   MSE X = 0.178630,   MSE Z = 0.160076
#
#
# Train Epoch 14: MSE Total = 0.514042,   MSE X = 0.272873,   MSE Z = 0.194580
# Test: MSE Total = 0.339332,   MSE X = 0.165754,   MSE Z = 0.157182
#
#
# Train Epoch 15: MSE Total = 0.506424,   MSE X = 0.271341,   MSE Z = 0.186675
# Test: MSE Total = 0.359373,   MSE X = 0.169198,   MSE Z = 0.179149
#
#
# Train Epoch 16: MSE Total = 0.507467,   MSE X = 0.271036,   MSE Z = 0.188789
# Test: MSE Total = 0.354517,   MSE X = 0.165016,   MSE Z = 0.180517
#
#
# Train Epoch 17: MSE Total = 0.494724,   MSE X = 0.266198,   MSE Z = 0.180115
# Test: MSE Total = 0.350227,   MSE X = 0.178199,   MSE Z = 0.147992
#
#
# Train Epoch 18: MSE Total = 0.498384,   MSE X = 0.270959,   MSE Z = 0.175866
# Test: MSE Total = 0.326055,   MSE X = 0.161626,   MSE Z = 0.146321
#
#
# Train Epoch 19: MSE Total = 0.497582,   MSE X = 0.268602,   MSE Z = 0.179421
# Test: MSE Total = 0.332989,   MSE X = 0.162045,   MSE Z = 0.155465
#
#
# Train Epoch 20: MSE Total = 0.493822,   MSE X = 0.266389,   MSE Z = 0.178434
# Test: MSE Total = 0.315612,   MSE X = 0.159509,   MSE Z = 0.135518
#
#
# Train Epoch 21: MSE Total = 0.488918,   MSE X = 0.264718,   MSE Z = 0.174713
# Test: MSE Total = 0.334607,   MSE X = 0.165889,   MSE Z = 0.150109
#
#
# Train Epoch 22: MSE Total = 0.492596,   MSE X = 0.266076,   MSE Z = 0.177294
# Test: MSE Total = 0.343226,   MSE X = 0.174513,   MSE Z = 0.145281
#
#
# Train Epoch 23: MSE Total = 0.493515,   MSE X = 0.267813,   MSE Z = 0.175145
# Test: MSE Total = 0.329482,   MSE X = 0.164463,   MSE Z = 0.145584
#
#
# Train Epoch 24: MSE Total = 0.488069,   MSE X = 0.264599,   MSE Z = 0.173728
# Test: MSE Total = 0.316864,   MSE X = 0.162138,   MSE Z = 0.132066
#
#
# Train Epoch 25: MSE Total = 0.493606,   MSE X = 0.266060,   MSE Z = 0.178781
# Test: MSE Total = 0.312138,   MSE X = 0.156712,   MSE Z = 0.136109
#
#
# Train Epoch 26: MSE Total = 0.487592,   MSE X = 0.264263,   MSE Z = 0.173714
# Test: MSE Total = 0.333955,   MSE X = 0.164437,   MSE Z = 0.152075
#
#
# Train Epoch 27: MSE Total = 0.484731,   MSE X = 0.263526,   MSE Z = 0.171069
# Test: MSE Total = 0.329020,   MSE X = 0.166075,   MSE Z = 0.141696
#
#
# Train Epoch 28: MSE Total = 0.487434,   MSE X = 0.263189,   MSE Z = 0.175633
# Test: MSE Total = 0.318432,   MSE X = 0.160417,   MSE Z = 0.137763
#
#
# Train Epoch 29: MSE Total = 0.482503,   MSE X = 0.262601,   MSE Z = 0.169709
# Test: MSE Total = 0.321074,   MSE X = 0.158186,   MSE Z = 0.146025
#
#
# Train Epoch 30: MSE Total = 0.485100,   MSE X = 0.262552,   MSE Z = 0.173546
# Test: MSE Total = 0.323698,   MSE X = 0.163471,   MSE Z = 0.139240
#
#
# Train Epoch 31: MSE Total = 0.480667,   MSE X = 0.260786,   MSE Z = 0.170696
# Test: MSE Total = 0.319418,   MSE X = 0.156783,   MSE Z = 0.146445
#
#
# Train Epoch 32: MSE Total = 0.479778,   MSE X = 0.259706,   MSE Z = 0.171575
# Test: MSE Total = 0.361199,   MSE X = 0.176208,   MSE Z = 0.167766
#
#
# Train Epoch 33: MSE Total = 0.488840,   MSE X = 0.264233,   MSE Z = 0.175571
# Test: MSE Total = 0.320748,   MSE X = 0.161741,   MSE Z = 0.138450
#
#
# Train Epoch 34: MSE Total = 0.475814,   MSE X = 0.257422,   MSE Z = 0.170433
# Test: MSE Total = 0.324523,   MSE X = 0.160039,   MSE Z = 0.147288
#
#
# Train Epoch 35: MSE Total = 0.477109,   MSE X = 0.257893,   MSE Z = 0.171355
# Test: MSE Total = 0.319561,   MSE X = 0.158728,   MSE Z = 0.142764
#
#
# Train Epoch 36: MSE Total = 0.478838,   MSE X = 0.258258,   MSE Z = 0.173115
# Test: MSE Total = 0.338600,   MSE X = 0.172858,   MSE Z = 0.141930
#
#
# Train Epoch 37: MSE Total = 0.475560,   MSE X = 0.256314,   MSE Z = 0.172281
# Test: MSE Total = 0.335525,   MSE X = 0.168596,   MSE Z = 0.146021
#
#
# Train Epoch 38: MSE Total = 0.479876,   MSE X = 0.259445,   MSE Z = 0.172237
# Test: MSE Total = 0.314010,   MSE X = 0.155363,   MSE Z = 0.141500
#
#
# Train Epoch 39: MSE Total = 0.468698,   MSE X = 0.252056,   MSE Z = 0.170914
# Test: MSE Total = 0.318277,   MSE X = 0.156867,   MSE Z = 0.144636
#
#
# Train Epoch 40: MSE Total = 0.467578,   MSE X = 0.251989,   MSE Z = 0.169435
# Test: MSE Total = 0.332016,   MSE X = 0.164414,   MSE Z = 0.149329
#
#
# Train Epoch 41: MSE Total = 0.461885,   MSE X = 0.248331,   MSE Z = 0.168551
# Test: MSE Total = 0.330781,   MSE X = 0.163100,   MSE Z = 0.150177
#
#
# Train Epoch 42: MSE Total = 0.456316,   MSE X = 0.242517,   MSE Z = 0.172156
# Test: MSE Total = 0.312431,   MSE X = 0.154702,   MSE Z = 0.140547
#
#
# Train Epoch 43: MSE Total = 0.463518,   MSE X = 0.246130,   MSE Z = 0.175302
# Test: MSE Total = 0.322670,   MSE X = 0.162492,   MSE Z = 0.139716
#
#
# Train Epoch 44: MSE Total = 0.460166,   MSE X = 0.242772,   MSE Z = 0.177188
# Test: MSE Total = 0.314878,   MSE X = 0.157589,   MSE Z = 0.138299
#
#
# Train Epoch 45: MSE Total = 0.446820,   MSE X = 0.237596,   MSE Z = 0.168322
# Test: MSE Total = 0.330932,   MSE X = 0.166879,   MSE Z = 0.142840
#
#
# Train Epoch 46: MSE Total = 0.449798,   MSE X = 0.239553,   MSE Z = 0.168696
# Test: MSE Total = 0.323970,   MSE X = 0.158072,   MSE Z = 0.150421
#
#
# Train Epoch 47: MSE Total = 0.449107,   MSE X = 0.237840,   MSE Z = 0.171125
# Test: MSE Total = 0.329890,   MSE X = 0.165325,   MSE Z = 0.144447
#
#
# Train Epoch 48: MSE Total = 0.451285,   MSE X = 0.239780,   MSE Z = 0.170383
# Test: MSE Total = 0.315798,   MSE X = 0.160453,   MSE Z = 0.133901
#
#
# Train Epoch 49: MSE Total = 0.445683,   MSE X = 0.236265,   MSE Z = 0.169345
# Test: MSE Total = 0.370397,   MSE X = 0.181821,   MSE Z = 0.169786
#
#
# Train Epoch 50: MSE Total = 0.454661,   MSE X = 0.243622,   MSE Z = 0.167564
# Test: MSE Total = 0.324521,   MSE X = 0.166003,   MSE Z = 0.135362
#
#
# Train Epoch 51: MSE Total = 0.444048,   MSE X = 0.234904,   MSE Z = 0.169712
# Test: MSE Total = 0.317927,   MSE X = 0.160598,   MSE Z = 0.136674
#
#
# Train Epoch 52: MSE Total = 0.441955,   MSE X = 0.235512,   MSE Z = 0.165483
# Test: MSE Total = 0.333536,   MSE X = 0.167014,   MSE Z = 0.146320
#
#
# Train Epoch 53: MSE Total = 0.439917,   MSE X = 0.232985,   MSE Z = 0.167601
# Test: MSE Total = 0.324443,   MSE X = 0.161657,   MSE Z = 0.143938
#
#
# Train Epoch 54: MSE Total = 0.446308,   MSE X = 0.236815,   MSE Z = 0.169145
# Test: MSE Total = 0.336595,   MSE X = 0.161506,   MSE Z = 0.161733
#
#
# Train Epoch 55: MSE Total = 0.436565,   MSE X = 0.231268,   MSE Z = 0.166207
# Test: MSE Total = 0.325585,   MSE X = 0.167354,   MSE Z = 0.134196
#
#
# Train Epoch 56: MSE Total = 0.439231,   MSE X = 0.232632,   MSE Z = 0.167318
# Test: MSE Total = 0.338495,   MSE X = 0.161636,   MSE Z = 0.164207
#
#
# Train Epoch 57: MSE Total = 0.439857,   MSE X = 0.233246,   MSE Z = 0.166992
# Test: MSE Total = 0.343209,   MSE X = 0.164111,   MSE Z = 0.166048
#
#
# Train Epoch 58: MSE Total = 0.442981,   MSE X = 0.235949,   MSE Z = 0.166087
# Test: MSE Total = 0.318413,   MSE X = 0.159951,   MSE Z = 0.138667
#
#
# Train Epoch 59: MSE Total = 0.436311,   MSE X = 0.232096,   MSE Z = 0.164187
# Test: MSE Total = 0.322361,   MSE X = 0.161790,   MSE Z = 0.140674
#
#
# Train Epoch 60: MSE Total = 0.435246,   MSE X = 0.229215,   MSE Z = 0.168412
# Test: MSE Total = 0.355507,   MSE X = 0.185393,   MSE Z = 0.141214
#
#
# Train Epoch 61: MSE Total = 0.439937,   MSE X = 0.235421,   MSE Z = 0.162760
# Test: MSE Total = 0.318958,   MSE X = 0.159468,   MSE Z = 0.140417
#
#
# Train Epoch 62: MSE Total = 0.431213,   MSE X = 0.228658,   MSE Z = 0.163719
# Test: MSE Total = 0.321040,   MSE X = 0.162430,   MSE Z = 0.137493
#
#
# Train Epoch 63: MSE Total = 0.434423,   MSE X = 0.232422,   MSE Z = 0.160818
# Test: MSE Total = 0.322684,   MSE X = 0.163779,   MSE Z = 0.137164
#
#
# Train Epoch 64: MSE Total = 0.427921,   MSE X = 0.226971,   MSE Z = 0.162354
# Test: MSE Total = 0.321748,   MSE X = 0.161533,   MSE Z = 0.140307
#
#
# Train Epoch 65: MSE Total = 0.441078,   MSE X = 0.234575,   MSE Z = 0.166095
# Test: MSE Total = 0.310993,   MSE X = 0.156781,   MSE Z = 0.134321
#
#
# Train Epoch 66: MSE Total = 0.438124,   MSE X = 0.233846,   MSE Z = 0.163299
# Test: MSE Total = 0.380329,   MSE X = 0.186070,   MSE Z = 0.175592
#
#
# Train Epoch 67: MSE Total = 0.433461,   MSE X = 0.230101,   MSE Z = 0.164071
# Test: MSE Total = 0.334565,   MSE X = 0.166609,   MSE Z = 0.148612
#
#
# Train Epoch 68: MSE Total = 0.433421,   MSE X = 0.230647,   MSE Z = 0.162921
# Test: MSE Total = 0.327892,   MSE X = 0.161168,   MSE Z = 0.149880
#
#
# Train Epoch 69: MSE Total = 0.430700,   MSE X = 0.229348,   MSE Z = 0.161603
# Test: MSE Total = 0.335011,   MSE X = 0.170630,   MSE Z = 0.141216
#
#
# Train Epoch 70: MSE Total = 0.425683,   MSE X = 0.227124,   MSE Z = 0.158826
# Test: MSE Total = 0.322352,   MSE X = 0.162127,   MSE Z = 0.139989
#
#
# Train Epoch 71: MSE Total = 0.422908,   MSE X = 0.223997,   MSE Z = 0.161081
# Test: MSE Total = 0.344837,   MSE X = 0.173329,   MSE Z = 0.149966
#
#
# Train Epoch 72: MSE Total = 0.427551,   MSE X = 0.227307,   MSE Z = 0.161148
# Test: MSE Total = 0.343256,   MSE X = 0.178024,   MSE Z = 0.138306
#
#
# Train Epoch 73: MSE Total = 0.430478,   MSE X = 0.228972,   MSE Z = 0.162035
# Test: MSE Total = 0.339180,   MSE X = 0.173323,   MSE Z = 0.141835
#
#
# Train Epoch 74: MSE Total = 0.428405,   MSE X = 0.228058,   MSE Z = 0.160877
# Test: MSE Total = 0.345270,   MSE X = 0.172690,   MSE Z = 0.151866
#
#
# Train Epoch 75: MSE Total = 0.425215,   MSE X = 0.226275,   MSE Z = 0.159848
# Test: MSE Total = 0.357444,   MSE X = 0.173431,   MSE Z = 0.167911
#
#
# Train Epoch 76: MSE Total = 0.429889,   MSE X = 0.223949,   MSE Z = 0.171226
# Test: MSE Total = 0.363984,   MSE X = 0.174997,   MSE Z = 0.174196
#
#
# Train Epoch 77: MSE Total = 0.426210,   MSE X = 0.226466,   MSE Z = 0.160899
# Test: MSE Total = 0.334157,   MSE X = 0.166247,   MSE Z = 0.148746
#
#
# Train Epoch 78: MSE Total = 0.432633,   MSE X = 0.230505,   MSE Z = 0.162072
# Test: MSE Total = 0.322197,   MSE X = 0.162708,   MSE Z = 0.138603
#
#
# Train Epoch 79: MSE Total = 0.428607,   MSE X = 0.228391,   MSE Z = 0.160502
# Test: MSE Total = 0.319481,   MSE X = 0.159821,   MSE Z = 0.140463
#
#
# Train Epoch 80: MSE Total = 0.419220,   MSE X = 0.222458,   MSE Z = 0.158846
# Test: MSE Total = 0.327851,   MSE X = 0.165789,   MSE Z = 0.140585
#
#
# Train Epoch 81: MSE Total = 0.418548,   MSE X = 0.222541,   MSE Z = 0.157715
# Test: MSE Total = 0.323747,   MSE X = 0.165461,   MSE Z = 0.135332
#
#
# Train Epoch 82: MSE Total = 0.431129,   MSE X = 0.230109,   MSE Z = 0.160699
# Test: MSE Total = 0.331731,   MSE X = 0.170184,   MSE Z = 0.137384
#
#
# Train Epoch 83: MSE Total = 0.421501,   MSE X = 0.224365,   MSE Z = 0.158319
# Test: MSE Total = 0.326472,   MSE X = 0.159171,   MSE Z = 0.151829
#
#
# Train Epoch 84: MSE Total = 0.420381,   MSE X = 0.223743,   MSE Z = 0.157949
# Test: MSE Total = 0.324431,   MSE X = 0.160404,   MSE Z = 0.146426
#
#
# Train Epoch 85: MSE Total = 0.422605,   MSE X = 0.226173,   MSE Z = 0.156295
# Test: MSE Total = 0.321098,   MSE X = 0.158149,   MSE Z = 0.146134
#
#
# Train Epoch 86: MSE Total = 0.426548,   MSE X = 0.227891,   MSE Z = 0.158538
# Test: MSE Total = 0.333584,   MSE X = 0.169611,   MSE Z = 0.141199
#
#
# Train Epoch 87: MSE Total = 0.421828,   MSE X = 0.222686,   MSE Z = 0.162146
# Test: MSE Total = 0.314149,   MSE X = 0.154349,   MSE Z = 0.143726
#
#
# Train Epoch 88: MSE Total = 0.420357,   MSE X = 0.223863,   MSE Z = 0.157677
# Test: MSE Total = 0.343610,   MSE X = 0.171751,   MSE Z = 0.151353
#
#
# Train Epoch 89: MSE Total = 0.420862,   MSE X = 0.223328,   MSE Z = 0.159473
# Test: MSE Total = 0.362856,   MSE X = 0.166515,   MSE Z = 0.189523
#
#
# Train Epoch 90: MSE Total = 0.415636,   MSE X = 0.219100,   MSE Z = 0.160400
# Test: MSE Total = 0.328585,   MSE X = 0.168201,   MSE Z = 0.136820
#
#
# Train Epoch 91: MSE Total = 0.416757,   MSE X = 0.222194,   MSE Z = 0.155829
# Test: MSE Total = 0.327689,   MSE X = 0.162542,   MSE Z = 0.146842
#
#
# Train Epoch 92: MSE Total = 0.415743,   MSE X = 0.219782,   MSE Z = 0.159190
# Test: MSE Total = 0.349126,   MSE X = 0.173826,   MSE Z = 0.155147
#
#
# Train Epoch 93: MSE Total = 0.415911,   MSE X = 0.220475,   MSE Z = 0.158046
# Test: MSE Total = 0.324078,   MSE X = 0.163184,   MSE Z = 0.140360
#
#
# Train Epoch 94: MSE Total = 0.414156,   MSE X = 0.219523,   MSE Z = 0.157424
# Test: MSE Total = 0.337189,   MSE X = 0.170962,   MSE Z = 0.143688
#
#
# Train Epoch 95: MSE Total = 0.417400,   MSE X = 0.221675,   MSE Z = 0.157793
# Test: MSE Total = 0.327158,   MSE X = 0.165767,   MSE Z = 0.139632
#
#
# Train Epoch 96: MSE Total = 0.420008,   MSE X = 0.224169,   MSE Z = 0.156561
# Test: MSE Total = 0.318642,   MSE X = 0.160816,   MSE Z = 0.137267
#
#
# Train Epoch 97: MSE Total = 0.411795,   MSE X = 0.218007,   MSE Z = 0.157056
# Test: MSE Total = 0.328089,   MSE X = 0.169538,   MSE Z = 0.133433
#
#
# Train Epoch 98: MSE Total = 0.422878,   MSE X = 0.224486,   MSE Z = 0.160060
# Test: MSE Total = 0.327392,   MSE X = 0.164500,   MSE Z = 0.142502
#
#
# Train Epoch 99: MSE Total = 0.415264,   MSE X = 0.220901,   MSE Z = 0.156264
# Test: MSE Total = 0.325066,   MSE X = 0.164360,   MSE Z = 0.139431
#
#
# Train Epoch 100: MSE Total = 0.416977,   MSE X = 0.222293,   MSE Z = 0.155948
# Test: MSE Total = 0.332889,   MSE X = 0.170867,   MSE Z = 0.137687
#
#
# Got the weights of the epoch 65
# Execution time: 2 minutes, 7.54 seconds

# %%
torch.save(model.state_dict(), "model_weights_step1_one_shot")

# %%
plot_loss(len(train_losses_total), train_losses_total, test_losses_total, train_losses_x, test_losses_x, train_losses_z, 
          test_losses_z)

# %% [markdown]
# ## Evaluation

# %%
model = MyGRU(input_size=input_size, hidden_size=hidden_size, output_size=input_size*future_seconds*framerate, 
              num_layers=num_layers, future_steps=future_seconds*framerate).to(device=device)
model.load_state_dict(torch.load("model_weights_step1_one_shot"))

model.eval()
# Out:
# MyGRU(
#   (gru): GRU(2, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=128, out_features=80, bias=True)
# )

# %%
model.eval()

examples = []
batch_indices = 6   # numero batch consecutivi usati
example_index = [9, 9, 9, 0, 5, 50]

# Itera sui primi 6 batch del test_loader
for b_idx, batch in enumerate(test_loader):
    if b_idx >= batch_indices:
        break

    past_batch, future_batch = batch
    
    examples.append((past_batch[example_index[b_idx]], future_batch[example_index[b_idx]]))

examples[3], examples[4], examples[5] = examples[4], examples[5], examples[3]    

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, (past, future) in enumerate(examples):

    all_points = torch.cat((past, future), 0)
    past_np = past.cpu().numpy()
    future_np = future.cpu().numpy()

    # Predizione del modello
    past_tensor = past.unsqueeze(0).to(device)  # aggiunge batch dim
    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    row, col = divmod(i, 3)  # Converte i in (riga, colonna)

    # Plot
    axes[row, col].plot(past_np[:, 0], past_np[:, 1], 'g-o', label="Past Trajectory") 
    axes[row, col].plot(future_np[:, 0], future_np[:, 1], 'r-o', label="Real Future Trajectory") 
    axes[row, col].plot(predicted_future[:, 0], predicted_future[:, 1], 'm-o', label="Predicted Future Trajectory")
    
    axes[row, col].set_xlabel("X")
    axes[row, col].set_ylabel("Z")
    axes[row, col].set_title(f"Case {i+1}")
    axes[row, col].legend()
    axes[row, col].grid()

    x_min, x_max = all_points[:, 0].min(), all_points[:, 0].max()
    z_min, z_max = all_points[:, 1].min(), all_points[:, 1].max()
    
    x_min_tick = float(np.floor(float(x_min)))
    x_max_tick = float(np.ceil(float(x_max)))
    z_min_tick = float(np.floor(float(z_min)))
    z_max_tick = float(np.ceil(float(z_max)))

    axes[row, col].set_xticks(np.arange(x_min_tick, x_max_tick + 0.5, 0.5))
    axes[row, col].set_yticks(np.arange(z_min_tick, z_max_tick + 1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
def performance_measurement(model, device, train_loader, test_loader):
    model.eval() #setta il modello in evaluation mode
    
    train_ade_x, train_ade_z, train_ade_total = 0, 0, 0
    train_fde_x, train_fde_z, train_fde_total = 0, 0, 0
    test_ade_x, test_ade_z, test_ade_total = 0, 0, 0
    test_fde_x, test_fde_z, test_fde_total = 0, 0, 0
    total_samples = 0

    # Misurazione performance sul train set

    with torch.no_grad():
        for past, future in train_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            train_ade_x += ade_x.item()
            train_ade_z += ade_z.item()
            train_ade_total += ade_total.item()

            train_fde_x += fde_x.item()
            train_fde_z += fde_z.item()
            train_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    train_ade_x /= total_samples
    train_ade_z /= total_samples
    train_ade_total /= total_samples

    train_fde_x /= len(train_loader.dataset)
    train_fde_z /= len(train_loader.dataset)
    train_fde_total /= len(train_loader.dataset)

    print(f'Model performances on train set:')
    print(f'\nADE Total = {train_ade_total:.6f},   ADE X = {train_ade_x:.6f},   ADE Z = {train_ade_z:.6f}')
    print(f'FDE Total = {train_fde_total:.6f},   FDE X = {train_fde_x:.6f},   FDE Z = {train_fde_z:.6f}')

    
    # Misurazione performance sul test set

    total_samples = 0

    with torch.no_grad():
        for past, future in test_loader:
            past, future = past.to(device), future.to(device)
            future_pred = model(past)

            ade_x = torch.abs(future_pred[:, :, 0] - future[:, :, 0]).sum()
            ade_z = torch.abs(future_pred[:, :, -1] - future[:, :, -1]).sum()
            ade_total = torch.norm(future_pred - future, dim=2).sum()

            fde_x = torch.abs(future_pred[:, -1, 0] - future[:, -1, 0]).sum()
            fde_z = torch.abs(future_pred[:, -1, -1] - future[:, -1, -1]).sum()
            fde_total = torch.norm(future_pred[:, -1, :] - future[:, -1, :], dim=1).sum()
            
            test_ade_x += ade_x.item()
            test_ade_z += ade_z.item()
            test_ade_total += ade_total.item()

            test_fde_x += fde_x.item()
            test_fde_z += fde_z.item()
            test_fde_total += fde_total.item()

            total_samples += future.size(0) * future.size(1)

    test_ade_x /= total_samples
    test_ade_z /= total_samples
    test_ade_total /= total_samples

    test_fde_x /= len(test_loader.dataset)
    test_fde_z /= len(test_loader.dataset)
    test_fde_total /= len(test_loader.dataset)

    print(f'\nModel performances on test set:')
    print(f'\nADE Total = {test_ade_total:.6f},   ADE X = {test_ade_x:.6f},   ADE Z = {test_ade_z:.6f}')
    print(f'FDE Total = {test_fde_total:.6f},   FDE X = {test_fde_x:.6f},   FDE Z = {test_fde_z:.6f}')

# %%
performance_measurement(model=model, device=device, train_loader=train_loader,  test_loader=test_loader)
# Out:
# Model performances on train set:
#
# ADE Total = 0.437266,   ADE X = 0.280174,   ADE Z = 0.268051
# FDE Total = 1.045370,   FDE X = 0.770750,   FDE Z = 0.551554
#
# Model performances on test set:
#
# ADE Total = 0.385288,   ADE X = 0.233652,   ADE Z = 0.253997
# FDE Total = 0.921913,   FDE X = 0.643486,   FDE Z = 0.525216

# %%
def save_prediction(index):
    model.eval()

    batch = next(iter(test_loader)) # prende un batch dal test_loader
    past_batch, _ = batch  # estrae passato e futuro dal batch

    past_tensor = past_batch[index].unsqueeze(0).to(device)  # prende un campione e aggiunge batch dim

    with torch.no_grad():
        predicted_future = model(past_tensor).squeeze(0).cpu().detach().numpy()  # predice e converte in numpy

    file_name = 'test_predictions_'+str(index)+'.npz'    

    if os.path.exists(file_name):
        with np.load(file_name) as data:
            data_dict = dict(data)
    else:
        data_dict = {}

    # Aggiunge la nuova coppia chiave-array
    data_dict['step1_one_shot'] = predicted_future

    # Salva tutto nel file, sovrascrivendo quello originale
    np.savez(file_name, **data_dict)

# %%
save_prediction(index=5)
